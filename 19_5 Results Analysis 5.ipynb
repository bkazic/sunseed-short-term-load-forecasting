# %% [markdown]
# # Results Analysis

# %%
# %matplotlib inline
import matplotlib as mpl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import numpy as np
import os
import time
from datetime import timedelta

# %% [markdown]
# ### Load dataset

# %%
input_file_name = "lotOfFeatures.csv"
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), input_file_name)

original_data = pd.read_csv(input_file_path, index_col=0, parse_dates=True)
originalSize = original_data.shape[1]
original_data.head()
original_data.shape
# Out:
# (139678, 535)

# %% [markdown]
# ## Excluding Testing Set

# %% [markdown]
# Spliting the dataset into three parts: training, testing and evaluation (last 10 percent).

# %%
#start_time = '2012-02-01 00:00:00'
start_time = '2013-01-01 00:00:00'
#start_time = '2014-02-01 00:00:00'
splitting_point = int(0.8 * original_data.shape[0])
splitting_time = original_data.iloc[[splitting_point]].index.to_pydatetime()[0]
#data = original_data[:splitting_time]
data = original_data[start_time:]

# %%
splitting_time
# Out:
# datetime.datetime(2014, 4, 17, 0, 0)

# %%
f = original_data[["id12041022"]].plot(figsize=(20,5)) 
original_data.iloc(splitting_point)
f.axvline(start_time, color='g')
f.axvline(splitting_time, color='r')

# %% [markdown]
# # Define Machine Learning Models and Data Sets

# %%
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import svm
from sklearn import neighbors
from sklearn import metrics
import regression_metrics as additional_metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.learning_curve import learning_curve
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import explained_variance_score
#from neural_network import PyBrainNN

# %% [markdown]
# ## Creating Feature Sets

# %%
autoregressive_ftrs = ['measurement', 'shifted_measurement_1d', 'shifted_measurement_2d', 'shifted_measurement_1w', 
                       'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_mean_d', 
                       'measurement_roll_mean_w', 'measurement_roll_mean_m', 'measurement_roll_min2_d',
                       'measurement_roll_min2_w', 'measurement_roll_max2_d', 'measurement_roll_max2_w',
                       'measurement_roll_var_6h', 'measurement_roll_var_d', 'measurement_roll_var_w']

wetaher_current_ftrs =  ['p', 't2m_termin', 'rh_termin', 'padavine', 'veter_hitrost', 'veter_vek_smer', 'energija_gl',
 'energija_di', 'p_roll_mean_1h', 'p_roll_mean_6h', 'p_roll_mean_d', 'p_roll_mean_w', 'p_roll_mean_m', 'p_roll_var_1h',
 'p_roll_var_d', 't2m_termin_roll_mean_1h', 't2m_termin_roll_mean_6h', 't2m_termin_roll_mean_d', 't2m_termin_roll_mean_w',
 't2m_termin_roll_mean_m', 't2m_termin_roll_min2_d', 't2m_termin_roll_min2_w', 't2m_termin_roll_max2_d',
 't2m_termin_roll_max2_w', 't2m_termin_roll_var_1h', 't2m_termin_roll_var_d', 'rh_termin_roll_mean_1h',
 'rh_termin_roll_mean_6h', 'rh_termin_roll_mean_d', 'rh_termin_roll_mean_w', 'rh_termin_roll_mean_m',
 'rh_termin_roll_min2_d', 'rh_termin_roll_min2_w', 'rh_termin_roll_max2_d', 'rh_termin_roll_max2_w',
 'rh_termin_roll_var_1h', 'rh_termin_roll_var_d', 'energija_gl_roll_mean_1h', 'energija_gl_roll_mean_6h',
 'energija_gl_roll_mean_d', 'energija_gl_roll_mean_w', 'energija_gl_roll_mean_m', 'energija_gl_roll_var_1h',
 'energija_gl_roll_var_d']

weather_forecasted_ftrs =  ['shifted_p', 'shifted_t2m_termin', 'shifted_rh_termin', 'shifted_padavine', 
                            'shifted_veter_hitrost', 'shifted_veter_vek_smer', 'shifted_energija_gl']

date_time_ftrs =  ['shifted_HourOfDay', 'shifted_DayOfWeek', 'shifted_Month', 'shifted_Weekday', 'shifted_Weekend', 
                   'shifted_Holiday', 'shifted_DayBeforeHoliday', 'shifted_DayAfterHodliay', 'shifted_BusinessDay', 
                   'shifted_BusinessDay_sum', 'shifted_Holiday_sum']

top20_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay', 't2m_termin_roll_mean_m', 'shifted_Holiday', 
              'shifted_energija_gl', 'shifted_DayOfWeek', 'shifted_t2m_termin', 'p_roll_var_d', 'shifted_measurement_2d', 
              'measurement_roll_mean_m', 'p_roll_mean_m', 'rh_termin_roll_mean_w']

top10_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay']

# %%
all_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_wc_wf_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs
ar_wc_dt_ftrs = autoregressive_ftrs + wetaher_current_ftrs + date_time_ftrs 
ar_wf_dt_ftrs = autoregressive_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_dt_ftrs = autoregressive_ftrs + date_time_ftrs 
ar_ftrs = autoregressive_ftrs
top20_ftrs = top20_ftrs
top10_ftrs = top10_ftrs

# %% [markdown]
# ## Prediction Results

# %%
class NaiveModel:
    
    def __init__(self, target):
        self.target = target

# %%
horizons = range(1,25)

baselines = [{'name': "Last value", 'init': "NaiveModel('measurement')"},
             {'name': "Previous day", 'init': "NaiveModel('shifted_measurement_1d')"},
             {'name': "Previous week", 'init': "NaiveModel('shifted_measurement_1w')"},
             #{'name': "Measurement average", 'init': "NaiveModel('measurement_avr')"},
            ]

models = [#{'name': "Ridge Regression", 'init': "linear_model.Ridge()"},
          #{'name': "K Nearest Neighbors", 'init': "neighbors.KNeighborsRegressor(n_neighbors = 5)"},
          {'name': "Random Forest", 'init': "RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, n_jobs=16)"},
          #{'name': "SVR", 'init': "svm.SVR(kernel ='rbf', C = 10, gamma = .001)"},
          #{'name': "Neural Network", 'init': "PyBrainNN(hidden_size = 100, learningrate = 0.001, momentum = 0.1, maxEpochs=10)"},
          ]

data_sets = [{'name': "Baselines", 'ftrs': ar_ftrs},
             #{'name': "AR", 'ftrs': ar_ftrs},
             #{'name': "AR_WC_WF", 'ftrs': ar_wc_wf_ftrs},
             #{'name': "AR_DT", 'ftrs': ar_dt_ftrs},             
             #{'name': "AR_WC_DT", 'ftrs': ar_wc_dt_ftrs},
             #{'name': "AR_WF_DT", 'ftrs': ar_wf_dt_ftrs},    
             #{'name': "ALL", 'ftrs': all_ftrs},
             {'name': "TOP_20", 'ftrs': top20_ftrs},
             #{'name': "TOP_10", 'ftrs': top10_ftrs},
             ]

error_metrics = [{'name': "R2 Score", 'short': "R2", 'function': metrics.r2_score},
                 #{'name': "Explained Variance Score", 'short': "EV", 'function': metrics.explained_variance_score},
                 {'name': "Mean Absolute Error", 'short': "MAE", 'function': metrics.mean_absolute_error},
                 #{'name': "Mean Squared Error", 'short': "MSE", 'function': metrics.mean_squared_error},
                 {'name': "Mean Absolute Percentage Error", 'short': "MAPE", 'function': additional_metrics.mean_absolute_percentage_error},
                 {'name': "Mean Absolute Scaled Error", 'short': "MASE", 'function': additional_metrics.mean_absolute_scaled_error}
                ]

#validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['sensor', 'horizon', 'error metric']),
#                             columns=pd.MultiIndex.from_arrays([[],[]], names=['method', 'data set']))

validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric']))

# %%
results_df = pd.DataFrame()

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[],[]], names=['horizon', 'testing_day','dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

#results_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[]], names=['horizon', 'ts']))
results_df = pd.DataFrame()

output_file_name = "results_id12041022_2.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

#horizons = [2, 10]
horizons = [20]
#horizons = range(1,25)


def start_prediction_valuation(verbose=False):
    
    arr = []

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041022']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
        
        #for horizon in range (1,25):
        for horizon in horizons:

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            #splitting_point = int(0.8 * data.shape[0]) # this is the reason for differences in baseline results (we use original_data in first which is wrong)
            #original_splitting_time = data.iloc[[splitting_point]].index.to_pydatetime()[0] # here as well
            splitting_point = int(0.8 * original_data.shape[0])
            original_splitting_time = original_data.iloc[[splitting_point]].index.to_pydatetime()[0]
            splitting_time = original_splitting_time.replace(hour=0, minute=0, second=0, microsecond=0) # setting to middnight
            latest_time = data.iloc[[-1]].index.to_pydatetime()[0]
            
            
            # Split Training and Testing set
            training_data = sensor_data[:splitting_time]
            testing_data = sensor_data[splitting_time:]
            
            # Create training vectors
            X_train = training_data[ar_wf_dt_ftrs].values
            y_train = training_data[["shifted_measurement"]].values.ravel()
            #print "Using dummy features:", X_train.shape

            # Create testing vectors
            X_test = testing_data[ar_wf_dt_ftrs].values
            y_test = testing_data[["shifted_measurement"]].values.ravel()
            
            # Initializing model
            mdl = RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, n_jobs=16)
            mdl.fit(X_train,y_train)
            pred = mdl.predict(X_test)
            

            # Prepare results df
            results_df = testing_data[["shifted_measurement"]]
            results_df.rename(columns={"shifted_measurement":"true"}, inplace=True)

            results_df['last value'] = testing_data[["measurement"]]
            results_df['previous day'] = testing_data[["shifted_measurement_1d"]]
            results_df['previous week'] = testing_data[["shifted_measurement_1w"]]           
            
            results_df['offline'] = mdl.predict(X_test)
            results_df['batch'] = np.nan
            
            arr.append(results_df)
            
            while (splitting_time < latest_time):
                                
                eval_start_time = splitting_time
                splitting_time = splitting_time + timedelta(days=1)
                eval_end_time = splitting_time
                    
                # Split Training and Testing set
                training_data = sensor_data[:eval_start_time - timedelta(minutes=15)]
                testing_data = sensor_data[eval_start_time:eval_end_time]
                
                # init temoporary batch datafreame
                batch_df_temp = pd.DataFrame(index = testing_data.index)

                # Create dummy feature vector for linear regression
                sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                        prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                        prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                        prefix='dummy_shifted_Month'))))
                #sensor_data_dummy.dropna(inplace=True)
                dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
                training_data_dummy = sensor_data_dummy[:eval_start_time - timedelta(minutes=15)]
                testing_data_dummy = sensor_data_dummy[eval_start_time:eval_start_time]
                
                if verbose: print "\n\t\t-->{} ({})".format('Evaluation', splitting_time)
                
                for data_set in data_sets:              
                
                    # Create training vectors
                    X_train = training_data[data_set['ftrs']].values
                    y_train = training_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train.shape

                    # Create testing vectors
                    X_test = testing_data[data_set['ftrs']].values
                    y_test = testing_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_test.shape

                    if verbose: print "\t\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                              X_train.shape, y_train.shape)

                    if data_set['name'] == "Baselines":
                        for baseline in baselines:

                            if verbose: print "\t\t\t\t-->Computing {}".format(baseline['name'])
                            bl = eval(baseline['init'])

                            for metric in error_metrics:
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                               y_test, testing_data[bl.target])
                                else:
                                    error = metric['function'](y_test, testing_data[bl.target])

                                validation_df.loc[(horizon, splitting_time, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

                    else:    
                        for model in models: 
                            # Initializing model
                            mdl = eval(model['init'])

                            # Model leraning
                            start = time.time() # Start measuring time
                            if model['name'] == "Ridge Regression":
                                mdl.fit(X_train_dummy, y_train_dummy)
                            else:
                                mdl.fit(X_train,y_train)
                                
                            # predictions
                            pred = mdl.predict(X_test)
                            batch_df_temp['batch'] = pred
                                
                            runtime = time.time() - start # Calculate runtime
                            
                            results_df.update(batch_df_temp)

                            if verbose: print "\t\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

                            for metric in error_metrics:
                                #print "\t-->Error metric: {}".format(metric['name'])

                                if model['name'] == "Ridge Regression":
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
                                                                   y_test_dummy, mdl.predict(X_test_dummy))
                                    else:
                                        error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

                                else: 
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
                                                                   y_test, mdl.predict(X_test))
                                    else:
                                        error = metric['function'](y_test, mdl.predict(X_test))

                                #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
                                validation_df.loc[(horizon, splitting_time, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

            
                #print results_df
        
        all_results = pd.concat(arr, keys=horizons)
        all_results.index.set_names(['horizons', 'values'], inplace=True)

        print all_results
        
        all_results.to_csv(output_file_path)
        
start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df

print "Finished."

#output_file_name = "testni_eval_top20_id12041992.csv"
#output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

#validation_df.to_csv(output_file_path)
# Out:
# Working with sensor: id12041022
#
# 	-->Prediction horizont: 20h. Shifting runtime: 0.51s
# C:\Python27\lib\site-packages\ipykernel\__main__.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 		-->Evaluation (2014-04-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (45216L, 16L), y_train: (45216L,)
# 				-->Computing Last value
# 					-->R2: -38.133
# 					-->MAE: 366.443
# 					-->MAPE: 89.605
# 					-->MASE: 1.322
# 				-->Computing Previous day
# 					-->R2: -34.387
# 					-->MAE: 333.864
# 					-->MAPE: 79.128
# 					-->MASE: 1.204
# 				-->Computing Previous week
# 					-->R2: -32.120
# 					-->MAE: 354.625
# 					-->MAPE: 84.096
# 					-->MASE: 1.279
# 			-->Dataset: TOP_20. X_train: (45216L, 20L), y_train: (45216L,)
# 				-->Training model: Random Forest, runtime: 7.00s
# 					-->R2: -32.807
# 					-->MAE: 335.048
# 					-->MAPE: 79.558
# 					-->MASE: 1.208
#
# 		-->Evaluation (2014-04-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (45312L, 16L), y_train: (45312L,)
# 				-->Computing Last value
# 					-->R2: -6.057
# 					-->MAE: 105.923
# 					-->MAPE: 39.408
# 					-->MASE: 0.382
# 				-->Computing Previous day
# 					-->R2: -8.978
# 					-->MAE: 130.673
# 					-->MAPE: 46.102
# 					-->MASE: 0.471
# 				-->Computing Previous week
# 					-->R2: -30.371
# 					-->MAE: 192.067
# 					-->MAPE: 66.260
# 					-->MASE: 0.692
# 			-->Dataset: TOP_20. X_train: (45312L, 20L), y_train: (45312L,)
# 				-->Training model: Random Forest, runtime: 6.92s
# 					-->R2: -8.119
# 					-->MAE: 116.247
# 					-->MAPE: 41.469
# 					-->MASE: 0.419
#
# 		-->Evaluation (2014-04-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (45408L, 16L), y_train: (45408L,)
# 				-->Computing Last value
# 					-->R2: -7.319
# 					-->MAE: 55.727
# 					-->MAPE: 26.407
# 					-->MASE: 0.201
# 				-->Computing Previous day
# 					-->R2: -10.154
# 					-->MAE: 69.926
# 					-->MAPE: 31.551
# 					-->MASE: 0.252
# 				-->Computing Previous week
# 					-->R2: -12.469
# 					-->MAE: 78.067
# 					-->MAPE: 34.868
# 					-->MASE: 0.282
# 			-->Dataset: TOP_20. X_train: (45408L, 20L), y_train: (45408L,)
# 				-->Training model: Random Forest, runtime: 7.18s
# 					-->R2: -6.951
# 					-->MAE: 60.491
# 					-->MAPE: 27.358
# 					-->MASE: 0.218
#
# 		-->Evaluation (2014-04-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (45504L, 16L), y_train: (45504L,)
# 				-->Computing Last value
# 					-->R2: -0.793
# 					-->MAE: 68.552
# 					-->MAPE: 20.872
# 					-->MASE: 0.248
# 				-->Computing Previous day
# 					-->R2: -0.758
# 					-->MAE: 71.888
# 					-->MAPE: 22.526
# 					-->MASE: 0.260
# 				-->Computing Previous week
# 					-->R2: -66.717
# 					-->MAE: 448.684
# 					-->MAPE: 152.809
# 					-->MASE: 1.622
# 			-->Dataset: TOP_20. X_train: (45504L, 20L), y_train: (45504L,)
# 				-->Training model: Random Forest, runtime: 6.15s
# 					-->R2: -1.199
# 					-->MAE: 73.460
# 					-->MAPE: 30.365
# 					-->MASE: 0.266
#
# 		-->Evaluation (2014-04-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (45600L, 16L), y_train: (45600L,)
# 				-->Computing Last value
# 					-->R2: -1.238
# 					-->MAE: 389.438
# 					-->MAPE: 49.039
# 					-->MASE: 1.410
# 				-->Computing Previous day
# 					-->R2: -1.427
# 					-->MAE: 412.077
# 					-->MAPE: 52.995
# 					-->MASE: 1.492
# 				-->Computing Previous week
# 					-->R2: 0.889
# 					-->MAE: 84.716
# 					-->MAPE: 15.938
# 					-->MASE: 0.307
# 			-->Dataset: TOP_20. X_train: (45600L, 20L), y_train: (45600L,)
# 				-->Training model: Random Forest, runtime: 7.01s
# 					-->R2: 0.878
# 					-->MAE: 87.505
# 					-->MAPE: 14.382
# 					-->MASE: 0.317
#
# 		-->Evaluation (2014-04-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (45696L, 16L), y_train: (45696L,)
# 				-->Computing Last value
# 					-->R2: -0.671
# 					-->MAE: 260.306
# 					-->MAPE: 43.298
# 					-->MASE: 0.942
# 				-->Computing Previous day
# 					-->R2: 0.830
# 					-->MAE: 75.873
# 					-->MAPE: 12.027
# 					-->MASE: 0.274
# 				-->Computing Previous week
# 					-->R2: 0.898
# 					-->MAE: 67.649
# 					-->MAPE: 9.553
# 					-->MASE: 0.245
# 			-->Dataset: TOP_20. X_train: (45696L, 20L), y_train: (45696L,)
# 				-->Training model: Random Forest, runtime: 6.34s
# 					-->R2: 0.891
# 					-->MAE: 70.677
# 					-->MAPE: 10.998
# 					-->MASE: 0.256
#
# 		-->Evaluation (2014-04-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (45792L, 16L), y_train: (45792L,)
# 				-->Computing Last value
# 					-->R2: -0.254
# 					-->MAE: 256.378
# 					-->MAPE: 43.048
# 					-->MASE: 0.928
# 				-->Computing Previous day
# 					-->R2: 0.955
# 					-->MAE: 48.762
# 					-->MAPE: 6.315
# 					-->MASE: 0.176
# 				-->Computing Previous week
# 					-->R2: 0.977
# 					-->MAE: 34.366
# 					-->MAPE: 5.405
# 					-->MASE: 0.124
# 			-->Dataset: TOP_20. X_train: (45792L, 20L), y_train: (45792L,)
# 				-->Training model: Random Forest, runtime: 6.87s
# 					-->R2: 0.976
# 					-->MAE: 36.956
# 					-->MAPE: 4.866
# 					-->MASE: 0.134
#
# 		-->Evaluation (2014-04-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (45888L, 16L), y_train: (45888L,)
# 				-->Computing Last value
# 					-->R2: -0.464
# 					-->MAE: 237.835
# 					-->MAPE: 40.344
# 					-->MASE: 0.861
# 				-->Computing Previous day
# 					-->R2: 0.926
# 					-->MAE: 45.405
# 					-->MAPE: 6.174
# 					-->MASE: 0.164
# 				-->Computing Previous week
# 					-->R2: -1.170
# 					-->MAE: 309.518
# 					-->MAPE: 35.698
# 					-->MASE: 1.120
# 			-->Dataset: TOP_20. X_train: (45888L, 20L), y_train: (45888L,)
# 				-->Training model: Random Forest, runtime: 6.34s
# 					-->R2: 0.952
# 					-->MAE: 40.848
# 					-->MAPE: 5.848
# 					-->MASE: 0.148
#
# 		-->Evaluation (2014-04-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (45984L, 16L), y_train: (45984L,)
# 				-->Computing Last value
# 					-->R2: -5.656
# 					-->MAE: 310.809
# 					-->MAPE: 72.917
# 					-->MASE: 1.125
# 				-->Computing Previous day
# 					-->R2: -6.065
# 					-->MAE: 288.566
# 					-->MAPE: 74.935
# 					-->MASE: 1.045
# 				-->Computing Previous week
# 					-->R2: -1.237
# 					-->MAE: 168.660
# 					-->MAPE: 31.859
# 					-->MASE: 0.611
# 			-->Dataset: TOP_20. X_train: (45984L, 20L), y_train: (45984L,)
# 				-->Training model: Random Forest, runtime: 6.72s
# 					-->R2: 0.484
# 					-->MAE: 73.338
# 					-->MAPE: 15.523
# 					-->MASE: 0.265
#
# 		-->Evaluation (2014-04-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (46080L, 16L), y_train: (46080L,)
# 				-->Computing Last value
# 					-->R2: -14.299
# 					-->MAE: 160.026
# 					-->MAPE: 73.941
# 					-->MASE: 0.579
# 				-->Computing Previous day
# 					-->R2: -15.191
# 					-->MAE: 194.322
# 					-->MAPE: 79.736
# 					-->MASE: 0.703
# 				-->Computing Previous week
# 					-->R2: -0.691
# 					-->MAE: 68.188
# 					-->MAPE: 21.848
# 					-->MASE: 0.247
# 			-->Dataset: TOP_20. X_train: (46080L, 20L), y_train: (46080L,)
# 				-->Training model: Random Forest, runtime: 6.23s
# 					-->R2: -0.024
# 					-->MAE: 51.590
# 					-->MAPE: 17.056
# 					-->MASE: 0.187
#
# 		-->Evaluation (2014-04-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (46176L, 16L), y_train: (46176L,)
# 				-->Computing Last value
# 					-->R2: -1.486
# 					-->MAE: 393.535
# 					-->MAPE: 51.933
# 					-->MASE: 1.425
# 				-->Computing Previous day
# 					-->R2: -1.753
# 					-->MAE: 402.435
# 					-->MAPE: 50.644
# 					-->MASE: 1.458
# 				-->Computing Previous week
# 					-->R2: -1.603
# 					-->MAE: 405.399
# 					-->MAPE: 53.627
# 					-->MASE: 1.468
# 			-->Dataset: TOP_20. X_train: (46176L, 20L), y_train: (46176L,)
# 				-->Training model: Random Forest, runtime: 6.79s
# 					-->R2: -0.062
# 					-->MAE: 234.482
# 					-->MAPE: 30.696
# 					-->MASE: 0.849
#
# 		-->Evaluation (2014-04-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (46272L, 16L), y_train: (46272L,)
# 				-->Computing Last value
# 					-->R2: -0.841
# 					-->MAE: 253.359
# 					-->MAPE: 41.770
# 					-->MASE: 0.917
# 				-->Computing Previous day
# 					-->R2: 0.747
# 					-->MAE: 94.860
# 					-->MAPE: 14.318
# 					-->MASE: 0.343
# 				-->Computing Previous week
# 					-->R2: 0.767
# 					-->MAE: 92.864
# 					-->MAPE: 14.567
# 					-->MASE: 0.336
# 			-->Dataset: TOP_20. X_train: (46272L, 20L), y_train: (46272L,)
# 				-->Training model: Random Forest, runtime: 6.09s
# 					-->R2: 0.838
# 					-->MAE: 75.307
# 					-->MAPE: 11.450
# 					-->MASE: 0.273
#
# 		-->Evaluation (2014-04-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (46368L, 16L), y_train: (46368L,)
# 				-->Computing Last value
# 					-->R2: -0.570
# 					-->MAE: 238.135
# 					-->MAPE: 44.042
# 					-->MASE: 0.862
# 				-->Computing Previous day
# 					-->R2: 0.812
# 					-->MAE: 87.678
# 					-->MAPE: 14.115
# 					-->MASE: 0.317
# 				-->Computing Previous week
# 					-->R2: 0.784
# 					-->MAE: 92.545
# 					-->MAPE: 15.530
# 					-->MASE: 0.335
# 			-->Dataset: TOP_20. X_train: (46368L, 20L), y_train: (46368L,)
# 				-->Training model: Random Forest, runtime: 6.58s
# 					-->R2: 0.808
# 					-->MAE: 84.739
# 					-->MAPE: 14.022
# 					-->MASE: 0.307
#
# 		-->Evaluation (2014-05-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (46464L, 16L), y_train: (46464L,)
# 				-->Computing Last value
# 					-->R2: -55.721
# 					-->MAE: 352.686
# 					-->MAPE: 125.701
# 					-->MASE: 1.277
# 				-->Computing Previous day
# 					-->R2: -56.030
# 					-->MAE: 377.335
# 					-->MAPE: 129.640
# 					-->MASE: 1.366
# 				-->Computing Previous week
# 					-->R2: -76.339
# 					-->MAE: 434.444
# 					-->MAPE: 148.840
# 					-->MASE: 1.573
# 			-->Dataset: TOP_20. X_train: (46464L, 20L), y_train: (46464L,)
# 				-->Training model: Random Forest, runtime: 6.26s
# 					-->R2: -1.903
# 					-->MAE: 80.926
# 					-->MAPE: 25.783
# 					-->MASE: 0.293
#
# 		-->Evaluation (2014-05-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (46560L, 16L), y_train: (46560L,)
# 				-->Computing Last value
# 					-->R2: 0.062
# 					-->MAE: 40.806
# 					-->MAPE: 15.378
# 					-->MASE: 0.148
# 				-->Computing Previous day
# 					-->R2: -0.578
# 					-->MAE: 49.516
# 					-->MAPE: 17.623
# 					-->MASE: 0.179
# 				-->Computing Previous week
# 					-->R2: -92.139
# 					-->MAE: 435.110
# 					-->MAPE: 147.959
# 					-->MASE: 1.574
# 			-->Dataset: TOP_20. X_train: (46560L, 20L), y_train: (46560L,)
# 				-->Training model: Random Forest, runtime: 6.68s
# 					-->R2: 0.692
# 					-->MAE: 23.568
# 					-->MAPE: 8.702
# 					-->MASE: 0.085
#
# 		-->Evaluation (2014-05-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (46656L, 16L), y_train: (46656L,)
# 				-->Computing Last value
# 					-->R2: -1.413
# 					-->MAE: 51.444
# 					-->MAPE: 16.882
# 					-->MASE: 0.186
# 				-->Computing Previous day
# 					-->R2: -0.215
# 					-->MAE: 34.298
# 					-->MAPE: 11.494
# 					-->MASE: 0.124
# 				-->Computing Previous week
# 					-->R2: -25.150
# 					-->MAE: 164.343
# 					-->MAPE: 54.476
# 					-->MASE: 0.596
# 			-->Dataset: TOP_20. X_train: (46656L, 20L), y_train: (46656L,)
# 				-->Training model: Random Forest, runtime: 6.41s
# 					-->R2: -0.284
# 					-->MAE: 31.994
# 					-->MAPE: 10.360
# 					-->MASE: 0.116
#
# 		-->Evaluation (2014-05-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (46752L, 16L), y_train: (46752L,)
# 				-->Computing Last value
# 					-->R2: -1.786
# 					-->MAE: 58.752
# 					-->MAPE: 28.199
# 					-->MASE: 0.213
# 				-->Computing Previous day
# 					-->R2: -0.609
# 					-->MAE: 51.995
# 					-->MAPE: 23.032
# 					-->MASE: 0.189
# 				-->Computing Previous week
# 					-->R2: 0.522
# 					-->MAE: 29.287
# 					-->MAPE: 11.324
# 					-->MASE: 0.106
# 			-->Dataset: TOP_20. X_train: (46752L, 20L), y_train: (46752L,)
# 				-->Training model: Random Forest, runtime: 6.71s
# 					-->R2: 0.716
# 					-->MAE: 22.031
# 					-->MAPE: 9.859
# 					-->MASE: 0.080
#
# 		-->Evaluation (2014-05-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (46848L, 16L), y_train: (46848L,)
# 				-->Computing Last value
# 					-->R2: -1.473
# 					-->MAE: 436.588
# 					-->MAPE: 55.032
# 					-->MASE: 1.588
# 				-->Computing Previous day
# 					-->R2: -1.646
# 					-->MAE: 446.216
# 					-->MAPE: 54.330
# 					-->MASE: 1.623
# 				-->Computing Previous week
# 					-->R2: 0.934
# 					-->MAE: 54.882
# 					-->MAPE: 7.257
# 					-->MASE: 0.200
# 			-->Dataset: TOP_20. X_train: (46848L, 20L), y_train: (46848L,)
# 				-->Training model: Random Forest, runtime: 6.51s
# 					-->R2: 0.944
# 					-->MAE: 60.747
# 					-->MAPE: 8.563
# 					-->MASE: 0.221
#
# 		-->Evaluation (2014-05-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (46944L, 16L), y_train: (46944L,)
# 				-->Computing Last value
# 					-->R2: -0.457
# 					-->MAE: 273.722
# 					-->MAPE: 45.409
# 					-->MASE: 0.994
# 				-->Computing Previous day
# 					-->R2: 0.890
# 					-->MAE: 72.227
# 					-->MAPE: 10.540
# 					-->MASE: 0.262
# 				-->Computing Previous week
# 					-->R2: 0.890
# 					-->MAE: 71.497
# 					-->MAPE: 11.239
# 					-->MASE: 0.260
# 			-->Dataset: TOP_20. X_train: (46944L, 20L), y_train: (46944L,)
# 				-->Training model: Random Forest, runtime: 6.68s
# 					-->R2: 0.947
# 					-->MAE: 53.286
# 					-->MAPE: 8.473
# 					-->MASE: 0.194
#
# 		-->Evaluation (2014-05-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (47040L, 16L), y_train: (47040L,)
# 				-->Computing Last value
# 					-->R2: -0.640
# 					-->MAE: 282.092
# 					-->MAPE: 48.123
# 					-->MASE: 1.025
# 				-->Computing Previous day
# 					-->R2: 0.954
# 					-->MAE: 47.731
# 					-->MAPE: 6.284
# 					-->MASE: 0.173
# 				-->Computing Previous week
# 					-->R2: 0.728
# 					-->MAE: 121.879
# 					-->MAPE: 16.690
# 					-->MASE: 0.443
# 			-->Dataset: TOP_20. X_train: (47040L, 20L), y_train: (47040L,)
# 				-->Training model: Random Forest, runtime: 6.10s
# 					-->R2: 0.947
# 					-->MAE: 50.567
# 					-->MAPE: 6.668
# 					-->MASE: 0.184
#
# 		-->Evaluation (2014-05-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (47136L, 16L), y_train: (47136L,)
# 				-->Computing Last value
# 					-->R2: -0.356
# 					-->MAE: 243.400
# 					-->MAPE: 39.780
# 					-->MASE: 0.884
# 				-->Computing Previous day
# 					-->R2: 0.970
# 					-->MAE: 37.869
# 					-->MAPE: 5.390
# 					-->MASE: 0.138
# 				-->Computing Previous week
# 					-->R2: -2.654
# 					-->MAE: 456.881
# 					-->MAPE: 53.304
# 					-->MASE: 1.659
# 			-->Dataset: TOP_20. X_train: (47136L, 20L), y_train: (47136L,)
# 				-->Training model: Random Forest, runtime: 6.60s
# 					-->R2: 0.961
# 					-->MAE: 41.110
# 					-->MAPE: 6.339
# 					-->MASE: 0.149
#
# 		-->Evaluation (2014-05-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (47232L, 16L), y_train: (47232L,)
# 				-->Computing Last value
# 					-->R2: -0.658
# 					-->MAE: 263.249
# 					-->MAPE: 41.666
# 					-->MASE: 0.956
# 				-->Computing Previous day
# 					-->R2: 0.957
# 					-->MAE: 41.794
# 					-->MAPE: 5.482
# 					-->MASE: 0.152
# 				-->Computing Previous week
# 					-->R2: -3.142
# 					-->MAE: 490.054
# 					-->MAPE: 59.233
# 					-->MASE: 1.780
# 			-->Dataset: TOP_20. X_train: (47232L, 20L), y_train: (47232L,)
# 				-->Training model: Random Forest, runtime: 6.29s
# 					-->R2: 0.932
# 					-->MAE: 54.016
# 					-->MAPE: 8.225
# 					-->MASE: 0.196
#
# 		-->Evaluation (2014-05-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (47328L, 16L), y_train: (47328L,)
# 				-->Computing Last value
# 					-->R2: -8.516
# 					-->MAE: 401.302
# 					-->MAPE: 100.254
# 					-->MASE: 1.458
# 				-->Computing Previous day
# 					-->R2: -7.296
# 					-->MAE: 343.019
# 					-->MAPE: 87.562
# 					-->MASE: 1.246
# 				-->Computing Previous week
# 					-->R2: -0.730
# 					-->MAE: 145.259
# 					-->MAPE: 27.447
# 					-->MASE: 0.528
# 			-->Dataset: TOP_20. X_train: (47328L, 20L), y_train: (47328L,)
# 				-->Training model: Random Forest, runtime: 6.66s
# 					-->R2: 0.745
# 					-->MAE: 57.126
# 					-->MAPE: 13.754
# 					-->MASE: 0.208
#
# 		-->Evaluation (2014-05-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (47424L, 16L), y_train: (47424L,)
# 				-->Computing Last value
# 					-->R2: -10.762
# 					-->MAE: 110.307
# 					-->MAPE: 46.787
# 					-->MASE: 0.400
# 				-->Computing Previous day
# 					-->R2: -14.423
# 					-->MAE: 151.715
# 					-->MAPE: 52.762
# 					-->MASE: 0.551
# 				-->Computing Previous week
# 					-->R2: 0.214
# 					-->MAE: 42.268
# 					-->MAPE: 14.011
# 					-->MASE: 0.153
# 			-->Dataset: TOP_20. X_train: (47424L, 20L), y_train: (47424L,)
# 				-->Training model: Random Forest, runtime: 7.06s
# 					-->R2: 0.758
# 					-->MAE: 21.246
# 					-->MAPE: 6.975
# 					-->MASE: 0.077
#
# 		-->Evaluation (2014-05-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (47520L, 16L), y_train: (47520L,)
# 				-->Computing Last value
# 					-->R2: -1.134
# 					-->MAE: 382.788
# 					-->MAPE: 47.034
# 					-->MASE: 1.391
# 				-->Computing Previous day
# 					-->R2: -1.241
# 					-->MAE: 384.415
# 					-->MAPE: 45.539
# 					-->MASE: 1.397
# 				-->Computing Previous week
# 					-->R2: 0.978
# 					-->MAE: 37.993
# 					-->MAPE: 6.566
# 					-->MASE: 0.138
# 			-->Dataset: TOP_20. X_train: (47520L, 20L), y_train: (47520L,)
# 				-->Training model: Random Forest, runtime: 6.62s
# 					-->R2: 0.979
# 					-->MAE: 36.182
# 					-->MAPE: 5.504
# 					-->MASE: 0.131
#
# 		-->Evaluation (2014-05-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (47616L, 16L), y_train: (47616L,)
# 				-->Computing Last value
# 					-->R2: -0.423
# 					-->MAE: 274.930
# 					-->MAPE: 47.307
# 					-->MASE: 0.998
# 				-->Computing Previous day
# 					-->R2: 0.905
# 					-->MAE: 55.504
# 					-->MAPE: 9.449
# 					-->MASE: 0.202
# 				-->Computing Previous week
# 					-->R2: 0.963
# 					-->MAE: 48.596
# 					-->MAPE: 7.164
# 					-->MASE: 0.176
# 			-->Dataset: TOP_20. X_train: (47616L, 20L), y_train: (47616L,)
# 				-->Training model: Random Forest, runtime: 6.59s
# 					-->R2: 0.983
# 					-->MAE: 31.403
# 					-->MAPE: 4.383
# 					-->MASE: 0.114
#
# 		-->Evaluation (2014-05-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (47712L, 16L), y_train: (47712L,)
# 				-->Computing Last value
# 					-->R2: -0.336
# 					-->MAE: 289.063
# 					-->MAPE: 53.808
# 					-->MASE: 1.050
# 				-->Computing Previous day
# 					-->R2: 0.976
# 					-->MAE: 36.188
# 					-->MAPE: 7.322
# 					-->MASE: 0.131
# 				-->Computing Previous week
# 					-->R2: 0.925
# 					-->MAE: 79.211
# 					-->MAPE: 13.915
# 					-->MASE: 0.288
# 			-->Dataset: TOP_20. X_train: (47712L, 20L), y_train: (47712L,)
# 				-->Training model: Random Forest, runtime: 6.55s
# 					-->R2: 0.975
# 					-->MAE: 41.796
# 					-->MAPE: 7.890
# 					-->MASE: 0.152
#
# 		-->Evaluation (2014-05-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (47808L, 16L), y_train: (47808L,)
# 				-->Computing Last value
# 					-->R2: -0.563
# 					-->MAE: 287.632
# 					-->MAPE: 53.454
# 					-->MASE: 1.044
# 				-->Computing Previous day
# 					-->R2: 0.974
# 					-->MAE: 37.967
# 					-->MAPE: 5.535
# 					-->MASE: 0.138
# 				-->Computing Previous week
# 					-->R2: 0.933
# 					-->MAE: 68.821
# 					-->MAPE: 12.840
# 					-->MASE: 0.250
# 			-->Dataset: TOP_20. X_train: (47808L, 20L), y_train: (47808L,)
# 				-->Training model: Random Forest, runtime: 6.63s
# 					-->R2: 0.982
# 					-->MAE: 29.030
# 					-->MAPE: 4.192
# 					-->MASE: 0.105
#
# 		-->Evaluation (2014-05-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (47904L, 16L), y_train: (47904L,)
# 				-->Computing Last value
# 					-->R2: -0.322
# 					-->MAE: 266.578
# 					-->MAPE: 44.319
# 					-->MASE: 0.968
# 				-->Computing Previous day
# 					-->R2: 0.958
# 					-->MAE: 48.807
# 					-->MAPE: 7.489
# 					-->MASE: 0.177
# 				-->Computing Previous week
# 					-->R2: 0.871
# 					-->MAE: 88.968
# 					-->MAPE: 12.757
# 					-->MASE: 0.323
# 			-->Dataset: TOP_20. X_train: (47904L, 20L), y_train: (47904L,)
# 				-->Training model: Random Forest, runtime: 6.54s
# 					-->R2: 0.956
# 					-->MAE: 50.546
# 					-->MAPE: 7.189
# 					-->MASE: 0.184
#
# 		-->Evaluation (2014-05-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (48000L, 16L), y_train: (48000L,)
# 				-->Computing Last value
# 					-->R2: -1.808
# 					-->MAE: 307.673
# 					-->MAPE: 73.485
# 					-->MASE: 1.117
# 				-->Computing Previous day
# 					-->R2: -1.516
# 					-->MAE: 259.988
# 					-->MAPE: 65.759
# 					-->MASE: 0.944
# 				-->Computing Previous week
# 					-->R2: 0.473
# 					-->MAE: 114.026
# 					-->MAPE: 17.448
# 					-->MASE: 0.414
# 			-->Dataset: TOP_20. X_train: (48000L, 20L), y_train: (48000L,)
# 				-->Training model: Random Forest, runtime: 6.86s
# 					-->R2: 0.652
# 					-->MAE: 83.602
# 					-->MAPE: 12.317
# 					-->MASE: 0.304
#
# 		-->Evaluation (2014-05-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (48096L, 16L), y_train: (48096L,)
# 				-->Computing Last value
# 					-->R2: -26.172
# 					-->MAE: 198.557
# 					-->MAPE: 87.259
# 					-->MASE: 0.721
# 				-->Computing Previous day
# 					-->R2: -22.791
# 					-->MAE: 218.992
# 					-->MAPE: 79.576
# 					-->MASE: 0.795
# 				-->Computing Previous week
# 					-->R2: 0.804
# 					-->MAE: 22.024
# 					-->MAPE: 7.067
# 					-->MASE: 0.080
# 			-->Dataset: TOP_20. X_train: (48096L, 20L), y_train: (48096L,)
# 				-->Training model: Random Forest, runtime: 6.09s
# 					-->R2: 0.684
# 					-->MAE: 27.940
# 					-->MAPE: 8.931
# 					-->MASE: 0.101
#
# 		-->Evaluation (2014-05-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (48192L, 16L), y_train: (48192L,)
# 				-->Computing Last value
# 					-->R2: -1.254
# 					-->MAE: 413.249
# 					-->MAPE: 49.709
# 					-->MASE: 1.501
# 				-->Computing Previous day
# 					-->R2: -1.427
# 					-->MAE: 421.793
# 					-->MAPE: 48.991
# 					-->MASE: 1.532
# 				-->Computing Previous week
# 					-->R2: 0.956
# 					-->MAE: 60.226
# 					-->MAPE: 9.368
# 					-->MASE: 0.219
# 			-->Dataset: TOP_20. X_train: (48192L, 20L), y_train: (48192L,)
# 				-->Training model: Random Forest, runtime: 6.18s
# 					-->R2: 0.588
# 					-->MAE: 144.299
# 					-->MAPE: 16.480
# 					-->MASE: 0.524
#
# 		-->Evaluation (2014-05-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (48288L, 16L), y_train: (48288L,)
# 				-->Computing Last value
# 					-->R2: -0.625
# 					-->MAE: 276.438
# 					-->MAPE: 45.542
# 					-->MASE: 1.003
# 				-->Computing Previous day
# 					-->R2: 0.873
# 					-->MAE: 74.099
# 					-->MAPE: 11.276
# 					-->MASE: 0.269
# 				-->Computing Previous week
# 					-->R2: 0.967
# 					-->MAE: 43.579
# 					-->MAPE: 7.368
# 					-->MASE: 0.158
# 			-->Dataset: TOP_20. X_train: (48288L, 20L), y_train: (48288L,)
# 				-->Training model: Random Forest, runtime: 6.08s
# 					-->R2: 0.959
# 					-->MAE: 48.101
# 					-->MAPE: 7.966
# 					-->MASE: 0.175
#
# 		-->Evaluation (2014-05-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (48384L, 16L), y_train: (48384L,)
# 				-->Computing Last value
# 					-->R2: -0.554
# 					-->MAE: 267.621
# 					-->MAPE: 44.088
# 					-->MASE: 0.971
# 				-->Computing Previous day
# 					-->R2: 0.954
# 					-->MAE: 46.238
# 					-->MAPE: 6.442
# 					-->MASE: 0.168
# 				-->Computing Previous week
# 					-->R2: 0.921
# 					-->MAE: 67.028
# 					-->MAPE: 11.330
# 					-->MASE: 0.243
# 			-->Dataset: TOP_20. X_train: (48384L, 20L), y_train: (48384L,)
# 				-->Training model: Random Forest, runtime: 6.29s
# 					-->R2: 0.969
# 					-->MAE: 38.808
# 					-->MAPE: 5.416
# 					-->MASE: 0.141
#
# 		-->Evaluation (2014-05-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (48480L, 16L), y_train: (48480L,)
# 				-->Computing Last value
# 					-->R2: -0.452
# 					-->MAE: 260.176
# 					-->MAPE: 42.397
# 					-->MASE: 0.944
# 				-->Computing Previous day
# 					-->R2: 0.978
# 					-->MAE: 33.148
# 					-->MAPE: 4.741
# 					-->MASE: 0.120
# 				-->Computing Previous week
# 					-->R2: 0.936
# 					-->MAE: 61.820
# 					-->MAPE: 10.338
# 					-->MASE: 0.224
# 			-->Dataset: TOP_20. X_train: (48480L, 20L), y_train: (48480L,)
# 				-->Training model: Random Forest, runtime: 6.00s
# 					-->R2: 0.979
# 					-->MAE: 32.796
# 					-->MAPE: 4.710
# 					-->MASE: 0.119
#
# 		-->Evaluation (2014-05-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (48576L, 16L), y_train: (48576L,)
# 				-->Computing Last value
# 					-->R2: -0.370
# 					-->MAE: 278.194
# 					-->MAPE: 45.379
# 					-->MASE: 1.010
# 				-->Computing Previous day
# 					-->R2: 0.976
# 					-->MAE: 38.005
# 					-->MAPE: 4.985
# 					-->MASE: 0.138
# 				-->Computing Previous week
# 					-->R2: 0.930
# 					-->MAE: 55.005
# 					-->MAPE: 7.988
# 					-->MASE: 0.200
# 			-->Dataset: TOP_20. X_train: (48576L, 20L), y_train: (48576L,)
# 				-->Training model: Random Forest, runtime: 6.14s
# 					-->R2: 0.951
# 					-->MAE: 54.046
# 					-->MAPE: 6.475
# 					-->MASE: 0.196
#
# 		-->Evaluation (2014-05-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (48672L, 16L), y_train: (48672L,)
# 				-->Computing Last value
# 					-->R2: -2.262
# 					-->MAE: 341.794
# 					-->MAPE: 80.166
# 					-->MASE: 1.240
# 				-->Computing Previous day
# 					-->R2: -2.083
# 					-->MAE: 298.592
# 					-->MAPE: 74.642
# 					-->MASE: 1.084
# 				-->Computing Previous week
# 					-->R2: 0.935
# 					-->MAE: 45.760
# 					-->MAPE: 8.816
# 					-->MASE: 0.166
# 			-->Dataset: TOP_20. X_train: (48672L, 20L), y_train: (48672L,)
# 				-->Training model: Random Forest, runtime: 6.20s
# 					-->R2: 0.886
# 					-->MAE: 54.117
# 					-->MAPE: 9.061
# 					-->MASE: 0.196
#
# 		-->Evaluation (2014-05-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (48768L, 16L), y_train: (48768L,)
# 				-->Computing Last value
# 					-->R2: -37.092
# 					-->MAE: 190.175
# 					-->MAPE: 85.372
# 					-->MASE: 0.690
# 				-->Computing Previous day
# 					-->R2: -38.051
# 					-->MAE: 227.608
# 					-->MAPE: 86.214
# 					-->MASE: 0.826
# 				-->Computing Previous week
# 					-->R2: 0.408
# 					-->MAE: 29.632
# 					-->MAPE: 10.016
# 					-->MASE: 0.107
# 			-->Dataset: TOP_20. X_train: (48768L, 20L), y_train: (48768L,)
# 				-->Training model: Random Forest, runtime: 5.94s
# 					-->R2: 0.711
# 					-->MAE: 24.047
# 					-->MAPE: 8.690
# 					-->MASE: 0.087
#
# 		-->Evaluation (2014-05-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (48864L, 16L), y_train: (48864L,)
# 				-->Computing Last value
# 					-->R2: -1.355
# 					-->MAE: 469.260
# 					-->MAPE: 53.542
# 					-->MASE: 1.703
# 				-->Computing Previous day
# 					-->R2: -1.541
# 					-->MAE: 474.028
# 					-->MAPE: 51.124
# 					-->MASE: 1.720
# 				-->Computing Previous week
# 					-->R2: 0.969
# 					-->MAE: 52.333
# 					-->MAPE: 7.631
# 					-->MASE: 0.190
# 			-->Dataset: TOP_20. X_train: (48864L, 20L), y_train: (48864L,)
# 				-->Training model: Random Forest, runtime: 6.03s
# 					-->R2: 0.944
# 					-->MAE: 66.432
# 					-->MAPE: 7.656
# 					-->MASE: 0.241
#
# 		-->Evaluation (2014-05-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (48960L, 16L), y_train: (48960L,)
# 				-->Computing Last value
# 					-->R2: -0.463
# 					-->MAE: 314.409
# 					-->MAPE: 51.240
# 					-->MASE: 1.139
# 				-->Computing Previous day
# 					-->R2: 0.910
# 					-->MAE: 68.561
# 					-->MAPE: 10.462
# 					-->MASE: 0.248
# 				-->Computing Previous week
# 					-->R2: 0.955
# 					-->MAE: 58.770
# 					-->MAPE: 8.418
# 					-->MASE: 0.213
# 			-->Dataset: TOP_20. X_train: (48960L, 20L), y_train: (48960L,)
# 				-->Training model: Random Forest, runtime: 6.53s
# 					-->R2: 0.971
# 					-->MAE: 45.693
# 					-->MAPE: 6.607
# 					-->MASE: 0.166
#
# 		-->Evaluation (2014-05-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (49056L, 16L), y_train: (49056L,)
# 				-->Computing Last value
# 					-->R2: -0.301
# 					-->MAE: 306.905
# 					-->MAPE: 53.747
# 					-->MASE: 1.112
# 				-->Computing Previous day
# 					-->R2: 0.973
# 					-->MAE: 46.290
# 					-->MAPE: 7.863
# 					-->MASE: 0.168
# 				-->Computing Previous week
# 					-->R2: 0.938
# 					-->MAE: 69.461
# 					-->MAPE: 11.188
# 					-->MASE: 0.252
# 			-->Dataset: TOP_20. X_train: (49056L, 20L), y_train: (49056L,)
# 				-->Training model: Random Forest, runtime: 6.07s
# 					-->R2: 0.982
# 					-->MAE: 35.624
# 					-->MAPE: 6.730
# 					-->MASE: 0.129
#
# 		-->Evaluation (2014-05-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (49152L, 16L), y_train: (49152L,)
# 				-->Computing Last value
# 					-->R2: -0.583
# 					-->MAE: 337.820
# 					-->MAPE: 56.526
# 					-->MASE: 1.224
# 				-->Computing Previous day
# 					-->R2: 0.924
# 					-->MAE: 67.092
# 					-->MAPE: 8.390
# 					-->MASE: 0.243
# 				-->Computing Previous week
# 					-->R2: 0.921
# 					-->MAE: 79.522
# 					-->MAPE: 13.200
# 					-->MASE: 0.288
# 			-->Dataset: TOP_20. X_train: (49152L, 20L), y_train: (49152L,)
# 				-->Training model: Random Forest, runtime: 6.22s
# 					-->R2: 0.940
# 					-->MAE: 65.839
# 					-->MAPE: 9.358
# 					-->MASE: 0.238
#
# 		-->Evaluation (2014-05-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (49248L, 16L), y_train: (49248L,)
# 				-->Computing Last value
# 					-->R2: -0.263
# 					-->MAE: 311.406
# 					-->MAPE: 54.464
# 					-->MASE: 1.128
# 				-->Computing Previous day
# 					-->R2: 0.977
# 					-->MAE: 37.270
# 					-->MAPE: 4.643
# 					-->MASE: 0.135
# 				-->Computing Previous week
# 					-->R2: 0.946
# 					-->MAE: 65.088
# 					-->MAPE: 11.560
# 					-->MASE: 0.236
# 			-->Dataset: TOP_20. X_train: (49248L, 20L), y_train: (49248L,)
# 				-->Training model: Random Forest, runtime: 6.10s
# 					-->R2: 0.984
# 					-->MAE: 34.920
# 					-->MAPE: 4.787
# 					-->MASE: 0.126
#
# 		-->Evaluation (2014-05-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (49344L, 16L), y_train: (49344L,)
# 				-->Computing Last value
# 					-->R2: -8.680
# 					-->MAE: 407.641
# 					-->MAPE: 99.232
# 					-->MASE: 1.476
# 				-->Computing Previous day
# 					-->R2: -8.765
# 					-->MAE: 360.495
# 					-->MAPE: 95.852
# 					-->MASE: 1.305
# 				-->Computing Previous week
# 					-->R2: 0.378
# 					-->MAE: 78.943
# 					-->MAPE: 15.378
# 					-->MASE: 0.286
# 			-->Dataset: TOP_20. X_train: (49344L, 20L), y_train: (49344L,)
# 				-->Training model: Random Forest, runtime: 6.27s
# 					-->R2: 0.667
# 					-->MAE: 55.641
# 					-->MAPE: 10.888
# 					-->MASE: 0.201
#
# 		-->Evaluation (2014-06-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (49440L, 16L), y_train: (49440L,)
# 				-->Computing Last value
# 					-->R2: -13.760
# 					-->MAE: 137.826
# 					-->MAPE: 62.130
# 					-->MASE: 0.498
# 				-->Computing Previous day
# 					-->R2: -14.067
# 					-->MAE: 164.915
# 					-->MAPE: 63.959
# 					-->MASE: 0.596
# 				-->Computing Previous week
# 					-->R2: 0.863
# 					-->MAE: 17.661
# 					-->MAPE: 5.754
# 					-->MASE: 0.064
# 			-->Dataset: TOP_20. X_train: (49440L, 20L), y_train: (49440L,)
# 				-->Training model: Random Forest, runtime: 6.07s
# 					-->R2: 0.880
# 					-->MAE: 15.713
# 					-->MAPE: 5.134
# 					-->MASE: 0.057
#
# 		-->Evaluation (2014-06-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (49536L, 16L), y_train: (49536L,)
# 				-->Computing Last value
# 					-->R2: -1.118
# 					-->MAE: 428.178
# 					-->MAPE: 50.849
# 					-->MASE: 1.550
# 				-->Computing Previous day
# 					-->R2: -1.297
# 					-->MAE: 431.204
# 					-->MAPE: 48.038
# 					-->MASE: 1.561
# 				-->Computing Previous week
# 					-->R2: 0.973
# 					-->MAE: 43.926
# 					-->MAPE: 6.717
# 					-->MASE: 0.159
# 			-->Dataset: TOP_20. X_train: (49536L, 20L), y_train: (49536L,)
# 				-->Training model: Random Forest, runtime: 5.87s
# 					-->R2: 0.965
# 					-->MAE: 51.267
# 					-->MAPE: 7.405
# 					-->MASE: 0.186
#
# 		-->Evaluation (2014-06-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (49632L, 16L), y_train: (49632L,)
# 				-->Computing Last value
# 					-->R2: -0.324
# 					-->MAE: 322.432
# 					-->MAPE: 54.742
# 					-->MASE: 1.166
# 				-->Computing Previous day
# 					-->R2: 0.955
# 					-->MAE: 44.795
# 					-->MAPE: 6.837
# 					-->MASE: 0.162
# 				-->Computing Previous week
# 					-->R2: 0.975
# 					-->MAE: 48.411
# 					-->MAPE: 7.955
# 					-->MASE: 0.175
# 			-->Dataset: TOP_20. X_train: (49632L, 20L), y_train: (49632L,)
# 				-->Training model: Random Forest, runtime: 6.06s
# 					-->R2: 0.971
# 					-->MAE: 50.664
# 					-->MAPE: 7.017
# 					-->MASE: 0.183
#
# 		-->Evaluation (2014-06-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (49728L, 16L), y_train: (49728L,)
# 				-->Computing Last value
# 					-->R2: -0.494
# 					-->MAE: 308.886
# 					-->MAPE: 55.876
# 					-->MASE: 1.117
# 				-->Computing Previous day
# 					-->R2: 0.958
# 					-->MAE: 46.018
# 					-->MAPE: 5.797
# 					-->MASE: 0.166
# 				-->Computing Previous week
# 					-->R2: 0.969
# 					-->MAE: 44.393
# 					-->MAPE: 6.344
# 					-->MASE: 0.160
# 			-->Dataset: TOP_20. X_train: (49728L, 20L), y_train: (49728L,)
# 				-->Training model: Random Forest, runtime: 6.19s
# 					-->R2: 0.983
# 					-->MAE: 32.269
# 					-->MAPE: 4.585
# 					-->MASE: 0.117
#
# 		-->Evaluation (2014-06-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (49824L, 16L), y_train: (49824L,)
# 				-->Computing Last value
# 					-->R2: -0.426
# 					-->MAE: 292.142
# 					-->MAPE: 49.145
# 					-->MASE: 1.056
# 				-->Computing Previous day
# 					-->R2: 0.959
# 					-->MAE: 54.193
# 					-->MAPE: 8.117
# 					-->MASE: 0.196
# 				-->Computing Previous week
# 					-->R2: 0.942
# 					-->MAE: 62.506
# 					-->MAPE: 9.715
# 					-->MASE: 0.226
# 			-->Dataset: TOP_20. X_train: (49824L, 20L), y_train: (49824L,)
# 				-->Training model: Random Forest, runtime: 6.37s
# 					-->R2: 0.968
# 					-->MAE: 47.043
# 					-->MAPE: 6.876
# 					-->MASE: 0.170
#
# 		-->Evaluation (2014-06-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (49920L, 16L), y_train: (49920L,)
# 				-->Computing Last value
# 					-->R2: -0.332
# 					-->MAE: 287.742
# 					-->MAPE: 50.790
# 					-->MASE: 1.040
# 				-->Computing Previous day
# 					-->R2: 0.981
# 					-->MAE: 33.995
# 					-->MAPE: 4.591
# 					-->MASE: 0.123
# 				-->Computing Previous week
# 					-->R2: 0.948
# 					-->MAE: 61.641
# 					-->MAPE: 9.491
# 					-->MASE: 0.223
# 			-->Dataset: TOP_20. X_train: (49920L, 20L), y_train: (49920L,)
# 				-->Training model: Random Forest, runtime: 6.28s
# 					-->R2: 0.974
# 					-->MAE: 40.317
# 					-->MAPE: 5.134
# 					-->MASE: 0.146
#
# 		-->Evaluation (2014-06-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (50016L, 16L), y_train: (50016L,)
# 				-->Computing Last value
# 					-->R2: -2.203
# 					-->MAE: 323.413
# 					-->MAPE: 79.193
# 					-->MASE: 1.169
# 				-->Computing Previous day
# 					-->R2: -1.954
# 					-->MAE: 282.647
# 					-->MAPE: 73.297
# 					-->MASE: 1.021
# 				-->Computing Previous week
# 					-->R2: 0.704
# 					-->MAE: 87.845
# 					-->MAPE: 15.396
# 					-->MASE: 0.317
# 			-->Dataset: TOP_20. X_train: (50016L, 20L), y_train: (50016L,)
# 				-->Training model: Random Forest, runtime: 6.21s
# 					-->R2: 0.860
# 					-->MAE: 62.794
# 					-->MAPE: 12.231
# 					-->MASE: 0.227
#
# 		-->Evaluation (2014-06-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (50112L, 16L), y_train: (50112L,)
# 				-->Computing Last value
# 					-->R2: -29.211
# 					-->MAE: 195.101
# 					-->MAPE: 74.687
# 					-->MASE: 0.705
# 				-->Computing Previous day
# 					-->R2: -25.336
# 					-->MAE: 210.879
# 					-->MAPE: 67.843
# 					-->MASE: 0.762
# 				-->Computing Previous week
# 					-->R2: 0.493
# 					-->MAE: 35.651
# 					-->MAPE: 10.943
# 					-->MASE: 0.129
# 			-->Dataset: TOP_20. X_train: (50112L, 20L), y_train: (50112L,)
# 				-->Training model: Random Forest, runtime: 6.40s
# 					-->R2: 0.573
# 					-->MAE: 32.053
# 					-->MAPE: 9.373
# 					-->MASE: 0.116
#
# 		-->Evaluation (2014-06-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (50208L, 16L), y_train: (50208L,)
# 				-->Computing Last value
# 					-->R2: -1.107
# 					-->MAE: 390.348
# 					-->MAPE: 45.583
# 					-->MASE: 1.411
# 				-->Computing Previous day
# 					-->R2: -1.248
# 					-->MAE: 393.667
# 					-->MAPE: 44.044
# 					-->MASE: 1.423
# 				-->Computing Previous week
# 					-->R2: 0.948
# 					-->MAE: 59.625
# 					-->MAPE: 8.148
# 					-->MASE: 0.216
# 			-->Dataset: TOP_20. X_train: (50208L, 20L), y_train: (50208L,)
# 				-->Training model: Random Forest, runtime: 6.24s
# 					-->R2: 0.950
# 					-->MAE: 56.056
# 					-->MAPE: 7.637
# 					-->MASE: 0.203
#
# 		-->Evaluation (2014-06-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (50304L, 16L), y_train: (50304L,)
# 				-->Computing Last value
# 					-->R2: -0.316
# 					-->MAE: 276.563
# 					-->MAPE: 46.274
# 					-->MASE: 0.999
# 				-->Computing Previous day
# 					-->R2: 0.896
# 					-->MAE: 69.962
# 					-->MAPE: 10.792
# 					-->MASE: 0.253
# 				-->Computing Previous week
# 					-->R2: 0.947
# 					-->MAE: 58.701
# 					-->MAPE: 8.288
# 					-->MASE: 0.212
# 			-->Dataset: TOP_20. X_train: (50304L, 20L), y_train: (50304L,)
# 				-->Training model: Random Forest, runtime: 5.97s
# 					-->R2: 0.968
# 					-->MAE: 48.255
# 					-->MAPE: 7.319
# 					-->MASE: 0.174
#
# 		-->Evaluation (2014-06-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (50400L, 16L), y_train: (50400L,)
# 				-->Computing Last value
# 					-->R2: -0.451
# 					-->MAE: 311.452
# 					-->MAPE: 47.578
# 					-->MASE: 1.125
# 				-->Computing Previous day
# 					-->R2: 0.949
# 					-->MAE: 54.115
# 					-->MAPE: 7.700
# 					-->MASE: 0.195
# 				-->Computing Previous week
# 					-->R2: 0.937
# 					-->MAE: 65.051
# 					-->MAPE: 9.687
# 					-->MASE: 0.235
# 			-->Dataset: TOP_20. X_train: (50400L, 20L), y_train: (50400L,)
# 				-->Training model: Random Forest, runtime: 6.30s
# 					-->R2: 0.957
# 					-->MAE: 52.473
# 					-->MAPE: 7.233
# 					-->MASE: 0.190
#
# 		-->Evaluation (2014-06-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (50496L, 16L), y_train: (50496L,)
# 				-->Computing Last value
# 					-->R2: -0.358
# 					-->MAE: 285.329
# 					-->MAPE: 47.924
# 					-->MASE: 1.030
# 				-->Computing Previous day
# 					-->R2: 0.965
# 					-->MAE: 44.286
# 					-->MAPE: 6.576
# 					-->MASE: 0.160
# 				-->Computing Previous week
# 					-->R2: 0.943
# 					-->MAE: 60.739
# 					-->MAPE: 8.464
# 					-->MASE: 0.219
# 			-->Dataset: TOP_20. X_train: (50496L, 20L), y_train: (50496L,)
# 				-->Training model: Random Forest, runtime: 6.19s
# 					-->R2: 0.975
# 					-->MAE: 38.864
# 					-->MAPE: 5.891
# 					-->MASE: 0.140
#
# 		-->Evaluation (2014-06-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (50592L, 16L), y_train: (50592L,)
# 				-->Computing Last value
# 					-->R2: -0.423
# 					-->MAE: 282.371
# 					-->MAPE: 44.893
# 					-->MASE: 1.019
# 				-->Computing Previous day
# 					-->R2: 0.946
# 					-->MAE: 51.698
# 					-->MAPE: 6.485
# 					-->MASE: 0.187
# 				-->Computing Previous week
# 					-->R2: 0.937
# 					-->MAE: 62.001
# 					-->MAPE: 8.360
# 					-->MASE: 0.224
# 			-->Dataset: TOP_20. X_train: (50592L, 20L), y_train: (50592L,)
# 				-->Training model: Random Forest, runtime: 6.19s
# 					-->R2: 0.957
# 					-->MAE: 43.592
# 					-->MAPE: 5.112
# 					-->MASE: 0.157
#
# 		-->Evaluation (2014-06-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (50688L, 16L), y_train: (50688L,)
# 				-->Computing Last value
# 					-->R2: -1.430
# 					-->MAE: 317.839
# 					-->MAPE: 72.167
# 					-->MASE: 1.148
# 				-->Computing Previous day
# 					-->R2: -1.605
# 					-->MAE: 279.478
# 					-->MAPE: 69.830
# 					-->MASE: 1.009
# 				-->Computing Previous week
# 					-->R2: 0.942
# 					-->MAE: 42.694
# 					-->MAPE: 7.913
# 					-->MASE: 0.154
# 			-->Dataset: TOP_20. X_train: (50688L, 20L), y_train: (50688L,)
# 				-->Training model: Random Forest, runtime: 6.20s
# 					-->R2: 0.741
# 					-->MAE: 72.168
# 					-->MAPE: 9.800
# 					-->MASE: 0.261
#
# 		-->Evaluation (2014-06-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (50784L, 16L), y_train: (50784L,)
# 				-->Computing Last value
# 					-->R2: -39.749
# 					-->MAE: 208.397
# 					-->MAPE: 82.516
# 					-->MASE: 0.752
# 				-->Computing Previous day
# 					-->R2: -38.589
# 					-->MAE: 240.842
# 					-->MAPE: 81.593
# 					-->MASE: 0.869
# 				-->Computing Previous week
# 					-->R2: 0.721
# 					-->MAE: 22.174
# 					-->MAPE: 7.304
# 					-->MASE: 0.080
# 			-->Dataset: TOP_20. X_train: (50784L, 20L), y_train: (50784L,)
# 				-->Training model: Random Forest, runtime: 6.22s
# 					-->R2: 0.761
# 					-->MAE: 20.033
# 					-->MAPE: 6.690
# 					-->MASE: 0.072
#
# 		-->Evaluation (2014-06-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (50880L, 16L), y_train: (50880L,)
# 				-->Computing Last value
# 					-->R2: -1.139
# 					-->MAE: 417.389
# 					-->MAPE: 47.947
# 					-->MASE: 1.507
# 				-->Computing Previous day
# 					-->R2: -1.275
# 					-->MAE: 420.349
# 					-->MAPE: 46.413
# 					-->MASE: 1.518
# 				-->Computing Previous week
# 					-->R2: 0.978
# 					-->MAE: 41.543
# 					-->MAPE: 5.708
# 					-->MASE: 0.150
# 			-->Dataset: TOP_20. X_train: (50880L, 20L), y_train: (50880L,)
# 				-->Training model: Random Forest, runtime: 6.13s
# 					-->R2: 0.895
# 					-->MAE: 82.866
# 					-->MAPE: 9.689
# 					-->MASE: 0.299
#
# 		-->Evaluation (2014-06-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (50976L, 16L), y_train: (50976L,)
# 				-->Computing Last value
# 					-->R2: -0.597
# 					-->MAE: 328.430
# 					-->MAPE: 55.626
# 					-->MASE: 1.185
# 				-->Computing Previous day
# 					-->R2: 0.897
# 					-->MAE: 71.359
# 					-->MAPE: 9.616
# 					-->MASE: 0.257
# 				-->Computing Previous week
# 					-->R2: 0.941
# 					-->MAE: 63.181
# 					-->MAPE: 8.954
# 					-->MASE: 0.228
# 			-->Dataset: TOP_20. X_train: (50976L, 20L), y_train: (50976L,)
# 				-->Training model: Random Forest, runtime: 6.23s
# 					-->R2: 0.957
# 					-->MAE: 47.133
# 					-->MAPE: 6.362
# 					-->MASE: 0.170
#
# 		-->Evaluation (2014-06-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (51072L, 16L), y_train: (51072L,)
# 				-->Computing Last value
# 					-->R2: -0.230
# 					-->MAE: 291.012
# 					-->MAPE: 50.759
# 					-->MASE: 1.049
# 				-->Computing Previous day
# 					-->R2: 0.968
# 					-->MAE: 46.734
# 					-->MAPE: 6.372
# 					-->MASE: 0.169
# 				-->Computing Previous week
# 					-->R2: 0.961
# 					-->MAE: 53.128
# 					-->MAPE: 8.220
# 					-->MASE: 0.192
# 			-->Dataset: TOP_20. X_train: (51072L, 20L), y_train: (51072L,)
# 				-->Training model: Random Forest, runtime: 6.20s
# 					-->R2: 0.963
# 					-->MAE: 48.860
# 					-->MAPE: 6.230
# 					-->MASE: 0.176
#
# 		-->Evaluation (2014-06-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (51168L, 16L), y_train: (51168L,)
# 				-->Computing Last value
# 					-->R2: -0.492
# 					-->MAE: 318.147
# 					-->MAPE: 56.908
# 					-->MASE: 1.147
# 				-->Computing Previous day
# 					-->R2: 0.977
# 					-->MAE: 37.423
# 					-->MAPE: 5.052
# 					-->MASE: 0.135
# 				-->Computing Previous week
# 					-->R2: 0.968
# 					-->MAE: 45.395
# 					-->MAPE: 6.793
# 					-->MASE: 0.164
# 			-->Dataset: TOP_20. X_train: (51168L, 20L), y_train: (51168L,)
# 				-->Training model: Random Forest, runtime: 6.07s
# 					-->R2: 0.927
# 					-->MAE: 57.052
# 					-->MAPE: 6.904
# 					-->MASE: 0.206
#
# 		-->Evaluation (2014-06-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (51264L, 16L), y_train: (51264L,)
# 				-->Computing Last value
# 					-->R2: -0.397
# 					-->MAE: 296.384
# 					-->MAPE: 54.544
# 					-->MASE: 1.068
# 				-->Computing Previous day
# 					-->R2: 0.985
# 					-->MAE: 29.759
# 					-->MAPE: 4.065
# 					-->MASE: 0.107
# 				-->Computing Previous week
# 					-->R2: 0.930
# 					-->MAE: 70.711
# 					-->MAPE: 10.707
# 					-->MASE: 0.255
# 			-->Dataset: TOP_20. X_train: (51264L, 20L), y_train: (51264L,)
# 				-->Training model: Random Forest, runtime: 6.19s
# 					-->R2: 0.967
# 					-->MAE: 42.932
# 					-->MAPE: 6.336
# 					-->MASE: 0.155
#
# 		-->Evaluation (2014-06-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (51360L, 16L), y_train: (51360L,)
# 				-->Computing Last value
# 					-->R2: -3.886
# 					-->MAE: 367.188
# 					-->MAPE: 84.506
# 					-->MASE: 1.324
# 				-->Computing Previous day
# 					-->R2: -3.650
# 					-->MAE: 316.496
# 					-->MAPE: 79.424
# 					-->MASE: 1.141
# 				-->Computing Previous week
# 					-->R2: 0.833
# 					-->MAE: 55.059
# 					-->MAPE: 10.099
# 					-->MASE: 0.198
# 			-->Dataset: TOP_20. X_train: (51360L, 20L), y_train: (51360L,)
# 				-->Training model: Random Forest, runtime: 6.96s
# 					-->R2: 0.931
# 					-->MAE: 37.862
# 					-->MAPE: 8.057
# 					-->MASE: 0.136
#
# 		-->Evaluation (2014-06-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (51456L, 16L), y_train: (51456L,)
# 				-->Computing Last value
# 					-->R2: -23.312
# 					-->MAE: 166.680
# 					-->MAPE: 63.058
# 					-->MASE: 0.600
# 				-->Computing Previous day
# 					-->R2: -23.413
# 					-->MAE: 194.808
# 					-->MAPE: 63.707
# 					-->MASE: 0.702
# 				-->Computing Previous week
# 					-->R2: 0.816
# 					-->MAE: 18.204
# 					-->MAPE: 5.458
# 					-->MASE: 0.066
# 			-->Dataset: TOP_20. X_train: (51456L, 20L), y_train: (51456L,)
# 				-->Training model: Random Forest, runtime: 7.96s
# 					-->R2: 0.797
# 					-->MAE: 18.708
# 					-->MAPE: 5.419
# 					-->MASE: 0.067
#
# 		-->Evaluation (2014-06-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (51552L, 16L), y_train: (51552L,)
# 				-->Computing Last value
# 					-->R2: -1.147
# 					-->MAE: 390.804
# 					-->MAPE: 45.625
# 					-->MASE: 1.409
# 				-->Computing Previous day
# 					-->R2: -1.334
# 					-->MAE: 395.320
# 					-->MAPE: 44.286
# 					-->MASE: 1.425
# 				-->Computing Previous week
# 					-->R2: 0.972
# 					-->MAE: 43.774
# 					-->MAPE: 6.316
# 					-->MASE: 0.158
# 			-->Dataset: TOP_20. X_train: (51552L, 20L), y_train: (51552L,)
# 				-->Training model: Random Forest, runtime: 6.79s
# 					-->R2: 0.964
# 					-->MAE: 38.063
# 					-->MAPE: 5.248
# 					-->MASE: 0.137
#
# 		-->Evaluation (2014-06-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (51648L, 16L), y_train: (51648L,)
# 				-->Computing Last value
# 					-->R2: -0.354
# 					-->MAE: 285.468
# 					-->MAPE: 51.751
# 					-->MASE: 1.028
# 				-->Computing Previous day
# 					-->R2: 0.935
# 					-->MAE: 52.790
# 					-->MAPE: 8.314
# 					-->MASE: 0.190
# 				-->Computing Previous week
# 					-->R2: 0.964
# 					-->MAE: 43.935
# 					-->MAPE: 7.284
# 					-->MASE: 0.158
# 			-->Dataset: TOP_20. X_train: (51648L, 20L), y_train: (51648L,)
# 				-->Training model: Random Forest, runtime: 6.78s
# 					-->R2: 0.953
# 					-->MAE: 52.745
# 					-->MAPE: 7.839
# 					-->MASE: 0.190
#
# 		-->Evaluation (2014-06-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (51744L, 16L), y_train: (51744L,)
# 				-->Computing Last value
# 					-->R2: -36.019
# 					-->MAE: 444.754
# 					-->MAPE: 138.751
# 					-->MASE: 1.602
# 				-->Computing Previous day
# 					-->R2: -32.818
# 					-->MAE: 391.040
# 					-->MAPE: 120.746
# 					-->MASE: 1.409
# 				-->Computing Previous week
# 					-->R2: -39.147
# 					-->MAE: 437.124
# 					-->MAPE: 134.494
# 					-->MASE: 1.575
# 			-->Dataset: TOP_20. X_train: (51744L, 20L), y_train: (51744L,)
# 				-->Training model: Random Forest, runtime: 6.78s
# 					-->R2: 0.403
# 					-->MAE: 59.900
# 					-->MAPE: 18.442
# 					-->MASE: 0.216
#
# 		-->Evaluation (2014-06-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (51840L, 16L), y_train: (51840L,)
# 				-->Computing Last value
# 					-->R2: -1.234
# 					-->MAE: 373.447
# 					-->MAPE: 43.597
# 					-->MASE: 1.344
# 				-->Computing Previous day
# 					-->R2: -1.340
# 					-->MAE: 392.469
# 					-->MAPE: 48.348
# 					-->MASE: 1.412
# 				-->Computing Previous week
# 					-->R2: 0.808
# 					-->MAE: 106.686
# 					-->MAPE: 20.467
# 					-->MASE: 0.384
# 			-->Dataset: TOP_20. X_train: (51840L, 20L), y_train: (51840L,)
# 				-->Training model: Random Forest, runtime: 6.50s
# 					-->R2: 0.934
# 					-->MAE: 57.234
# 					-->MAPE: 8.274
# 					-->MASE: 0.206
#
# 		-->Evaluation (2014-06-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (51936L, 16L), y_train: (51936L,)
# 				-->Computing Last value
# 					-->R2: -0.267
# 					-->MAE: 277.678
# 					-->MAPE: 54.339
# 					-->MASE: 0.998
# 				-->Computing Previous day
# 					-->R2: 0.846
# 					-->MAE: 79.962
# 					-->MAPE: 13.341
# 					-->MASE: 0.288
# 				-->Computing Previous week
# 					-->R2: 0.923
# 					-->MAE: 70.513
# 					-->MAPE: 10.530
# 					-->MASE: 0.254
# 			-->Dataset: TOP_20. X_train: (51936L, 20L), y_train: (51936L,)
# 				-->Training model: Random Forest, runtime: 6.38s
# 					-->R2: 0.928
# 					-->MAE: 58.321
# 					-->MAPE: 9.018
# 					-->MASE: 0.210
#
# 		-->Evaluation (2014-06-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (52032L, 16L), y_train: (52032L,)
# 				-->Computing Last value
# 					-->R2: -4.036
# 					-->MAE: 337.078
# 					-->MAPE: 83.560
# 					-->MASE: 1.212
# 				-->Computing Previous day
# 					-->R2: -4.062
# 					-->MAE: 298.059
# 					-->MAPE: 80.932
# 					-->MASE: 1.072
# 				-->Computing Previous week
# 					-->R2: 0.881
# 					-->MAE: 45.130
# 					-->MAPE: 9.841
# 					-->MASE: 0.162
# 			-->Dataset: TOP_20. X_train: (52032L, 20L), y_train: (52032L,)
# 				-->Training model: Random Forest, runtime: 6.43s
# 					-->R2: 0.226
# 					-->MAE: 101.182
# 					-->MAPE: 18.093
# 					-->MASE: 0.364
#
# 		-->Evaluation (2014-06-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (52128L, 16L), y_train: (52128L,)
# 				-->Computing Last value
# 					-->R2: -19.986
# 					-->MAE: 159.524
# 					-->MAPE: 62.502
# 					-->MASE: 0.573
# 				-->Computing Previous day
# 					-->R2: -17.927
# 					-->MAE: 170.582
# 					-->MAPE: 58.243
# 					-->MASE: 0.613
# 				-->Computing Previous week
# 					-->R2: 0.827
# 					-->MAE: 18.267
# 					-->MAPE: 5.824
# 					-->MASE: 0.066
# 			-->Dataset: TOP_20. X_train: (52128L, 20L), y_train: (52128L,)
# 				-->Training model: Random Forest, runtime: 6.45s
# 					-->R2: 0.641
# 					-->MAE: 26.024
# 					-->MAPE: 7.644
# 					-->MASE: 0.094
#
# 		-->Evaluation (2014-06-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (52224L, 16L), y_train: (52224L,)
# 				-->Computing Last value
# 					-->R2: -1.257
# 					-->MAE: 419.073
# 					-->MAPE: 48.063
# 					-->MASE: 1.507
# 				-->Computing Previous day
# 					-->R2: -1.395
# ...
# 				-->Training model: Random Forest, runtime: 9.15s
# 					-->R2: 0.984
# 					-->MAE: 38.065
# 					-->MAPE: 4.809
# 					-->MASE: 0.135
#
# 		-->Evaluation (2015-01-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (72096L, 16L), y_train: (72096L,)
# 				-->Computing Last value
# 					-->R2: -0.287
# 					-->MAE: 333.561
# 					-->MAPE: 59.216
# 					-->MASE: 1.183
# 				-->Computing Previous day
# 					-->R2: 0.966
# 					-->MAE: 54.603
# 					-->MAPE: 8.331
# 					-->MASE: 0.194
# 				-->Computing Previous week
# 					-->R2: 0.974
# 					-->MAE: 46.001
# 					-->MAPE: 6.613
# 					-->MASE: 0.163
# 			-->Dataset: TOP_20. X_train: (72096L, 20L), y_train: (72096L,)
# 				-->Training model: Random Forest, runtime: 10.20s
# 					-->R2: 0.981
# 					-->MAE: 39.655
# 					-->MAPE: 6.559
# 					-->MASE: 0.141
#
# 		-->Evaluation (2015-01-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (72192L, 16L), y_train: (72192L,)
# 				-->Computing Last value
# 					-->R2: -2.426
# 					-->MAE: 411.444
# 					-->MAPE: 99.689
# 					-->MASE: 1.458
# 				-->Computing Previous day
# 					-->R2: -1.706
# 					-->MAE: 322.987
# 					-->MAPE: 80.157
# 					-->MASE: 1.145
# 				-->Computing Previous week
# 					-->R2: 0.782
# 					-->MAE: 98.825
# 					-->MAPE: 21.445
# 					-->MASE: 0.350
# 			-->Dataset: TOP_20. X_train: (72192L, 20L), y_train: (72192L,)
# 				-->Training model: Random Forest, runtime: 10.58s
# 					-->R2: 0.858
# 					-->MAE: 78.264
# 					-->MAPE: 16.723
# 					-->MASE: 0.277
#
# 		-->Evaluation (2015-01-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (72288L, 16L), y_train: (72288L,)
# 				-->Computing Last value
# 					-->R2: -35.931
# 					-->MAE: 216.216
# 					-->MAPE: 91.797
# 					-->MASE: 0.766
# 				-->Computing Previous day
# 					-->R2: -38.165
# 					-->MAE: 263.573
# 					-->MAPE: 94.500
# 					-->MASE: 0.934
# 				-->Computing Previous week
# 					-->R2: 0.678
# 					-->MAE: 27.524
# 					-->MAPE: 9.323
# 					-->MASE: 0.098
# 			-->Dataset: TOP_20. X_train: (72288L, 20L), y_train: (72288L,)
# 				-->Training model: Random Forest, runtime: 9.76s
# 					-->R2: 0.564
# 					-->MAE: 32.907
# 					-->MAPE: 12.100
# 					-->MASE: 0.117
#
# 		-->Evaluation (2015-01-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (72384L, 16L), y_train: (72384L,)
# 				-->Computing Last value
# 					-->R2: -1.245
# 					-->MAE: 528.668
# 					-->MAPE: 54.595
# 					-->MASE: 1.873
# 				-->Computing Previous day
# 					-->R2: -1.401
# 					-->MAE: 535.047
# 					-->MAPE: 53.006
# 					-->MASE: 1.896
# 				-->Computing Previous week
# 					-->R2: 0.966
# 					-->MAE: 66.185
# 					-->MAPE: 10.990
# 					-->MASE: 0.235
# 			-->Dataset: TOP_20. X_train: (72384L, 20L), y_train: (72384L,)
# 				-->Training model: Random Forest, runtime: 11.76s
# 					-->R2: 0.953
# 					-->MAE: 78.345
# 					-->MAPE: 10.877
# 					-->MASE: 0.278
#
# 		-->Evaluation (2015-01-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (72480L, 16L), y_train: (72480L,)
# 				-->Computing Last value
# 					-->R2: -0.345
# 					-->MAE: 335.469
# 					-->MAPE: 52.444
# 					-->MASE: 1.187
# 				-->Computing Previous day
# 					-->R2: 0.786
# 					-->MAE: 103.168
# 					-->MAPE: 12.920
# 					-->MASE: 0.365
# 				-->Computing Previous week
# 					-->R2: 0.966
# 					-->MAE: 53.948
# 					-->MAPE: 7.659
# 					-->MASE: 0.191
# 			-->Dataset: TOP_20. X_train: (72480L, 20L), y_train: (72480L,)
# 				-->Training model: Random Forest, runtime: 10.28s
# 					-->R2: 0.987
# 					-->MAE: 35.445
# 					-->MAPE: 4.667
# 					-->MASE: 0.125
#
# 		-->Evaluation (2015-01-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (72576L, 16L), y_train: (72576L,)
# 				-->Computing Last value
# 					-->R2: -0.491
# 					-->MAE: 346.523
# 					-->MAPE: 49.184
# 					-->MASE: 1.226
# 				-->Computing Previous day
# 					-->R2: 0.974
# 					-->MAE: 48.379
# 					-->MAPE: 6.169
# 					-->MASE: 0.171
# 				-->Computing Previous week
# 					-->R2: 0.970
# 					-->MAE: 47.030
# 					-->MAPE: 6.426
# 					-->MASE: 0.166
# 			-->Dataset: TOP_20. X_train: (72576L, 20L), y_train: (72576L,)
# 				-->Training model: Random Forest, runtime: 11.80s
# 					-->R2: 0.979
# 					-->MAE: 43.020
# 					-->MAPE: 5.752
# 					-->MASE: 0.152
#
# 		-->Evaluation (2015-01-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (72672L, 16L), y_train: (72672L,)
# 				-->Computing Last value
# 					-->R2: -0.220
# 					-->MAE: 319.006
# 					-->MAPE: 44.314
# 					-->MASE: 1.129
# 				-->Computing Previous day
# 					-->R2: 0.986
# 					-->MAE: 35.539
# 					-->MAPE: 4.414
# 					-->MASE: 0.126
# 				-->Computing Previous week
# 					-->R2: 0.958
# 					-->MAE: 56.569
# 					-->MAPE: 7.690
# 					-->MASE: 0.200
# 			-->Dataset: TOP_20. X_train: (72672L, 20L), y_train: (72672L,)
# 				-->Training model: Random Forest, runtime: 10.38s
# 					-->R2: 0.978
# 					-->MAE: 44.052
# 					-->MAPE: 5.188
# 					-->MASE: 0.156
#
# 		-->Evaluation (2015-01-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (72768L, 16L), y_train: (72768L,)
# 				-->Computing Last value
# 					-->R2: -0.345
# 					-->MAE: 336.006
# 					-->MAPE: 48.255
# 					-->MASE: 1.188
# 				-->Computing Previous day
# 					-->R2: 0.971
# 					-->MAE: 45.174
# 					-->MAPE: 5.439
# 					-->MASE: 0.160
# 				-->Computing Previous week
# 					-->R2: 0.929
# 					-->MAE: 81.730
# 					-->MAPE: 11.114
# 					-->MASE: 0.289
# 			-->Dataset: TOP_20. X_train: (72768L, 20L), y_train: (72768L,)
# 				-->Training model: Random Forest, runtime: 11.89s
# 					-->R2: 0.969
# 					-->MAE: 46.953
# 					-->MAPE: 5.457
# 					-->MASE: 0.166
#
# 		-->Evaluation (2015-01-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (72864L, 16L), y_train: (72864L,)
# 				-->Computing Last value
# 					-->R2: -2.288
# 					-->MAE: 396.326
# 					-->MAPE: 71.139
# 					-->MASE: 1.401
# 				-->Computing Previous day
# 					-->R2: -2.126
# 					-->MAE: 326.343
# 					-->MAPE: 65.195
# 					-->MASE: 1.154
# 				-->Computing Previous week
# 					-->R2: 0.677
# 					-->MAE: 123.897
# 					-->MAPE: 21.202
# 					-->MASE: 0.438
# 			-->Dataset: TOP_20. X_train: (72864L, 20L), y_train: (72864L,)
# 				-->Training model: Random Forest, runtime: 9.90s
# 					-->R2: 0.809
# 					-->MAE: 83.171
# 					-->MAPE: 13.650
# 					-->MASE: 0.294
#
# 		-->Evaluation (2015-02-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (72960L, 16L), y_train: (72960L,)
# 				-->Computing Last value
# 					-->R2: -22.958
# 					-->MAE: 271.772
# 					-->MAPE: 93.869
# 					-->MASE: 0.961
# 				-->Computing Previous day
# 					-->R2: -24.515
# 					-->MAE: 319.870
# 					-->MAPE: 97.607
# 					-->MASE: 1.131
# 				-->Computing Previous week
# 					-->R2: -0.024
# 					-->MAE: 71.466
# 					-->MAPE: 18.568
# 					-->MASE: 0.253
# 			-->Dataset: TOP_20. X_train: (72960L, 20L), y_train: (72960L,)
# 				-->Training model: Random Forest, runtime: 12.42s
# 					-->R2: 0.432
# 					-->MAE: 49.075
# 					-->MAPE: 12.683
# 					-->MASE: 0.173
#
# 		-->Evaluation (2015-02-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (73056L, 16L), y_train: (73056L,)
# 				-->Computing Last value
# 					-->R2: -30.269
# 					-->MAE: 137.731
# 					-->MAPE: 32.270
# 					-->MASE: 0.487
# 				-->Computing Previous day
# 					-->R2: -5.587
# 					-->MAE: 60.144
# 					-->MAPE: 14.021
# 					-->MASE: 0.213
# 				-->Computing Previous week
# 					-->R2: -10.697
# 					-->MAE: 76.994
# 					-->MAPE: 17.697
# 					-->MASE: 0.272
# 			-->Dataset: TOP_20. X_train: (73056L, 20L), y_train: (73056L,)
# 				-->Training model: Random Forest, runtime: 11.63s
# 					-->R2: 0.298
# 					-->MAE: 17.052
# 					-->MAPE: 4.051
# 					-->MASE: 0.060
#                                true  last value  previous day  previous week  \
# horizons values
# 20       2014-04-17 00:00:00  688.0       442.0         688.0          804.1
#          2014-04-17 00:15:00  689.2       431.1         688.2          820.0
#          2014-04-17 00:30:00  683.4       419.3         660.0          825.2
#          2014-04-17 00:45:00  678.2       425.2         650.5          821.0
#          2014-04-17 01:00:00  667.0       407.0         654.0          797.8
#          2014-04-17 01:15:00  613.1       383.1         625.1          766.0
#          2014-04-17 01:30:00  582.0       381.1         591.1          789.1
#          2014-04-17 01:45:00  508.2       375.1         578.1          710.1
#          2014-04-17 02:00:00  449.3       362.5         493.0          579.1
#          2014-04-17 02:15:00  397.1       484.1         459.5          535.1
#          2014-04-17 02:30:00  417.0       448.0         437.0          535.1
#          2014-04-17 02:45:00  397.1       418.1         432.1          531.0
#          2014-04-17 03:00:00  378.1       396.1         446.0          441.2
#          2014-04-17 03:15:00  385.5       416.3         444.6          409.2
#          2014-04-17 03:30:00  374.1       405.1         426.0          428.2
#          2014-04-17 03:45:00  385.1       387.1         428.2          425.4
#          2014-04-17 04:00:00  409.0       386.0         442.0          409.1
#          2014-04-17 04:15:00  406.3       378.2         431.1          405.0
#          2014-04-17 04:30:00  359.1       426.4         419.3          413.2
#          2014-04-17 04:45:00  361.1       426.2         425.2          409.0
#          2014-04-17 05:00:00  368.1       438.0         407.0          423.1
#          2014-04-17 05:15:00  393.1       593.2         383.1          387.0
#          2014-04-17 05:30:00  367.0       604.2         381.1          377.2
#          2014-04-17 05:45:00  368.5       646.1         375.1          377.3
#          2014-04-17 06:00:00  357.1       694.1         362.5          384.1
#          2014-04-17 06:15:00  367.1       942.0         484.1          471.4
#          2014-04-17 06:30:00  354.3      1065.0         448.0          490.2
#          2014-04-17 06:45:00  353.1      1130.0         418.1          459.0
#          2014-04-17 07:00:00  332.1      1222.1         396.1          453.2
#          2014-04-17 07:15:00  354.1      1307.0         416.3          442.0
# ...                             ...         ...           ...            ...
#          2015-01-31 20:30:00  422.5       408.2         401.5          351.5
#          2015-01-31 20:45:00  433.6       414.2         390.6          339.0
#          2015-01-31 21:00:00  454.5       382.7         390.4          345.3
#          2015-01-31 21:15:00  474.2       371.0         447.9          360.9
#          2015-01-31 21:30:00  514.8       366.5         456.4          376.4
#          2015-01-31 21:45:00  506.9       364.3         453.3          402.6
#          2015-01-31 22:00:00  486.3       370.2         433.5          380.7
#          2015-01-31 22:15:00  440.5       383.5         450.7          333.6
#          2015-01-31 22:30:00  428.9       370.7         447.4          373.0
#          2015-01-31 22:45:00  441.8       333.2         426.9          390.0
#          2015-01-31 23:00:00  429.3       331.5         452.4          391.1
#          2015-01-31 23:15:00  459.5       325.9         415.8          390.9
#          2015-01-31 23:30:00  472.9       328.3         398.1          432.4
#          2015-01-31 23:45:00  441.4       337.8         371.9          374.7
#          2015-02-01 00:00:00  428.3       344.6         393.8          345.5
#          2015-02-01 00:15:00  423.6       320.0         397.6          348.2
#          2015-02-01 00:30:00  448.7       315.8         408.2          332.9
#          2015-02-01 00:45:00  442.6       310.1         414.2          323.1
#          2015-02-01 01:00:00  457.5       302.1         382.7          342.2
#          2015-02-01 01:15:00  475.9       311.6         371.0          413.3
#          2015-02-01 01:30:00  442.6       336.7         366.5          364.7
#          2015-02-01 01:45:00  451.7       320.3         364.3          360.6
#          2015-02-01 02:00:00  440.5       280.4         370.2          340.1
#          2015-02-01 02:15:00  411.0       272.4         383.5          314.4
#          2015-02-01 02:30:00  424.8       259.7         370.7          300.9
#          2015-02-01 02:45:00  419.3       247.4         333.2          324.5
#          2015-02-01 03:00:00  396.1       264.5         331.5          364.3
#          2015-02-01 03:15:00  380.4       278.1         325.9          381.1
#          2015-02-01 03:30:00  396.7       244.5         328.3          386.4
#          2015-02-01 03:45:00  402.0       229.8         337.8          369.0
#
#                                  offline       batch
# horizons values
# 20       2014-04-17 00:00:00  682.366801  694.252639
#          2014-04-17 00:15:00  682.286978  696.561533
#          2014-04-17 00:30:00  671.041029  677.890560
#          2014-04-17 00:45:00  666.460549  676.950551
#          2014-04-17 01:00:00  667.451044  678.691123
#          2014-04-17 01:15:00  646.735591  658.474373
#          2014-04-17 01:30:00  637.114283  646.659325
#          2014-04-17 01:45:00  614.890591  634.784244
#          2014-04-17 02:00:00  499.680962  481.921363
#          2014-04-17 02:15:00  489.970841  472.628955
#          2014-04-17 02:30:00  456.554244  445.504685
#          2014-04-17 02:45:00  450.476349  443.342501
#          2014-04-17 03:00:00  462.901610  453.529083
#          2014-04-17 03:15:00  441.810999  432.943514
#          2014-04-17 03:30:00  424.090411  430.759467
#          2014-04-17 03:45:00  428.313705  433.278901
#          2014-04-17 04:00:00  437.107280  435.526632
#          2014-04-17 04:15:00  428.203523  431.155450
#          2014-04-17 04:30:00  423.727783  428.023040
#          2014-04-17 04:45:00  424.724588  432.458673
#          2014-04-17 05:00:00  414.592147  415.744484
#          2014-04-17 05:15:00  405.558176  404.311573
#          2014-04-17 05:30:00  391.300934  388.243653
#          2014-04-17 05:45:00  392.423456  386.287239
#          2014-04-17 06:00:00  377.805002  380.469954
#          2014-04-17 06:15:00  471.540511  477.103466
#          2014-04-17 06:30:00  454.845458  453.757637
#          2014-04-17 06:45:00  429.473689  433.701703
#          2014-04-17 07:00:00  411.531934  420.622167
#          2014-04-17 07:15:00  422.855578  428.423115
# ...                                  ...         ...
#          2015-01-31 20:30:00  378.926713  383.821016
#          2015-01-31 20:45:00  379.122105  382.914829
#          2015-01-31 21:00:00  379.747925  383.862296
#          2015-01-31 21:15:00  379.806420  396.585575
#          2015-01-31 21:30:00  404.383214  397.469412
#          2015-01-31 21:45:00  437.914363  403.455346
#          2015-01-31 22:00:00  419.594996  401.206078
#          2015-01-31 22:15:00  376.034026  389.172159
#          2015-01-31 22:30:00  395.173105  398.419342
#          2015-01-31 22:45:00  426.377447  400.580823
#          2015-01-31 23:00:00  433.327099  399.256958
#          2015-01-31 23:15:00  427.992552  398.936283
#          2015-01-31 23:30:00  413.125922  405.035068
#          2015-01-31 23:45:00  401.582768  392.875121
#          2015-02-01 00:00:00  400.792114  453.934379
#          2015-02-01 00:15:00  404.048511  454.643927
#          2015-02-01 00:30:00  393.638691  446.919041
#          2015-02-01 00:45:00  384.581871  441.371504
#          2015-02-01 01:00:00  384.555196  446.902560
#          2015-02-01 01:15:00  403.542458  440.276039
#          2015-02-01 01:30:00  403.583547  442.977142
#          2015-02-01 01:45:00  393.545539  437.754135
#          2015-02-01 02:00:00  374.279267  441.991251
#          2015-02-01 02:15:00  376.958817  428.389168
#          2015-02-01 02:30:00  375.116481  388.400782
#          2015-02-01 02:45:00  366.305335  430.982020
#          2015-02-01 03:00:00  377.182313  415.599552
#          2015-02-01 03:15:00  394.065765  415.724600
#          2015-02-01 03:30:00  392.144186  412.893808
#          2015-02-01 03:45:00  379.255127  416.621310
#
# [27856 rows x 6 columns]
# Finished.
# C:\Python27\lib\site-packages\ipykernel\__main__.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# read from csv
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)
test =  pd.read_csv(input_file_path, index_col=[0,1])

test
# Out:
#                                true  last value  previous day  previous week  \
# horizons values
# 20       2014-04-17 00:00:00  688.0       442.0         688.0          804.1
#          2014-04-17 00:15:00  689.2       431.1         688.2          820.0
#          2014-04-17 00:30:00  683.4       419.3         660.0          825.2
#          2014-04-17 00:45:00  678.2       425.2         650.5          821.0
#          2014-04-17 01:00:00  667.0       407.0         654.0          797.8
#          2014-04-17 01:15:00  613.1       383.1         625.1          766.0
#          2014-04-17 01:30:00  582.0       381.1         591.1          789.1
#          2014-04-17 01:45:00  508.2       375.1         578.1          710.1
#          2014-04-17 02:00:00  449.3       362.5         493.0          579.1
#          2014-04-17 02:15:00  397.1       484.1         459.5          535.1
#          2014-04-17 02:30:00  417.0       448.0         437.0          535.1
#          2014-04-17 02:45:00  397.1       418.1         432.1          531.0
#          2014-04-17 03:00:00  378.1       396.1         446.0          441.2
#          2014-04-17 03:15:00  385.5       416.3         444.6          409.2
#          2014-04-17 03:30:00  374.1       405.1         426.0          428.2
#          2014-04-17 03:45:00  385.1       387.1         428.2          425.4
#          2014-04-17 04:00:00  409.0       386.0         442.0          409.1
#          2014-04-17 04:15:00  406.3       378.2         431.1          405.0
#          2014-04-17 04:30:00  359.1       426.4         419.3          413.2
#          2014-04-17 04:45:00  361.1       426.2         425.2          409.0
#          2014-04-17 05:00:00  368.1       438.0         407.0          423.1
#          2014-04-17 05:15:00  393.1       593.2         383.1          387.0
#          2014-04-17 05:30:00  367.0       604.2         381.1          377.2
#          2014-04-17 05:45:00  368.5       646.1         375.1          377.3
#          2014-04-17 06:00:00  357.1       694.1         362.5          384.1
#          2014-04-17 06:15:00  367.1       942.0         484.1          471.4
#          2014-04-17 06:30:00  354.3      1065.0         448.0          490.2
#          2014-04-17 06:45:00  353.1      1130.0         418.1          459.0
#          2014-04-17 07:00:00  332.1      1222.1         396.1          453.2
#          2014-04-17 07:15:00  354.1      1307.0         416.3          442.0
# ...                             ...         ...           ...            ...
#          2015-01-31 20:30:00  422.5       408.2         401.5          351.5
#          2015-01-31 20:45:00  433.6       414.2         390.6          339.0
#          2015-01-31 21:00:00  454.5       382.7         390.4          345.3
#          2015-01-31 21:15:00  474.2       371.0         447.9          360.9
#          2015-01-31 21:30:00  514.8       366.5         456.4          376.4
#          2015-01-31 21:45:00  506.9       364.3         453.3          402.6
#          2015-01-31 22:00:00  486.3       370.2         433.5          380.7
#          2015-01-31 22:15:00  440.5       383.5         450.7          333.6
#          2015-01-31 22:30:00  428.9       370.7         447.4          373.0
#          2015-01-31 22:45:00  441.8       333.2         426.9          390.0
#          2015-01-31 23:00:00  429.3       331.5         452.4          391.1
#          2015-01-31 23:15:00  459.5       325.9         415.8          390.9
#          2015-01-31 23:30:00  472.9       328.3         398.1          432.4
#          2015-01-31 23:45:00  441.4       337.8         371.9          374.7
#          2015-02-01 00:00:00  428.3       344.6         393.8          345.5
#          2015-02-01 00:15:00  423.6       320.0         397.6          348.2
#          2015-02-01 00:30:00  448.7       315.8         408.2          332.9
#          2015-02-01 00:45:00  442.6       310.1         414.2          323.1
#          2015-02-01 01:00:00  457.5       302.1         382.7          342.2
#          2015-02-01 01:15:00  475.9       311.6         371.0          413.3
#          2015-02-01 01:30:00  442.6       336.7         366.5          364.7
#          2015-02-01 01:45:00  451.7       320.3         364.3          360.6
#          2015-02-01 02:00:00  440.5       280.4         370.2          340.1
#          2015-02-01 02:15:00  411.0       272.4         383.5          314.4
#          2015-02-01 02:30:00  424.8       259.7         370.7          300.9
#          2015-02-01 02:45:00  419.3       247.4         333.2          324.5
#          2015-02-01 03:00:00  396.1       264.5         331.5          364.3
#          2015-02-01 03:15:00  380.4       278.1         325.9          381.1
#          2015-02-01 03:30:00  396.7       244.5         328.3          386.4
#          2015-02-01 03:45:00  402.0       229.8         337.8          369.0
#
#                                  offline       batch
# horizons values
# 20       2014-04-17 00:00:00  687.957716  696.270514
#          2014-04-17 00:15:00  685.822340  696.725287
#          2014-04-17 00:30:00  664.764466  676.037732
#          2014-04-17 00:45:00  668.541916  678.472837
#          2014-04-17 01:00:00  667.355127  677.697051
#          2014-04-17 01:15:00  650.004936  661.627896
#          2014-04-17 01:30:00  643.518840  643.293239
#          2014-04-17 01:45:00  621.510374  634.470303
#          2014-04-17 02:00:00  494.991698  482.393281
#          2014-04-17 02:15:00  479.413369  473.298785
#          2014-04-17 02:30:00  451.918368  443.948290
#          2014-04-17 02:45:00  449.750804  440.884256
#          2014-04-17 03:00:00  458.193694  450.575849
#          2014-04-17 03:15:00  445.555378  440.129001
#          2014-04-17 03:30:00  431.217224  438.608742
#          2014-04-17 03:45:00  432.277843  441.583508
#          2014-04-17 04:00:00  437.164831  434.604664
#          2014-04-17 04:15:00  431.230141  432.657950
#          2014-04-17 04:30:00  421.850925  427.639428
#          2014-04-17 04:45:00  425.169013  429.536535
#          2014-04-17 05:00:00  410.690367  414.025831
#          2014-04-17 05:15:00  407.005761  402.623390
#          2014-04-17 05:30:00  387.584023  387.628154
#          2014-04-17 05:45:00  386.427298  382.606902
#          2014-04-17 06:00:00  379.149748  379.687360
#          2014-04-17 06:15:00  479.147194  470.637342
#          2014-04-17 06:30:00  452.791491  452.337094
#          2014-04-17 06:45:00  426.393164  427.652831
#          2014-04-17 07:00:00  417.390984  414.716243
#          2014-04-17 07:15:00  420.631205  417.240643
# ...                                  ...         ...
#          2015-01-31 20:30:00  381.542062  387.546397
#          2015-01-31 20:45:00  380.432823  386.797884
#          2015-01-31 21:00:00  382.873960  387.254632
#          2015-01-31 21:15:00  387.136777  398.739011
#          2015-01-31 21:30:00  404.556057  399.903001
#          2015-01-31 21:45:00  436.245584  402.066840
#          2015-01-31 22:00:00  417.924778  401.118137
#          2015-01-31 22:15:00  377.564454  390.558335
#          2015-01-31 22:30:00  390.115024  399.732238
#          2015-01-31 22:45:00  425.051723  395.710080
#          2015-01-31 23:00:00  431.956521  394.030188
#          2015-01-31 23:15:00  422.243969  393.350405
#          2015-01-31 23:30:00  412.692055  401.059483
#          2015-01-31 23:45:00  408.266154  391.105412
#          2015-02-01 00:00:00  404.779654  451.179301
#          2015-02-01 00:15:00  406.967397  448.112897
#          2015-02-01 00:30:00  396.926094  452.586687
#          2015-02-01 00:45:00  386.261393  449.399416
#          2015-02-01 01:00:00  391.150437  447.854351
#          2015-02-01 01:15:00  411.066676  427.104496
#          2015-02-01 01:30:00  410.323369  433.981935
#          2015-02-01 01:45:00  400.789068  431.557262
#          2015-02-01 02:00:00  377.020927  438.421799
#          2015-02-01 02:15:00  371.861962  425.734337
#          2015-02-01 02:30:00  373.687178  378.872484
#          2015-02-01 02:45:00  371.948319  437.200974
#          2015-02-01 03:00:00  379.750587  415.444073
#          2015-02-01 03:15:00  396.132389  416.283892
#          2015-02-01 03:30:00  395.757916  413.177902
#          2015-02-01 03:45:00  379.354875  416.621532
#
# [27856 rows x 6 columns]

# %%
test.loc[20]['2014-04-17 00:00:00':'2014-04-20 00:00:00'][['true','offline','batch']].plot(figsize=(15,4))
test.loc[20]['2015-01-27 00:00:00':'2015-02-01 23:59:00'][['true','offline','batch']].plot(figsize=(15,4))

# %%
a=test.loc[20].groupby(test.index.to_datetime().dayofyear, sort=False).mean()
a
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-3e6c165fb994> in <module>()
# ----> 1 a=test.loc[20].groupby(test.index.to_datetime().dayofyear, sort=False).mean()
#       2 a
#
# C:\Python27\lib\site-packages\pandas\core\indexes\base.pyc in to_datetime(self, dayfirst)
#    1024             return DatetimeIndex(parsed)
#    1025         else:
# -> 1026             return DatetimeIndex(self.values)
#    1027
#    1028     def _assert_can_do_setop(self, other):
#
# C:\Python27\lib\site-packages\pandas\util\_decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# C:\Python27\lib\site-packages\pandas\core\indexes\datetimes.pyc in __new__(cls, data, freq, start, end, periods, copy, name, tz, verify_integrity, normalize, closed, ambiguous, dtype, **kwargs)
#     333                 is_integer_dtype(data)):
#     334             data = tools.to_datetime(data, dayfirst=dayfirst,
# --> 335                                      yearfirst=yearfirst)
#     336
#     337         if issubclass(data.dtype.type, np.datetime64) or is_datetimetz(data):
#
# C:\Python27\lib\site-packages\pandas\core\tools\datetimes.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     514         result = _convert_listlike(arg, box, format, name=arg.name)
#     515     elif is_list_like(arg):
# --> 516         result = _convert_listlike(arg, box, format)
#     517     else:
#     518         result = _convert_listlike(np.array([arg]), box, format)[0]
#
# C:\Python27\lib\site-packages\pandas\core\tools\datetimes.pyc in _convert_listlike(arg, box, format, name, tz)
#     433                     dayfirst=dayfirst,
#     434                     yearfirst=yearfirst,
# --> 435                     require_iso8601=require_iso8601
#     436                 )
#     437
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime (pandas\_libs\tslib.c:46617)()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime (pandas\_libs\tslib.c:46321)()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime (pandas\_libs\tslib.c:45268)()
#
# TypeError: <type 'tuple'> is not convertible to datetime

# %%
from sklearn.metrics import r2_score

def r2( g ):
    r2_lv = r2_score( g['true'], g['last value'] )
    r2_pd = r2_score( g['true'], g['previous day'] )
    r2_pw = r2_score( g['true'], g['previous week'] )
    r2_offline = r2_score( g['true'], g['offline'] )
    r2_batch = r2_score( g['true'], g['batch'] )
    return pd.Series( dict(  r2_lv=r2_lv, r2_pd=r2_pd, r2_pw=r2_pw, r2_offline=r2_offline, r2_batch=r2_batch ) )

#subset = test['2014-04-17 00:00:00':'2014-04-27 00:00:00']
subset = test.loc[20]['2015-01-05 00:00:00':'2015-02-01 23:59:00']
#subset = test['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)
a
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:14: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#     r2_batch      r2_lv  r2_offline      r2_pd      r2_pw
# 5   0.803031  -0.523683    0.779073   0.676658  -1.924356
# 6   0.978347  -0.311814    0.962896   0.983248  -3.142257
# 7   0.984944  -0.237250    0.946753   0.987545  -3.294934
# 8   0.945661  -0.386345    0.942638   0.928803  -1.180523
# 9   0.865746  -3.774695    0.824096  -2.466987  -0.560880
# 10  0.745570 -32.352578    0.638292 -33.563672   0.069094
# 11  0.423213  -1.066683    0.949106  -1.191521   0.952132
# 12  0.955328  -0.327135    0.935104   0.872044   0.938378
# 13  0.837279  -0.173000    0.981980   0.971693   0.968808
# 14  0.975735  -0.288703    0.970112   0.976642   0.959743
# 15  0.984985  -0.365000    0.984335   0.989621   0.965464
# 16  0.577250  -1.370766    0.685678  -1.168444   0.662644
# 17 -1.428410 -48.645939   -1.086162 -50.648963   0.547027
# 18  0.446053  -1.035071    0.941896  -1.172346   0.963995
# 19  0.985471  -0.319779    0.970727   0.821941   0.966552
# 20  0.876166  -0.356005    0.981873   0.982423   0.970598
# 21  0.982706  -0.267330    0.971806   0.981174   0.969248
# 22  0.979881  -0.275869    0.981297   0.965534   0.974418
# 23  0.858615  -2.447344    0.819515  -1.691798   0.780318
# 24  0.563752 -36.140234    0.469729 -38.413759   0.677935
# 25  0.962227  -1.231820    0.961551  -1.386347   0.966062
# 26  0.987729  -0.330286    0.971563   0.785638   0.966280
# 27  0.979856  -0.475936    0.975833   0.974036   0.970215
# 28  0.979646  -0.204858    0.977113   0.985636   0.957945
# 29  0.968811  -0.326641    0.965894   0.971342   0.929163
# 30  0.806908  -2.322538    0.625178  -2.123285   0.673689
# 31  0.441976 -23.077583   -0.173770 -24.652630  -0.019004
# 32  0.112261 -30.269497   -2.016212  -5.587368 -10.696844

# %% [markdown]
# Bar plot for last month. Major improvement for batch is not visible.

# %%
a[['r2_offline','r2_batch']].plot( kind='bar', figsize=(15,4), ylim=(-3, 1.1))

# %% [markdown]
# Diff is not very informative

# %%
#subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
#a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]
b['diff'] = b['r2_batch'] - b['r2_offline']
b.reset_index()['diff'].plot()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Scatter plot for entire testing dataset.

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]
#a[['r2_offline','r2_batch']].plot( kind='hist', figsize=(15,4))
#a[['r2_offline','r2_batch']].hist(figsize=(15,4), bins=20)
#a[['r2_offline','r2_batch']].plot.hist(bins=30)
b[b > 0].plot.hist(bins=30, alpha=0.8)
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

b = a[['r2_offline','r2_batch']]

c = b[b > 0].reset_index()[['r2_offline','r2_batch']]

c = c.fillna(0)

x = c["r2_offline"].values
y = c["r2_batch"].values
data = np.vstack([x, y]).T
bins = np.linspace(0, 1, 30)

plt.hist(data, bins, alpha=0.7, label=['Offline', 'Batch'])
plt.legend(loc='upper right')
plt.show()

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]

#a[['r2_offline','r2_batch']].plot( figsize=(15,4), marker='*')
b[b > 0].reset_index()[['r2_offline','r2_batch']].plot( figsize=(15,4), marker='.', linestyle='')
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %% [markdown]
# Scatter plot for entire testing dataset with regression plot trend, showing that Batch is better. Unfortunatelly the trend is downword. Maybe try with different sensor.

# %%
import seaborn as sns

sns.set_style("white")

subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]

#c = b.reset_index()[['r2_offline','r2_batch']]
c = b[b > 0].reset_index()[['r2_offline','r2_batch']]
c = c.fillna(0)
c['index'] = c.index

plt.figure(figsize=(13,4))
#sns.pairplot(c, size=5, aspect=.8, kind="reg");
g = sns.regplot(y="r2_offline", x="index", data=c, label='Offline');
g.set(xlim=(0,300), ylim=(0,1))
sns.regplot(y="r2_batch", x="index", data=c, label='Batch');

plt.legend(loc='upper right')
plt.show()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)

# %%
import scipy

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[0].get_xdata(),y=g.get_lines()[0].get_ydata())
print "Offline slope:", slope

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[1].get_xdata(),y=g.get_lines()[1].get_ydata())
print "Batch slope:", slope
# Out:
# Offline slope: -0.000181916450663
# Batch slope: -4.29949639811e-05

# %% [markdown]
# ## MAPE analysis

# %%
import regression_metrics as additional_metrics

def mape(g):
    mape_lv = additional_metrics.mean_absolute_percentage_error( g['true'], g['last value'] )
    mape_pd = additional_metrics.mean_absolute_percentage_error( g['true'], g['previous day'] )
    mape_pw = additional_metrics.mean_absolute_percentage_error( g['true'], g['previous week'] )
    mape_offline = additional_metrics.mean_absolute_percentage_error( g['true'], g['offline'] )
    mape_batch = additional_metrics.mean_absolute_percentage_error( g['true'], g['batch'] )
    return pd.Series( dict(  mape_lv=mape_lv, mape_pd=mape_pd, mape_pw=mape_pw, mape_offline=mape_offline, mape_batch=mape_batch ) )

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(mape)
a

b = a[['mape_offline','mape_batch']]

c = b[b > 0].reset_index()[['mape_offline','mape_batch']]
c = c.fillna(0)
c['index'] = c.index

plt.figure(figsize=(13,4))
#sns.pairplot(c, size=5, aspect=.8, kind="reg");
g = sns.regplot(y="mape_offline", x="index", data=c, label='Offline');
g.set(xlim=(0,300), ylim=(0,70))
sns.regplot(y="mape_batch", x="index", data=c, label='Batch');

plt.legend(loc='upper right')
plt.show()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Future work

# %% [markdown]
# - more horizons
# - more sensors
# - online approach
