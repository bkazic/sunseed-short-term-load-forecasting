# %% [markdown]
# # Results Analysis

# %%
# %matplotlib inline
import matplotlib as mpl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import numpy as np
import os
import time
from datetime import timedelta

# %% [markdown]
# ### Load dataset

# %%
input_file_name = "lotOfFeatures.csv"
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), input_file_name)

original_data = pd.read_csv(input_file_path, index_col=0, parse_dates=True)
originalSize = original_data.shape[1]
original_data.head()
original_data.shape
# Out:
# (139678, 535)

# %% [markdown]
# ## Excluding Testing Set

# %% [markdown]
# Spliting the dataset into three parts: training, testing and evaluation (last 10 percent).

# %%
start_time = '2012-02-01 00:00:00'
#start_time = '2014-02-01 00:00:00'
splitting_point = int(0.8 * original_data.shape[0])
splitting_time = original_data.iloc[[splitting_point]].index.to_pydatetime()[0]
#data = original_data[:splitting_time]
data = original_data[start_time:]

# %%
splitting_time
# Out:
# datetime.datetime(2014, 4, 17, 0, 0)

# %%
f = original_data[["id12041992"]].plot(figsize=(20,5)) 
original_data.iloc(splitting_point)
f.axvline(start_time, color='g')
f.axvline(splitting_time, color='r')

# %% [markdown]
# # Define Machine Learning Models and Data Sets

# %%
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import svm
from sklearn import neighbors
from sklearn import metrics
import regression_metrics as additional_metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.learning_curve import learning_curve
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import explained_variance_score
#from neural_network import PyBrainNN

# %% [markdown]
# ## Creating Feature Sets

# %%
autoregressive_ftrs = ['measurement', 'shifted_measurement_1d', 'shifted_measurement_2d', 'shifted_measurement_1w', 
                       'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_mean_d', 
                       'measurement_roll_mean_w', 'measurement_roll_mean_m', 'measurement_roll_min2_d',
                       'measurement_roll_min2_w', 'measurement_roll_max2_d', 'measurement_roll_max2_w',
                       'measurement_roll_var_6h', 'measurement_roll_var_d', 'measurement_roll_var_w']

wetaher_current_ftrs =  ['p', 't2m_termin', 'rh_termin', 'padavine', 'veter_hitrost', 'veter_vek_smer', 'energija_gl',
 'energija_di', 'p_roll_mean_1h', 'p_roll_mean_6h', 'p_roll_mean_d', 'p_roll_mean_w', 'p_roll_mean_m', 'p_roll_var_1h',
 'p_roll_var_d', 't2m_termin_roll_mean_1h', 't2m_termin_roll_mean_6h', 't2m_termin_roll_mean_d', 't2m_termin_roll_mean_w',
 't2m_termin_roll_mean_m', 't2m_termin_roll_min2_d', 't2m_termin_roll_min2_w', 't2m_termin_roll_max2_d',
 't2m_termin_roll_max2_w', 't2m_termin_roll_var_1h', 't2m_termin_roll_var_d', 'rh_termin_roll_mean_1h',
 'rh_termin_roll_mean_6h', 'rh_termin_roll_mean_d', 'rh_termin_roll_mean_w', 'rh_termin_roll_mean_m',
 'rh_termin_roll_min2_d', 'rh_termin_roll_min2_w', 'rh_termin_roll_max2_d', 'rh_termin_roll_max2_w',
 'rh_termin_roll_var_1h', 'rh_termin_roll_var_d', 'energija_gl_roll_mean_1h', 'energija_gl_roll_mean_6h',
 'energija_gl_roll_mean_d', 'energija_gl_roll_mean_w', 'energija_gl_roll_mean_m', 'energija_gl_roll_var_1h',
 'energija_gl_roll_var_d']

weather_forecasted_ftrs =  ['shifted_p', 'shifted_t2m_termin', 'shifted_rh_termin', 'shifted_padavine', 
                            'shifted_veter_hitrost', 'shifted_veter_vek_smer', 'shifted_energija_gl']

date_time_ftrs =  ['shifted_HourOfDay', 'shifted_DayOfWeek', 'shifted_Month', 'shifted_Weekday', 'shifted_Weekend', 
                   'shifted_Holiday', 'shifted_DayBeforeHoliday', 'shifted_DayAfterHodliay', 'shifted_BusinessDay', 
                   'shifted_BusinessDay_sum', 'shifted_Holiday_sum']

top20_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay', 't2m_termin_roll_mean_m', 'shifted_Holiday', 
              'shifted_energija_gl', 'shifted_DayOfWeek', 'shifted_t2m_termin', 'p_roll_var_d', 'shifted_measurement_2d', 
              'measurement_roll_mean_m', 'p_roll_mean_m', 'rh_termin_roll_mean_w']

top10_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay']

# %%
all_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_wc_wf_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs
ar_wc_dt_ftrs = autoregressive_ftrs + wetaher_current_ftrs + date_time_ftrs 
ar_wf_dt_ftrs = autoregressive_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_dt_ftrs = autoregressive_ftrs + date_time_ftrs 
ar_ftrs = autoregressive_ftrs
top20_ftrs = top20_ftrs
top10_ftrs = top10_ftrs

# %% [markdown]
# ## Prediction Results

# %%
class NaiveModel:
    
    def __init__(self, target):
        self.target = target

# %%
horizons = range(1,25)

baselines = [{'name': "Last value", 'init': "NaiveModel('measurement')"},
             {'name': "Previous day", 'init': "NaiveModel('shifted_measurement_1d')"},
             {'name': "Previous week", 'init': "NaiveModel('shifted_measurement_1w')"},
             #{'name': "Measurement average", 'init': "NaiveModel('measurement_avr')"},
            ]

models = [#{'name': "Ridge Regression", 'init': "linear_model.Ridge()"},
          #{'name': "K Nearest Neighbors", 'init': "neighbors.KNeighborsRegressor(n_neighbors = 5)"},
          {'name': "Random Forest", 'init': "RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, n_jobs=16)"},
          #{'name': "SVR", 'init': "svm.SVR(kernel ='rbf', C = 10, gamma = .001)"},
          #{'name': "Neural Network", 'init': "PyBrainNN(hidden_size = 100, learningrate = 0.001, momentum = 0.1, maxEpochs=10)"},
          ]

data_sets = [{'name': "Baselines", 'ftrs': ar_ftrs},
             #{'name': "AR", 'ftrs': ar_ftrs},
             #{'name': "AR_WC_WF", 'ftrs': ar_wc_wf_ftrs},
             #{'name': "AR_DT", 'ftrs': ar_dt_ftrs},             
             #{'name': "AR_WC_DT", 'ftrs': ar_wc_dt_ftrs},
             #{'name': "AR_WF_DT", 'ftrs': ar_wf_dt_ftrs},    
             #{'name': "ALL", 'ftrs': all_ftrs},
             {'name': "TOP_20", 'ftrs': top20_ftrs},
             #{'name': "TOP_10", 'ftrs': top10_ftrs},
             ]

error_metrics = [{'name': "R2 Score", 'short': "R2", 'function': metrics.r2_score},
                 #{'name': "Explained Variance Score", 'short': "EV", 'function': metrics.explained_variance_score},
                 {'name': "Mean Absolute Error", 'short': "MAE", 'function': metrics.mean_absolute_error},
                 #{'name': "Mean Squared Error", 'short': "MSE", 'function': metrics.mean_squared_error},
                 {'name': "Mean Absolute Percentage Error", 'short': "MAPE", 'function': additional_metrics.mean_absolute_percentage_error},
                 {'name': "Mean Absolute Scaled Error", 'short': "MASE", 'function': additional_metrics.mean_absolute_scaled_error}
                ]

#validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['sensor', 'horizon', 'error metric']),
#                             columns=pd.MultiIndex.from_arrays([[],[]], names=['method', 'data set']))

validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric']))

# %%
results_df = pd.DataFrame()

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[],[]], names=['horizon', 'testing_day','dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

#results_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[]], names=['horizon', 'ts']))
results_df = pd.DataFrame()

output_file_name = "results_id12041992.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

#horizons = [2, 10]
horizons = [20]
#horizons = range(1,25)


def start_prediction_valuation(verbose=False):
    
    arr = []

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041992']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
        
        #for horizon in range (1,25):
        for horizon in horizons:

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            #splitting_point = int(0.8 * data.shape[0]) # this is the reason for differences in baseline results (we use original_data in first which is wrong)
            #original_splitting_time = data.iloc[[splitting_point]].index.to_pydatetime()[0] # here as well
            splitting_point = int(0.8 * original_data.shape[0])
            original_splitting_time = original_data.iloc[[splitting_point]].index.to_pydatetime()[0]
            splitting_time = original_splitting_time.replace(hour=0, minute=0, second=0, microsecond=0) # setting to middnight
            latest_time = data.iloc[[-1]].index.to_pydatetime()[0]
            
            
            # Split Training and Testing set
            training_data = sensor_data[:splitting_time]
            testing_data = sensor_data[splitting_time:]
            
            # Create training vectors
            X_train = training_data[ar_wf_dt_ftrs].values
            y_train = training_data[["shifted_measurement"]].values.ravel()
            #print "Using dummy features:", X_train.shape

            # Create testing vectors
            X_test = testing_data[ar_wf_dt_ftrs].values
            y_test = testing_data[["shifted_measurement"]].values.ravel()
            
            # Initializing model
            mdl = RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, n_jobs=16)
            mdl.fit(X_train,y_train)
            pred = mdl.predict(X_test)
            

            # Prepare results df
            results_df = testing_data[["shifted_measurement"]]
            results_df.rename(columns={"shifted_measurement":"true"}, inplace=True)

            results_df['last value'] = testing_data[["measurement"]]
            results_df['previous day'] = testing_data[["shifted_measurement_1d"]]
            results_df['previous week'] = testing_data[["shifted_measurement_1w"]]           
            
            results_df['offline'] = mdl.predict(X_test)
            results_df['batch'] = np.nan
            
            arr.append(results_df)
            
            while (splitting_time < latest_time):
                                
                eval_start_time = splitting_time
                splitting_time = splitting_time + timedelta(days=1)
                eval_end_time = splitting_time
                    
                # Split Training and Testing set
                training_data = sensor_data[:eval_start_time - timedelta(minutes=15)]
                testing_data = sensor_data[eval_start_time:eval_end_time]
                
                # init temoporary batch datafreame
                batch_df_temp = pd.DataFrame(index = testing_data.index)

                # Create dummy feature vector for linear regression
                sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                        prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                        prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                        prefix='dummy_shifted_Month'))))
                #sensor_data_dummy.dropna(inplace=True)
                dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
                training_data_dummy = sensor_data_dummy[:eval_start_time - timedelta(minutes=15)]
                testing_data_dummy = sensor_data_dummy[eval_start_time:eval_start_time]
                
                if verbose: print "\n\t\t-->{} ({})".format('Evaluation', splitting_time)
                
                for data_set in data_sets:              
                
                    # Create training vectors
                    X_train = training_data[data_set['ftrs']].values
                    y_train = training_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train.shape

                    # Create testing vectors
                    X_test = testing_data[data_set['ftrs']].values
                    y_test = testing_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_test.shape

                    if verbose: print "\t\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                              X_train.shape, y_train.shape)

                    if data_set['name'] == "Baselines":
                        for baseline in baselines:

                            if verbose: print "\t\t\t\t-->Computing {}".format(baseline['name'])
                            bl = eval(baseline['init'])

                            for metric in error_metrics:
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                               y_test, testing_data[bl.target])
                                else:
                                    error = metric['function'](y_test, testing_data[bl.target])

                                validation_df.loc[(horizon, splitting_time, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

                    else:    
                        for model in models: 
                            # Initializing model
                            mdl = eval(model['init'])

                            # Model leraning
                            start = time.time() # Start measuring time
                            if model['name'] == "Ridge Regression":
                                mdl.fit(X_train_dummy, y_train_dummy)
                            else:
                                mdl.fit(X_train,y_train)
                                
                            # predictions
                            pred = mdl.predict(X_test)
                            batch_df_temp['batch'] = pred
                                
                            runtime = time.time() - start # Calculate runtime
                            
                            results_df.update(batch_df_temp)

                            if verbose: print "\t\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

                            for metric in error_metrics:
                                #print "\t-->Error metric: {}".format(metric['name'])

                                if model['name'] == "Ridge Regression":
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
                                                                   y_test_dummy, mdl.predict(X_test_dummy))
                                    else:
                                        error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

                                else: 
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
                                                                   y_test, mdl.predict(X_test))
                                    else:
                                        error = metric['function'](y_test, mdl.predict(X_test))

                                #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
                                validation_df.loc[(horizon, splitting_time, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

            
                #print results_df
        
        all_results = pd.concat(arr, keys=horizons)
        all_results.index.set_names(['horizons', 'values'], inplace=True)

        print all_results
        
        all_results.to_csv(output_file_path)
        
start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df

print "Finished."

#output_file_name = "testni_eval_top20_id12041992.csv"
#output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

#validation_df.to_csv(output_file_path)
# Out:
# Working with sensor: id12041992
#
# 	-->Prediction horizont: 20h. Shifting runtime: 1.01s
# C:\Python27\lib\site-packages\ipykernel\__main__.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 		-->Evaluation (2014-04-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (77376L, 16L), y_train: (77376L,)
# 				-->Computing Last value
# 					-->R2: -0.704
# 					-->MAE: 32.122
# 					-->MAPE: 39.025
# 					-->MASE: 0.978
# 				-->Computing Previous day
# 					-->R2: 0.772
# 					-->MAE: 11.740
# 					-->MAPE: 12.274
# 					-->MASE: 0.358
# 				-->Computing Previous week
# 					-->R2: 0.629
# 					-->MAE: 15.798
# 					-->MAPE: 16.443
# 					-->MASE: 0.481
# 			-->Dataset: TOP_20. X_train: (77376L, 20L), y_train: (77376L,)
# 				-->Training model: Random Forest, runtime: 8.41s
# 					-->R2: 0.859
# 					-->MAE: 9.318
# 					-->MAPE: 9.717
# 					-->MASE: 0.284
#
# 		-->Evaluation (2014-04-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (77472L, 16L), y_train: (77472L,)
# 				-->Computing Last value
# 					-->R2: -3.180
# 					-->MAE: 43.401
# 					-->MAPE: 56.141
# 					-->MASE: 1.322
# 				-->Computing Previous day
# 					-->R2: -0.725
# 					-->MAE: 23.931
# 					-->MAPE: 29.281
# 					-->MASE: 0.729
# 				-->Computing Previous week
# 					-->R2: 0.828
# 					-->MAE: 7.964
# 					-->MAPE: 9.154
# 					-->MASE: 0.243
# 			-->Dataset: TOP_20. X_train: (77472L, 20L), y_train: (77472L,)
# 				-->Training model: Random Forest, runtime: 8.09s
# 					-->R2: 0.805
# 					-->MAE: 8.543
# 					-->MAPE: 9.987
# 					-->MASE: 0.260
#
# 		-->Evaluation (2014-04-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (77568L, 16L), y_train: (77568L,)
# 				-->Computing Last value
# 					-->R2: -2.019
# 					-->MAE: 25.131
# 					-->MAPE: 31.535
# 					-->MASE: 0.765
# 				-->Computing Previous day
# 					-->R2: 0.175
# 					-->MAE: 13.043
# 					-->MAPE: 16.362
# 					-->MASE: 0.397
# 				-->Computing Previous week
# 					-->R2: -0.438
# 					-->MAE: 15.976
# 					-->MAPE: 19.197
# 					-->MASE: 0.486
# 			-->Dataset: TOP_20. X_train: (77568L, 20L), y_train: (77568L,)
# 				-->Training model: Random Forest, runtime: 8.14s
# 					-->R2: 0.425
# 					-->MAE: 10.932
# 					-->MAPE: 13.289
# 					-->MASE: 0.333
#
# 		-->Evaluation (2014-04-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (77664L, 16L), y_train: (77664L,)
# 				-->Computing Last value
# 					-->R2: 0.080
# 					-->MAE: 22.564
# 					-->MAPE: 23.060
# 					-->MASE: 0.687
# 				-->Computing Previous day
# 					-->R2: 0.110
# 					-->MAE: 23.288
# 					-->MAPE: 24.116
# 					-->MASE: 0.709
# 				-->Computing Previous week
# 					-->R2: 0.161
# 					-->MAE: 20.234
# 					-->MAPE: 24.159
# 					-->MASE: 0.616
# 			-->Dataset: TOP_20. X_train: (77664L, 20L), y_train: (77664L,)
# 				-->Training model: Random Forest, runtime: 8.16s
# 					-->R2: 0.516
# 					-->MAE: 17.178
# 					-->MAPE: 18.685
# 					-->MASE: 0.523
#
# 		-->Evaluation (2014-04-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (77760L, 16L), y_train: (77760L,)
# 				-->Computing Last value
# 					-->R2: 0.157
# 					-->MAE: 26.797
# 					-->MAPE: 25.246
# 					-->MASE: 0.816
# 				-->Computing Previous day
# 					-->R2: 0.134
# 					-->MAE: 23.331
# 					-->MAPE: 18.413
# 					-->MASE: 0.711
# 				-->Computing Previous week
# 					-->R2: 0.652
# 					-->MAE: 15.906
# 					-->MAPE: 13.876
# 					-->MASE: 0.485
# 			-->Dataset: TOP_20. X_train: (77760L, 20L), y_train: (77760L,)
# 				-->Training model: Random Forest, runtime: 8.22s
# 					-->R2: 0.481
# 					-->MAE: 17.563
# 					-->MAPE: 14.126
# 					-->MASE: 0.535
#
# 		-->Evaluation (2014-04-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (77856L, 16L), y_train: (77856L,)
# 				-->Computing Last value
# 					-->R2: -0.843
# 					-->MAE: 32.952
# 					-->MAPE: 37.121
# 					-->MASE: 1.004
# 				-->Computing Previous day
# 					-->R2: 0.780
# 					-->MAE: 10.572
# 					-->MAPE: 9.152
# 					-->MASE: 0.322
# 				-->Computing Previous week
# 					-->R2: 0.463
# 					-->MAE: 17.876
# 					-->MAPE: 16.358
# 					-->MASE: 0.545
# 			-->Dataset: TOP_20. X_train: (77856L, 20L), y_train: (77856L,)
# 				-->Training model: Random Forest, runtime: 8.87s
# 					-->R2: 0.885
# 					-->MAE: 8.657
# 					-->MAPE: 7.874
# 					-->MASE: 0.264
#
# 		-->Evaluation (2014-04-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (77952L, 16L), y_train: (77952L,)
# 				-->Computing Last value
# 					-->R2: -0.443
# 					-->MAE: 31.964
# 					-->MAPE: 35.383
# 					-->MASE: 0.974
# 				-->Computing Previous day
# 					-->R2: 0.846
# 					-->MAE: 9.331
# 					-->MAPE: 8.791
# 					-->MASE: 0.284
# 				-->Computing Previous week
# 					-->R2: 0.748
# 					-->MAE: 12.881
# 					-->MAPE: 13.320
# 					-->MASE: 0.393
# 			-->Dataset: TOP_20. X_train: (77952L, 20L), y_train: (77952L,)
# 				-->Training model: Random Forest, runtime: 8.53s
# 					-->R2: 0.884
# 					-->MAE: 8.155
# 					-->MAPE: 7.901
# 					-->MASE: 0.248
#
# 		-->Evaluation (2014-04-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (78048L, 16L), y_train: (78048L,)
# 				-->Computing Last value
# 					-->R2: -0.296
# 					-->MAE: 38.190
# 					-->MAPE: 39.427
# 					-->MASE: 1.164
# 				-->Computing Previous day
# 					-->R2: 0.717
# 					-->MAE: 13.034
# 					-->MAPE: 10.375
# 					-->MASE: 0.397
# 				-->Computing Previous week
# 					-->R2: 0.657
# 					-->MAE: 17.130
# 					-->MAPE: 14.670
# 					-->MASE: 0.522
# 			-->Dataset: TOP_20. X_train: (78048L, 20L), y_train: (78048L,)
# 				-->Training model: Random Forest, runtime: 8.33s
# 					-->R2: 0.759
# 					-->MAE: 12.861
# 					-->MAPE: 10.375
# 					-->MASE: 0.392
#
# 		-->Evaluation (2014-04-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (78144L, 16L), y_train: (78144L,)
# 				-->Computing Last value
# 					-->R2: -5.246
# 					-->MAE: 46.766
# 					-->MAPE: 60.472
# 					-->MASE: 1.425
# 				-->Computing Previous day
# 					-->R2: -2.627
# 					-->MAE: 31.302
# 					-->MAPE: 38.613
# 					-->MASE: 0.954
# 				-->Computing Previous week
# 					-->R2: 0.678
# 					-->MAE: 11.085
# 					-->MAPE: 12.704
# 					-->MASE: 0.338
# 			-->Dataset: TOP_20. X_train: (78144L, 20L), y_train: (78144L,)
# 				-->Training model: Random Forest, runtime: 8.37s
# 					-->R2: 0.554
# 					-->MAE: 12.215
# 					-->MAPE: 14.823
# 					-->MASE: 0.372
#
# 		-->Evaluation (2014-04-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (78240L, 16L), y_train: (78240L,)
# 				-->Computing Last value
# 					-->R2: -0.170
# 					-->MAE: 22.424
# 					-->MAPE: 31.428
# 					-->MASE: 0.683
# 				-->Computing Previous day
# 					-->R2: 0.691
# 					-->MAE: 12.645
# 					-->MAPE: 17.726
# 					-->MASE: 0.385
# 				-->Computing Previous week
# 					-->R2: 0.709
# 					-->MAE: 12.107
# 					-->MAPE: 15.986
# 					-->MASE: 0.369
# 			-->Dataset: TOP_20. X_train: (78240L, 20L), y_train: (78240L,)
# 				-->Training model: Random Forest, runtime: 8.24s
# 					-->R2: 0.792
# 					-->MAE: 9.912
# 					-->MAPE: 15.455
# 					-->MASE: 0.302
#
# 		-->Evaluation (2014-04-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (78336L, 16L), y_train: (78336L,)
# 				-->Computing Last value
# 					-->R2: 0.187
# 					-->MAE: 21.844
# 					-->MAPE: 22.667
# 					-->MASE: 0.665
# 				-->Computing Previous day
# 					-->R2: 0.104
# 					-->MAE: 22.487
# 					-->MAPE: 24.887
# 					-->MASE: 0.685
# 				-->Computing Previous week
# 					-->R2: 0.605
# 					-->MAE: 14.494
# 					-->MAPE: 16.522
# 					-->MASE: 0.442
# 			-->Dataset: TOP_20. X_train: (78336L, 20L), y_train: (78336L,)
# 				-->Training model: Random Forest, runtime: 8.67s
# 					-->R2: 0.607
# 					-->MAE: 13.286
# 					-->MAPE: 15.412
# 					-->MASE: 0.405
#
# 		-->Evaluation (2014-04-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (78432L, 16L), y_train: (78432L,)
# 				-->Computing Last value
# 					-->R2: -0.527
# 					-->MAE: 27.299
# 					-->MAPE: 34.723
# 					-->MASE: 0.832
# 				-->Computing Previous day
# 					-->R2: 0.806
# 					-->MAE: 9.447
# 					-->MAPE: 9.981
# 					-->MASE: 0.288
# 				-->Computing Previous week
# 					-->R2: 0.126
# 					-->MAE: 19.456
# 					-->MAPE: 20.636
# 					-->MASE: 0.593
# 			-->Dataset: TOP_20. X_train: (78432L, 20L), y_train: (78432L,)
# 				-->Training model: Random Forest, runtime: 8.10s
# 					-->R2: 0.812
# 					-->MAE: 10.261
# 					-->MAPE: 11.933
# 					-->MASE: 0.313
#
# 		-->Evaluation (2014-04-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (78528L, 16L), y_train: (78528L,)
# 				-->Computing Last value
# 					-->R2: -0.247
# 					-->MAE: 26.467
# 					-->MAPE: 30.032
# 					-->MASE: 0.807
# 				-->Computing Previous day
# 					-->R2: 0.784
# 					-->MAE: 11.685
# 					-->MAPE: 12.053
# 					-->MASE: 0.356
# 				-->Computing Previous week
# 					-->R2: 0.697
# 					-->MAE: 12.624
# 					-->MAPE: 13.737
# 					-->MASE: 0.385
# 			-->Dataset: TOP_20. X_train: (78528L, 20L), y_train: (78528L,)
# 				-->Training model: Random Forest, runtime: 8.04s
# 					-->R2: 0.898
# 					-->MAE: 7.842
# 					-->MAPE: 8.387
# 					-->MASE: 0.239
#
# 		-->Evaluation (2014-05-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (78624L, 16L), y_train: (78624L,)
# 				-->Computing Last value
# 					-->R2: -3.041
# 					-->MAE: 39.624
# 					-->MAPE: 53.730
# 					-->MASE: 1.208
# 				-->Computing Previous day
# 					-->R2: -0.925
# 					-->MAE: 24.888
# 					-->MAPE: 31.956
# 					-->MASE: 0.759
# 				-->Computing Previous week
# 					-->R2: -2.176
# 					-->MAE: 30.667
# 					-->MAPE: 40.571
# 					-->MASE: 0.935
# 			-->Dataset: TOP_20. X_train: (78624L, 20L), y_train: (78624L,)
# 				-->Training model: Random Forest, runtime: 8.46s
# 					-->R2: 0.546
# 					-->MAE: 12.564
# 					-->MAPE: 16.589
# 					-->MASE: 0.383
#
# 		-->Evaluation (2014-05-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (78720L, 16L), y_train: (78720L,)
# 				-->Computing Last value
# 					-->R2: -0.097
# 					-->MAE: 20.171
# 					-->MAPE: 24.050
# 					-->MASE: 0.615
# 				-->Computing Previous day
# 					-->R2: 0.559
# 					-->MAE: 12.875
# 					-->MAPE: 13.647
# 					-->MASE: 0.392
# 				-->Computing Previous week
# 					-->R2: -1.287
# 					-->MAE: 27.374
# 					-->MAPE: 32.630
# 					-->MASE: 0.834
# 			-->Dataset: TOP_20. X_train: (78720L, 20L), y_train: (78720L,)
# 				-->Training model: Random Forest, runtime: 8.54s
# 					-->R2: 0.715
# 					-->MAE: 11.126
# 					-->MAPE: 13.294
# 					-->MASE: 0.339
#
# 		-->Evaluation (2014-05-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (78816L, 16L), y_train: (78816L,)
# 				-->Computing Last value
# 					-->R2: -0.689
# 					-->MAE: 26.914
# 					-->MAPE: 32.114
# 					-->MASE: 0.821
# 				-->Computing Previous day
# 					-->R2: 0.654
# 					-->MAE: 11.428
# 					-->MAPE: 13.748
# 					-->MASE: 0.349
# 				-->Computing Previous week
# 					-->R2: 0.548
# 					-->MAE: 13.539
# 					-->MAPE: 15.745
# 					-->MASE: 0.413
# 			-->Dataset: TOP_20. X_train: (78816L, 20L), y_train: (78816L,)
# 				-->Training model: Random Forest, runtime: 8.40s
# 					-->R2: 0.774
# 					-->MAE: 8.906
# 					-->MAPE: 10.196
# 					-->MASE: 0.272
#
# 		-->Evaluation (2014-05-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (78912L, 16L), y_train: (78912L,)
# 				-->Computing Last value
# 					-->R2: -0.353
# 					-->MAE: 19.822
# 					-->MAPE: 23.136
# 					-->MASE: 0.605
# 				-->Computing Previous day
# 					-->R2: 0.530
# 					-->MAE: 12.209
# 					-->MAPE: 13.909
# 					-->MASE: 0.372
# 				-->Computing Previous week
# 					-->R2: 0.689
# 					-->MAE: 9.602
# 					-->MAPE: 11.631
# 					-->MASE: 0.293
# 			-->Dataset: TOP_20. X_train: (78912L, 20L), y_train: (78912L,)
# 				-->Training model: Random Forest, runtime: 8.40s
# 					-->R2: 0.739
# 					-->MAE: 8.639
# 					-->MAPE: 9.699
# 					-->MASE: 0.264
#
# 		-->Evaluation (2014-05-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (79008L, 16L), y_train: (79008L,)
# 				-->Computing Last value
# 					-->R2: 0.106
# 					-->MAE: 27.497
# 					-->MAPE: 23.442
# 					-->MASE: 0.839
# 				-->Computing Previous day
# 					-->R2: -0.025
# 					-->MAE: 30.905
# 					-->MAPE: 27.378
# 					-->MASE: 0.943
# 				-->Computing Previous week
# 					-->R2: 0.581
# 					-->MAE: 18.200
# 					-->MAPE: 15.787
# 					-->MASE: 0.555
# 			-->Dataset: TOP_20. X_train: (79008L, 20L), y_train: (79008L,)
# 				-->Training model: Random Forest, runtime: 8.12s
# 					-->R2: 0.753
# 					-->MAE: 13.606
# 					-->MAPE: 12.010
# 					-->MASE: 0.415
#
# 		-->Evaluation (2014-05-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (79104L, 16L), y_train: (79104L,)
# 				-->Computing Last value
# 					-->R2: -0.687
# 					-->MAE: 33.163
# 					-->MAPE: 37.568
# 					-->MASE: 1.012
# 				-->Computing Previous day
# 					-->R2: 0.704
# 					-->MAE: 12.132
# 					-->MAPE: 10.860
# 					-->MASE: 0.370
# 				-->Computing Previous week
# 					-->R2: 0.568
# 					-->MAE: 15.895
# 					-->MAPE: 14.583
# 					-->MASE: 0.485
# 			-->Dataset: TOP_20. X_train: (79104L, 20L), y_train: (79104L,)
# 				-->Training model: Random Forest, runtime: 8.34s
# 					-->R2: 0.835
# 					-->MAE: 8.894
# 					-->MAPE: 8.241
# 					-->MASE: 0.271
#
# 		-->Evaluation (2014-05-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (79200L, 16L), y_train: (79200L,)
# 				-->Computing Last value
# 					-->R2: -0.198
# 					-->MAE: 35.366
# 					-->MAPE: 39.502
# 					-->MASE: 1.080
# 				-->Computing Previous day
# 					-->R2: 0.688
# 					-->MAE: 16.347
# 					-->MAPE: 14.243
# 					-->MASE: 0.499
# 				-->Computing Previous week
# 					-->R2: 0.704
# 					-->MAE: 15.048
# 					-->MAPE: 11.627
# 					-->MASE: 0.459
# 			-->Dataset: TOP_20. X_train: (79200L, 20L), y_train: (79200L,)
# 				-->Training model: Random Forest, runtime: 8.31s
# 					-->R2: 0.807
# 					-->MAE: 12.389
# 					-->MAPE: 10.739
# 					-->MASE: 0.378
#
# 		-->Evaluation (2014-05-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (79296L, 16L), y_train: (79296L,)
# 				-->Computing Last value
# 					-->R2: -0.487
# 					-->MAE: 32.810
# 					-->MAPE: 38.617
# 					-->MASE: 1.001
# 				-->Computing Previous day
# 					-->R2: 0.698
# 					-->MAE: 14.418
# 					-->MAPE: 12.935
# 					-->MASE: 0.440
# 				-->Computing Previous week
# 					-->R2: -0.472
# 					-->MAE: 32.486
# 					-->MAPE: 25.653
# 					-->MASE: 0.991
# 			-->Dataset: TOP_20. X_train: (79296L, 20L), y_train: (79296L,)
# 				-->Training model: Random Forest, runtime: 8.09s
# 					-->R2: 0.797
# 					-->MAE: 12.593
# 					-->MAPE: 11.278
# 					-->MASE: 0.384
#
# 		-->Evaluation (2014-05-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (79392L, 16L), y_train: (79392L,)
# 				-->Computing Last value
# 					-->R2: -0.479
# 					-->MAE: 38.297
# 					-->MAPE: 41.807
# 					-->MASE: 1.169
# 				-->Computing Previous day
# 					-->R2: 0.673
# 					-->MAE: 14.320
# 					-->MAPE: 12.575
# 					-->MASE: 0.437
# 				-->Computing Previous week
# 					-->R2: 0.181
# 					-->MAE: 25.085
# 					-->MAPE: 20.520
# 					-->MASE: 0.766
# 			-->Dataset: TOP_20. X_train: (79392L, 20L), y_train: (79392L,)
# 				-->Training model: Random Forest, runtime: 8.10s
# 					-->R2: 0.726
# 					-->MAE: 14.100
# 					-->MAPE: 12.135
# 					-->MASE: 0.430
#
# 		-->Evaluation (2014-05-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (79488L, 16L), y_train: (79488L,)
# 				-->Computing Last value
# 					-->R2: -2.980
# 					-->MAE: 41.989
# 					-->MAPE: 48.924
# 					-->MASE: 1.281
# 				-->Computing Previous day
# 					-->R2: -1.207
# 					-->MAE: 28.161
# 					-->MAPE: 30.536
# 					-->MASE: 0.859
# 				-->Computing Previous week
# 					-->R2: 0.471
# 					-->MAE: 15.003
# 					-->MAPE: 15.145
# 					-->MASE: 0.458
# 			-->Dataset: TOP_20. X_train: (79488L, 20L), y_train: (79488L,)
# 				-->Training model: Random Forest, runtime: 8.04s
# 					-->R2: 0.753
# 					-->MAE: 9.424
# 					-->MAPE: 10.543
# 					-->MASE: 0.288
#
# 		-->Evaluation (2014-05-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (79584L, 16L), y_train: (79584L,)
# 				-->Computing Last value
# 					-->R2: -0.430
# 					-->MAE: 23.157
# 					-->MAPE: 30.827
# 					-->MASE: 0.706
# 				-->Computing Previous day
# 					-->R2: 0.379
# 					-->MAE: 14.781
# 					-->MAPE: 18.475
# 					-->MASE: 0.451
# 				-->Computing Previous week
# 					-->R2: 0.669
# 					-->MAE: 10.779
# 					-->MAPE: 13.512
# 					-->MASE: 0.329
# 			-->Dataset: TOP_20. X_train: (79584L, 20L), y_train: (79584L,)
# 				-->Training model: Random Forest, runtime: 8.20s
# 					-->R2: 0.727
# 					-->MAE: 9.848
# 					-->MAPE: 12.919
# 					-->MASE: 0.300
#
# 		-->Evaluation (2014-05-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (79680L, 16L), y_train: (79680L,)
# 				-->Computing Last value
# 					-->R2: 0.239
# 					-->MAE: 20.581
# 					-->MAPE: 22.048
# 					-->MASE: 0.628
# 				-->Computing Previous day
# 					-->R2: 0.520
# 					-->MAE: 17.300
# 					-->MAPE: 17.932
# 					-->MASE: 0.528
# 				-->Computing Previous week
# 					-->R2: 0.379
# 					-->MAE: 16.193
# 					-->MAPE: 16.397
# 					-->MASE: 0.494
# 			-->Dataset: TOP_20. X_train: (79680L, 20L), y_train: (79680L,)
# 				-->Training model: Random Forest, runtime: 8.18s
# 					-->R2: 0.706
# 					-->MAE: 12.285
# 					-->MAPE: 13.748
# 					-->MASE: 0.375
#
# 		-->Evaluation (2014-05-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (79776L, 16L), y_train: (79776L,)
# 				-->Computing Last value
# 					-->R2: -0.127
# 					-->MAE: 24.124
# 					-->MAPE: 29.322
# 					-->MASE: 0.736
# 				-->Computing Previous day
# 					-->R2: 0.812
# 					-->MAE: 9.585
# 					-->MAPE: 9.470
# 					-->MASE: 0.293
# 				-->Computing Previous week
# 					-->R2: 0.719
# 					-->MAE: 11.056
# 					-->MAPE: 11.502
# 					-->MASE: 0.338
# 			-->Dataset: TOP_20. X_train: (79776L, 20L), y_train: (79776L,)
# 				-->Training model: Random Forest, runtime: 8.16s
# 					-->R2: 0.881
# 					-->MAE: 8.108
# 					-->MAPE: 8.621
# 					-->MASE: 0.248
#
# 		-->Evaluation (2014-05-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (79872L, 16L), y_train: (79872L,)
# 				-->Computing Last value
# 					-->R2: -0.145
# 					-->MAE: 28.702
# 					-->MAPE: 34.568
# 					-->MASE: 0.877
# 				-->Computing Previous day
# 					-->R2: 0.849
# 					-->MAE: 9.068
# 					-->MAPE: 8.934
# 					-->MASE: 0.277
# 				-->Computing Previous week
# 					-->R2: 0.650
# 					-->MAE: 14.659
# 					-->MAPE: 14.676
# 					-->MASE: 0.448
# 			-->Dataset: TOP_20. X_train: (79872L, 20L), y_train: (79872L,)
# 				-->Training model: Random Forest, runtime: 8.26s
# 					-->R2: 0.915
# 					-->MAE: 7.750
# 					-->MAPE: 8.379
# 					-->MASE: 0.237
#
# 		-->Evaluation (2014-05-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (79968L, 16L), y_train: (79968L,)
# 				-->Computing Last value
# 					-->R2: -0.742
# 					-->MAE: 28.370
# 					-->MAPE: 33.870
# 					-->MASE: 0.867
# 				-->Computing Previous day
# 					-->R2: 0.767
# 					-->MAE: 10.524
# 					-->MAPE: 10.605
# 					-->MASE: 0.321
# 				-->Computing Previous week
# 					-->R2: 0.437
# 					-->MAE: 14.520
# 					-->MAPE: 13.733
# 					-->MASE: 0.443
# 			-->Dataset: TOP_20. X_train: (79968L, 20L), y_train: (79968L,)
# 				-->Training model: Random Forest, runtime: 8.47s
# 					-->R2: 0.814
# 					-->MAE: 8.934
# 					-->MAPE: 8.731
# 					-->MASE: 0.273
#
# 		-->Evaluation (2014-05-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (80064L, 16L), y_train: (80064L,)
# 				-->Computing Last value
# 					-->R2: -0.203
# 					-->MAE: 28.112
# 					-->MAPE: 32.251
# 					-->MASE: 0.859
# 				-->Computing Previous day
# 					-->R2: 0.845
# 					-->MAE: 9.469
# 					-->MAPE: 8.968
# 					-->MASE: 0.289
# 				-->Computing Previous week
# 					-->R2: 0.495
# 					-->MAE: 16.073
# 					-->MAPE: 14.293
# 					-->MASE: 0.491
# 			-->Dataset: TOP_20. X_train: (80064L, 20L), y_train: (80064L,)
# 				-->Training model: Random Forest, runtime: 8.67s
# 					-->R2: 0.889
# 					-->MAE: 7.694
# 					-->MAPE: 7.446
# 					-->MASE: 0.235
#
# 		-->Evaluation (2014-05-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (80160L, 16L), y_train: (80160L,)
# 				-->Computing Last value
# 					-->R2: -3.007
# 					-->MAE: 38.077
# 					-->MAPE: 54.604
# 					-->MASE: 1.163
# 				-->Computing Previous day
# 					-->R2: -0.670
# 					-->MAE: 21.936
# 					-->MAPE: 27.588
# 					-->MASE: 0.670
# 				-->Computing Previous week
# 					-->R2: 0.487
# 					-->MAE: 13.438
# 					-->MAPE: 17.054
# 					-->MASE: 0.411
# 			-->Dataset: TOP_20. X_train: (80160L, 20L), y_train: (80160L,)
# 				-->Training model: Random Forest, runtime: 9.23s
# 					-->R2: 0.778
# 					-->MAE: 9.070
# 					-->MAPE: 12.489
# 					-->MASE: 0.277
#
# 		-->Evaluation (2014-05-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (80256L, 16L), y_train: (80256L,)
# 				-->Computing Last value
# 					-->R2: -0.698
# 					-->MAE: 24.392
# 					-->MAPE: 31.840
# 					-->MASE: 0.745
# 				-->Computing Previous day
# 					-->R2: 0.687
# 					-->MAE: 9.973
# 					-->MAPE: 11.916
# 					-->MASE: 0.305
# 				-->Computing Previous week
# 					-->R2: 0.744
# 					-->MAE: 8.978
# 					-->MAPE: 11.524
# 					-->MASE: 0.274
# 			-->Dataset: TOP_20. X_train: (80256L, 20L), y_train: (80256L,)
# 				-->Training model: Random Forest, runtime: 8.66s
# 					-->R2: 0.814
# 					-->MAE: 8.423
# 					-->MAPE: 10.674
# 					-->MASE: 0.257
#
# 		-->Evaluation (2014-05-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (80352L, 16L), y_train: (80352L,)
# 				-->Computing Last value
# 					-->R2: 0.132
# 					-->MAE: 29.794
# 					-->MAPE: 24.481
# 					-->MASE: 0.910
# 				-->Computing Previous day
# 					-->R2: -0.207
# 					-->MAE: 35.308
# 					-->MAPE: 29.919
# 					-->MASE: 1.079
# 				-->Computing Previous week
# 					-->R2: 0.600
# 					-->MAE: 18.527
# 					-->MAPE: 14.777
# 					-->MASE: 0.566
# 			-->Dataset: TOP_20. X_train: (80352L, 20L), y_train: (80352L,)
# 				-->Training model: Random Forest, runtime: 8.91s
# 					-->R2: 0.739
# 					-->MAE: 14.619
# 					-->MAPE: 12.335
# 					-->MASE: 0.447
#
# 		-->Evaluation (2014-05-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (80448L, 16L), y_train: (80448L,)
# 				-->Computing Last value
# 					-->R2: -0.451
# 					-->MAE: 35.448
# 					-->MAPE: 40.394
# 					-->MASE: 1.083
# 				-->Computing Previous day
# 					-->R2: 0.629
# 					-->MAE: 17.016
# 					-->MAPE: 15.147
# 					-->MASE: 0.520
# 				-->Computing Previous week
# 					-->R2: 0.649
# 					-->MAE: 15.821
# 					-->MAPE: 13.075
# 					-->MASE: 0.484
# 			-->Dataset: TOP_20. X_train: (80448L, 20L), y_train: (80448L,)
# 				-->Training model: Random Forest, runtime: 8.97s
# 					-->R2: 0.782
# 					-->MAE: 12.549
# 					-->MAPE: 11.075
# 					-->MASE: 0.384
#
# 		-->Evaluation (2014-05-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (80544L, 16L), y_train: (80544L,)
# 				-->Computing Last value
# 					-->R2: -0.540
# 					-->MAE: 35.798
# 					-->MAPE: 43.181
# 					-->MASE: 1.094
# 				-->Computing Previous day
# 					-->R2: 0.770
# 					-->MAE: 12.234
# 					-->MAPE: 11.764
# 					-->MASE: 0.374
# 				-->Computing Previous week
# 					-->R2: 0.761
# 					-->MAE: 11.999
# 					-->MAPE: 10.675
# 					-->MASE: 0.367
# 			-->Dataset: TOP_20. X_train: (80544L, 20L), y_train: (80544L,)
# 				-->Training model: Random Forest, runtime: 8.29s
# 					-->R2: 0.852
# 					-->MAE: 11.279
# 					-->MAPE: 11.301
# 					-->MASE: 0.345
#
# 		-->Evaluation (2014-05-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (80640L, 16L), y_train: (80640L,)
# 				-->Computing Last value
# 					-->R2: -0.175
# 					-->MAE: 34.904
# 					-->MAPE: 42.478
# 					-->MASE: 1.067
# 				-->Computing Previous day
# 					-->R2: 0.810
# 					-->MAE: 12.169
# 					-->MAPE: 10.483
# 					-->MASE: 0.372
# 				-->Computing Previous week
# 					-->R2: 0.715
# 					-->MAE: 14.879
# 					-->MAPE: 12.937
# 					-->MASE: 0.455
# 			-->Dataset: TOP_20. X_train: (80640L, 20L), y_train: (80640L,)
# 				-->Training model: Random Forest, runtime: 8.32s
# 					-->R2: 0.874
# 					-->MAE: 10.556
# 					-->MAPE: 10.320
# 					-->MASE: 0.323
#
# 		-->Evaluation (2014-05-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (80736L, 16L), y_train: (80736L,)
# 				-->Computing Last value
# 					-->R2: -0.347
# 					-->MAE: 37.355
# 					-->MAPE: 41.319
# 					-->MASE: 1.141
# 				-->Computing Previous day
# 					-->R2: 0.899
# 					-->MAE: 9.624
# 					-->MAPE: 9.127
# 					-->MASE: 0.294
# 				-->Computing Previous week
# 					-->R2: 0.738
# 					-->MAE: 13.655
# 					-->MAPE: 11.005
# 					-->MASE: 0.417
# 			-->Dataset: TOP_20. X_train: (80736L, 20L), y_train: (80736L,)
# 				-->Training model: Random Forest, runtime: 8.30s
# 					-->R2: 0.879
# 					-->MAE: 9.290
# 					-->MAPE: 7.781
# 					-->MASE: 0.284
#
# 		-->Evaluation (2014-05-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (80832L, 16L), y_train: (80832L,)
# 				-->Computing Last value
# 					-->R2: -4.525
# 					-->MAE: 46.435
# 					-->MAPE: 66.412
# 					-->MASE: 1.419
# 				-->Computing Previous day
# 					-->R2: -1.883
# 					-->MAE: 31.181
# 					-->MAPE: 38.270
# 					-->MASE: 0.953
# 				-->Computing Previous week
# 					-->R2: 0.788
# 					-->MAE: 8.787
# 					-->MAPE: 10.561
# 					-->MASE: 0.268
# 			-->Dataset: TOP_20. X_train: (80832L, 20L), y_train: (80832L,)
# 				-->Training model: Random Forest, runtime: 8.45s
# 					-->R2: 0.658
# 					-->MAE: 11.588
# 					-->MAPE: 15.455
# 					-->MASE: 0.354
#
# 		-->Evaluation (2014-05-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (80928L, 16L), y_train: (80928L,)
# 				-->Computing Last value
# 					-->R2: -1.857
# 					-->MAE: 26.610
# 					-->MAPE: 41.624
# 					-->MASE: 0.813
# 				-->Computing Previous day
# 					-->R2: -0.082
# 					-->MAE: 16.318
# 					-->MAPE: 23.833
# 					-->MASE: 0.498
# 				-->Computing Previous week
# 					-->R2: -0.026
# 					-->MAE: 15.787
# 					-->MAPE: 23.242
# 					-->MASE: 0.482
# 			-->Dataset: TOP_20. X_train: (80928L, 20L), y_train: (80928L,)
# 				-->Training model: Random Forest, runtime: 8.65s
# 					-->R2: 0.257
# 					-->MAE: 14.355
# 					-->MAPE: 22.478
# 					-->MASE: 0.438
#
# 		-->Evaluation (2014-05-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (81024L, 16L), y_train: (81024L,)
# 				-->Computing Last value
# 					-->R2: -0.596
# 					-->MAE: 40.470
# 					-->MAPE: 33.520
# 					-->MASE: 1.236
# 				-->Computing Previous day
# 					-->R2: -1.021
# 					-->MAE: 41.327
# 					-->MAPE: 31.837
# 					-->MASE: 1.262
# 				-->Computing Previous week
# 					-->R2: 0.764
# 					-->MAE: 13.422
# 					-->MAPE: 11.994
# 					-->MASE: 0.410
# 			-->Dataset: TOP_20. X_train: (81024L, 20L), y_train: (81024L,)
# 				-->Training model: Random Forest, runtime: 8.27s
# 					-->R2: 0.646
# 					-->MAE: 16.169
# 					-->MAPE: 13.184
# 					-->MASE: 0.494
#
# 		-->Evaluation (2014-05-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (81120L, 16L), y_train: (81120L,)
# 				-->Computing Last value
# 					-->R2: -0.506
# 					-->MAE: 38.745
# 					-->MAPE: 45.790
# 					-->MASE: 1.183
# 				-->Computing Previous day
# 					-->R2: 0.753
# 					-->MAE: 14.959
# 					-->MAPE: 14.460
# 					-->MASE: 0.457
# 				-->Computing Previous week
# 					-->R2: 0.797
# 					-->MAE: 12.811
# 					-->MAPE: 12.530
# 					-->MASE: 0.391
# 			-->Dataset: TOP_20. X_train: (81120L, 20L), y_train: (81120L,)
# 				-->Training model: Random Forest, runtime: 8.28s
# 					-->R2: 0.841
# 					-->MAE: 11.917
# 					-->MAPE: 11.600
# 					-->MASE: 0.364
#
# 		-->Evaluation (2014-05-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (81216L, 16L), y_train: (81216L,)
# 				-->Computing Last value
# 					-->R2: -0.209
# 					-->MAE: 33.322
# 					-->MAPE: 39.408
# 					-->MASE: 1.017
# 				-->Computing Previous day
# 					-->R2: 0.751
# 					-->MAE: 12.475
# 					-->MAPE: 11.932
# 					-->MASE: 0.381
# 				-->Computing Previous week
# 					-->R2: 0.897
# 					-->MAE: 9.063
# 					-->MAPE: 8.663
# 					-->MASE: 0.277
# 			-->Dataset: TOP_20. X_train: (81216L, 20L), y_train: (81216L,)
# 				-->Training model: Random Forest, runtime: 8.35s
# 					-->R2: 0.874
# 					-->MAE: 10.065
# 					-->MAPE: 9.864
# 					-->MASE: 0.307
#
# 		-->Evaluation (2014-05-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (81312L, 16L), y_train: (81312L,)
# 				-->Computing Last value
# 					-->R2: -0.586
# 					-->MAE: 32.593
# 					-->MAPE: 43.989
# 					-->MASE: 0.995
# 				-->Computing Previous day
# 					-->R2: 0.757
# 					-->MAE: 12.640
# 					-->MAPE: 13.998
# 					-->MASE: 0.386
# 				-->Computing Previous week
# 					-->R2: 0.627
# 					-->MAE: 15.668
# 					-->MAPE: 16.479
# 					-->MASE: 0.478
# 			-->Dataset: TOP_20. X_train: (81312L, 20L), y_train: (81312L,)
# 				-->Training model: Random Forest, runtime: 8.37s
# 					-->R2: 0.756
# 					-->MAE: 13.939
# 					-->MAPE: 15.942
# 					-->MASE: 0.425
#
# 		-->Evaluation (2014-05-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (81408L, 16L), y_train: (81408L,)
# 				-->Computing Last value
# 					-->R2: -0.129
# 					-->MAE: 34.130
# 					-->MAPE: 39.665
# 					-->MASE: 1.042
# 				-->Computing Previous day
# 					-->R2: 0.729
# 					-->MAE: 15.829
# 					-->MAPE: 14.209
# 					-->MASE: 0.483
# 				-->Computing Previous week
# 					-->R2: 0.855
# 					-->MAE: 11.475
# 					-->MAPE: 11.954
# 					-->MASE: 0.350
# 			-->Dataset: TOP_20. X_train: (81408L, 20L), y_train: (81408L,)
# 				-->Training model: Random Forest, runtime: 8.30s
# 					-->R2: 0.872
# 					-->MAE: 10.321
# 					-->MAPE: 9.937
# 					-->MASE: 0.315
#
# 		-->Evaluation (2014-05-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (81504L, 16L), y_train: (81504L,)
# 				-->Computing Last value
# 					-->R2: -5.842
# 					-->MAE: 45.031
# 					-->MAPE: 66.237
# 					-->MASE: 1.375
# 				-->Computing Previous day
# 					-->R2: -2.756
# 					-->MAE: 29.920
# 					-->MAPE: 38.072
# 					-->MASE: 0.913
# 				-->Computing Previous week
# 					-->R2: 0.642
# 					-->MAE: 9.545
# 					-->MAPE: 11.767
# 					-->MASE: 0.291
# 			-->Dataset: TOP_20. X_train: (81504L, 20L), y_train: (81504L,)
# 				-->Training model: Random Forest, runtime: 8.71s
# 					-->R2: 0.581
# 					-->MAE: 11.238
# 					-->MAPE: 14.879
# 					-->MASE: 0.343
#
# 		-->Evaluation (2014-06-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (81600L, 16L), y_train: (81600L,)
# 				-->Computing Last value
# 					-->R2: -0.375
# 					-->MAE: 21.997
# 					-->MAPE: 29.256
# 					-->MASE: 0.671
# 				-->Computing Previous day
# 					-->R2: 0.729
# 					-->MAE: 9.367
# 					-->MAPE: 11.695
# 					-->MASE: 0.286
# 				-->Computing Previous week
# 					-->R2: 0.537
# 					-->MAE: 12.370
# 					-->MAPE: 14.361
# 					-->MASE: 0.377
# 			-->Dataset: TOP_20. X_train: (81600L, 20L), y_train: (81600L,)
# 				-->Training model: Random Forest, runtime: 8.43s
# 					-->R2: 0.768
# 					-->MAE: 8.538
# 					-->MAPE: 10.522
# 					-->MASE: 0.260
#
# 		-->Evaluation (2014-06-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (81696L, 16L), y_train: (81696L,)
# 				-->Computing Last value
# 					-->R2: 0.046
# 					-->MAE: 30.337
# 					-->MAPE: 27.555
# 					-->MASE: 0.926
# 				-->Computing Previous day
# 					-->R2: -0.038
# 					-->MAE: 28.505
# 					-->MAPE: 23.514
# 					-->MASE: 0.870
# 				-->Computing Previous week
# 					-->R2: 0.809
# 					-->MAE: 12.468
# 					-->MAPE: 11.868
# 					-->MASE: 0.381
# 			-->Dataset: TOP_20. X_train: (81696L, 20L), y_train: (81696L,)
# 				-->Training model: Random Forest, runtime: 8.55s
# 					-->R2: 0.807
# 					-->MAE: 11.913
# 					-->MAPE: 11.234
# 					-->MASE: 0.364
#
# 		-->Evaluation (2014-06-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (81792L, 16L), y_train: (81792L,)
# 				-->Computing Last value
# 					-->R2: -0.218
# 					-->MAE: 34.296
# 					-->MAPE: 37.747
# 					-->MASE: 1.047
# 				-->Computing Previous day
# 					-->R2: 0.853
# 					-->MAE: 10.824
# 					-->MAPE: 10.493
# 					-->MASE: 0.330
# 				-->Computing Previous week
# 					-->R2: 0.804
# 					-->MAE: 11.698
# 					-->MAPE: 10.500
# 					-->MASE: 0.357
# 			-->Dataset: TOP_20. X_train: (81792L, 20L), y_train: (81792L,)
# 				-->Training model: Random Forest, runtime: 8.63s
# 					-->R2: 0.888
# 					-->MAE: 9.029
# 					-->MAPE: 8.243
# 					-->MASE: 0.276
#
# 		-->Evaluation (2014-06-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (81888L, 16L), y_train: (81888L,)
# 				-->Computing Last value
# 					-->R2: -0.643
# 					-->MAE: 37.708
# 					-->MAPE: 43.229
# 					-->MASE: 1.151
# 				-->Computing Previous day
# 					-->R2: 0.679
# 					-->MAE: 13.426
# 					-->MAPE: 11.373
# 					-->MASE: 0.410
# 				-->Computing Previous week
# 					-->R2: 0.780
# 					-->MAE: 11.244
# 					-->MAPE: 10.539
# 					-->MASE: 0.343
# 			-->Dataset: TOP_20. X_train: (81888L, 20L), y_train: (81888L,)
# 				-->Training model: Random Forest, runtime: 8.93s
# 					-->R2: 0.856
# 					-->MAE: 9.969
# 					-->MAPE: 9.383
# 					-->MASE: 0.304
#
# 		-->Evaluation (2014-06-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (81984L, 16L), y_train: (81984L,)
# 				-->Computing Last value
# 					-->R2: 0.090
# 					-->MAE: 35.252
# 					-->MAPE: 37.664
# 					-->MASE: 1.076
# 				-->Computing Previous day
# 					-->R2: 0.755
# 					-->MAE: 16.119
# 					-->MAPE: 12.353
# 					-->MASE: 0.492
# 				-->Computing Previous week
# 					-->R2: 0.540
# 					-->MAE: 22.768
# 					-->MAPE: 18.008
# 					-->MASE: 0.695
# 			-->Dataset: TOP_20. X_train: (81984L, 20L), y_train: (81984L,)
# 				-->Training model: Random Forest, runtime: 8.76s
# 					-->R2: 0.792
# 					-->MAE: 14.401
# 					-->MAPE: 10.789
# 					-->MASE: 0.439
#
# 		-->Evaluation (2014-06-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (82080L, 16L), y_train: (82080L,)
# 				-->Computing Last value
# 					-->R2: -0.205
# 					-->MAE: 40.068
# 					-->MAPE: 47.313
# 					-->MASE: 1.223
# 				-->Computing Previous day
# 					-->R2: 0.811
# 					-->MAE: 15.088
# 					-->MAPE: 14.124
# 					-->MASE: 0.460
# 				-->Computing Previous week
# 					-->R2: 0.820
# 					-->MAE: 14.270
# 					-->MAPE: 11.840
# 					-->MASE: 0.435
# 			-->Dataset: TOP_20. X_train: (82080L, 20L), y_train: (82080L,)
# 				-->Training model: Random Forest, runtime: 8.44s
# 					-->R2: 0.863
# 					-->MAE: 13.507
# 					-->MAPE: 12.686
# 					-->MASE: 0.412
#
# 		-->Evaluation (2014-06-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (82176L, 16L), y_train: (82176L,)
# 				-->Computing Last value
# 					-->R2: -5.350
# 					-->MAE: 49.857
# 					-->MAPE: 72.738
# 					-->MASE: 1.521
# 				-->Computing Previous day
# 					-->R2: -2.433
# 					-->MAE: 35.080
# 					-->MAPE: 41.289
# 					-->MASE: 1.070
# 				-->Computing Previous week
# 					-->R2: 0.748
# 					-->MAE: 10.171
# 					-->MAPE: 12.145
# 					-->MASE: 0.310
# 			-->Dataset: TOP_20. X_train: (82176L, 20L), y_train: (82176L,)
# 				-->Training model: Random Forest, runtime: 9.03s
# 					-->R2: 0.834
# 					-->MAE: 8.028
# 					-->MAPE: 11.463
# 					-->MASE: 0.245
#
# 		-->Evaluation (2014-06-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (82272L, 16L), y_train: (82272L,)
# 				-->Computing Last value
# 					-->R2: -0.455
# 					-->MAE: 23.915
# 					-->MAPE: 34.102
# 					-->MASE: 0.729
# 				-->Computing Previous day
# 					-->R2: 0.761
# 					-->MAE: 9.048
# 					-->MAPE: 11.392
# 					-->MASE: 0.276
# 				-->Computing Previous week
# 					-->R2: 0.755
# 					-->MAE: 9.580
# 					-->MAPE: 11.793
# 					-->MASE: 0.292
# 			-->Dataset: TOP_20. X_train: (82272L, 20L), y_train: (82272L,)
# 				-->Training model: Random Forest, runtime: 8.60s
# 					-->R2: 0.683
# 					-->MAE: 11.157
# 					-->MAPE: 13.794
# 					-->MASE: 0.340
#
# 		-->Evaluation (2014-06-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (82368L, 16L), y_train: (82368L,)
# 				-->Computing Last value
# 					-->R2: 0.031
# 					-->MAE: 41.206
# 					-->MAPE: 32.105
# 					-->MASE: 1.257
# 				-->Computing Previous day
# 					-->R2: -0.116
# 					-->MAE: 40.116
# 					-->MAPE: 29.208
# 					-->MASE: 1.224
# 				-->Computing Previous week
# 					-->R2: 0.721
# 					-->MAE: 19.447
# 					-->MAPE: 14.906
# 					-->MASE: 0.593
# 			-->Dataset: TOP_20. X_train: (82368L, 20L), y_train: (82368L,)
# 				-->Training model: Random Forest, runtime: 8.65s
# 					-->R2: 0.622
# 					-->MAE: 22.156
# 					-->MAPE: 16.133
# 					-->MASE: 0.676
#
# 		-->Evaluation (2014-06-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (82464L, 16L), y_train: (82464L,)
# 				-->Computing Last value
# 					-->R2: -0.734
# 					-->MAE: 42.678
# 					-->MAPE: 50.668
# 					-->MASE: 1.301
# 				-->Computing Previous day
# 					-->R2: 0.717
# 					-->MAE: 15.871
# 					-->MAPE: 13.902
# 					-->MASE: 0.484
# 				-->Computing Previous week
# 					-->R2: 0.775
# 					-->MAE: 13.697
# 					-->MAPE: 11.500
# 					-->MASE: 0.418
# 			-->Dataset: TOP_20. X_train: (82464L, 20L), y_train: (82464L,)
# 				-->Training model: Random Forest, runtime: 8.91s
# 					-->R2: 0.867
# 					-->MAE: 11.844
# 					-->MAPE: 10.620
# 					-->MASE: 0.361
#
# 		-->Evaluation (2014-06-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (82560L, 16L), y_train: (82560L,)
# 				-->Computing Last value
# 					-->R2: -0.155
# 					-->MAE: 41.408
# 					-->MAPE: 48.086
# 					-->MASE: 1.262
# 				-->Computing Previous day
# 					-->R2: 0.865
# 					-->MAE: 13.326
# 					-->MAPE: 11.928
# 					-->MASE: 0.406
# 				-->Computing Previous week
# 					-->R2: 0.735
# 					-->MAE: 17.094
# 					-->MAPE: 13.931
# 					-->MASE: 0.521
# 			-->Dataset: TOP_20. X_train: (82560L, 20L), y_train: (82560L,)
# 				-->Training model: Random Forest, runtime: 9.02s
# 					-->R2: 0.861
# 					-->MAE: 12.321
# 					-->MAPE: 11.539
# 					-->MASE: 0.376
#
# 		-->Evaluation (2014-06-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (82656L, 16L), y_train: (82656L,)
# 				-->Computing Last value
# 					-->R2: -0.424
# 					-->MAE: 38.368
# 					-->MAPE: 37.534
# 					-->MASE: 1.169
# 				-->Computing Previous day
# 					-->R2: 0.734
# 					-->MAE: 16.519
# 					-->MAPE: 14.722
# 					-->MASE: 0.503
# 				-->Computing Previous week
# 					-->R2: 0.767
# 					-->MAE: 14.898
# 					-->MAPE: 12.734
# 					-->MASE: 0.454
# 			-->Dataset: TOP_20. X_train: (82656L, 20L), y_train: (82656L,)
# 				-->Training model: Random Forest, runtime: 9.18s
# 					-->R2: 0.868
# 					-->MAE: 11.237
# 					-->MAPE: 9.825
# 					-->MASE: 0.342
#
# 		-->Evaluation (2014-06-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (82752L, 16L), y_train: (82752L,)
# 				-->Computing Last value
# 					-->R2: -0.413
# 					-->MAE: 42.736
# 					-->MAPE: 43.418
# 					-->MASE: 1.302
# 				-->Computing Previous day
# 					-->R2: 0.812
# 					-->MAE: 14.298
# 					-->MAPE: 10.828
# 					-->MASE: 0.436
# 				-->Computing Previous week
# 					-->R2: 0.845
# 					-->MAE: 14.892
# 					-->MAPE: 13.302
# 					-->MASE: 0.454
# 			-->Dataset: TOP_20. X_train: (82752L, 20L), y_train: (82752L,)
# 				-->Training model: Random Forest, runtime: 9.26s
# 					-->R2: 0.849
# 					-->MAE: 13.142
# 					-->MAPE: 10.058
# 					-->MASE: 0.400
#
# 		-->Evaluation (2014-06-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (82848L, 16L), y_train: (82848L,)
# 				-->Computing Last value
# 					-->R2: -12.313
# 					-->MAE: 57.344
# 					-->MAPE: 74.471
# 					-->MASE: 1.746
# 				-->Computing Previous day
# 					-->R2: -9.821
# 					-->MAE: 44.274
# 					-->MAPE: 57.438
# 					-->MASE: 1.348
# 				-->Computing Previous week
# 					-->R2: -0.151
# 					-->MAE: 16.801
# 					-->MAPE: 22.150
# 					-->MASE: 0.512
# 			-->Dataset: TOP_20. X_train: (82848L, 20L), y_train: (82848L,)
# 				-->Training model: Random Forest, runtime: 8.88s
# 					-->R2: -0.272
# 					-->MAE: 15.623
# 					-->MAPE: 20.747
# 					-->MASE: 0.476
#
# 		-->Evaluation (2014-06-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (82944L, 16L), y_train: (82944L,)
# 				-->Computing Last value
# 					-->R2: -0.577
# 					-->MAE: 17.486
# 					-->MAPE: 21.915
# 					-->MASE: 0.532
# 				-->Computing Previous day
# 					-->R2: 0.404
# 					-->MAE: 10.407
# 					-->MAPE: 13.455
# 					-->MASE: 0.317
# 				-->Computing Previous week
# 					-->R2: -0.201
# 					-->MAE: 15.587
# 					-->MAPE: 20.012
# 					-->MASE: 0.474
# 			-->Dataset: TOP_20. X_train: (82944L, 20L), y_train: (82944L,)
# 				-->Training model: Random Forest, runtime: 8.68s
# 					-->R2: 0.652
# 					-->MAE: 8.149
# 					-->MAPE: 10.920
# 					-->MASE: 0.248
#
# 		-->Evaluation (2014-06-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (83040L, 16L), y_train: (83040L,)
# 				-->Computing Last value
# 					-->R2: -0.466
# 					-->MAE: 29.139
# 					-->MAPE: 25.145
# 					-->MASE: 0.887
# 				-->Computing Previous day
# 					-->R2: -0.694
# 					-->MAE: 31.071
# 					-->MAPE: 27.144
# 					-->MASE: 0.946
# 				-->Computing Previous week
# 					-->R2: -0.058
# 					-->MAE: 23.716
# 					-->MAPE: 21.605
# 					-->MASE: 0.722
# 			-->Dataset: TOP_20. X_train: (83040L, 20L), y_train: (83040L,)
# 				-->Training model: Random Forest, runtime: 8.58s
# 					-->R2: 0.713
# 					-->MAE: 14.065
# 					-->MAPE: 13.820
# 					-->MASE: 0.428
#
# 		-->Evaluation (2014-06-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (83136L, 16L), y_train: (83136L,)
# 				-->Computing Last value
# 					-->R2: -0.702
# 					-->MAE: 29.521
# 					-->MAPE: 33.430
# 					-->MASE: 0.899
# 				-->Computing Previous day
# 					-->R2: 0.645
# 					-->MAE: 13.054
# 					-->MAPE: 12.342
# 					-->MASE: 0.397
# 				-->Computing Previous week
# 					-->R2: 0.214
# 					-->MAE: 19.668
# 					-->MAPE: 18.559
# 					-->MASE: 0.599
# 			-->Dataset: TOP_20. X_train: (83136L, 20L), y_train: (83136L,)
# 				-->Training model: Random Forest, runtime: 8.59s
# 					-->R2: 0.690
# 					-->MAE: 12.960
# 					-->MAPE: 12.205
# 					-->MASE: 0.395
#
# 		-->Evaluation (2014-06-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (83232L, 16L), y_train: (83232L,)
# 				-->Computing Last value
# 					-->R2: -0.217
# 					-->MAE: 28.806
# 					-->MAPE: 32.159
# 					-->MASE: 0.877
# 				-->Computing Previous day
# 					-->R2: 0.566
# 					-->MAE: 14.394
# 					-->MAPE: 13.326
# 					-->MASE: 0.438
# 				-->Computing Previous week
# 					-->R2: 0.110
# 					-->MAE: 22.775
# 					-->MAPE: 20.469
# 					-->MASE: 0.694
# 			-->Dataset: TOP_20. X_train: (83232L, 20L), y_train: (83232L,)
# 				-->Training model: Random Forest, runtime: 8.65s
# 					-->R2: 0.750
# 					-->MAE: 11.765
# 					-->MAPE: 10.918
# 					-->MASE: 0.358
#
# 		-->Evaluation (2014-06-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (83328L, 16L), y_train: (83328L,)
# 				-->Computing Last value
# 					-->R2: -0.538
# 					-->MAE: 29.692
# 					-->MAPE: 33.732
# 					-->MASE: 0.904
# 				-->Computing Previous day
# 					-->R2: 0.642
# 					-->MAE: 13.501
# 					-->MAPE: 12.211
# 					-->MASE: 0.411
# 				-->Computing Previous week
# 					-->R2: 0.398
# 					-->MAE: 19.714
# 					-->MAPE: 18.401
# 					-->MASE: 0.600
# 			-->Dataset: TOP_20. X_train: (83328L, 20L), y_train: (83328L,)
# 				-->Training model: Random Forest, runtime: 9.03s
# 					-->R2: 0.781
# 					-->MAE: 12.062
# 					-->MAPE: 11.671
# 					-->MASE: 0.367
#
# 		-->Evaluation (2014-06-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (83424L, 16L), y_train: (83424L,)
# 				-->Computing Last value
# 					-->R2: -1.931
# 					-->MAE: 34.645
# 					-->MAPE: 51.785
# 					-->MASE: 1.055
# 				-->Computing Previous day
# 					-->R2: 0.313
# 					-->MAE: 17.592
# 					-->MAPE: 20.430
# 					-->MASE: 0.536
# 				-->Computing Previous week
# 					-->R2: -0.895
# 					-->MAE: 30.004
# 					-->MAPE: 31.813
# 					-->MASE: 0.914
# 			-->Dataset: TOP_20. X_train: (83424L, 20L), y_train: (83424L,)
# 				-->Training model: Random Forest, runtime: 9.17s
# 					-->R2: 0.286
# 					-->MAE: 18.979
# 					-->MAPE: 23.667
# 					-->MASE: 0.578
#
# 		-->Evaluation (2014-06-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (83520L, 16L), y_train: (83520L,)
# 				-->Computing Last value
# 					-->R2: -1.444
# 					-->MAE: 27.876
# 					-->MAPE: 32.087
# 					-->MASE: 0.849
# 				-->Computing Previous day
# 					-->R2: 0.035
# 					-->MAE: 16.836
# 					-->MAPE: 19.420
# 					-->MASE: 0.513
# 				-->Computing Previous week
# 					-->R2: 0.260
# 					-->MAE: 13.987
# 					-->MAPE: 14.154
# 					-->MASE: 0.426
# 			-->Dataset: TOP_20. X_train: (83520L, 20L), y_train: (83520L,)
# 				-->Training model: Random Forest, runtime: 9.21s
# 					-->R2: 0.475
# 					-->MAE: 12.035
# 					-->MAPE: 12.228
# 					-->MASE: 0.367
#
# 		-->Evaluation (2014-06-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (83616L, 16L), y_train: (83616L,)
# 				-->Computing Last value
# 					-->R2: -1.404
# 					-->MAE: 21.014
# 					-->MAPE: 25.854
# 					-->MASE: 0.640
# 				-->Computing Previous day
# 					-->R2: 0.377
# 					-->MAE: 10.134
# 					-->MAPE: 12.173
# 					-->MASE: 0.309
# 				-->Computing Previous week
# 					-->R2: 0.449
# 					-->MAE: 10.307
# 					-->MAPE: 11.685
# 					-->MASE: 0.314
# 			-->Dataset: TOP_20. X_train: (83616L, 20L), y_train: (83616L,)
# 				-->Training model: Random Forest, runtime: 9.11s
# 					-->R2: 0.694
# 					-->MAE: 7.561
# 					-->MAPE: 8.820
# 					-->MASE: 0.230
#
# 		-->Evaluation (2014-06-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (83712L, 16L), y_train: (83712L,)
# 				-->Computing Last value
# 					-->R2: -0.525
# 					-->MAE: 25.823
# 					-->MAPE: 21.731
# 					-->MASE: 0.787
# 				-->Computing Previous day
# 					-->R2: -0.699
# 					-->MAE: 26.344
# 					-->MAPE: 21.984
# 					-->MASE: 0.803
# 				-->Computing Previous week
# 					-->R2: 0.479
# 					-->MAE: 15.116
# 					-->MAPE: 13.576
# 					-->MASE: 0.461
# 			-->Dataset: TOP_20. X_train: (83712L, 20L), y_train: (83712L,)
# 				-->Training model: Random Forest, runtime: 8.84s
# 					-->R2: 0.748
# 					-->MAE: 9.946
# 					-->MAPE: 8.960
# 					-->MASE: 0.303
#
# 		-->Evaluation (2014-06-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (83808L, 16L), y_train: (83808L,)
# 				-->Computing Last value
# 					-->R2: -0.284
# 					-->MAE: 25.478
# 					-->MAPE: 26.686
# 					-->MASE: 0.777
# 				-->Computing Previous day
# 					-->R2: 0.399
# 					-->MAE: 15.425
# 					-->MAPE: 14.541
# 					-->MASE: 0.470
# 				-->Computing Previous week
# 					-->R2: 0.361
# 					-->MAE: 16.265
# 					-->MAPE: 15.094
# 					-->MASE: 0.496
# 			-->Dataset: TOP_20. X_train: (83808L, 20L), y_train: (83808L,)
# 				-->Training model: Random Forest, runtime: 8.81s
# 					-->R2: 0.622
# 					-->MAE: 12.742
# 					-->MAPE: 11.833
# 					-->MASE: 0.388
#
# 		-->Evaluation (2014-06-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (83904L, 16L), y_train: (83904L,)
# 				-->Computing Last value
# 					-->R2: -4.857
# 					-->MAE: 35.733
# 					-->MAPE: 45.893
# 					-->MASE: 1.090
# 				-->Computing Previous day
# 					-->R2: -2.200
# 					-->MAE: 23.795
# 					-->MAPE: 29.276
# 					-->MASE: 0.726
# 				-->Computing Previous week
# 					-->R2: -2.647
# 					-->MAE: 24.814
# 					-->MAPE: 30.021
# 					-->MASE: 0.757
# 			-->Dataset: TOP_20. X_train: (83904L, 20L), y_train: (83904L,)
# 				-->Training model: Random Forest, runtime: 9.01s
# 					-->R2: 0.477
# 					-->MAE: 11.366
# 					-->MAPE: 14.461
# 					-->MASE: 0.347
#
# 		-->Evaluation (2014-06-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (84000L, 16L), y_train: (84000L,)
# 				-->Computing Last value
# 					-->R2: -0.122
# 					-->MAE: 21.408
# 					-->MAPE: 20.989
# 					-->MASE: 0.653
# 				-->Computing Previous day
# 					-->R2: -0.036
# 					-->MAE: 19.234
# 					-->MAPE: 17.446
# 					-->MASE: 0.586
# 				-->Computing Previous week
# 					-->R2: 0.511
# 					-->MAE: 12.857
# 					-->MAPE: 12.653
# 					-->MASE: 0.392
# 			-->Dataset: TOP_20. X_train: (84000L, 20L), y_train: (84000L,)
# 				-->Training model: Random Forest, runtime: 8.79s
# 					-->R2: 0.687
# 					-->MAE: 10.266
# 					-->MAPE: 9.983
# 					-->MASE: 0.313
#
# 		-->Evaluation (2014-06-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (84096L, 16L), y_train: (84096L,)
# 				-->Computing Last value
# 					-->R2: -0.392
# 					-->MAE: 29.406
# 					-->MAPE: 31.868
# 					-->MASE: 0.897
# 				-->Computing Previous day
# 					-->R2: 0.733
# 					-->MAE: 11.496
# 					-->MAPE: 10.498
# 					-->MASE: 0.351
# 				-->Computing Previous week
# 					-->R2: 0.568
# 					-->MAE: 15.645
# 					-->MAPE: 15.258
# 					-->MASE: 0.477
# 			-->Dataset: TOP_20. X_train: (84096L, 20L), y_train: (84096L,)
# 				-->Training model: Random Forest, runtime: 8.77s
# 					-->R2: 0.767
# 					-->MAE: 10.415
# 					-->MAPE: 9.490
# 					-->MASE: 0.318
#
# 		-->Evaluation (2014-06-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (84192L, 16L), y_train: (84192L,)
# 				-->Computing Last value
# 					-->R2: -6.421
# 					-->MAE: 37.043
# 					-->MAPE: 51.149
# 					-->MASE: 1.130
# 				-->Computing Previous day
# 					-->R2: -4.633
# 					-->MAE: 27.300
# 					-->MAPE: 37.892
# 					-->MASE: 0.833
# 				-->Computing Previous week
# 					-->R2: -0.663
# 					-->MAE: 16.765
# 					-->MAPE: 22.373
# 					-->MASE: 0.511
# 			-->Dataset: TOP_20. X_train: (84192L, 20L), y_train: (84192L,)
# 				-->Training model: Random Forest, runtime: 8.82s
# 					-->R2: -0.007
# 					-->MAE: 12.955
# 					-->MAPE: 18.278
# 					-->MASE: 0.395
#
# 		-->Evaluation (2014-06-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (84288L, 16L), y_train: (84288L,)
# 				-->Computing Last value
# 					-->R2: -0.567
# 					-->MAE: 17.148
# 					-->MAPE: 23.556
# 					-->MASE: 0.523
# 				-->Computing Previous day
# 					-->R2: 0.487
# 					-->MAE: 9.362
# 					-->MAPE: 12.251
# 					-->MASE: 0.286
# 				-->Computing Previous week
# 					-->R2: 0.392
# 					-->MAE: 10.632
# 					-->MAPE: 14.641
# 					-->MASE: 0.324
# 			-->Dataset: TOP_20. X_train: (84288L, 20L), y_train: (84288L,)
# 				-->Training model: Random Forest, runtime: 8.92s
# 					-->R2: 0.797
# 					-->MAE: 6.096
# 					-->MAPE: 8.701
# 					-->MASE: 0.186
#
# 		-->Evaluation (2014-06-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (84384L, 16L), y_train: (84384L,)
# 				-->Computing Last value
# 					-->R2: -0.472
# 					-->MAE: 26.046
# 					-->MAPE: 22.225
# 					-->MASE: 0.795
# 				-->Computing Previous day
# 					-->R2: -0.760
# 					-->MAE: 28.160
# 					-->MAPE: 24.226
# 					-->MASE: 0.859
# 				-->Computing Previous week
# 					-->R2: 0.607
# 					-->MAE: 14.703
# 					-->MAPE: 15.318
# 					-->MASE: 0.449
# ...
# 					-->R2: 0.824
# 					-->MAE: 15.492
# 					-->MAPE: 15.332
# 					-->MASE: 0.475
#
# 		-->Evaluation (2015-01-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (104256L, 16L), y_train: (104256L,)
# 				-->Computing Last value
# 					-->R2: -0.773
# 					-->MAE: 39.400
# 					-->MAPE: 49.558
# 					-->MASE: 1.207
# 				-->Computing Previous day
# 					-->R2: 0.294
# 					-->MAE: 24.830
# 					-->MAPE: 25.918
# 					-->MASE: 0.761
# 				-->Computing Previous week
# 					-->R2: 0.292
# 					-->MAE: 23.386
# 					-->MAPE: 24.569
# 					-->MASE: 0.716
# 			-->Dataset: TOP_20. X_train: (104256L, 20L), y_train: (104256L,)
# 				-->Training model: Random Forest, runtime: 11.51s
# 					-->R2: 0.565
# 					-->MAE: 20.032
# 					-->MAPE: 21.265
# 					-->MASE: 0.614
#
# 		-->Evaluation (2015-01-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (104352L, 16L), y_train: (104352L,)
# 				-->Computing Last value
# 					-->R2: -2.416
# 					-->MAE: 50.499
# 					-->MAPE: 92.043
# 					-->MASE: 1.547
# 				-->Computing Previous day
# 					-->R2: -0.861
# 					-->MAE: 35.029
# 					-->MAPE: 58.697
# 					-->MASE: 1.073
# 				-->Computing Previous week
# 					-->R2: 0.373
# 					-->MAE: 21.195
# 					-->MAPE: 30.502
# 					-->MASE: 0.649
# 			-->Dataset: TOP_20. X_train: (104352L, 20L), y_train: (104352L,)
# 				-->Training model: Random Forest, runtime: 11.86s
# 					-->R2: 0.592
# 					-->MAE: 18.578
# 					-->MAPE: 29.803
# 					-->MASE: 0.569
#
# 		-->Evaluation (2015-01-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (104448L, 16L), y_train: (104448L,)
# 				-->Computing Last value
# 					-->R2: -1.032
# 					-->MAE: 32.969
# 					-->MAPE: 42.502
# 					-->MASE: 1.009
# 				-->Computing Previous day
# 					-->R2: 0.197
# 					-->MAE: 20.222
# 					-->MAPE: 25.199
# 					-->MASE: 0.619
# 				-->Computing Previous week
# 					-->R2: 0.011
# 					-->MAE: 22.876
# 					-->MAPE: 28.485
# 					-->MASE: 0.700
# 			-->Dataset: TOP_20. X_train: (104448L, 20L), y_train: (104448L,)
# 				-->Training model: Random Forest, runtime: 11.65s
# 					-->R2: 0.477
# 					-->MAE: 16.593
# 					-->MAPE: 20.333
# 					-->MASE: 0.508
#
# 		-->Evaluation (2015-01-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (104544L, 16L), y_train: (104544L,)
# 				-->Computing Last value
# 					-->R2: 0.109
# 					-->MAE: 37.356
# 					-->MAPE: 44.086
# 					-->MASE: 1.143
# 				-->Computing Previous day
# 					-->R2: -0.111
# 					-->MAE: 39.487
# 					-->MAPE: 43.849
# 					-->MASE: 1.209
# 				-->Computing Previous week
# 					-->R2: 0.692
# 					-->MAE: 19.840
# 					-->MAPE: 27.103
# 					-->MASE: 0.607
# 			-->Dataset: TOP_20. X_train: (104544L, 20L), y_train: (104544L,)
# 				-->Training model: Random Forest, runtime: 11.20s
# 					-->R2: 0.826
# 					-->MAE: 16.195
# 					-->MAPE: 22.734
# 					-->MASE: 0.496
#
# 		-->Evaluation (2015-01-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (104640L, 16L), y_train: (104640L,)
# 				-->Computing Last value
# 					-->R2: -0.641
# 					-->MAE: 38.819
# 					-->MAPE: 57.037
# 					-->MASE: 1.188
# 				-->Computing Previous day
# 					-->R2: 0.641
# 					-->MAE: 19.244
# 					-->MAPE: 22.873
# 					-->MASE: 0.589
# 				-->Computing Previous week
# 					-->R2: 0.662
# 					-->MAE: 17.291
# 					-->MAPE: 17.367
# 					-->MASE: 0.529
# 			-->Dataset: TOP_20. X_train: (104640L, 20L), y_train: (104640L,)
# 				-->Training model: Random Forest, runtime: 11.24s
# 					-->R2: 0.794
# 					-->MAE: 14.906
# 					-->MAPE: 16.304
# 					-->MASE: 0.456
#
# 		-->Evaluation (2015-01-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (104736L, 16L), y_train: (104736L,)
# 				-->Computing Last value
# 					-->R2: -0.268
# 					-->MAE: 53.713
# 					-->MAPE: 67.065
# 					-->MASE: 1.644
# 				-->Computing Previous day
# 					-->R2: 0.715
# 					-->MAE: 21.856
# 					-->MAPE: 18.273
# 					-->MASE: 0.669
# 				-->Computing Previous week
# 					-->R2: 0.681
# 					-->MAE: 24.037
# 					-->MAPE: 26.973
# 					-->MASE: 0.736
# 			-->Dataset: TOP_20. X_train: (104736L, 20L), y_train: (104736L,)
# 				-->Training model: Random Forest, runtime: 11.49s
# 					-->R2: 0.757
# 					-->MAE: 21.889
# 					-->MAPE: 19.601
# 					-->MASE: 0.670
#
# 		-->Evaluation (2015-01-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (104832L, 16L), y_train: (104832L,)
# 				-->Computing Last value
# 					-->R2: -0.510
# 					-->MAE: 44.797
# 					-->MAPE: 57.602
# 					-->MASE: 1.370
# 				-->Computing Previous day
# 					-->R2: 0.788
# 					-->MAE: 17.455
# 					-->MAPE: 20.139
# 					-->MASE: 0.534
# 				-->Computing Previous week
# 					-->R2: 0.719
# 					-->MAE: 19.652
# 					-->MAPE: 20.085
# 					-->MASE: 0.601
# 			-->Dataset: TOP_20. X_train: (104832L, 20L), y_train: (104832L,)
# 				-->Training model: Random Forest, runtime: 11.42s
# 					-->R2: 0.854
# 					-->MAE: 16.435
# 					-->MAPE: 17.463
# 					-->MASE: 0.503
#
# 		-->Evaluation (2015-01-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (104928L, 16L), y_train: (104928L,)
# 				-->Computing Last value
# 					-->R2: -0.323
# 					-->MAE: 49.011
# 					-->MAPE: 69.825
# 					-->MASE: 1.498
# 				-->Computing Previous day
# 					-->R2: 0.852
# 					-->MAE: 16.240
# 					-->MAPE: 20.960
# 					-->MASE: 0.497
# 				-->Computing Previous week
# 					-->R2: 0.562
# 					-->MAE: 29.487
# 					-->MAPE: 30.370
# 					-->MASE: 0.901
# 			-->Dataset: TOP_20. X_train: (104928L, 20L), y_train: (104928L,)
# 				-->Training model: Random Forest, runtime: 11.63s
# 					-->R2: 0.865
# 					-->MAE: 17.649
# 					-->MAPE: 21.784
# 					-->MASE: 0.540
#
# 		-->Evaluation (2015-01-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (105024L, 16L), y_train: (105024L,)
# 				-->Computing Last value
# 					-->R2: -5.117
# 					-->MAE: 64.742
# 					-->MAPE: 95.912
# 					-->MASE: 1.978
# 				-->Computing Previous day
# 					-->R2: -2.115
# 					-->MAE: 44.862
# 					-->MAPE: 55.806
# 					-->MASE: 1.371
# 				-->Computing Previous week
# 					-->R2: 0.490
# 					-->MAE: 17.497
# 					-->MAPE: 22.353
# 					-->MASE: 0.535
# 			-->Dataset: TOP_20. X_train: (105024L, 20L), y_train: (105024L,)
# 				-->Training model: Random Forest, runtime: 11.30s
# 					-->R2: 0.697
# 					-->MAE: 13.623
# 					-->MAPE: 17.782
# 					-->MASE: 0.416
#
# 		-->Evaluation (2015-02-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (105120L, 16L), y_train: (105120L,)
# 				-->Computing Last value
# 					-->R2: -0.493
# 					-->MAE: 28.707
# 					-->MAPE: 37.626
# 					-->MASE: 0.876
# 				-->Computing Previous day
# 					-->R2: 0.303
# 					-->MAE: 18.764
# 					-->MAPE: 24.160
# 					-->MASE: 0.573
# 				-->Computing Previous week
# 					-->R2: 0.307
# 					-->MAE: 18.342
# 					-->MAPE: 23.594
# 					-->MASE: 0.560
# 			-->Dataset: TOP_20. X_train: (105120L, 20L), y_train: (105120L,)
# 				-->Training model: Random Forest, runtime: 11.44s
# 					-->R2: 0.633
# 					-->MAE: 14.209
# 					-->MAPE: 18.725
# 					-->MASE: 0.434
#
# 		-->Evaluation (2015-02-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (105216L, 16L), y_train: (105216L,)
# 				-->Computing Last value
# 					-->R2: -0.736
# 					-->MAE: 20.137
# 					-->MAPE: 22.243
# 					-->MASE: 0.615
# 				-->Computing Previous day
# 					-->R2: -1.764
# 					-->MAE: 26.681
# 					-->MAPE: 35.498
# 					-->MASE: 0.815
# 				-->Computing Previous week
# 					-->R2: 0.062
# 					-->MAE: 14.006
# 					-->MAPE: 16.968
# 					-->MASE: 0.428
# 			-->Dataset: TOP_20. X_train: (105216L, 20L), y_train: (105216L,)
# 				-->Training model: Random Forest, runtime: 11.46s
# 					-->R2: 0.554
# 					-->MAE: 9.592
# 					-->MAPE: 11.431
# 					-->MASE: 0.293
#                                true  last value  previous day  previous week  \
# horizons values
# 20       2014-04-17 00:00:00  127.0        71.0         129.0          115.1
#          2014-04-17 00:15:00  122.2        72.1         124.2          148.0
#          2014-04-17 00:30:00  133.4        66.3         114.0          136.2
#          2014-04-17 00:45:00  124.2        66.2         111.5          113.0
#          2014-04-17 01:00:00  126.0        53.0         117.0          121.8
#          2014-04-17 01:15:00  105.1        43.1         102.1          109.0
#          2014-04-17 01:30:00   95.0        40.1          98.1          102.1
#          2014-04-17 01:45:00   83.2        37.1          98.1          100.1
#          2014-04-17 02:00:00   90.3        42.5         102.0          101.1
#          2014-04-17 02:15:00   79.1        38.1          99.5           95.1
#          2014-04-17 02:30:00   87.0        40.0          85.0           97.1
#          2014-04-17 02:45:00   79.1        37.1          88.1           91.0
#          2014-04-17 03:00:00   76.1        40.1          87.0           89.2
#          2014-04-17 03:15:00   71.5        38.3          86.6           79.2
#          2014-04-17 03:30:00   73.1        39.1          73.0           82.2
#          2014-04-17 03:45:00   68.1        36.1          75.2           84.4
#          2014-04-17 04:00:00   74.0        41.0          71.0           76.1
#          2014-04-17 04:15:00   69.3        50.2          72.1           81.0
#          2014-04-17 04:30:00   52.1        70.4          66.3           79.2
#          2014-04-17 04:45:00   49.1        82.2          66.2           81.0
#          2014-04-17 05:00:00   55.1        65.0          53.0           82.1
#          2014-04-17 05:15:00   49.1        71.2          43.1           66.0
#          2014-04-17 05:30:00   52.0        74.2          40.1           66.2
#          2014-04-17 05:45:00   51.5        65.1          37.1           64.3
#          2014-04-17 06:00:00   48.1        76.1          42.5           66.1
#          2014-04-17 06:15:00   50.1        98.0          38.1           60.4
#          2014-04-17 06:30:00   47.3       119.0          40.0           65.2
#          2014-04-17 06:45:00   51.1       112.0          37.1           64.0
#          2014-04-17 07:00:00   44.1       124.1          40.1           48.2
#          2014-04-17 07:15:00   50.1       151.0          38.3           51.0
# ...                             ...         ...           ...            ...
#          2015-01-31 20:30:00  104.3       130.6         101.4           87.3
#          2015-01-31 20:45:00  113.4       147.6         103.4           91.7
#          2015-01-31 21:00:00  110.3       122.0         103.3           96.1
#          2015-01-31 21:15:00  110.9       112.3         127.7           98.8
#          2015-01-31 21:30:00  127.4       105.7         143.1          103.0
#          2015-01-31 21:45:00  144.3       104.7         110.6          140.9
#          2015-01-31 22:00:00  129.7       106.6         105.9          125.9
#          2015-01-31 22:15:00  112.8       135.8         116.1           93.0
#          2015-01-31 22:30:00  112.2       121.0         111.7          105.3
#          2015-01-31 22:45:00  115.9        97.5         114.1           96.3
#          2015-01-31 23:00:00  104.7        96.7         138.8           96.4
#          2015-01-31 23:15:00  131.8        92.2         130.2           98.3
#          2015-01-31 23:30:00  137.3        91.6         113.4          145.6
#          2015-01-31 23:45:00  105.7       105.2         105.3          120.0
#          2015-02-01 00:00:00   99.6       121.9         111.1           96.8
#          2015-02-01 00:15:00   98.0        90.2         114.8           97.6
#          2015-02-01 00:30:00  104.8        82.2         130.6           90.1
#          2015-02-01 00:45:00  110.9        77.4         147.6           91.5
#          2015-02-01 01:00:00  115.9        80.4         122.0           95.5
#          2015-02-01 01:15:00  101.2        78.0         112.3          128.7
#          2015-02-01 01:30:00   76.9        96.0         105.7           91.0
#          2015-02-01 01:45:00   84.1        90.4         104.7           83.8
#          2015-02-01 02:00:00   75.7        52.7         106.6           69.4
#          2015-02-01 02:15:00   71.3        54.7         135.8           65.7
#          2015-02-01 02:30:00   95.2        48.0         121.0           62.2
#          2015-02-01 02:45:00   88.6        45.8          97.5           77.7
#          2015-02-01 03:00:00   65.4        66.8          96.7          104.7
#          2015-02-01 03:15:00   65.7        76.3          92.2           57.4
#          2015-02-01 03:30:00   62.9        57.8          91.6           53.8
#          2015-02-01 03:45:00   52.3        47.1         105.2           40.3
#
#                                  offline       batch
# horizons values
# 20       2014-04-17 00:00:00  123.119534  123.138771
#          2014-04-17 00:15:00  126.314162  126.186004
#          2014-04-17 00:30:00  120.928983  120.813018
#          2014-04-17 00:45:00  118.433939  118.624113
#          2014-04-17 01:00:00  119.069452  118.122885
#          2014-04-17 01:15:00  107.382852  107.843810
#          2014-04-17 01:30:00  103.256839  103.424406
#          2014-04-17 01:45:00  101.023510  101.115516
#          2014-04-17 02:00:00  102.789658  102.494205
#          2014-04-17 02:15:00   93.424661   92.707857
#          2014-04-17 02:30:00   96.942899   92.516695
#          2014-04-17 02:45:00   86.301820   86.715898
#          2014-04-17 03:00:00   85.452243   86.061633
#          2014-04-17 03:15:00   78.279222   78.903622
#          2014-04-17 03:30:00   73.207719   74.628597
#          2014-04-17 03:45:00   73.467455   74.102622
#          2014-04-17 04:00:00   71.882966   71.766845
#          2014-04-17 04:15:00   69.743591   71.151114
#          2014-04-17 04:30:00   69.259373   69.296775
#          2014-04-17 04:45:00   69.155013   69.788075
#          2014-04-17 05:00:00   68.269717   70.513487
#          2014-04-17 05:15:00   56.814410   56.437245
#          2014-04-17 05:30:00   55.037496   55.723417
#          2014-04-17 05:45:00   55.320803   55.562665
#          2014-04-17 06:00:00   55.232950   55.913671
#          2014-04-17 06:15:00   53.949756   54.494615
#          2014-04-17 06:30:00   55.851141   57.086957
#          2014-04-17 06:45:00   57.215274   57.198257
#          2014-04-17 07:00:00   45.681473   45.393984
#          2014-04-17 07:15:00   47.420096   46.798585
# ...                                  ...         ...
#          2015-01-31 20:30:00  108.859672  107.433151
#          2015-01-31 20:45:00  111.973698  108.503034
#          2015-01-31 21:00:00  105.713657  108.871983
#          2015-01-31 21:15:00  122.399833  120.716221
#          2015-01-31 21:30:00  120.102953  120.084164
#          2015-01-31 21:45:00  123.615194  122.569155
#          2015-01-31 22:00:00  119.223235  117.642960
#          2015-01-31 22:15:00  105.918560  108.044941
#          2015-01-31 22:30:00  107.330722  115.475090
#          2015-01-31 22:45:00  115.504536  118.889166
#          2015-01-31 23:00:00  116.094780  117.312082
#          2015-01-31 23:15:00  117.042779  115.792284
#          2015-01-31 23:30:00  123.397471  123.994857
#          2015-01-31 23:45:00  111.489322  110.837919
#          2015-02-01 00:00:00  102.466887  102.709601
#          2015-02-01 00:15:00  105.783770  104.525429
#          2015-02-01 00:30:00   97.801278  103.477815
#          2015-02-01 00:45:00   99.174013  102.336416
#          2015-02-01 01:00:00   98.990897   99.264510
#          2015-02-01 01:15:00  118.239159  121.408014
#          2015-02-01 01:30:00  101.465894   96.361009
#          2015-02-01 01:45:00  100.567511   92.391925
#          2015-02-01 02:00:00   79.217358   76.619049
#          2015-02-01 02:15:00   85.125293   76.630206
#          2015-02-01 02:30:00   84.808767   73.011055
#          2015-02-01 02:45:00   86.212779   81.692954
#          2015-02-01 03:00:00  101.380768   88.459293
#          2015-02-01 03:15:00   65.364685   64.103531
#          2015-02-01 03:30:00   62.554910   60.638776
#          2015-02-01 03:45:00   58.840068   59.392707
#
# [27856 rows x 6 columns]
# Finished.
# C:\Python27\lib\site-packages\ipykernel\__main__.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# read from csv
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)
test =  pd.read_csv(input_file_path, index_col=[0,1])

test
# Out:
#                                true  last value  previous day  previous week  \
# horizons values
# 20       2014-04-17 00:00:00  127.0        71.0         129.0          115.1
#          2014-04-17 00:15:00  122.2        72.1         124.2          148.0
#          2014-04-17 00:30:00  133.4        66.3         114.0          136.2
#          2014-04-17 00:45:00  124.2        66.2         111.5          113.0
#          2014-04-17 01:00:00  126.0        53.0         117.0          121.8
#          2014-04-17 01:15:00  105.1        43.1         102.1          109.0
#          2014-04-17 01:30:00   95.0        40.1          98.1          102.1
#          2014-04-17 01:45:00   83.2        37.1          98.1          100.1
#          2014-04-17 02:00:00   90.3        42.5         102.0          101.1
#          2014-04-17 02:15:00   79.1        38.1          99.5           95.1
#          2014-04-17 02:30:00   87.0        40.0          85.0           97.1
#          2014-04-17 02:45:00   79.1        37.1          88.1           91.0
#          2014-04-17 03:00:00   76.1        40.1          87.0           89.2
#          2014-04-17 03:15:00   71.5        38.3          86.6           79.2
#          2014-04-17 03:30:00   73.1        39.1          73.0           82.2
#          2014-04-17 03:45:00   68.1        36.1          75.2           84.4
#          2014-04-17 04:00:00   74.0        41.0          71.0           76.1
#          2014-04-17 04:15:00   69.3        50.2          72.1           81.0
#          2014-04-17 04:30:00   52.1        70.4          66.3           79.2
#          2014-04-17 04:45:00   49.1        82.2          66.2           81.0
#          2014-04-17 05:00:00   55.1        65.0          53.0           82.1
#          2014-04-17 05:15:00   49.1        71.2          43.1           66.0
#          2014-04-17 05:30:00   52.0        74.2          40.1           66.2
#          2014-04-17 05:45:00   51.5        65.1          37.1           64.3
#          2014-04-17 06:00:00   48.1        76.1          42.5           66.1
#          2014-04-17 06:15:00   50.1        98.0          38.1           60.4
#          2014-04-17 06:30:00   47.3       119.0          40.0           65.2
#          2014-04-17 06:45:00   51.1       112.0          37.1           64.0
#          2014-04-17 07:00:00   44.1       124.1          40.1           48.2
#          2014-04-17 07:15:00   50.1       151.0          38.3           51.0
# ...                             ...         ...           ...            ...
#          2015-01-31 20:30:00  104.3       130.6         101.4           87.3
#          2015-01-31 20:45:00  113.4       147.6         103.4           91.7
#          2015-01-31 21:00:00  110.3       122.0         103.3           96.1
#          2015-01-31 21:15:00  110.9       112.3         127.7           98.8
#          2015-01-31 21:30:00  127.4       105.7         143.1          103.0
#          2015-01-31 21:45:00  144.3       104.7         110.6          140.9
#          2015-01-31 22:00:00  129.7       106.6         105.9          125.9
#          2015-01-31 22:15:00  112.8       135.8         116.1           93.0
#          2015-01-31 22:30:00  112.2       121.0         111.7          105.3
#          2015-01-31 22:45:00  115.9        97.5         114.1           96.3
#          2015-01-31 23:00:00  104.7        96.7         138.8           96.4
#          2015-01-31 23:15:00  131.8        92.2         130.2           98.3
#          2015-01-31 23:30:00  137.3        91.6         113.4          145.6
#          2015-01-31 23:45:00  105.7       105.2         105.3          120.0
#          2015-02-01 00:00:00   99.6       121.9         111.1           96.8
#          2015-02-01 00:15:00   98.0        90.2         114.8           97.6
#          2015-02-01 00:30:00  104.8        82.2         130.6           90.1
#          2015-02-01 00:45:00  110.9        77.4         147.6           91.5
#          2015-02-01 01:00:00  115.9        80.4         122.0           95.5
#          2015-02-01 01:15:00  101.2        78.0         112.3          128.7
#          2015-02-01 01:30:00   76.9        96.0         105.7           91.0
#          2015-02-01 01:45:00   84.1        90.4         104.7           83.8
#          2015-02-01 02:00:00   75.7        52.7         106.6           69.4
#          2015-02-01 02:15:00   71.3        54.7         135.8           65.7
#          2015-02-01 02:30:00   95.2        48.0         121.0           62.2
#          2015-02-01 02:45:00   88.6        45.8          97.5           77.7
#          2015-02-01 03:00:00   65.4        66.8          96.7          104.7
#          2015-02-01 03:15:00   65.7        76.3          92.2           57.4
#          2015-02-01 03:30:00   62.9        57.8          91.6           53.8
#          2015-02-01 03:45:00   52.3        47.1         105.2           40.3
#
#                                  offline       batch
# horizons values
# 20       2014-04-17 00:00:00  123.119534  123.138771
#          2014-04-17 00:15:00  126.314162  126.186004
#          2014-04-17 00:30:00  120.928983  120.813018
#          2014-04-17 00:45:00  118.433939  118.624113
#          2014-04-17 01:00:00  119.069452  118.122885
#          2014-04-17 01:15:00  107.382852  107.843810
#          2014-04-17 01:30:00  103.256839  103.424406
#          2014-04-17 01:45:00  101.023510  101.115516
#          2014-04-17 02:00:00  102.789658  102.494205
#          2014-04-17 02:15:00   93.424661   92.707857
#          2014-04-17 02:30:00   96.942899   92.516695
#          2014-04-17 02:45:00   86.301820   86.715898
#          2014-04-17 03:00:00   85.452243   86.061633
#          2014-04-17 03:15:00   78.279222   78.903622
#          2014-04-17 03:30:00   73.207719   74.628597
#          2014-04-17 03:45:00   73.467455   74.102622
#          2014-04-17 04:00:00   71.882966   71.766845
#          2014-04-17 04:15:00   69.743591   71.151114
#          2014-04-17 04:30:00   69.259373   69.296775
#          2014-04-17 04:45:00   69.155013   69.788075
#          2014-04-17 05:00:00   68.269717   70.513487
#          2014-04-17 05:15:00   56.814410   56.437245
#          2014-04-17 05:30:00   55.037496   55.723417
#          2014-04-17 05:45:00   55.320803   55.562665
#          2014-04-17 06:00:00   55.232950   55.913671
#          2014-04-17 06:15:00   53.949756   54.494615
#          2014-04-17 06:30:00   55.851141   57.086957
#          2014-04-17 06:45:00   57.215274   57.198257
#          2014-04-17 07:00:00   45.681473   45.393984
#          2014-04-17 07:15:00   47.420096   46.798585
# ...                                  ...         ...
#          2015-01-31 20:30:00  108.859672  107.433151
#          2015-01-31 20:45:00  111.973698  108.503034
#          2015-01-31 21:00:00  105.713657  108.871983
#          2015-01-31 21:15:00  122.399833  120.716221
#          2015-01-31 21:30:00  120.102953  120.084164
#          2015-01-31 21:45:00  123.615194  122.569155
#          2015-01-31 22:00:00  119.223235  117.642960
#          2015-01-31 22:15:00  105.918560  108.044941
#          2015-01-31 22:30:00  107.330722  115.475090
#          2015-01-31 22:45:00  115.504536  118.889166
#          2015-01-31 23:00:00  116.094780  117.312082
#          2015-01-31 23:15:00  117.042779  115.792284
#          2015-01-31 23:30:00  123.397471  123.994857
#          2015-01-31 23:45:00  111.489322  110.837919
#          2015-02-01 00:00:00  102.466887  102.709601
#          2015-02-01 00:15:00  105.783770  104.525429
#          2015-02-01 00:30:00   97.801278  103.477815
#          2015-02-01 00:45:00   99.174013  102.336416
#          2015-02-01 01:00:00   98.990897   99.264510
#          2015-02-01 01:15:00  118.239159  121.408014
#          2015-02-01 01:30:00  101.465894   96.361009
#          2015-02-01 01:45:00  100.567511   92.391925
#          2015-02-01 02:00:00   79.217358   76.619049
#          2015-02-01 02:15:00   85.125293   76.630206
#          2015-02-01 02:30:00   84.808767   73.011055
#          2015-02-01 02:45:00   86.212779   81.692954
#          2015-02-01 03:00:00  101.380768   88.459293
#          2015-02-01 03:15:00   65.364685   64.103531
#          2015-02-01 03:30:00   62.554910   60.638776
#          2015-02-01 03:45:00   58.840068   59.392707
#
# [27856 rows x 6 columns]

# %%
test.loc[20]['2014-04-17 00:00:00':'2014-04-23 00:00:00'][['true','offline','batch']].plot(figsize=(15,4))
test.loc[20]['2015-01-27 00:00:00':'2015-02-01 23:59:00'][['true','offline','batch']].plot(figsize=(15,4))

# %%
test.index.to_datetime().dayofyear
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   if __name__ == '__main__':
# Int64Index([107, 107, 107, 107, 107, 107, 107, 107, 107, 107,
#             ...
#              32,  32,  32,  32,  32,  32,  32,  32,  32,  32],
#            dtype='int64', length=27932)

# %%
a=test.groupby(test.index.to_datetime().dayofyear, sort=False).mean()
a
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   if __name__ == '__main__':
#            true  last value  previous day  previous week     offline  \
# 107  107.063542  105.942708    104.995833     103.214583  104.829689
# 108  100.204167  108.309375    107.063542     104.943750  100.034430
# 109   89.452083   89.281250    100.204167      91.144792   89.992677
# 110   78.502083   79.286458     89.452083      98.927083   86.927859
# 111  104.895833   95.008333     78.502083      99.862500   90.637076
# 112  110.705208  111.708333    104.895833      99.969792  105.252439
# 113  108.936458  108.089583    110.705208     104.995833  108.879269
# 114  107.834375  109.010417    108.936458     107.063542  109.377374
# 115  107.233333  114.827083    107.834375     100.204167  103.359870
# 116   86.413542   90.683333    107.233333      89.452083   93.041639
# 117   86.965625   80.693750     86.413542      78.502083   84.267811
# 118   93.202083   94.568750     86.965625     104.895833  106.335902
# 119   96.752083   93.392708     93.202083     110.705208  101.838876
# 120   94.870833  101.771875     96.752083     108.936458   96.100301
# 121   81.517708   81.015625     94.870833     107.834375   85.900346
# 122   89.568750   88.247917     81.517708     107.233333   89.065232
# 123   89.414583   88.841667     89.568750      86.413542   84.776938
# 124   92.340625   85.102083     89.414583      86.965625   86.698534
# 125  109.564583  108.959375     92.340625      93.202083   98.836936
# 126  107.889583  105.960417    109.564583      96.752083  105.880573
# 127  112.688542  114.000000    107.889583      94.870833  108.453514
# 128  108.001042  109.856250    112.688542      81.517708  112.063931
# 129  109.426042  113.251042    108.001042      89.568750  102.447006
# 130   89.246875   93.173958    109.426042      89.414583   91.511851
# 131   87.318750   83.729167     89.246875      92.340625   93.773346
# 132   98.798958   96.968750     87.318750     109.564583  105.388457
# 133   98.145833   96.451042     98.798958     107.889583  104.011667
# 134  102.997917  102.814583     98.145833     112.688542  102.950835
# 135  101.492708  100.875000    102.997917     108.001042  104.566831
# 136   96.084375  104.728125    101.492708     109.426042  101.429690
# ..          ...         ...           ...            ...         ...
# 3     82.222917   73.904167     65.645833      74.490625   82.098695
# 4    101.235417   89.269792     82.222917      70.491667   81.108188
# 5    102.087500  108.861458    101.235417      79.428125  102.789842
# 6     96.270833   99.448958    102.087500      72.936458  102.247141
# 7     96.181250   94.838542     96.270833      29.541667   96.630785
# 8     88.857292   94.370833     96.181250      38.596875   97.953746
# 9     87.883333   91.125000     88.857292      65.645833   93.193093
# 10    81.282292   76.544792     87.883333      82.222917   85.494584
# 11    72.153125   75.353125     81.282292     101.235417   96.769211
# 12    86.547917   85.087500     72.153125     102.087500   97.371848
# 13   106.169792   98.321875     86.547917      96.270833   94.356132
# 14   101.596875  104.431250    106.169792      96.181250  104.889418
# 15   101.734375  101.379167    101.596875      88.857292  101.747883
# 16    99.668750  103.365625    101.734375      87.883333   98.118286
# 17    89.084375   86.256250     99.668750      81.282292   90.491362
# 18    84.179167   83.231250     89.084375      72.153125   84.839137
# 19   100.510417  100.590625     84.179167      86.547917   98.119908
# 20    92.481250  102.834375    100.510417     106.169792  105.146211
# 21   106.986458   96.995833     92.481250     101.596875  102.749048
# 22   109.859375  104.567708    106.986458     101.734375  106.193711
# 23    92.512500  103.010417    109.859375      99.668750  102.267765
# 24    85.927083   81.575000     92.512500      89.084375   91.977341
# 25    80.295833   79.915625     85.927083      84.179167   88.734319
# 26   104.066667  102.671875     80.295833     100.510417  100.662095
# 27    96.380208   96.129167    104.066667      92.481250  102.689181
# 28   118.264583  114.869792     96.380208     106.986458  103.131597
# 29   108.186458  112.026042    118.264583     109.859375  112.861398
# 30   114.644792  117.166667    108.186458      92.512500  105.640640
# 31    88.672917   87.654167    114.644792      85.927083   98.301406
# 32    95.341071   68.823214    106.212500      91.333929   98.314067
#
#           batch
# 107  104.915682
# 108  100.044284
# 109   89.982633
# 110   89.820944
# 111   87.021699
# 112  104.295775
# 113  110.084351
# 114  110.652701
# 115  104.593433
# 116   93.236689
# 117   84.051218
# 118  105.310099
# 119  101.598521
# 120   95.656760
# 121   85.727606
# 122   82.410485
# 123   83.990244
# 124   89.663550
# 125  102.562830
# 126  106.874690
# 127  109.989611
# 128  109.849819
# 129  104.619751
# 130   94.298316
# 131   93.839362
# 132  104.178013
# 133  104.873534
# 134  103.534013
# 135  104.689092
# 136  101.912787
# ..          ...
# 3     65.586967
# 4     73.378469
# 5     97.432592
# 6    100.329771
# 7     89.465095
# 8     93.310245
# 9     89.194672
# 10    82.983774
# 11    92.620466
# 12    89.867003
# 13    89.706320
# 14   100.921357
# 15    99.796066
# 16    97.118514
# 17    87.746368
# 18    81.402416
# 19    98.670813
# 20   102.589586
# 21    97.098266
# 22   103.719532
# 23   101.983005
# 24    87.493509
# 25    84.482119
# 26    99.498983
# 27   100.364230
# 28   101.956267
# 29   110.393766
# 30   104.859975
# 31    92.611692
# 32    96.442481
#
# [291 rows x 6 columns]

# %%
from sklearn.metrics import r2_score

def r2( g ):
    r2_lv = r2_score( g['true'], g['last value'] )
    r2_pd = r2_score( g['true'], g['previous day'] )
    r2_pw = r2_score( g['true'], g['previous week'] )
    r2_offline = r2_score( g['true'], g['offline'] )
    r2_batch = r2_score( g['true'], g['batch'] )
    return pd.Series( dict(  r2_lv=r2_lv, r2_pd=r2_pd, r2_pw=r2_pw, r2_offline=r2_offline, r2_batch=r2_batch ) )

#subset = test['2014-04-17 00:00:00':'2014-04-27 00:00:00']
subset = test.loc[20]['2015-01-05 00:00:00':'2015-02-01 23:59:00']
#subset = test['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)
a
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:14: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#     r2_batch     r2_lv  r2_offline     r2_pd     r2_pw
# 5   0.723645 -0.570706    0.753277  0.608645  0.201785
# 6   0.695740 -0.981022    0.707764  0.621184 -2.496323
# 7   0.783763 -0.299510    0.766943  0.788527 -2.970806
# 8   0.882035 -0.679287    0.827702  0.721435  0.002400
# 9   0.769532 -2.065558    0.729472 -0.178633  0.734967
# 10  0.809167 -0.828385    0.726922  0.757059  0.445495
# 11  0.553038  0.445588    0.535448  0.181657  0.128073
# 12  0.729494 -0.093710    0.715340  0.673541  0.624853
# 13  0.671558  0.066480    0.658707  0.586806  0.600238
# 14  0.757539 -0.662315    0.735797  0.586304  0.645584
# 15  0.826154 -0.263253    0.817085  0.743410  0.646673
# 16  0.707678 -3.077208    0.554213 -0.759913  0.565290
# 17  0.665555 -0.987507    0.636375  0.421426  0.626682
# 18  0.785238  0.219325    0.816431 -0.115750  0.595195
# 19  0.828574 -0.346337    0.817641  0.689223  0.635568
# 20  0.721590 -0.336026    0.675970  0.762716  0.557229
# 21  0.820504 -0.264556    0.789747  0.547368  0.740495
# 22  0.562432 -0.772729    0.684606  0.305861  0.292138
# 23  0.598339 -2.438766    0.513579 -0.873757  0.381517
# 24  0.481821 -1.031897    0.430810  0.197149  0.015390
# 25  0.821151  0.150005    0.789847 -0.110584  0.694788
# 26  0.790614 -0.607300    0.787780  0.640098  0.661365
# 27  0.757244 -0.251756    0.766015  0.716175  0.685189
# 28  0.853276 -0.469614    0.870558  0.792749  0.717996
# 29  0.864851 -0.287715    0.853484  0.851619  0.567076
# 30  0.685140 -5.138689    0.470672 -2.114559  0.487153
# 31  0.634592 -0.489597    0.560931  0.303363  0.305495
# 32  0.558725 -0.735961    0.424097 -1.763542  0.062413

# %% [markdown]
# Bar plot for last month. Major improvement for batch is not visible.

# %%
a[['r2_offline','r2_batch']].plot( kind='bar', figsize=(15,4))

# %% [markdown]
# Diff is not very informative

# %%
b['diff'] = b['r2_batch'] - b['r2_offline']
b.reset_index()['diff'].plot()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# Scatter plot for entire testing dataset.

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]
#a[['r2_offline','r2_batch']].plot( kind='hist', figsize=(15,4))
#a[['r2_offline','r2_batch']].hist(figsize=(15,4), bins=20)
#a[['r2_offline','r2_batch']].plot.hist(bins=30)
b[b > 0].plot.hist(bins=30, alpha=0.8)
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]

c = b[b > 0].reset_index()[['r2_offline','r2_batch']]

c = c.fillna(0)

x = c["r2_offline"].values
y = c["r2_batch"].values
data = np.vstack([x, y]).T
bins = np.linspace(0, 1, 30)

plt.hist(data, bins, alpha=0.7, label=['Offline', 'Batch'])
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]

#a[['r2_offline','r2_batch']].plot( figsize=(15,4), marker='*')
b[b > 0].reset_index()[['r2_offline','r2_batch']].plot( figsize=(15,4), marker='.', linestyle='')
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %% [markdown]
# Scatter plot for entire testing dataset with regression plot trend, showing that Batch is better. Unfortunatelly the trend is downword. Maybe try with different sensor.

# %%
import seaborn as sns

sns.set_style("white")

subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]

#c = b.reset_index()[['r2_offline','r2_batch']]
c = b[b > 0].reset_index()[['r2_offline','r2_batch']]
c = c.fillna(0)
c['index'] = c.index

plt.figure(figsize=(13,4))
#sns.pairplot(c, size=5, aspect=.8, kind="reg");
g = sns.regplot(y="r2_offline", x="index", data=c, label='Offline');
g.set(xlim=(0,300), ylim=(0,1))
sns.regplot(y="r2_batch", x="index", data=c, label='Batch');

plt.legend(loc='lower right')
plt.show()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)

# %%
import scipy

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[0].get_xdata(),y=g.get_lines()[0].get_ydata())
print "Offline slope:", slope

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[1].get_xdata(),y=g.get_lines()[1].get_ydata())
print "Batch slope:", slope
# Out:
# Offline slope: -0.000130665701841
# Batch slope: -3.00036993185e-05

# %%
## MAPE analysis

# %%
import regression_metrics as additional_metrics

def mape(g):
    mape_lv = additional_metrics.mean_absolute_percentage_error( g['true'], g['last value'] )
    mape_pd = additional_metrics.mean_absolute_percentage_error( g['true'], g['previous day'] )
    mape_pw = additional_metrics.mean_absolute_percentage_error( g['true'], g['previous week'] )
    mape_offline = additional_metrics.mean_absolute_percentage_error( g['true'], g['offline'] )
    mape_batch = additional_metrics.mean_absolute_percentage_error( g['true'], g['batch'] )
    return pd.Series( dict(  mape_lv=mape_lv, mape_pd=mape_pd, mape_pw=mape_pw, mape_offline=mape_offline, mape_batch=mape_batch ) )

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(mape)
a

b = a[['mape_offline','mape_batch']]

c = b[b > 0].reset_index()[['mape_offline','mape_batch']]
#c = c.fillna(0)
c['index'] = c.index

plt.figure(figsize=(13,4))
#sns.pairplot(c, size=5, aspect=.8, kind="reg");
g = sns.regplot(y="mape_offline", x="index", data=c, label='Offline');
g.set(xlim=(0,300), ylim=(0,70))
sns.regplot(y="mape_batch", x="index", data=c, label='Batch');

plt.legend(loc='upper right')
plt.show()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %%
import scipy

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[0].get_xdata(),y=g.get_lines()[0].get_ydata())
print "Offline slope:", slope

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[1].get_xdata(),y=g.get_lines()[1].get_ydata())
print "Batch slope:", slope
# Out:
# Offline slope: 0.0608984822637
# Batch slope: 0.04574173323

# %% [markdown]
# ## Future work

# %% [markdown]
# - more horizons
# - more sensors
# - online approach
