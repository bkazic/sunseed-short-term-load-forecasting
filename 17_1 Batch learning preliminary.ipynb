# %% [markdown]
# # Batch Learning - Preliminary tests

# %%
# %matplotlib inline
import matplotlib as mpl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import numpy as np
import os
import time
from datetime import timedelta

# %% [markdown]
# ### Load dataset

# %%
input_file_name = "lotOfFeatures.csv"
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), input_file_name)

original_data = pd.read_csv(input_file_path, index_col=0, parse_dates=True)
originalSize = original_data.shape[1]
original_data.head()
original_data.shape
# Out:
# (139678, 535)

# %% [markdown]
# ## Excluding Testing Set

# %% [markdown]
# Spliting the dataset into three parts: training, testing and evaluation (last 10 percent).

# %%
start_time = '2012-02-01 00:00:00'
#start_time = '2014-02-01 00:00:00'
splitting_point = int(0.8 * original_data.shape[0])
splitting_time = original_data.iloc[[splitting_point]].index.to_pydatetime()[0]
#data = original_data[:splitting_time]
data = original_data[start_time:]

# %%
splitting_time
# Out:
# datetime.datetime(2014, 4, 17, 0, 0)

# %%
f = original_data[["id12041992"]].plot(figsize=(20,5)) 
original_data.iloc(splitting_point)
f.axvline(start_time, color='g')
f.axvline(splitting_time, color='r')

# %% [markdown]
# Testing how to iterate day by day

# %%
from datetime import timedelta

splitting_point = int(0.8 * data.shape[0])
splitting_time = data.iloc[[splitting_point]].index.to_pydatetime()[0]
splitting_time = splitting_time.replace(hour=0, minute=0, second=0, microsecond=0) # setting to middnight
latest_time = data.iloc[[-1]].index.to_pydatetime()[0]
    
while (splitting_time < latest_time):
    
    eval_start_time = splitting_time
    splitting_time = splitting_time + timedelta(days=1)
    eval_end_time = splitting_time

    print "\n", start_time, eval_end_time
    
    data[:eval_start_time - timedelta(minutes=15)].info()
    data[eval_start_time:eval_end_time].info()
# Out:
# 2012-02-01 00:00:00 2014-06-28 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84192 entries, 2012-02-01 00:00:00 to 2014-06-26 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 344.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-06-27 00:00:00 to 2014-06-28 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-06-29 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84288 entries, 2012-02-01 00:00:00 to 2014-06-27 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 344.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-06-28 00:00:00 to 2014-06-29 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-06-30 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84384 entries, 2012-02-01 00:00:00 to 2014-06-28 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 345.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-06-29 00:00:00 to 2014-06-30 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-01 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84480 entries, 2012-02-01 00:00:00 to 2014-06-29 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 345.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-06-30 00:00:00 to 2014-07-01 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-02 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84576 entries, 2012-02-01 00:00:00 to 2014-06-30 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 345.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-01 00:00:00 to 2014-07-02 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-03 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84672 entries, 2012-02-01 00:00:00 to 2014-07-01 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 346.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-02 00:00:00 to 2014-07-03 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-04 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84768 entries, 2012-02-01 00:00:00 to 2014-07-02 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 346.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-03 00:00:00 to 2014-07-04 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-05 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84864 entries, 2012-02-01 00:00:00 to 2014-07-03 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 347.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-04 00:00:00 to 2014-07-05 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-06 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84960 entries, 2012-02-01 00:00:00 to 2014-07-04 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 347.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-05 00:00:00 to 2014-07-06 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-07 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85056 entries, 2012-02-01 00:00:00 to 2014-07-05 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 347.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-06 00:00:00 to 2014-07-07 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-08 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85152 entries, 2012-02-01 00:00:00 to 2014-07-06 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 348.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-07 00:00:00 to 2014-07-08 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-09 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85248 entries, 2012-02-01 00:00:00 to 2014-07-07 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 348.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-08 00:00:00 to 2014-07-09 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-10 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85344 entries, 2012-02-01 00:00:00 to 2014-07-08 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 349.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-09 00:00:00 to 2014-07-10 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-11 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85440 entries, 2012-02-01 00:00:00 to 2014-07-09 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 349.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-10 00:00:00 to 2014-07-11 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-12 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85536 entries, 2012-02-01 00:00:00 to 2014-07-10 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 349.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-11 00:00:00 to 2014-07-12 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-13 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85632 entries, 2012-02-01 00:00:00 to 2014-07-11 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 350.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-12 00:00:00 to 2014-07-13 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-14 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85728 entries, 2012-02-01 00:00:00 to 2014-07-12 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 350.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-13 00:00:00 to 2014-07-14 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-15 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85824 entries, 2012-02-01 00:00:00 to 2014-07-13 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 351.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-14 00:00:00 to 2014-07-15 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-16 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85920 entries, 2012-02-01 00:00:00 to 2014-07-14 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 351.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-15 00:00:00 to 2014-07-16 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-17 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86016 entries, 2012-02-01 00:00:00 to 2014-07-15 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 351.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-16 00:00:00 to 2014-07-17 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-18 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86112 entries, 2012-02-01 00:00:00 to 2014-07-16 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 352.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-17 00:00:00 to 2014-07-18 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-19 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86208 entries, 2012-02-01 00:00:00 to 2014-07-17 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 352.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-18 00:00:00 to 2014-07-19 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-20 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86304 entries, 2012-02-01 00:00:00 to 2014-07-18 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 352.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-19 00:00:00 to 2014-07-20 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-21 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86400 entries, 2012-02-01 00:00:00 to 2014-07-19 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 353.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-20 00:00:00 to 2014-07-21 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-22 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86496 entries, 2012-02-01 00:00:00 to 2014-07-20 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 353.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-21 00:00:00 to 2014-07-22 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-23 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86592 entries, 2012-02-01 00:00:00 to 2014-07-21 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 354.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-22 00:00:00 to 2014-07-23 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-24 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86688 entries, 2012-02-01 00:00:00 to 2014-07-22 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 354.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-23 00:00:00 to 2014-07-24 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-25 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86784 entries, 2012-02-01 00:00:00 to 2014-07-23 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 354.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-24 00:00:00 to 2014-07-25 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-26 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86880 entries, 2012-02-01 00:00:00 to 2014-07-24 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 355.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-25 00:00:00 to 2014-07-26 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-27 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86976 entries, 2012-02-01 00:00:00 to 2014-07-25 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 355.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-26 00:00:00 to 2014-07-27 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-28 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87072 entries, 2012-02-01 00:00:00 to 2014-07-26 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 356.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-27 00:00:00 to 2014-07-28 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-29 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87168 entries, 2012-02-01 00:00:00 to 2014-07-27 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 356.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-28 00:00:00 to 2014-07-29 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-30 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87264 entries, 2012-02-01 00:00:00 to 2014-07-28 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 356.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-29 00:00:00 to 2014-07-30 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-07-31 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87360 entries, 2012-02-01 00:00:00 to 2014-07-29 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 357.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-30 00:00:00 to 2014-07-31 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-01 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87456 entries, 2012-02-01 00:00:00 to 2014-07-30 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 357.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-07-31 00:00:00 to 2014-08-01 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-02 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87552 entries, 2012-02-01 00:00:00 to 2014-07-31 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 358.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-01 00:00:00 to 2014-08-02 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-03 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87648 entries, 2012-02-01 00:00:00 to 2014-08-01 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 358.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-02 00:00:00 to 2014-08-03 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-04 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87744 entries, 2012-02-01 00:00:00 to 2014-08-02 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 358.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-03 00:00:00 to 2014-08-04 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-05 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87840 entries, 2012-02-01 00:00:00 to 2014-08-03 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 359.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-04 00:00:00 to 2014-08-05 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-06 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87936 entries, 2012-02-01 00:00:00 to 2014-08-04 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 359.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-05 00:00:00 to 2014-08-06 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-07 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88032 entries, 2012-02-01 00:00:00 to 2014-08-05 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 360.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-06 00:00:00 to 2014-08-07 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-08 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88128 entries, 2012-02-01 00:00:00 to 2014-08-06 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 360.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-07 00:00:00 to 2014-08-08 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-09 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88224 entries, 2012-02-01 00:00:00 to 2014-08-07 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 360.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-08 00:00:00 to 2014-08-09 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-10 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88320 entries, 2012-02-01 00:00:00 to 2014-08-08 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 361.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-09 00:00:00 to 2014-08-10 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-11 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88416 entries, 2012-02-01 00:00:00 to 2014-08-09 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 361.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-10 00:00:00 to 2014-08-11 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-12 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88512 entries, 2012-02-01 00:00:00 to 2014-08-10 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 362.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-11 00:00:00 to 2014-08-12 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-13 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88608 entries, 2012-02-01 00:00:00 to 2014-08-11 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 362.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-12 00:00:00 to 2014-08-13 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-14 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88704 entries, 2012-02-01 00:00:00 to 2014-08-12 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 362.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-13 00:00:00 to 2014-08-14 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-15 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88800 entries, 2012-02-01 00:00:00 to 2014-08-13 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 363.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-14 00:00:00 to 2014-08-15 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-16 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88896 entries, 2012-02-01 00:00:00 to 2014-08-14 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 363.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-15 00:00:00 to 2014-08-16 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-17 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88992 entries, 2012-02-01 00:00:00 to 2014-08-15 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 363.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-16 00:00:00 to 2014-08-17 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-18 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89088 entries, 2012-02-01 00:00:00 to 2014-08-16 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 364.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-17 00:00:00 to 2014-08-18 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-19 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89184 entries, 2012-02-01 00:00:00 to 2014-08-17 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 364.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-18 00:00:00 to 2014-08-19 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-20 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89280 entries, 2012-02-01 00:00:00 to 2014-08-18 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 365.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-19 00:00:00 to 2014-08-20 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-21 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89376 entries, 2012-02-01 00:00:00 to 2014-08-19 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 365.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-20 00:00:00 to 2014-08-21 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-22 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89472 entries, 2012-02-01 00:00:00 to 2014-08-20 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 365.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-21 00:00:00 to 2014-08-22 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-23 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89568 entries, 2012-02-01 00:00:00 to 2014-08-21 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 366.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-22 00:00:00 to 2014-08-23 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-24 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89664 entries, 2012-02-01 00:00:00 to 2014-08-22 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 366.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-23 00:00:00 to 2014-08-24 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-25 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89760 entries, 2012-02-01 00:00:00 to 2014-08-23 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 367.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-24 00:00:00 to 2014-08-25 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-26 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89856 entries, 2012-02-01 00:00:00 to 2014-08-24 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 367.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-25 00:00:00 to 2014-08-26 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-27 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89952 entries, 2012-02-01 00:00:00 to 2014-08-25 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 367.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-26 00:00:00 to 2014-08-27 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-28 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90048 entries, 2012-02-01 00:00:00 to 2014-08-26 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 368.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-27 00:00:00 to 2014-08-28 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-29 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90144 entries, 2012-02-01 00:00:00 to 2014-08-27 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 368.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-28 00:00:00 to 2014-08-29 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-30 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90240 entries, 2012-02-01 00:00:00 to 2014-08-28 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 369.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-29 00:00:00 to 2014-08-30 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-08-31 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90336 entries, 2012-02-01 00:00:00 to 2014-08-29 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 369.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-30 00:00:00 to 2014-08-31 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-01 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90432 entries, 2012-02-01 00:00:00 to 2014-08-30 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 369.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-08-31 00:00:00 to 2014-09-01 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-02 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90528 entries, 2012-02-01 00:00:00 to 2014-08-31 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 370.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-01 00:00:00 to 2014-09-02 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-03 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90624 entries, 2012-02-01 00:00:00 to 2014-09-01 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 370.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-02 00:00:00 to 2014-09-03 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-04 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90720 entries, 2012-02-01 00:00:00 to 2014-09-02 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 371.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-03 00:00:00 to 2014-09-04 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-05 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90816 entries, 2012-02-01 00:00:00 to 2014-09-03 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 371.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-04 00:00:00 to 2014-09-05 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-06 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90912 entries, 2012-02-01 00:00:00 to 2014-09-04 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 371.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-05 00:00:00 to 2014-09-06 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-07 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91008 entries, 2012-02-01 00:00:00 to 2014-09-05 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 372.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-06 00:00:00 to 2014-09-07 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-08 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91104 entries, 2012-02-01 00:00:00 to 2014-09-06 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 372.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-07 00:00:00 to 2014-09-08 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-09 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91200 entries, 2012-02-01 00:00:00 to 2014-09-07 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 372.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-08 00:00:00 to 2014-09-09 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-10 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91296 entries, 2012-02-01 00:00:00 to 2014-09-08 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 373.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-09 00:00:00 to 2014-09-10 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-11 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91392 entries, 2012-02-01 00:00:00 to 2014-09-09 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 373.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-10 00:00:00 to 2014-09-11 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-12 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91488 entries, 2012-02-01 00:00:00 to 2014-09-10 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 374.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-11 00:00:00 to 2014-09-12 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-13 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91584 entries, 2012-02-01 00:00:00 to 2014-09-11 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 374.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-12 00:00:00 to 2014-09-13 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-14 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91680 entries, 2012-02-01 00:00:00 to 2014-09-12 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 374.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-13 00:00:00 to 2014-09-14 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-15 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91776 entries, 2012-02-01 00:00:00 to 2014-09-13 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 375.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-14 00:00:00 to 2014-09-15 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-16 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91872 entries, 2012-02-01 00:00:00 to 2014-09-14 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 375.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-15 00:00:00 to 2014-09-16 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-17 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91968 entries, 2012-02-01 00:00:00 to 2014-09-15 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 376.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-16 00:00:00 to 2014-09-17 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-18 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92064 entries, 2012-02-01 00:00:00 to 2014-09-16 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 376.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-17 00:00:00 to 2014-09-18 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-19 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92160 entries, 2012-02-01 00:00:00 to 2014-09-17 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 376.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-18 00:00:00 to 2014-09-19 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-20 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92256 entries, 2012-02-01 00:00:00 to 2014-09-18 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 377.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-19 00:00:00 to 2014-09-20 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-21 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92352 entries, 2012-02-01 00:00:00 to 2014-09-19 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 377.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-20 00:00:00 to 2014-09-21 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-22 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92448 entries, 2012-02-01 00:00:00 to 2014-09-20 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 378.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-21 00:00:00 to 2014-09-22 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-23 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92544 entries, 2012-02-01 00:00:00 to 2014-09-21 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 378.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-22 00:00:00 to 2014-09-23 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-24 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92640 entries, 2012-02-01 00:00:00 to 2014-09-22 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 378.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-23 00:00:00 to 2014-09-24 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-25 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92736 entries, 2012-02-01 00:00:00 to 2014-09-23 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 379.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-24 00:00:00 to 2014-09-25 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-26 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92832 entries, 2012-02-01 00:00:00 to 2014-09-24 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 379.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-25 00:00:00 to 2014-09-26 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-27 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92928 entries, 2012-02-01 00:00:00 to 2014-09-25 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 380.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-26 00:00:00 to 2014-09-27 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-28 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93024 entries, 2012-02-01 00:00:00 to 2014-09-26 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 380.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-27 00:00:00 to 2014-09-28 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-29 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93120 entries, 2012-02-01 00:00:00 to 2014-09-27 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 380.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-28 00:00:00 to 2014-09-29 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-09-30 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93216 entries, 2012-02-01 00:00:00 to 2014-09-28 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 381.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-29 00:00:00 to 2014-09-30 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-01 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93312 entries, 2012-02-01 00:00:00 to 2014-09-29 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 381.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-09-30 00:00:00 to 2014-10-01 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-02 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93408 entries, 2012-02-01 00:00:00 to 2014-09-30 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 382.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-10-01 00:00:00 to 2014-10-02 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-03 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93504 entries, 2012-02-01 00:00:00 to 2014-10-01 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 382.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-10-02 00:00:00 to 2014-10-03 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-04 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93600 entries, 2012-02-01 00:00:00 to 2014-10-02 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 382.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-10-03 00:00:00 to 2014-10-04 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-05 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93696 entries, 2012-02-01 00:00:00 to 2014-10-03 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 383.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-10-04 00:00:00 to 2014-10-05 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-06 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93792 entries, 2012-02-01 00:00:00 to 2014-10-04 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 383.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-10-05 00:00:00 to 2014-10-06 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-07 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93888 entries, 2012-02-01 00:00:00 to 2014-10-05 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 383.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-10-06 00:00:00 to 2014-10-07 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-08 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93984 entries, 2012-02-01 00:00:00 to 2014-10-06 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 384.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-10-07 00:00:00 to 2014-10-08 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-10-09 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 94080 entries, 2012-02-01 00:00:00 to 2014-10-07 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# ...
# DatetimeIndex: 97 entries, 2014-12-29 00:00:00 to 2014-12-30 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2014-12-31 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102048 entries, 2012-02-01 00:00:00 to 2014-12-29 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 417.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-12-30 00:00:00 to 2014-12-31 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-01 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102144 entries, 2012-02-01 00:00:00 to 2014-12-30 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 417.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2014-12-31 00:00:00 to 2015-01-01 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-02 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102240 entries, 2012-02-01 00:00:00 to 2014-12-31 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 418.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-01 00:00:00 to 2015-01-02 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-03 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102336 entries, 2012-02-01 00:00:00 to 2015-01-01 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 418.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-02 00:00:00 to 2015-01-03 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-04 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102432 entries, 2012-02-01 00:00:00 to 2015-01-02 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 418.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-03 00:00:00 to 2015-01-04 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-05 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102528 entries, 2012-02-01 00:00:00 to 2015-01-03 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 419.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-04 00:00:00 to 2015-01-05 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-06 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102624 entries, 2012-02-01 00:00:00 to 2015-01-04 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 419.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-05 00:00:00 to 2015-01-06 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-07 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102720 entries, 2012-02-01 00:00:00 to 2015-01-05 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 420.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-06 00:00:00 to 2015-01-07 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-08 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102816 entries, 2012-02-01 00:00:00 to 2015-01-06 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 420.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-07 00:00:00 to 2015-01-08 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-09 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102912 entries, 2012-02-01 00:00:00 to 2015-01-07 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 420.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-08 00:00:00 to 2015-01-09 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-10 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103008 entries, 2012-02-01 00:00:00 to 2015-01-08 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 421.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-09 00:00:00 to 2015-01-10 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-11 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103104 entries, 2012-02-01 00:00:00 to 2015-01-09 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 421.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-10 00:00:00 to 2015-01-11 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-12 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103200 entries, 2012-02-01 00:00:00 to 2015-01-10 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 422.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-11 00:00:00 to 2015-01-12 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-13 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103296 entries, 2012-02-01 00:00:00 to 2015-01-11 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 422.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-12 00:00:00 to 2015-01-13 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-14 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103392 entries, 2012-02-01 00:00:00 to 2015-01-12 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 422.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-13 00:00:00 to 2015-01-14 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-15 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103488 entries, 2012-02-01 00:00:00 to 2015-01-13 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 423.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-14 00:00:00 to 2015-01-15 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-16 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103584 entries, 2012-02-01 00:00:00 to 2015-01-14 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 423.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-15 00:00:00 to 2015-01-16 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-17 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103680 entries, 2012-02-01 00:00:00 to 2015-01-15 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 424.0 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-16 00:00:00 to 2015-01-17 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-18 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103776 entries, 2012-02-01 00:00:00 to 2015-01-16 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 424.4 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-17 00:00:00 to 2015-01-18 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-19 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103872 entries, 2012-02-01 00:00:00 to 2015-01-17 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 424.8 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-18 00:00:00 to 2015-01-19 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-20 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103968 entries, 2012-02-01 00:00:00 to 2015-01-18 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 425.2 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-19 00:00:00 to 2015-01-20 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-21 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104064 entries, 2012-02-01 00:00:00 to 2015-01-19 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 425.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-20 00:00:00 to 2015-01-21 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-22 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104160 entries, 2012-02-01 00:00:00 to 2015-01-20 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 425.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-21 00:00:00 to 2015-01-22 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-23 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104256 entries, 2012-02-01 00:00:00 to 2015-01-21 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 426.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-22 00:00:00 to 2015-01-23 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-24 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104352 entries, 2012-02-01 00:00:00 to 2015-01-22 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 426.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-23 00:00:00 to 2015-01-24 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-25 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104448 entries, 2012-02-01 00:00:00 to 2015-01-23 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 427.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-24 00:00:00 to 2015-01-25 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-26 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104544 entries, 2012-02-01 00:00:00 to 2015-01-24 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 427.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-25 00:00:00 to 2015-01-26 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-27 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104640 entries, 2012-02-01 00:00:00 to 2015-01-25 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 427.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-26 00:00:00 to 2015-01-27 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-28 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104736 entries, 2012-02-01 00:00:00 to 2015-01-26 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 428.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-27 00:00:00 to 2015-01-28 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-29 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104832 entries, 2012-02-01 00:00:00 to 2015-01-27 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 428.7 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-28 00:00:00 to 2015-01-29 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-30 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104928 entries, 2012-02-01 00:00:00 to 2015-01-28 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 429.1 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-29 00:00:00 to 2015-01-30 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-01-31 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 105024 entries, 2012-02-01 00:00:00 to 2015-01-29 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 429.5 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-30 00:00:00 to 2015-01-31 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-02-01 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 105120 entries, 2012-02-01 00:00:00 to 2015-01-30 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 429.9 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2015-01-31 00:00:00 to 2015-02-01 00:00:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 406.2 KB
#
# 2012-02-01 00:00:00 2015-02-02 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 105216 entries, 2012-02-01 00:00:00 to 2015-01-31 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 430.3 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 96 entries, 2015-02-01 00:00:00 to 2015-02-01 23:45:00
# Columns: 535 entries, id14061671 to Holiday_sum
# dtypes: float64(526), int64(9)
# memory usage: 402.0 KB

# %% [markdown]
# # Define Machine Learning Models and Data Sets

# %%
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import svm
from sklearn import neighbors
from sklearn import metrics
import regression_metrics as additional_metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.learning_curve import learning_curve
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import explained_variance_score
#from neural_network import PyBrainNN
# Out:
# C:\Python27\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Python27\lib\site-packages\sklearn\learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)
# C:\Python27\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# ## Creating Feature Sets

# %%
autoregressive_ftrs = ['measurement', 'shifted_measurement_1d', 'shifted_measurement_2d', 'shifted_measurement_1w', 
                       'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_mean_d', 
                       'measurement_roll_mean_w', 'measurement_roll_mean_m', 'measurement_roll_min2_d',
                       'measurement_roll_min2_w', 'measurement_roll_max2_d', 'measurement_roll_max2_w',
                       'measurement_roll_var_6h', 'measurement_roll_var_d', 'measurement_roll_var_w']

wetaher_current_ftrs =  ['p', 't2m_termin', 'rh_termin', 'padavine', 'veter_hitrost', 'veter_vek_smer', 'energija_gl',
 'energija_di', 'p_roll_mean_1h', 'p_roll_mean_6h', 'p_roll_mean_d', 'p_roll_mean_w', 'p_roll_mean_m', 'p_roll_var_1h',
 'p_roll_var_d', 't2m_termin_roll_mean_1h', 't2m_termin_roll_mean_6h', 't2m_termin_roll_mean_d', 't2m_termin_roll_mean_w',
 't2m_termin_roll_mean_m', 't2m_termin_roll_min2_d', 't2m_termin_roll_min2_w', 't2m_termin_roll_max2_d',
 't2m_termin_roll_max2_w', 't2m_termin_roll_var_1h', 't2m_termin_roll_var_d', 'rh_termin_roll_mean_1h',
 'rh_termin_roll_mean_6h', 'rh_termin_roll_mean_d', 'rh_termin_roll_mean_w', 'rh_termin_roll_mean_m',
 'rh_termin_roll_min2_d', 'rh_termin_roll_min2_w', 'rh_termin_roll_max2_d', 'rh_termin_roll_max2_w',
 'rh_termin_roll_var_1h', 'rh_termin_roll_var_d', 'energija_gl_roll_mean_1h', 'energija_gl_roll_mean_6h',
 'energija_gl_roll_mean_d', 'energija_gl_roll_mean_w', 'energija_gl_roll_mean_m', 'energija_gl_roll_var_1h',
 'energija_gl_roll_var_d']

weather_forecasted_ftrs =  ['shifted_p', 'shifted_t2m_termin', 'shifted_rh_termin', 'shifted_padavine', 
                            'shifted_veter_hitrost', 'shifted_veter_vek_smer', 'shifted_energija_gl']

date_time_ftrs =  ['shifted_HourOfDay', 'shifted_DayOfWeek', 'shifted_Month', 'shifted_Weekday', 'shifted_Weekend', 
                   'shifted_Holiday', 'shifted_DayBeforeHoliday', 'shifted_DayAfterHodliay', 'shifted_BusinessDay', 
                   'shifted_BusinessDay_sum', 'shifted_Holiday_sum']

top20_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay', 't2m_termin_roll_mean_m', 'shifted_Holiday', 
              'shifted_energija_gl', 'shifted_DayOfWeek', 'shifted_t2m_termin', 'p_roll_var_d', 'shifted_measurement_2d', 
              'measurement_roll_mean_m', 'p_roll_mean_m', 'rh_termin_roll_mean_w']

top10_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay']

# %%
all_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_wc_wf_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs
ar_wc_dt_ftrs = autoregressive_ftrs + wetaher_current_ftrs + date_time_ftrs 
ar_wf_dt_ftrs = autoregressive_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_dt_ftrs = autoregressive_ftrs + date_time_ftrs 
ar_ftrs = autoregressive_ftrs
top20_ftrs = top20_ftrs
top10_ftrs = top10_ftrs

# %% [markdown]
# ## Prediction Results

# %%
class NaiveModel:
    
    def __init__(self, target):
        self.target = target

# %%
horizons = range(1,25)

baselines = [{'name': "Last value", 'init': "NaiveModel('measurement')"},
             {'name': "Previous day", 'init': "NaiveModel('shifted_measurement_1d')"},
             {'name': "Previous week", 'init': "NaiveModel('shifted_measurement_1w')"},
             #{'name': "Measurement average", 'init': "NaiveModel('measurement_avr')"},
            ]

models = [#{'name': "Ridge Regression", 'init': "linear_model.Ridge()"},
          #{'name': "K Nearest Neighbors", 'init': "neighbors.KNeighborsRegressor(n_neighbors = 5)"},
          {'name': "Random Forest", 'init': "RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, n_jobs=16)"},
          #{'name': "SVR", 'init': "svm.SVR(kernel ='rbf', C = 10, gamma = .001)"},
          #{'name': "Neural Network", 'init': "PyBrainNN(hidden_size = 100, learningrate = 0.001, momentum = 0.1, maxEpochs=10)"},
          ]

data_sets = [{'name': "Baselines", 'ftrs': ar_ftrs},
             #{'name': "AR", 'ftrs': ar_ftrs},
             #{'name': "AR_WC_WF", 'ftrs': ar_wc_wf_ftrs},
             #{'name': "AR_DT", 'ftrs': ar_dt_ftrs},             
             #{'name': "AR_WC_DT", 'ftrs': ar_wc_dt_ftrs},
             #{'name': "AR_WF_DT", 'ftrs': ar_wf_dt_ftrs},    
             #{'name': "ALL", 'ftrs': all_ftrs},
             {'name': "TOP_20", 'ftrs': top20_ftrs},
             #{'name': "TOP_10", 'ftrs': top10_ftrs},
             ]

error_metrics = [{'name': "R2 Score", 'short': "R2", 'function': metrics.r2_score},
                 #{'name': "Explained Variance Score", 'short': "EV", 'function': metrics.explained_variance_score},
                 {'name': "Mean Absolute Error", 'short': "MAE", 'function': metrics.mean_absolute_error},
                 #{'name': "Mean Squared Error", 'short': "MSE", 'function': metrics.mean_squared_error},
                 {'name': "Mean Absolute Percentage Error", 'short': "MAPE", 'function': additional_metrics.mean_absolute_percentage_error},
                 {'name': "Mean Absolute Scaled Error", 'short': "MASE", 'function': additional_metrics.mean_absolute_scaled_error}
                ]

#validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['sensor', 'horizon', 'error metric']),
#                             columns=pd.MultiIndex.from_arrays([[],[]], names=['method', 'data set']))

validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric']))

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[],[]], names=['horizon', 'testing_day','dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

def start_prediction_valuation(verbose=False):

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041992']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
        
        #for horizon in range (1,25):
        for horizon in horizons:

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            splitting_point = int(0.8 * data.shape[0])
            splitting_time = data.iloc[[splitting_point]].index.to_pydatetime()[0]
            splitting_time = splitting_time.replace(hour=0, minute=0, second=0, microsecond=0) # setting to middnight
            latest_time = data.iloc[[-1]].index.to_pydatetime()[0]
            
            while (splitting_time < latest_time):
                                
                eval_start_time = splitting_time
                splitting_time = splitting_time + timedelta(days=1)
                eval_end_time = splitting_time
                    
                # Split Training and Testing set
                training_data = sensor_data[:eval_start_time - timedelta(minutes=15)]
                testing_data = sensor_data[eval_start_time:eval_end_time]

                # Create dummy feature vector for linear regression
                sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                        prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                        prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                        prefix='dummy_shifted_Month'))))
                #sensor_data_dummy.dropna(inplace=True)
                dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
                training_data_dummy = sensor_data_dummy[:eval_start_time - timedelta(minutes=15)]
                testing_data_dummy = sensor_data_dummy[eval_start_time:eval_start_time]
                
                if verbose: print "\n\t\t-->{} ({})".format('Evaluation', splitting_time)
                
                for data_set in data_sets:              
                
                    # Create training vectors
                    X_train = training_data[data_set['ftrs']].values
                    y_train = training_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train.shape

                    # Create testing vectors
                    X_test = testing_data[data_set['ftrs']].values
                    y_test = testing_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_test.shape

                    # Create dummy feature vector for linear regression
                    if "shifted_HourOfDay" in data_set['ftrs']: 
                        X_train_dummy = training_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                    else: 
                        X_train_dummy = training_data_dummy[data_set['ftrs']].values
                    y_train_dummy = training_data_dummy[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train_dummy.shape

                    if "shifted_HourOfDay" in data_set['ftrs']:
                        X_test_dummy = testing_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                    else:
                        X_test_dummy = testing_data_dummy[data_set['ftrs']].values    
                    y_test_dummy = testing_data_dummy[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features: ", X_test_dummy.shape

                    if verbose: print "\t\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                              X_train.shape, y_train.shape)

                    if data_set['name'] == "Baselines":
                        for baseline in baselines:

                            if verbose: print "\t\t\t\t-->Computing {}".format(baseline['name'])
                            bl = eval(baseline['init'])

                            for metric in error_metrics:
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                               y_test, testing_data[bl.target])
                                else:
                                    error = metric['function'](y_test, testing_data[bl.target])

                                validation_df.loc[(horizon, splitting_time, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

                    else:    
                        for model in models: 
                            # Initializing model
                            mdl = eval(model['init'])

                            # Model leraning
                            start = time.time() # Start measuring time
                            if model['name'] == "Ridge Regression":
                                mdl.fit(X_train_dummy, y_train_dummy)
                            else:
                                mdl.fit(X_train,y_train)
                            runtime = time.time() - start # Calculate runtime

                            if verbose: print "\t\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

                            for metric in error_metrics:
                                #print "\t-->Error metric: {}".format(metric['name'])

                                if model['name'] == "Ridge Regression":
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
                                                                   y_test_dummy, mdl.predict(X_test_dummy))
                                    else:
                                        error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

                                else: 
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
                                                                   y_test, mdl.predict(X_test))
                                    else:
                                        error = metric['function'](y_test, mdl.predict(X_test))

                                #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
                                validation_df.loc[(horizon, splitting_time, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)


start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df

print "Finished."

output_file_name = "testni_eval_top20_id12041992.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

validation_df.to_csv(output_file_path)
# Out:
# Working with sensor: id12041992
# DatetimeIndex: 105308 entries, 2012-02-01 00:00:00 to 2015-02-01 22:45:00
# DatetimeIndex: 105300 entries, 2012-02-01 00:00:00 to 2015-02-01 20:45:00
# DatetimeIndex: 105288 entries, 2012-02-01 00:00:00 to 2015-02-01 17:45:00
# DatetimeIndex: 105272 entries, 2012-02-01 00:00:00 to 2015-02-01 13:45:00
# DatetimeIndex: 105252 entries, 2012-02-01 00:00:00 to 2015-02-01 08:45:00
# DatetimeIndex: 105228 entries, 2012-02-01 00:00:00 to 2015-02-01 02:45:00
# DatetimeIndex: 105200 entries, 2012-02-01 00:00:00 to 2015-01-31 19:45:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-f9d22a42a7c8> in <module>()
#     154
#     155
# --> 156 start_prediction_valuation(verbose=True)
#     157 # #start_prediction_valuation(verbose=False)
#     158 # #validation_df
#
# <ipython-input-19-f9d22a42a7c8> in start_prediction_valuation(verbose)
#      34             # Shift columns
#      35             start = time.time() # Start measuring time
# ---> 36             sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
#      37             sensor_data.dropna(inplace=True)
#      38             runtime = time.time() - start # Calculate runtime
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in __setitem__(self, key, value)
#    2324
#    2325         if isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2326             self._setitem_array(key, value)
#    2327         elif isinstance(key, DataFrame):
#    2328             self._setitem_frame(key, value)
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in _setitem_array(self, key, value)
#    2350                     raise ValueError('Columns must be same length as key')
#    2351                 for k1, k2 in zip(key, value.columns):
# -> 2352                     self[k1] = value[k2]
#    2353             else:
#    2354                 indexer = self.loc._convert_to_indexer(key, axis=1)
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in _sanitize_column(self, key, value, broadcast)
#    2545
#    2546         if isinstance(value, Series):
# -> 2547             value = reindexer(value)
#    2548
#    2549         elif isinstance(value, DataFrame):
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in reindexer(value)
#    2532                 # GH 4107
#    2533                 try:
# -> 2534                     value = value.reindex(self.index)._values
#    2535                 except Exception as e:
#    2536
#
# C:\Python27\lib\site-packages\pandas\core\series.pyc in reindex(self, index, **kwargs)
#    2424     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    2425     def reindex(self, index=None, **kwargs):
# -> 2426         return super(Series, self).reindex(index=index, **kwargs)
#    2427
#    2428     @Appender(generic._shared_docs['fillna'] % _shared_doc_kwargs)
#
# C:\Python27\lib\site-packages\pandas\core\generic.pyc in reindex(self, *args, **kwargs)
#    2513         # perform the reindex on the axes
#    2514         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 2515                                   fill_value, copy).__finalize__(self)
#    2516
#    2517     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# C:\Python27\lib\site-packages\pandas\core\generic.pyc in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    2526             ax = self._get_axis(a)
#    2527             new_index, indexer = ax.reindex(labels, level=level, limit=limit,
# -> 2528                                             tolerance=tolerance, method=method)
#    2529
#    2530             axis = self._get_axis_number(a)
#
# C:\Python27\lib\site-packages\pandas\core\indexes\base.pyc in reindex(self, target, method, level, limit, tolerance)
#    2880                     indexer = self.get_indexer(target, method=method,
#    2881                                                limit=limit,
# -> 2882                                                tolerance=tolerance)
#    2883                 else:
#    2884                     if method is not None or limit is not None:
#
# C:\Python27\lib\site-packages\pandas\core\indexes\base.pyc in get_indexer(self, target, method, limit, tolerance)
#    2596                                  'backfill or nearest reindexing')
#    2597
# -> 2598             indexer = self._engine.get_indexer(target._values)
#    2599
#    2600         return _ensure_platform_int(indexer)
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_indexer (pandas\_libs\index.c:10535)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.lookup (pandas\_libs\hashtable.c:14956)()
#
# C:\Python27\lib\site-packages\numpy\core\numeric.pyc in asarray(a, dtype, order)
#     461
#     462
# --> 463 def asarray(a, dtype=None, order=None):
#     464     """Convert the input to an array.
#     465
#
# KeyboardInterrupt:

# %%
output_file_name = "testni_eval_top20_id12041992.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

validation_df.to_csv(output_file_path)

# %%
sensor_name = 'id12041992'

# Create dataframe for specific sensor
sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
sensor_data = data[sensor_data_ftrs]

# Replace 'sensor id' column names with 'measurement'
sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

# Compute localized average
average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                 on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
horizon = 1

columnsToShift = list(sensor_data)
shiftedColumns = ["shifted_" + col for col in columnsToShift]

sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')

sensor_data[['measurement', 'shifted_measurement']]
# Out:
#                      measurement  shifted_measurement
# 2012-02-01 00:00:00         81.0                 66.0
# 2012-02-01 00:15:00         69.0                 61.0
# 2012-02-01 00:30:00         59.0                 51.0
# 2012-02-01 00:45:00         66.0                 63.0
# 2012-02-01 01:00:00         66.0                 62.0
# 2012-02-01 01:15:00         61.0                 68.0
# 2012-02-01 01:30:00         51.0                 51.0
# 2012-02-01 01:45:00         63.0                 71.0
# 2012-02-01 02:00:00         62.0                 52.0
# 2012-02-01 02:15:00         68.0                 58.0
# 2012-02-01 02:30:00         51.0                 62.0
# 2012-02-01 02:45:00         71.0                 72.0
# 2012-02-01 03:00:00         52.0                 53.0
# 2012-02-01 03:15:00         58.0                 67.0
# 2012-02-01 03:30:00         62.0                 69.0
# 2012-02-01 03:45:00         72.0                 62.0
# 2012-02-01 04:00:00         53.0                 75.0
# 2012-02-01 04:15:00         67.0                 60.0
# 2012-02-01 04:30:00         69.0                 70.0
# 2012-02-01 04:45:00         62.0                 71.0
# 2012-02-01 05:00:00         75.0                 59.0
# 2012-02-01 05:15:00         60.0                 67.0
# 2012-02-01 05:30:00         70.0                 76.0
# 2012-02-01 05:45:00         71.0                 83.0
# 2012-02-01 06:00:00         59.0                 75.0
# 2012-02-01 06:15:00         67.0                115.0
# 2012-02-01 06:30:00         76.0                139.0
# 2012-02-01 06:45:00         83.0                146.0
# 2012-02-01 07:00:00         75.0                158.0
# 2012-02-01 07:15:00        115.0                175.0
# ...                          ...                  ...
# 2015-02-01 16:30:00        104.3                127.4
# 2015-02-01 16:45:00        113.4                144.3
# 2015-02-01 17:00:00        110.3                129.7
# 2015-02-01 17:15:00        110.9                112.8
# 2015-02-01 17:30:00        127.4                112.2
# 2015-02-01 17:45:00        144.3                115.9
# 2015-02-01 18:00:00        129.7                104.7
# 2015-02-01 18:15:00        112.8                131.8
# 2015-02-01 18:30:00        112.2                137.3
# 2015-02-01 18:45:00        115.9                105.7
# 2015-02-01 19:00:00        104.7                 99.6
# 2015-02-01 19:15:00        131.8                 98.0
# 2015-02-01 19:30:00        137.3                104.8
# 2015-02-01 19:45:00        105.7                110.9
# 2015-02-01 20:00:00         99.6                115.9
# 2015-02-01 20:15:00         98.0                101.2
# 2015-02-01 20:30:00        104.8                 76.9
# 2015-02-01 20:45:00        110.9                 84.1
# 2015-02-01 21:00:00        115.9                 75.7
# 2015-02-01 21:15:00        101.2                 71.3
# 2015-02-01 21:30:00         76.9                 95.2
# 2015-02-01 21:45:00         84.1                 88.6
# 2015-02-01 22:00:00         75.7                 65.4
# 2015-02-01 22:15:00         71.3                 65.7
# 2015-02-01 22:30:00         95.2                 62.9
# 2015-02-01 22:45:00         88.6                 52.3
# 2015-02-01 23:00:00         65.4                  NaN
# 2015-02-01 23:15:00         65.7                  NaN
# 2015-02-01 23:30:00         62.9                  NaN
# 2015-02-01 23:45:00         52.3                  NaN
#
# [105312 rows x 2 columns]

# %%
bl = eval(baselines[0]['init'])
bl.target
# Out:
# 'measurement'

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

def start_prediction_valuation(verbose=False):

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041992']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)
        
        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
        
        for horizon in range (1,25):
        #for horizon in range (1,4):

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            # Split Training and Testing set
            training_data = sensor_data[:splitting_time]
            testing_data = sensor_data[splitting_time:]
            
            # Create dummy feature vector for linear regression
            sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                    prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                    prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                    prefix='dummy_shifted_Month'))))
            #sensor_data_dummy.dropna(inplace=True)
            dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
            training_data_dummy = sensor_data_dummy[:splitting_time]
            testing_data_dummy = sensor_data_dummy[splitting_time:]

            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            for data_set in data_sets:            
                # Create training vectors
                X_train = training_data[data_set['ftrs']].values
                y_train = training_data[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_train.shape
                
                # Create testing vectors
                X_test = testing_data[data_set['ftrs']].values
                y_test = testing_data[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_test.shape
                
                # Create dummy feature vector for linear regression
                if "shifted_HourOfDay" in data_set['ftrs']: 
                    X_train_dummy = training_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                else: 
                    X_train_dummy = training_data_dummy[data_set['ftrs']].values
                y_train_dummy = training_data_dummy[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_train_dummy.shape

                if "shifted_HourOfDay" in data_set['ftrs']:
                    X_test_dummy = testing_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                else:
                    X_test_dummy = testing_data_dummy[data_set['ftrs']].values    
                y_test_dummy = testing_data_dummy[["shifted_measurement"]].values.ravel()
                #print "Using dummy features: ", X_test_dummy.shape
                                                           
                if verbose: print "\n\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                          X_train.shape, y_train.shape)

                if data_set['name'] == "Baselines":
                    for baseline in baselines:
                        
                        if verbose: print "\t\t\t-->Computing {}".format(baseline['name'])
                        bl = eval(baseline['init'])

                        for metric in error_metrics:
                            if metric['short'] == 'MASE':
                                error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                           y_test, testing_data[bl.target])
                            else:
                                error = metric['function'](y_test, testing_data[bl.target])

                            validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)
                                
                        print y_test[1:12]
                        print testing_data[bl.target].values[1:12]
                                
#                 else:    
#                     for model in models: 
#                         # Initializing model
#                         mdl = eval(model['init'])

#                         # Model leraning
#                         start = time.time() # Start measuring time
#                         if model['name'] == "Ridge Regression":
#                             mdl.fit(X_train_dummy, y_train_dummy)
#                         else:
#                             mdl.fit(X_train,y_train)
#                         runtime = time.time() - start # Calculate runtime

#                         if verbose: print "\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

#                         for metric in error_metrics:
#                             #print "\t-->Error metric: {}".format(metric['name'])

#                             if model['name'] == "Ridge Regression":
#                                 if metric['short'] == 'MASE':
#                                     error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
#                                                                y_test_dummy, mdl.predict(X_test_dummy))
#                                 else:
#                                     error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

#                             else: 
#                                 if metric['short'] == 'MASE':
#                                     error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
#                                                                y_test, mdl.predict(X_test))
#                                 else:
#                                     error = metric['function'](y_test, mdl.predict(X_test))

#                             #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
#                             validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

#                             if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df
# Out:
# Working with sensor: id12041992
#
# 	-->Prediction horizont: 1h. Shifting runtime: 0.75s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: 0.637
# 				-->MAE: 15.876
# 				-->MAPE: 18.577
# 				-->MASE: 1.123
# [ 43.1  40.1  37.1  42.5  38.1  40.   37.1  40.1  38.3  39.1  36.1]
# [ 72.1  66.3  66.2  53.   43.1  40.1  37.1  42.5  38.1  40.   37.1]
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.918
# 				-->MAPE: 23.415
# 				-->MASE: 1.409
# [ 43.1  40.1  37.1  42.5  38.1  40.   37.1  40.1  38.3  39.1  36.1]
# [ 57.   40.2  43.   40.1  43.   36.6  40.   40.1  37.4  41.1  41.1]
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.400
# 				-->MAPE: 20.381
# 				-->MASE: 1.231
# [ 43.1  40.1  37.1  42.5  38.1  40.   37.1  40.1  38.3  39.1  36.1]
# [ 49.1  41.   44.1  42.1  45.1  42.3  45.1  44.   52.6  47.   50.2]
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
#
# 	-->Prediction horizont: 2h. Shifting runtime: 1.15s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: 0.370
# 				-->MAE: 21.307
# 				-->MAPE: 25.289
# 				-->MASE: 1.035
# [ 38.1  40.   37.1  40.1  38.3  39.1  36.1  41.   50.2  70.4  82.2]
# [ 72.1  66.3  66.2  53.   43.1  40.1  37.1  42.5  38.1  40.   37.1]
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.918
# 				-->MAPE: 23.412
# 				-->MASE: 0.968
# [ 38.1  40.   37.1  40.1  38.3  39.1  36.1  41.   50.2  70.4  82.2]
# [ 43.   36.6  40.   40.1  37.4  41.1  41.1  40.5  55.   54.1  54. ]
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.402
# 				-->MAPE: 20.381
# 				-->MASE: 0.846
# [ 38.1  40.   37.1  40.1  38.3  39.1  36.1  41.   50.2  70.4  82.2]
# [ 45.1  42.3  45.1  44.   52.6  47.   50.2  49.   57.2  59.   53.3]
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-649-201c2ad0c9f0> in <module>()
#     140 #                             if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)
#     141
# --> 142 start_prediction_valuation(verbose=True)
#     143 #start_prediction_valuation(verbose=False)
#     144 #validation_df
#
# <ipython-input-649-201c2ad0c9f0> in start_prediction_valuation(verbose)
#      46                     prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'],
#      47                     prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'],
# ---> 48                     prefix='dummy_shifted_Month'))))
#      49             #sensor_data_dummy.dropna(inplace=True)
#      50             dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4667         # For SparseDataFrame's benefit
#    4668         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4669                                  rsuffix=rsuffix, sort=sort)
#    4670
#    4671     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4682             return merge(self, other, left_on=on, how=how,
#    4683                          left_index=on is None, right_index=True,
# -> 4684                          suffixes=(lsuffix, rsuffix), sort=sort)
#    4685         else:
#    4686             if on is not None:
#
# C:\Python27\lib\site-packages\pandas\core\reshape\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
#      53                          copy=copy, indicator=indicator)
# ---> 54     return op.get_result()
#      55
#      56
#
# C:\Python27\lib\site-packages\pandas\core\reshape\merge.pyc in get_result(self)
#     581             [(ldata, lindexers), (rdata, rindexers)],
#     582             axes=[llabels.append(rlabels), join_index],
# --> 583             concat_axis=0, copy=self.copy)
#     584
#     585         typ = self.left._constructor
#
# C:\Python27\lib\site-packages\pandas\core\internals.pyc in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    4830     blocks = [make_block(
#    4831         concatenate_join_units(join_units, concat_axis, copy=copy),
# -> 4832         placement=placement) for placement, join_units in concat_plan]
#    4833
#    4834     return BlockManager(blocks, axes)
#
# C:\Python27\lib\site-packages\pandas\core\internals.pyc in combine_concat_plans(plans, concat_axis)
#    5049
#    5050             if last_plc is not None:
# -> 5051                 offset += last_plc.as_slice.stop
#    5052
#    5053     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluation results

# %%
validation_df
# Out:
# sensor                                          id12041992             \
# error metric                                            R2        MAE
# horizon testing_day dataset       model
# 1.0     2014-06-28  Last value    Baselines       0.591010  14.014433
#                     Previous day  Baselines       0.717247  11.328866
#                     Previous week Baselines       0.525938  16.644330
#                     TOP_20        Random Forest   0.824376   9.349535
#         2014-06-29  Last value    Baselines       0.195606   9.813402
#                     Previous day  Baselines      -6.152736  27.529897
#                     Previous week Baselines      -1.113039  16.687629
#                     TOP_20        Random Forest   0.288903   9.111412
#         2014-06-30  Last value    Baselines       0.575196   8.226804
#                     Previous day  Baselines       0.489490   9.102062
#                     Previous week Baselines       0.393274  10.509278
#                     TOP_20        Random Forest   0.793814   6.041215
#         2014-07-01  Last value    Baselines       0.484461  15.505155
#                     Previous day  Baselines      -0.797943  28.007216
#                     Previous week Baselines       0.606016  14.418557
#                     TOP_20        Random Forest   0.788293  10.379309
#         2014-07-02  Last value    Baselines       0.472400  16.456701
#                     Previous day  Baselines       0.559024  15.671134
#                     Previous week Baselines       0.535193  16.109278
#                     TOP_20        Random Forest   0.723927  13.230458
#         2014-07-03  Last value    Baselines       0.462220  14.193814
#                     Previous day  Baselines       0.588972  12.508247
#                     Previous week Baselines      -0.275254  23.797938
#                     TOP_20        Random Forest   0.694443  10.771588
#         2014-07-04  Last value    Baselines       0.278601  16.136082
#                     Previous day  Baselines       0.403564  15.755670
#                     Previous week Baselines       0.720479  10.527835
#                     TOP_20        Random Forest   0.710182   9.632269
#         2014-07-05  Last value    Baselines       0.690746  10.291753
#                     Previous day  Baselines       0.599616  11.044330
# ...                                                    ...        ...
# 7.0     2015-01-25  Previous week Baselines       0.176911  21.367010
#                     TOP_20        Random Forest   0.562373  16.353218
#         2015-01-26  Last value    Baselines      -0.763733  33.793814
#                     Previous day  Baselines       0.245468  21.090722
#                     Previous week Baselines       0.075982  23.191753
#                     TOP_20        Random Forest   0.528064  17.478855
#         2015-01-27  Last value    Baselines      -1.552787  61.775258
#                     Previous day  Baselines      -0.116822  36.389691
#                     Previous week Baselines       0.806617  14.049485
#                     TOP_20        Random Forest   0.875799  12.351585
#         2015-01-28  Last value    Baselines      -1.493953  53.037113
#                     Previous day  Baselines       0.771172  14.548454
#                     Previous week Baselines       0.604877  20.813402
#                     TOP_20        Random Forest   0.800985  14.699558
#         2015-01-29  Last value    Baselines      -1.596696  74.815464
#                     Previous day  Baselines       0.634189  25.945361
#                     Previous week Baselines       0.646342  23.614433
#                     TOP_20        Random Forest   0.727769  23.389170
#         2015-01-30  Last value    Baselines      -1.281584  69.343299
#                     Previous day  Baselines       0.823130  15.829897
#                     Previous week Baselines       0.734818  20.807216
#                     TOP_20        Random Forest   0.859093  17.621804
#         2015-01-31  Last value    Baselines      -1.758573  69.567010
#                     Previous day  Baselines       0.718237  20.404124
#                     Previous week Baselines       0.447357  29.856701
#                     TOP_20        Random Forest   0.830633  16.665742
#         2015-02-01  Last value    Baselines      -1.595495  35.243750
#                     Previous day  Baselines      -3.884913  47.615000
#                     Previous week Baselines       0.324014  16.103750
#                     TOP_20        Random Forest   0.411038  16.242956
#
# sensor
# error metric                                          MAPE      MASE
# horizon testing_day dataset       model
# 1.0     2014-06-28  Last value    Baselines      13.598038  0.989411
#                     Previous day  Baselines      10.044539  0.799811
#                     Previous week Baselines      16.622144  1.175080
#                     TOP_20        Random Forest   8.935971  0.660072
#         2014-06-29  Last value    Baselines      13.126186  0.692822
#                     Previous day  Baselines      38.367757  1.943598
#                     Previous week Baselines      22.285533  1.178139
#                     TOP_20        Random Forest  13.040949  0.643261
#         2014-06-30  Last value    Baselines      10.967124  0.581015
#                     Previous day  Baselines      12.489793  0.642829
#                     Previous week Baselines      14.995595  0.742213
#                     TOP_20        Random Forest   8.541638  0.426658
#         2014-07-01  Last value    Baselines      14.985306  1.095564
#                     Previous day  Baselines      23.389721  1.978935
#                     Previous week Baselines      14.669995  1.018787
#                     TOP_20        Random Forest   9.921547  0.733382
#         2014-07-02  Last value    Baselines      16.238624  1.162669
#                     Previous day  Baselines      17.368712  1.107169
#                     Previous week Baselines      17.820335  1.138124
#                     TOP_20        Random Forest  14.414863  0.934735
#         2014-07-03  Last value    Baselines      14.438118  1.002601
#                     Previous day  Baselines      13.012720  0.883539
#                     Previous week Baselines      23.357464  1.681003
#                     TOP_20        Random Forest  11.325444  0.760867
#         2014-07-04  Last value    Baselines      15.830859  1.139788
#                     Previous day  Baselines      15.716142  1.112917
#                     Previous week Baselines      10.626275  0.743644
#                     TOP_20        Random Forest   9.354752  0.680385
#         2014-07-05  Last value    Baselines      10.495432  0.726846
#                     Previous day  Baselines      10.818013  0.779996
# ...                                                    ...       ...
# 7.0     2015-01-25  Previous week Baselines      27.373187  0.509787
#                     TOP_20        Random Forest  21.703613  0.390165
#         2015-01-26  Last value    Baselines      62.522028  0.806335
#                     Previous day  Baselines      36.340564  0.503233
#                     Previous week Baselines      35.532029  0.553365
#                     TOP_20        Random Forest  28.425266  0.417053
#         2015-01-27  Last value    Baselines      78.618079  1.474237
#                     Previous day  Baselines      33.431836  0.868423
#                     Previous week Baselines      14.089831  0.335284
#                     TOP_20        Random Forest  14.234438  0.294765
#         2015-01-28  Last value    Baselines      72.849858  1.265140
#                     Previous day  Baselines      16.214575  0.347037
#                     Previous week Baselines      26.791807  0.496480
#                     TOP_20        Random Forest  16.758317  0.350641
#         2015-01-29  Last value    Baselines      79.428505  1.784187
#                     Previous day  Baselines      24.262675  0.618741
#                     Previous week Baselines      23.162785  0.563153
#                     TOP_20        Random Forest  21.766293  0.557781
#         2015-01-30  Last value    Baselines      84.840372  1.652476
#                     Previous day  Baselines      20.999198  0.377232
#                     Previous week Baselines      25.412765  0.495843
#                     TOP_20        Random Forest  21.871432  0.419934
#         2015-01-31  Last value    Baselines      70.114553  1.656796
#                     Previous day  Baselines      20.467932  0.485941
#                     Previous week Baselines      25.980990  0.711062
#                     TOP_20        Random Forest  15.624014  0.396908
#         2015-02-01  Last value    Baselines      43.304514  0.838850
#                     Previous day  Baselines      59.093904  1.133303
#                     Previous week Baselines      19.016457  0.383292
#                     TOP_20        Random Forest  20.084876  0.386605
#
# [6156 rows x 4 columns]

# %% [markdown]
# ### Evaluation results averaged over all testing days

# %%
# validation_df['id12041992']['R2'][1.0].unstack()['Baselines'].unstack()['Last value'] # testing
validation_df.groupby(level=['horizon','dataset', 'model'], sort=False).mean()
# Out:
# sensor                              id12041992
# error metric                                R2        MAE       MAPE      MASE
# horizon dataset       model
# 1.0     Last value    Baselines       0.508957  16.294739  19.738277  1.141670
#         Previous day  Baselines      -0.463405  20.531834  25.092916  1.438767
#         Previous week Baselines       0.011775  17.890916  21.838463  1.252257
#         TOP_20        Random Forest   0.575835  12.394644  15.531299  0.868272
# 2.0     Last value    Baselines       0.173764  21.766391  26.844938  1.063473
#         Previous day  Baselines      -0.487620  20.522658  25.121173  1.002824
#         Previous week Baselines      -0.000692  17.879858  21.868915  0.872989
#         TOP_20        Random Forest   0.394524  13.324601  17.042937  0.650917
# 3.0     Last value    Baselines      -0.108788  25.400457  31.445883  0.998967
#         Previous day  Baselines      -0.470800  20.526126  25.110622  0.807296
#         Previous week Baselines       0.009510  17.896056  21.877304  0.703713
#         TOP_20        Random Forest   0.305636  13.471203  17.359612  0.529799
# 4.0     Last value    Baselines      -0.365297  28.593137  35.656417  0.961355
#         Previous day  Baselines      -0.454070  20.522494  25.115438  0.689924
#         Previous week Baselines       0.021349  17.901362  21.903315  0.601877
#         TOP_20        Random Forest   0.253365  13.581762  17.567137  0.456631
# 5.0     Last value    Baselines      -0.694177  32.825058  41.825681  0.975429
#         Previous day  Baselines      -0.432621  20.521140  25.114836  0.609772
#         Previous week Baselines       0.033237  17.908485  21.915538  0.532119
#         TOP_20        Random Forest   0.279814  13.697267  17.731659  0.406999
# 6.0     Last value    Baselines      -1.117910  37.424818  48.730688  0.994705
#         Previous day  Baselines      -0.436366  20.535022  25.127003  0.545830
#         Previous week Baselines       0.031177  17.911104  21.921110  0.476007
#         TOP_20        Random Forest   0.172262  13.875029  18.063344  0.368766
# 7.0     Last value    Baselines      -1.456223  41.731184  54.411375  1.003685
#         Previous day  Baselines      -0.442517  20.626374  25.189015  0.496126
#         Previous week Baselines       0.031969  17.929815  21.857395  0.431186
#         TOP_20        Random Forest   0.074759  14.038782  18.348920  0.337626

# %% [markdown]
# ## Results analysis

# %%
# read from csv
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)
test =  pd.read_csv(input_file_path, index_col=[0,1,2,3], header=[0,1])

test
# Out:
# sensor                                          id12041992             \
# error metric                                            R2        MAE
# horizon testing_day dataset       model
# 1.0     2014-06-28  Last value    Baselines       0.591010  14.014433
#                     Previous day  Baselines       0.717247  11.328866
#                     Previous week Baselines       0.525938  16.644330
#                     TOP_20        Random Forest   0.824376   9.349535
#         2014-06-29  Last value    Baselines       0.195606   9.813402
#                     Previous day  Baselines      -6.152736  27.529897
#                     Previous week Baselines      -1.113039  16.687629
#                     TOP_20        Random Forest   0.288903   9.111412
#         2014-06-30  Last value    Baselines       0.575196   8.226804
#                     Previous day  Baselines       0.489490   9.102062
#                     Previous week Baselines       0.393274  10.509278
#                     TOP_20        Random Forest   0.793814   6.041215
#         2014-07-01  Last value    Baselines       0.484461  15.505155
#                     Previous day  Baselines      -0.797943  28.007216
#                     Previous week Baselines       0.606016  14.418557
#                     TOP_20        Random Forest   0.788293  10.379309
#         2014-07-02  Last value    Baselines       0.472400  16.456701
#                     Previous day  Baselines       0.559024  15.671134
#                     Previous week Baselines       0.535193  16.109278
#                     TOP_20        Random Forest   0.723927  13.230458
#         2014-07-03  Last value    Baselines       0.462220  14.193814
#                     Previous day  Baselines       0.588972  12.508247
#                     Previous week Baselines      -0.275254  23.797938
#                     TOP_20        Random Forest   0.694443  10.771588
#         2014-07-04  Last value    Baselines       0.278601  16.136082
#                     Previous day  Baselines       0.403564  15.755670
#                     Previous week Baselines       0.720479  10.527835
#                     TOP_20        Random Forest   0.710182   9.632269
#         2014-07-05  Last value    Baselines       0.690746  10.291753
#                     Previous day  Baselines       0.599616  11.044330
# ...                                                    ...        ...
# 7.0     2015-01-25  Previous week Baselines       0.176911  21.367010
#                     TOP_20        Random Forest   0.562373  16.353218
#         2015-01-26  Last value    Baselines      -0.763733  33.793814
#                     Previous day  Baselines       0.245468  21.090722
#                     Previous week Baselines       0.075982  23.191753
#                     TOP_20        Random Forest   0.528064  17.478855
#         2015-01-27  Last value    Baselines      -1.552787  61.775258
#                     Previous day  Baselines      -0.116822  36.389691
#                     Previous week Baselines       0.806617  14.049485
#                     TOP_20        Random Forest   0.875799  12.351585
#         2015-01-28  Last value    Baselines      -1.493953  53.037113
#                     Previous day  Baselines       0.771172  14.548454
#                     Previous week Baselines       0.604877  20.813402
#                     TOP_20        Random Forest   0.800985  14.699558
#         2015-01-29  Last value    Baselines      -1.596696  74.815464
#                     Previous day  Baselines       0.634189  25.945361
#                     Previous week Baselines       0.646342  23.614433
#                     TOP_20        Random Forest   0.727769  23.389170
#         2015-01-30  Last value    Baselines      -1.281584  69.343299
#                     Previous day  Baselines       0.823130  15.829897
#                     Previous week Baselines       0.734818  20.807216
#                     TOP_20        Random Forest   0.859093  17.621804
#         2015-01-31  Last value    Baselines      -1.758573  69.567010
#                     Previous day  Baselines       0.718237  20.404124
#                     Previous week Baselines       0.447357  29.856701
#                     TOP_20        Random Forest   0.830633  16.665742
#         2015-02-01  Last value    Baselines      -1.595495  35.243750
#                     Previous day  Baselines      -3.884913  47.615000
#                     Previous week Baselines       0.324014  16.103750
#                     TOP_20        Random Forest   0.411038  16.242956
#
# sensor
# error metric                                          MAPE      MASE
# horizon testing_day dataset       model
# 1.0     2014-06-28  Last value    Baselines      13.598038  0.989411
#                     Previous day  Baselines      10.044539  0.799811
#                     Previous week Baselines      16.622144  1.175080
#                     TOP_20        Random Forest   8.935971  0.660072
#         2014-06-29  Last value    Baselines      13.126186  0.692822
#                     Previous day  Baselines      38.367757  1.943598
#                     Previous week Baselines      22.285533  1.178139
#                     TOP_20        Random Forest  13.040949  0.643261
#         2014-06-30  Last value    Baselines      10.967124  0.581015
#                     Previous day  Baselines      12.489793  0.642829
#                     Previous week Baselines      14.995595  0.742213
#                     TOP_20        Random Forest   8.541638  0.426658
#         2014-07-01  Last value    Baselines      14.985306  1.095564
#                     Previous day  Baselines      23.389721  1.978935
#                     Previous week Baselines      14.669995  1.018787
#                     TOP_20        Random Forest   9.921547  0.733382
#         2014-07-02  Last value    Baselines      16.238624  1.162669
#                     Previous day  Baselines      17.368712  1.107169
#                     Previous week Baselines      17.820335  1.138124
#                     TOP_20        Random Forest  14.414863  0.934735
#         2014-07-03  Last value    Baselines      14.438118  1.002601
#                     Previous day  Baselines      13.012720  0.883539
#                     Previous week Baselines      23.357464  1.681003
#                     TOP_20        Random Forest  11.325444  0.760867
#         2014-07-04  Last value    Baselines      15.830859  1.139788
#                     Previous day  Baselines      15.716142  1.112917
#                     Previous week Baselines      10.626275  0.743644
#                     TOP_20        Random Forest   9.354752  0.680385
#         2014-07-05  Last value    Baselines      10.495432  0.726846
#                     Previous day  Baselines      10.818013  0.779996
# ...                                                    ...       ...
# 7.0     2015-01-25  Previous week Baselines      27.373187  0.509787
#                     TOP_20        Random Forest  21.703613  0.390165
#         2015-01-26  Last value    Baselines      62.522028  0.806335
#                     Previous day  Baselines      36.340564  0.503233
#                     Previous week Baselines      35.532029  0.553365
#                     TOP_20        Random Forest  28.425266  0.417053
#         2015-01-27  Last value    Baselines      78.618079  1.474237
#                     Previous day  Baselines      33.431836  0.868423
#                     Previous week Baselines      14.089831  0.335284
#                     TOP_20        Random Forest  14.234438  0.294765
#         2015-01-28  Last value    Baselines      72.849858  1.265140
#                     Previous day  Baselines      16.214575  0.347037
#                     Previous week Baselines      26.791807  0.496480
#                     TOP_20        Random Forest  16.758317  0.350641
#         2015-01-29  Last value    Baselines      79.428505  1.784187
#                     Previous day  Baselines      24.262675  0.618741
#                     Previous week Baselines      23.162785  0.563153
#                     TOP_20        Random Forest  21.766293  0.557781
#         2015-01-30  Last value    Baselines      84.840372  1.652476
#                     Previous day  Baselines      20.999198  0.377232
#                     Previous week Baselines      25.412765  0.495843
#                     TOP_20        Random Forest  21.871432  0.419934
#         2015-01-31  Last value    Baselines      70.114553  1.656796
#                     Previous day  Baselines      20.467932  0.485941
#                     Previous week Baselines      25.980990  0.711062
#                     TOP_20        Random Forest  15.624014  0.396908
#         2015-02-01  Last value    Baselines      43.304514  0.838850
#                     Previous day  Baselines      59.093904  1.133303
#                     Previous week Baselines      19.016457  0.383292
#                     TOP_20        Random Forest  20.084876  0.386605
#
# [6156 rows x 4 columns]

# %%
test.loc[1]['id12041992']['R2'].unstack()['Random Forest'].unstack()[['TOP_20']].mean()
# Out:
# dataset
# TOP_20    0.575835
# dtype: float64

# %%
test.xs(["Baselines"], level=["model"]).unstack()['id12041992']['R2'].join(
        test.xs(["TOP_20"], level=["dataset"]).unstack()['id12041992']['R2']).loc[1]
# Out:
#              Last value  Previous day  Previous week  Random Forest
# testing_day
# 2014-06-28     0.591010      0.717247       0.525938       0.824376
# 2014-06-29     0.195606     -6.152736      -1.113039       0.288903
# 2014-06-30     0.575196      0.489490       0.393274       0.793814
# 2014-07-01     0.484461     -0.797943       0.606016       0.788293
# 2014-07-02     0.472400      0.559024       0.535193       0.723927
# 2014-07-03     0.462220      0.588972      -0.275254       0.694443
# 2014-07-04     0.278601      0.403564       0.720479       0.710182
# 2014-07-05     0.690746      0.599616       0.676653       0.839842
# 2014-07-06     0.411884     -6.229409       0.526675       0.441861
# 2014-07-07     0.546416      0.758123       0.759812       0.794668
# 2014-07-08     0.674561     -0.808991       0.722573       0.848172
# 2014-07-09     0.752376      0.540417       0.562018       0.857954
# 2014-07-10     0.496538      0.475943       0.317361       0.641523
# 2014-07-11     0.507271      0.084294       0.312838       0.700357
# 2014-07-12     0.472833      0.638945       0.671124       0.727444
# 2014-07-13     0.479496     -2.945378       0.719318       0.674658
# 2014-07-14    -0.163381     -0.205321      -0.078239       0.365349
# 2014-07-15     0.328573     -1.326770       0.669662       0.716630
# 2014-07-16     0.272855      0.578983       0.483689       0.574478
# 2014-07-17     0.501527      0.583649       0.541825       0.765921
# 2014-07-18     0.565450     -0.169163       0.756174       0.744594
# 2014-07-19     0.500831      0.324340       0.293113       0.642287
# 2014-07-20     0.113821     -1.039963       0.021756       0.470452
# 2014-07-21     0.262302     -9.153884       0.000513       0.035209
# 2014-07-22     0.538494     -1.242708       0.438450       0.682083
# 2014-07-23     0.433491     -1.650040      -3.653742       0.185858
# 2014-07-24     0.622469      0.641069      -1.345554       0.649744
# 2014-07-25     0.459194      0.306374       0.021132       0.709406
# 2014-07-26     0.463083      0.534417      -1.231386       0.690052
# 2014-07-27     0.567724     -1.316134      -0.812314       0.590406
# ...                 ...           ...            ...            ...
# 2015-01-04     0.714212      0.698225       0.756639       0.769219
# 2015-01-05     0.729553      0.499424       0.359829       0.763222
# 2015-01-06     0.617183     -0.412883      -0.255870       0.616728
# 2015-01-07     0.630586      0.583802       0.201090       0.791602
# 2015-01-08     0.684112      0.688492      -2.925891       0.785912
# 2015-01-09     0.730295      0.773392      -2.354928       0.848145
# 2015-01-10     0.819147      0.641021       0.061128       0.897879
# 2015-01-11     0.823281     -0.069284       0.764004       0.878733
# 2015-01-12     0.736674      0.323133       0.030542       0.753671
# 2015-01-13     0.806204      0.305664       0.283038       0.888822
# 2015-01-14     0.601776      0.673331       0.592157       0.759370
# 2015-01-15     0.350358      0.584507       0.609253       0.675227
# 2015-01-16     0.469047      0.594343       0.646893       0.761080
# 2015-01-17     0.403337      0.706457       0.630555       0.776745
# 2015-01-18     0.173209     -0.713502       0.573545       0.628831
# 2015-01-19     0.066261      0.329519       0.582446       0.605196
# 2015-01-20     0.527364     -0.114071       0.609047       0.785650
# 2015-01-21     0.538822      0.728911       0.572684       0.824023
# 2015-01-22     0.618972      0.751151       0.605717       0.787724
# 2015-01-23     0.565447      0.504607       0.684148       0.796058
# 2015-01-24     0.324543      0.254680       0.265488       0.630046
# 2015-01-25     0.270487     -0.953438       0.323717       0.602626
# 2015-01-26    -0.332572     -0.060905      -0.145189       0.369031
# 2015-01-27     0.662874     -0.052330       0.746790       0.853962
# 2015-01-28     0.455651      0.716019       0.657526       0.820939
# 2015-01-29     0.727766      0.685431       0.657849       0.837022
# 2015-01-30     0.693438      0.798892       0.731881       0.871242
# 2015-01-31     0.771930      0.770927       0.517524       0.890753
# 2015-02-01     0.261655     -2.439423       0.399708       0.671418
# 2015-02-02     0.147347      0.128603       0.294088       0.575454
#
# [220 rows x 4 columns]

# %% [markdown]
# Ploting R2 evaluation results for each day of testing data. We can see that on particular bad day lowers the overall average drastically.

# %%
test.loc[1]['id12041992']['R2'].unstack()['Random Forest'].unstack()[['TOP_20']].plot( kind='bar', figsize=(15,4))

# %% [markdown]
# Ploting evaluation results by ignoring negative R2 values. This is for horizon 1h into the future.

# %%
a = test.loc[1]['id12041992']['R2'].unstack()['Random Forest'].unstack()[['TOP_20']]
a[a > 0].plot( kind='bar', figsize=(15,4))
a[a > 0].mean()
# Out:
# dataset
# TOP_20    0.723405
# dtype: float64

# %% [markdown]
# 3 hours into the future.

# %%
a = test.loc[3]['id12041992']['R2'].unstack()['Random Forest'].unstack()[['TOP_20']]
a[a > 0].plot( kind='bar', figsize=(15,4))
a[a > 0].mean()
# Out:
# dataset
# TOP_20    0.699797
# dtype: float64

# %% [markdown]
# 5 hours into the future.

# %%
a = test.loc[5]['id12041992']['R2'].unstack()['Random Forest'].unstack()[['TOP_20']]
a[a > 0].plot( kind='bar', figsize=(15,4))
a[a > 0].mean()
# Out:
# dataset
# TOP_20    0.69128
# dtype: float64

# %% [markdown]
# ## Old code

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon','dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'results'])) 

def start_prediction_valuation(verbose=False):

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041992']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
        
        #for horizon in range (1,25):
        for horizon in horizons:

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            splitting_point = int(0.8 * data.shape[0])
            splitting_time = data.iloc[[splitting_point]].index.to_pydatetime()[0]
            splitting_time = splitting_time.replace(hour=0, minute=0, second=0, microsecond=0) # setting to middnight
            latest_time = data.iloc[[-1]].index.to_pydatetime()[0]
            
            # Init results df
            for data_set in data_sets:
                if data_set['name'] == "Baselines":
                    for baseline in baselines:
                        validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, 'true')] = pd.Series([[]]).values
                        validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, 'predicted')] = pd.Series([[]]).values  
                else:
                    for model in models:
                        validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, 'true')] = pd.Series([[]]).values
                        validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, 'predicted')] = pd.Series([[]]).values
            
            
            # batch approach
            while (splitting_time < latest_time):
                                
                eval_start_time = splitting_time
                splitting_time = splitting_time + timedelta(days=1)
                eval_end_time = splitting_time
                    
                # Split Training and Testing set
                training_data = sensor_data[:eval_start_time - timedelta(minutes=15)]
                testing_data = sensor_data[eval_start_time:eval_end_time]

                # Create dummy feature vector for linear regression
                sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                        prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                        prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                        prefix='dummy_shifted_Month'))))
                #sensor_data_dummy.dropna(inplace=True)
                dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
                training_data_dummy = sensor_data_dummy[:eval_start_time - timedelta(minutes=15)]
                testing_data_dummy = sensor_data_dummy[eval_start_time:eval_start_time]
                
                if verbose: print "\n\t\t-->{} ({})".format('Evaluation', splitting_time)
                
                for data_set in data_sets:              
                
                    # Create training vectors
                    X_train = training_data[data_set['ftrs']].values
                    y_train = training_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train.shape

                    # Create testing vectors
                    X_test = testing_data[data_set['ftrs']].values
                    y_test = testing_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_test.shape

                    # Create dummy feature vector for linear regression
                    if "shifted_HourOfDay" in data_set['ftrs']: 
                        X_train_dummy = training_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                    else: 
                        X_train_dummy = training_data_dummy[data_set['ftrs']].values
                    y_train_dummy = training_data_dummy[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train_dummy.shape

                    if "shifted_HourOfDay" in data_set['ftrs']:
                        X_test_dummy = testing_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                    else:
                        X_test_dummy = testing_data_dummy[data_set['ftrs']].values    
                    y_test_dummy = testing_data_dummy[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features: ", X_test_dummy.shape

                    if verbose: print "\t\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                              X_train.shape, y_train.shape)

                    if data_set['name'] == "Baselines":
                        for baseline in baselines:

                            if verbose: print "\t\t\t\t-->Computing {}".format(baseline['name'])
                            bl = eval(baseline['init'])
                            
                            validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, 'true')][0].extend(y_test)
                            validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, 'predicted')][0].extend(testing_data[bl.target])
                            
                    else:
                        for model in models: 
                            # Initializing model
                            mdl = eval(model['init'])

                            # Model leraning
                            start = time.time() # Start measuring time
                            if model['name'] == "Ridge Regression":
                                mdl.fit(X_train_dummy, y_train_dummy)
                            else:
                                mdl.fit(X_train,y_train)
                            runtime = time.time() - start # Calculate runtime

                            if verbose: print "\t\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)
                                                       
                            if model['name'] == "Ridge Regression":
                                validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, 'true')][0].extend(y_test_dummy)
                                validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, 'predicted')][0].extend(mdl.predict(X_test_dummy))
                            else:                               
                                validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, 'true')][0].extend(y_test)
                                validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, 'predicted')][0].extend(mdl.predict(X_test))

            # evaluation
            for data_set in data_sets:
                if data_set['name'] == "Baselines":
                    for baseline in baselines:
                        for metric in error_metrics:
                            true = validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, 'true')][0]
                            pred = validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, 'predicted')][0]

                            error = metric['function'](true, pred)

                            validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

                else:
                    for model in models: 
                        for metric in error_metrics:
                            #print "\t-->Error metric: {}".format(metric['name'])
                            
                            true = validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, 'true')][0]
                            pred = validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, 'predicted')][0]
                            error = metric['function'](true, pred)

                            validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)
                                    
                                
            print validation_df


start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df

print "Finished."

output_file_name = "testni_eval_top20_id12041992.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

validation_df.to_csv(output_file_path)

# %%
rec = {'training': [1, 2, 3], 'testing': [5, 6, 7]}
rec
# Out:
# {'testing': [5, 6, 7], 'training': [1, 2, 3]}

# %%
rec2 = [1,2,3]
rec2
# Out:
# [1, 2, 3]

# %%
rec3 = np.array([5,6,7,8])
rec3
# Out:
# array([5, 6, 7, 8])

# %%
rec4 = np.array([5,6,7,8], dtype='O')
rec4
# Out:
# array([5, 6, 7, 8], dtype=object)

# %%
rec5 = pd.Series([5,6,7,8]).values
rec5
# Out:
# array([5, 6, 7, 8], dtype=int64)

# %%
rec6 = pd.Series([[5,6,7,8]]).values
rec6
# Out:
# array([list([5, 6, 7, 8])], dtype=object)

# %%
a = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric']), dtype='O') 

a.loc[(1, 'a', 'b'), ('c', 'd')] = rec6
#a.loc[(1, 'a', 'b'), ('c', 'd')] = rec4
#a[1.0]['a']['b']['c']['d']= 3
a
# Out:
# sensor                              c
# error metric                        d
# horizon dataset model
# 1.0     a       b      [[5, 6, 7, 8]]

# %%
#a['c','d'][1.0]['a']['b'] = pd.Series([5,6,7,8]).values
a['c','d'][1.0]['a']['b'] = 4
a
# Out:
# sensor                   c
# error metric             d
# horizon dataset model
# 1.0     a       b      4.0

# %%
#ref: https://stackoverflow.com/questions/39103060/adding-a-new-row-to-a-multiindex-pandas-dataframe-with-both-values-and-lists

df = pd.DataFrame(index=pd.MultiIndex(levels=[[], []], labels=[[], []], names=['subj_id', 'org_clip']),
                  columns=['predicted_y', 'actual_y', 'predicted_full', 'actual_full'])

#df.loc[('123', 3),['predicted_y', 'actual_y']] = [2, 5]
#df.loc[('123', 3),['predicted_full', 'actual_full']] = [[1,2,3], [4,5,6]]
#df.loc[('123', 3),['predicted_y', 'actual_y', 'predicted_full', 'actual_full']] = [20, 50, [10, 20, 30], [40, 50, 60]] # doesent work
#df.loc[('123', 3),['predicted_y', 'actual_y', 'predicted_full', 'actual_full']] = pd.Series([20, 50, [10, 20, 30], [40, 50, 60]]).values


# np.array as object
#df.loc[('321', 4),['predicted_y', 'actual_y', 'predicted_full', 'actual_full']] = [20, 50, np.array([10,20,30], dtype='O'), np.array([40,50,60])]

# pd.Series 
df.loc[('123', 3),['predicted_full', 'actual_full']] =  pd.Series([[2, 5],[3,4]]).values

df
# Out:
#                  predicted_y actual_y predicted_full   actual_full
# subj_id org_clip
# 321     4                 20       50   [10, 20, 30]  [40, 50, 60]

# %%
#ref: https://stackoverflow.com/questions/39103060/adding-a-new-row-to-a-multiindex-pandas-dataframe-with-both-values-and-lists

df = pd.DataFrame(index=pd.MultiIndex(levels=[[], []], labels=[[], []], names=['subj_id', 'org_clip']),
                  columns=['true', 'predicted'])

#df.loc[('123', 3),['predicted_y', 'actual_y']] = [2, 5]
#df.loc[('123', 3),['predicted_full', 'actual_full']] = [[1,2,3], [4,5,6]]
#df.loc[('123', 3),['predicted_y', 'actual_y', 'predicted_full', 'actual_full']] = [20, 50, [10, 20, 30], [40, 50, 60]] # doesent work
#df.loc[('123', 3),['predicted_y', 'actual_y', 'predicted_full', 'actual_full']] = pd.Series([20, 50, [10, 20, 30], [40, 50, 60]]).values


# np.array as object
#df.loc[('123', 3),['true', 'predicted']] = [np.array([10,20,30], dtype='O'), np.array([40,50,60], dtype='O')]
#df.loc[('123', 3),'true'] = np.array([10,20,30], dtype='O')

# pd.Series 
#df.loc[('123', 3),['true', 'predicted']] =  pd.Series([[2, 5],[3,4]]).values
df.loc[('123', 3),'true'] =  pd.Series([[2, 5]]).values
df.loc[('124', 3),'true'] =  pd.Series([[2, 5]]).values

df
# Out:
#                       true predicted
# subj_id org_clip
# 123     3         [[2, 5]]       NaN
# 124     3         [[2, 5]]       NaN

# %%
df.index.tolist()
# Out:
# [('123', 3L), ('124', 3L)]

# %%
a = df.loc[('123', 3),'true']
a
# Out:
# array([list([2, 5])], dtype=object)

# %%
a
# Out:
# array([list([2, 5])], dtype=object)

# %%
a = pd.Series([[2, 5]]).values
a
# Out:
# array([list([2, 5])], dtype=object)

# %%
a[0].extend([2,4])
a
# Out:
# array([list([2, 5, 2, 4])], dtype=object)

# %%
a = pd.Series([[]]).values
a[0].extend([2,4])
a[0].extend([2,4])
a
# Out:
# array([list([2, 4, 2, 4])], dtype=object)

# %%
pd.Series([[2, 5]]).values
# Out:
# array([list([2, 5])], dtype=object)

# %%
pd.Series([2, 5]).values
# Out:
# array([2, 5], dtype=int64)

# %%
a = np.array([5,6,7,8])
#df = pd.DataFrame({"a":[a]})
df = pd.DataFrame()
df.loc('a') = 3
df
# Out:
#   File "<ipython-input-263-36f3d5ecc5b7>", line 4
#     df.loc('a') = 3
# SyntaxError: can't assign to function call

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

def start_prediction_valuation(verbose=False):

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041992']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
        
        #for horizon in range (1,25):
        for horizon in horizons:

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            splitting_point = int(0.8 * data.shape[0])
            splitting_time = data.iloc[[splitting_point]].index.to_pydatetime()[0]
            splitting_time = splitting_time.replace(hour=0, minute=0, second=0, microsecond=0) # setting to middnight
            latest_time = data.iloc[[-1]].index.to_pydatetime()[0]
            
            while (splitting_time < latest_time):
                                
                eval_start_time = splitting_time
                splitting_time = splitting_time + timedelta(days=1)
                eval_end_time = splitting_time
                    
                # Split Training and Testing set
                training_data = sensor_data[:eval_start_time - timedelta(minutes=15)]
                testing_data = sensor_data[eval_start_time:eval_end_time]

                # Create dummy feature vector for linear regression
                sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                        prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                        prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                        prefix='dummy_shifted_Month'))))
                #sensor_data_dummy.dropna(inplace=True)
                dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
                training_data_dummy = sensor_data_dummy[:eval_start_time - timedelta(minutes=15)]
                testing_data_dummy = sensor_data_dummy[eval_start_time:eval_start_time]
                
                if verbose: print "\n\t\t-->{} ({})".format('Evaluation', splitting_time)
                
                for data_set in data_sets:              
                
                    # Create training vectors
                    X_train = training_data[data_set['ftrs']].values
                    y_train = training_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train.shape

                    # Create testing vectors
                    X_test = testing_data[data_set['ftrs']].values
                    y_test = testing_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_test.shape

                    # Create dummy feature vector for linear regression
                    if "shifted_HourOfDay" in data_set['ftrs']: 
                        X_train_dummy = training_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                    else: 
                        X_train_dummy = training_data_dummy[data_set['ftrs']].values
                    y_train_dummy = training_data_dummy[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train_dummy.shape

                    if "shifted_HourOfDay" in data_set['ftrs']:
                        X_test_dummy = testing_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                    else:
                        X_test_dummy = testing_data_dummy[data_set['ftrs']].values    
                    y_test_dummy = testing_data_dummy[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features: ", X_test_dummy.shape

                    if verbose: print "\t\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                              X_train.shape, y_train.shape)

                    if data_set['name'] == "Baselines":
                        for baseline in baselines:

                            if verbose: print "\t\t\t\t-->Computing {}".format(baseline['name'])
                            bl = eval(baseline['init'])

                            for metric in error_metrics:
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                               y_test, testing_data[bl.target])
                                else:
                                    error = metric['function'](y_test, testing_data[bl.target])

                                validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)
"""
                    else:    
                        for model in models: 
                            # Initializing model
                            mdl = eval(model['init'])

                            # Model leraning
                            start = time.time() # Start measuring time
                            if model['name'] == "Ridge Regression":
                                mdl.fit(X_train_dummy, y_train_dummy)
                            else:
                                mdl.fit(X_train,y_train)
                            runtime = time.time() - start # Calculate runtime

                            if verbose: print "\t\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

                            for metric in error_metrics:
                                #print "\t-->Error metric: {}".format(metric['name'])

                                if model['name'] == "Ridge Regression":
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
                                                                   y_test_dummy, mdl.predict(X_test_dummy))
                                    else:
                                        error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

                                else: 
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
                                                                   y_test, mdl.predict(X_test))
                                    else:
                                        error = metric['function'](y_test, mdl.predict(X_test))

                                #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
                                validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)
"""

start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df

print "Finished."
# Out:
# Working with sensor: id12041992
#
# 	-->Prediction horizont: 1h. Shifting runtime: 0.72s
#
# 		-->Evaluation (2014-06-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (84192L, 16L), y_train: (84192L,)
# 				-->Computing Last value
# 					-->R2: 0.591
# 					-->MAE: 14.014
# 					-->MAPE: 13.598
# 					-->MASE: 0.989
# 				-->Computing Previous day
# 					-->R2: 0.717
# 					-->MAE: 11.329
# 					-->MAPE: 10.045
# 					-->MASE: 0.800
# 				-->Computing Previous week
# 					-->R2: 0.526
# 					-->MAE: 16.644
# 					-->MAPE: 16.622
# 					-->MASE: 1.175
# 			-->Dataset: TOP_10. X_train: (84192L, 10L), y_train: (84192L,)
#
# 		-->Evaluation (2014-06-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (84288L, 16L), y_train: (84288L,)
# 				-->Computing Last value
# 					-->R2: 0.196
# 					-->MAE: 9.813
# 					-->MAPE: 13.126
# 					-->MASE: 0.693
# 				-->Computing Previous day
# 					-->R2: -6.153
# 					-->MAE: 27.530
# 					-->MAPE: 38.368
# 					-->MASE: 1.944
# 				-->Computing Previous week
# 					-->R2: -1.113
# 					-->MAE: 16.688
# 					-->MAPE: 22.286
# 					-->MASE: 1.178
# 			-->Dataset: TOP_10. X_train: (84288L, 10L), y_train: (84288L,)
#
# 		-->Evaluation (2014-06-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (84384L, 16L), y_train: (84384L,)
# 				-->Computing Last value
# 					-->R2: 0.575
# 					-->MAE: 8.227
# 					-->MAPE: 10.967
# 					-->MASE: 0.581
# 				-->Computing Previous day
# 					-->R2: 0.489
# 					-->MAE: 9.102
# 					-->MAPE: 12.490
# 					-->MASE: 0.643
# 				-->Computing Previous week
# 					-->R2: 0.393
# 					-->MAE: 10.509
# 					-->MAPE: 14.996
# 					-->MASE: 0.742
# 			-->Dataset: TOP_10. X_train: (84384L, 10L), y_train: (84384L,)
#
# 		-->Evaluation (2014-07-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (84480L, 16L), y_train: (84480L,)
# 				-->Computing Last value
# 					-->R2: 0.484
# 					-->MAE: 15.505
# 					-->MAPE: 14.985
# 					-->MASE: 1.096
# 				-->Computing Previous day
# 					-->R2: -0.798
# 					-->MAE: 28.007
# 					-->MAPE: 23.390
# 					-->MASE: 1.979
# 				-->Computing Previous week
# 					-->R2: 0.606
# 					-->MAE: 14.419
# 					-->MAPE: 14.670
# 					-->MASE: 1.019
# 			-->Dataset: TOP_10. X_train: (84480L, 10L), y_train: (84480L,)
#
# 		-->Evaluation (2014-07-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (84576L, 16L), y_train: (84576L,)
# 				-->Computing Last value
# 					-->R2: 0.472
# 					-->MAE: 16.457
# 					-->MAPE: 16.239
# 					-->MASE: 1.163
# 				-->Computing Previous day
# 					-->R2: 0.559
# 					-->MAE: 15.671
# 					-->MAPE: 17.369
# 					-->MASE: 1.107
# 				-->Computing Previous week
# 					-->R2: 0.535
# 					-->MAE: 16.109
# 					-->MAPE: 17.820
# 					-->MASE: 1.138
# 			-->Dataset: TOP_10. X_train: (84576L, 10L), y_train: (84576L,)
#
# 		-->Evaluation (2014-07-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (84672L, 16L), y_train: (84672L,)
# 				-->Computing Last value
# 					-->R2: 0.462
# 					-->MAE: 14.194
# 					-->MAPE: 14.438
# 					-->MASE: 1.003
# 				-->Computing Previous day
# 					-->R2: 0.589
# 					-->MAE: 12.508
# 					-->MAPE: 13.013
# 					-->MASE: 0.884
# 				-->Computing Previous week
# 					-->R2: -0.275
# 					-->MAE: 23.798
# 					-->MAPE: 23.357
# 					-->MASE: 1.681
# 			-->Dataset: TOP_10. X_train: (84672L, 10L), y_train: (84672L,)
#
# 		-->Evaluation (2014-07-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (84768L, 16L), y_train: (84768L,)
# 				-->Computing Last value
# 					-->R2: 0.279
# 					-->MAE: 16.136
# 					-->MAPE: 15.831
# 					-->MASE: 1.140
# 				-->Computing Previous day
# 					-->R2: 0.404
# 					-->MAE: 15.756
# 					-->MAPE: 15.716
# 					-->MASE: 1.113
# 				-->Computing Previous week
# 					-->R2: 0.720
# 					-->MAE: 10.528
# 					-->MAPE: 10.626
# 					-->MASE: 0.744
# 			-->Dataset: TOP_10. X_train: (84768L, 10L), y_train: (84768L,)
#
# 		-->Evaluation (2014-07-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (84864L, 16L), y_train: (84864L,)
# 				-->Computing Last value
# 					-->R2: 0.691
# 					-->MAE: 10.292
# 					-->MAPE: 10.495
# 					-->MASE: 0.727
# 				-->Computing Previous day
# 					-->R2: 0.600
# 					-->MAE: 11.044
# 					-->MAPE: 10.818
# 					-->MASE: 0.780
# 				-->Computing Previous week
# 					-->R2: 0.677
# 					-->MAE: 10.093
# 					-->MAPE: 10.167
# 					-->MASE: 0.713
# 			-->Dataset: TOP_10. X_train: (84864L, 10L), y_train: (84864L,)
#
# 		-->Evaluation (2014-07-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (84960L, 16L), y_train: (84960L,)
# 				-->Computing Last value
# 					-->R2: 0.412
# 					-->MAE: 7.012
# 					-->MAPE: 9.572
# 					-->MASE: 0.495
# 				-->Computing Previous day
# 					-->R2: -6.229
# 					-->MAE: 23.618
# 					-->MAPE: 33.824
# 					-->MASE: 1.668
# 				-->Computing Previous week
# 					-->R2: 0.527
# 					-->MAE: 6.343
# 					-->MAPE: 8.583
# 					-->MASE: 0.448
# 			-->Dataset: TOP_10. X_train: (84960L, 10L), y_train: (84960L,)
#
# 		-->Evaluation (2014-07-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (85056L, 16L), y_train: (85056L,)
# 				-->Computing Last value
# 					-->R2: 0.546
# 					-->MAE: 7.466
# 					-->MAPE: 10.017
# 					-->MASE: 0.528
# 				-->Computing Previous day
# 					-->R2: 0.758
# 					-->MAE: 5.443
# 					-->MAPE: 7.488
# 					-->MASE: 0.385
# 				-->Computing Previous week
# 					-->R2: 0.760
# 					-->MAE: 5.216
# 					-->MAPE: 6.665
# 					-->MASE: 0.369
# 			-->Dataset: TOP_10. X_train: (85056L, 10L), y_train: (85056L,)
#
# 		-->Evaluation (2014-07-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (85152L, 16L), y_train: (85152L,)
# 				-->Computing Last value
# 					-->R2: 0.675
# 					-->MAE: 12.234
# 					-->MAPE: 11.931
# 					-->MASE: 0.865
# 				-->Computing Previous day
# 					-->R2: -0.809
# 					-->MAE: 29.294
# 					-->MAPE: 24.717
# 					-->MASE: 2.072
# 				-->Computing Previous week
# 					-->R2: 0.723
# 					-->MAE: 10.963
# 					-->MAPE: 9.940
# 					-->MASE: 0.775
# 			-->Dataset: TOP_10. X_train: (85152L, 10L), y_train: (85152L,)
#
# 		-->Evaluation (2014-07-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (85248L, 16L), y_train: (85248L,)
# 				-->Computing Last value
# 					-->R2: 0.752
# 					-->MAE: 9.772
# 					-->MAPE: 9.942
# 					-->MASE: 0.691
# 				-->Computing Previous day
# 					-->R2: 0.540
# 					-->MAE: 14.666
# 					-->MAPE: 15.527
# 					-->MASE: 1.037
# 				-->Computing Previous week
# 					-->R2: 0.562
# 					-->MAE: 14.731
# 					-->MAPE: 13.664
# 					-->MASE: 1.042
# 			-->Dataset: TOP_10. X_train: (85248L, 10L), y_train: (85248L,)
#
# 		-->Evaluation (2014-07-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (85344L, 16L), y_train: (85344L,)
# 				-->Computing Last value
# 					-->R2: 0.497
# 					-->MAE: 14.119
# 					-->MAPE: 15.360
# 					-->MASE: 0.999
# 				-->Computing Previous day
# 					-->R2: 0.476
# 					-->MAE: 15.329
# 					-->MAPE: 15.721
# 					-->MASE: 1.085
# 				-->Computing Previous week
# 					-->R2: 0.317
# 					-->MAE: 15.618
# 					-->MAPE: 15.492
# 					-->MASE: 1.105
# 			-->Dataset: TOP_10. X_train: (85344L, 10L), y_train: (85344L,)
#
# 		-->Evaluation (2014-07-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (85440L, 16L), y_train: (85440L,)
# 				-->Computing Last value
# 					-->R2: 0.507
# 					-->MAE: 12.197
# 					-->MAPE: 13.124
# 					-->MASE: 0.863
# 				-->Computing Previous day
# 					-->R2: 0.084
# 					-->MAE: 14.941
# 					-->MAPE: 15.040
# 					-->MASE: 1.057
# 				-->Computing Previous week
# 					-->R2: 0.313
# 					-->MAE: 11.494
# 					-->MAPE: 11.549
# 					-->MASE: 0.813
# 			-->Dataset: TOP_10. X_train: (85440L, 10L), y_train: (85440L,)
#
# 		-->Evaluation (2014-07-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (85536L, 16L), y_train: (85536L,)
# 				-->Computing Last value
# 					-->R2: 0.473
# 					-->MAE: 11.974
# 					-->MAPE: 12.813
# 					-->MASE: 0.847
# 				-->Computing Previous day
# 					-->R2: 0.639
# 					-->MAE: 10.170
# 					-->MAPE: 10.986
# 					-->MASE: 0.720
# 				-->Computing Previous week
# 					-->R2: 0.671
# 					-->MAE: 9.302
# 					-->MAPE: 9.668
# 					-->MASE: 0.658
# 			-->Dataset: TOP_10. X_train: (85536L, 10L), y_train: (85536L,)
#
# 		-->Evaluation (2014-07-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (85632L, 16L), y_train: (85632L,)
# 				-->Computing Last value
# 					-->R2: 0.479
# 					-->MAE: 8.182
# 					-->MAPE: 11.246
# 					-->MASE: 0.579
# 				-->Computing Previous day
# 					-->R2: -2.945
# 					-->MAE: 21.309
# 					-->MAPE: 31.216
# 					-->MASE: 1.508
# 				-->Computing Previous week
# 					-->R2: 0.719
# 					-->MAE: 6.299
# 					-->MAPE: 8.277
# 					-->MASE: 0.446
# 			-->Dataset: TOP_10. X_train: (85632L, 10L), y_train: (85632L,)
#
# 		-->Evaluation (2014-07-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (85728L, 16L), y_train: (85728L,)
# 				-->Computing Last value
# 					-->R2: -0.163
# 					-->MAE: 9.860
# 					-->MAPE: 14.578
# 					-->MASE: 0.698
# 				-->Computing Previous day
# 					-->R2: -0.205
# 					-->MAE: 10.057
# 					-->MAPE: 14.943
# 					-->MASE: 0.712
# 				-->Computing Previous week
# 					-->R2: -0.078
# 					-->MAE: 9.737
# 					-->MAPE: 14.368
# 					-->MASE: 0.690
# 			-->Dataset: TOP_10. X_train: (85728L, 10L), y_train: (85728L,)
#
# 		-->Evaluation (2014-07-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (85824L, 16L), y_train: (85824L,)
# 				-->Computing Last value
# 					-->R2: 0.329
# 					-->MAE: 18.527
# 					-->MAPE: 18.594
# 					-->MASE: 1.312
# 				-->Computing Previous day
# 					-->R2: -1.327
# 					-->MAE: 34.524
# 					-->MAPE: 29.038
# 					-->MASE: 2.446
# 				-->Computing Previous week
# 					-->R2: 0.670
# 					-->MAE: 12.384
# 					-->MAPE: 11.679
# 					-->MASE: 0.877
# 			-->Dataset: TOP_10. X_train: (85824L, 10L), y_train: (85824L,)
#
# 		-->Evaluation (2014-07-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (85920L, 16L), y_train: (85920L,)
# 				-->Computing Last value
# 					-->R2: 0.273
# 					-->MAE: 21.112
# 					-->MAPE: 21.154
# 					-->MASE: 1.495
# 				-->Computing Previous day
# 					-->R2: 0.579
# 					-->MAE: 15.688
# 					-->MAPE: 15.014
# 					-->MASE: 1.111
# 				-->Computing Previous week
# 					-->R2: 0.484
# 					-->MAE: 17.376
# 					-->MAPE: 16.245
# 					-->MASE: 1.230
# 			-->Dataset: TOP_10. X_train: (85920L, 10L), y_train: (85920L,)
#
# 		-->Evaluation (2014-07-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (86016L, 16L), y_train: (86016L,)
# 				-->Computing Last value
# 					-->R2: 0.502
# 					-->MAE: 17.006
# 					-->MAPE: 16.057
# 					-->MASE: 1.204
# 				-->Computing Previous day
# 					-->R2: 0.584
# 					-->MAE: 17.656
# 					-->MAPE: 18.540
# 					-->MASE: 1.250
# 				-->Computing Previous week
# 					-->R2: 0.542
# 					-->MAE: 17.171
# 					-->MAPE: 15.637
# 					-->MASE: 1.215
# 			-->Dataset: TOP_10. X_train: (86016L, 10L), y_train: (86016L,)
#
# 		-->Evaluation (2014-07-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (86112L, 16L), y_train: (86112L,)
# 				-->Computing Last value
# 					-->R2: 0.565
# 					-->MAE: 11.070
# 					-->MAPE: 11.242
# 					-->MASE: 0.783
# 				-->Computing Previous day
# 					-->R2: -0.169
# 					-->MAE: 19.415
# 					-->MAPE: 18.884
# 					-->MASE: 1.374
# 				-->Computing Previous week
# 					-->R2: 0.756
# 					-->MAE: 8.206
# 					-->MAPE: 8.162
# 					-->MASE: 0.581
# 			-->Dataset: TOP_10. X_train: (86112L, 10L), y_train: (86112L,)
#
# 		-->Evaluation (2014-07-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (86208L, 16L), y_train: (86208L,)
# 				-->Computing Last value
# 					-->R2: 0.501
# 					-->MAE: 18.686
# 					-->MAPE: 17.987
# 					-->MASE: 1.322
# 				-->Computing Previous day
# 					-->R2: 0.324
# 					-->MAE: 21.555
# 					-->MAPE: 17.229
# 					-->MASE: 1.525
# 				-->Computing Previous week
# 					-->R2: 0.293
# 					-->MAE: 22.632
# 					-->MAPE: 17.781
# 					-->MASE: 1.602
# 			-->Dataset: TOP_10. X_train: (86208L, 10L), y_train: (86208L,)
#
# 		-->Evaluation (2014-07-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (86304L, 16L), y_train: (86304L,)
# 				-->Computing Last value
# 					-->R2: 0.114
# 					-->MAE: 16.995
# 					-->MAPE: 19.041
# 					-->MASE: 1.202
# 				-->Computing Previous day
# 					-->R2: -1.040
# 					-->MAE: 28.673
# 					-->MAPE: 32.349
# 					-->MASE: 2.028
# 				-->Computing Previous week
# 					-->R2: 0.022
# 					-->MAE: 18.559
# 					-->MAPE: 19.044
# 					-->MASE: 1.313
# 			-->Dataset: TOP_10. X_train: (86304L, 10L), y_train: (86304L,)
#
# 		-->Evaluation (2014-07-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (86400L, 16L), y_train: (86400L,)
# 				-->Computing Last value
# 					-->R2: 0.262
# 					-->MAE: 7.499
# 					-->MAPE: 12.583
# 					-->MASE: 0.530
# 				-->Computing Previous day
# 					-->R2: -9.154
# 					-->MAE: 29.516
# 					-->MAPE: 48.640
# 					-->MASE: 2.088
# 				-->Computing Previous week
# 					-->R2: 0.001
# 					-->MAE: 8.264
# 					-->MAPE: 14.709
# 					-->MASE: 0.584
# 			-->Dataset: TOP_10. X_train: (86400L, 10L), y_train: (86400L,)
#
# 		-->Evaluation (2014-07-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (86496L, 16L), y_train: (86496L,)
# 				-->Computing Last value
# 					-->R2: 0.538
# 					-->MAE: 15.620
# 					-->MAPE: 15.648
# 					-->MASE: 1.105
# 				-->Computing Previous day
# 					-->R2: -1.243
# 					-->MAE: 35.078
# 					-->MAPE: 31.133
# 					-->MASE: 2.482
# 				-->Computing Previous week
# 					-->R2: 0.438
# 					-->MAE: 17.672
# 					-->MAPE: 18.595
# 					-->MASE: 1.251
# 			-->Dataset: TOP_10. X_train: (86496L, 10L), y_train: (86496L,)
#
# 		-->Evaluation (2014-07-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (86592L, 16L), y_train: (86592L,)
# 				-->Computing Last value
# 					-->R2: 0.433
# 					-->MAE: 10.526
# 					-->MAPE: 14.078
# 					-->MASE: 0.745
# 				-->Computing Previous day
# 					-->R2: -1.650
# 					-->MAE: 22.177
# 					-->MAPE: 28.672
# 					-->MASE: 1.569
# 				-->Computing Previous week
# 					-->R2: -3.654
# 					-->MAE: 29.912
# 					-->MAPE: 40.965
# 					-->MASE: 2.116
# 			-->Dataset: TOP_10. X_train: (86592L, 10L), y_train: (86592L,)
#
# 		-->Evaluation (2014-07-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (86688L, 16L), y_train: (86688L,)
# 				-->Computing Last value
# 					-->R2: 0.622
# 					-->MAE: 9.760
# 					-->MAPE: 13.356
# 					-->MASE: 0.691
# 				-->Computing Previous day
# 					-->R2: 0.641
# 					-->MAE: 9.269
# 					-->MAPE: 11.880
# 					-->MASE: 0.656
# 				-->Computing Previous week
# 					-->R2: -1.346
# 					-->MAE: 25.266
# 					-->MAPE: 32.452
# 					-->MASE: 1.788
# 			-->Dataset: TOP_10. X_train: (86688L, 10L), y_train: (86688L,)
#
# 		-->Evaluation (2014-07-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (86784L, 16L), y_train: (86784L,)
# 				-->Computing Last value
# 					-->R2: 0.459
# 					-->MAE: 11.065
# 					-->MAPE: 14.315
# 					-->MASE: 0.783
# 				-->Computing Previous day
# 					-->R2: 0.306
# 					-->MAE: 12.865
# 					-->MAPE: 15.461
# 					-->MASE: 0.911
# 				-->Computing Previous week
# 					-->R2: 0.021
# 					-->MAE: 16.406
# 					-->MAPE: 21.158
# 					-->MASE: 1.162
# 			-->Dataset: TOP_10. X_train: (86784L, 10L), y_train: (86784L,)
#
# 		-->Evaluation (2014-07-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (86880L, 16L), y_train: (86880L,)
# 				-->Computing Last value
# 					-->R2: 0.463
# 					-->MAE: 13.092
# 					-->MAPE: 15.222
# 					-->MASE: 0.927
# 				-->Computing Previous day
# 					-->R2: 0.534
# 					-->MAE: 11.747
# 					-->MAPE: 12.509
# 					-->MASE: 0.832
# 				-->Computing Previous week
# 					-->R2: -1.231
# 					-->MAE: 26.686
# 					-->MAPE: 30.464
# 					-->MASE: 1.890
# 			-->Dataset: TOP_10. X_train: (86880L, 10L), y_train: (86880L,)
#
# 		-->Evaluation (2014-07-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (86976L, 16L), y_train: (86976L,)
# 				-->Computing Last value
# 					-->R2: 0.568
# 					-->MAE: 9.999
# 					-->MAPE: 13.722
# 					-->MASE: 0.708
# 				-->Computing Previous day
# 					-->R2: -1.316
# 					-->MAE: 22.556
# 					-->MAPE: 35.896
# 					-->MASE: 1.597
# 				-->Computing Previous week
# 					-->R2: -0.812
# 					-->MAE: 21.593
# 					-->MAPE: 32.723
# 					-->MASE: 1.529
# 			-->Dataset: TOP_10. X_train: (86976L, 10L), y_train: (86976L,)
#
# 		-->Evaluation (2014-07-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (87072L, 16L), y_train: (87072L,)
# 				-->Computing Last value
# 					-->R2: 0.399
# 					-->MAE: 8.777
# 					-->MAPE: 21.223
# 					-->MASE: 0.622
# 				-->Computing Previous day
# 					-->R2: -2.866
# 					-->MAE: 28.879
# 					-->MAPE: 75.620
# 					-->MASE: 2.046
# 				-->Computing Previous week
# 					-->R2: -0.686
# 					-->MAE: 18.787
# 					-->MAPE: 54.125
# 					-->MASE: 1.331
# 			-->Dataset: TOP_10. X_train: (87072L, 10L), y_train: (87072L,)
#
# 		-->Evaluation (2014-07-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (87168L, 16L), y_train: (87168L,)
# 				-->Computing Last value
# 					-->R2: 0.749
# 					-->MAE: 11.201
# 					-->MAPE: 14.609
# 					-->MASE: 0.794
# 				-->Computing Previous day
# 					-->R2: -2.238
# 					-->MAE: 42.560
# 					-->MAPE: 47.775
# 					-->MASE: 3.016
# 				-->Computing Previous week
# 					-->R2: 0.210
# 					-->MAE: 17.922
# 					-->MAPE: 23.689
# 					-->MASE: 1.270
# 			-->Dataset: TOP_10. X_train: (87168L, 10L), y_train: (87168L,)
#
# 		-->Evaluation (2014-07-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (87264L, 16L), y_train: (87264L,)
# 				-->Computing Last value
# 					-->R2: 0.580
# 					-->MAE: 11.197
# 					-->MAPE: 15.458
# 					-->MASE: 0.794
# 				-->Computing Previous day
# 					-->R2: 0.527
# 					-->MAE: 12.381
# 					-->MAPE: 16.670
# 					-->MASE: 0.878
# 				-->Computing Previous week
# 					-->R2: 0.646
# 					-->MAE: 10.794
# 					-->MAPE: 15.305
# 					-->MASE: 0.765
# 			-->Dataset: TOP_10. X_train: (87264L, 10L), y_train: (87264L,)
#
# 		-->Evaluation (2014-07-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (87360L, 16L), y_train: (87360L,)
# 				-->Computing Last value
# 					-->R2: 0.644
# 					-->MAE: 11.691
# 					-->MAPE: 15.371
# 					-->MASE: 0.829
# 				-->Computing Previous day
# 					-->R2: 0.630
# 					-->MAE: 11.352
# 					-->MAPE: 14.552
# 					-->MASE: 0.805
# 				-->Computing Previous week
# 					-->R2: 0.716
# 					-->MAE: 9.342
# 					-->MAPE: 11.647
# 					-->MASE: 0.662
# 			-->Dataset: TOP_10. X_train: (87360L, 10L), y_train: (87360L,)
#
# 		-->Evaluation (2014-08-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (87456L, 16L), y_train: (87456L,)
# 				-->Computing Last value
# 					-->R2: 0.612
# 					-->MAE: 13.587
# 					-->MAPE: 15.636
# 					-->MASE: 0.964
# 				-->Computing Previous day
# 					-->R2: 0.111
# 					-->MAE: 18.311
# 					-->MAPE: 17.819
# 					-->MASE: 1.299
# 				-->Computing Previous week
# 					-->R2: 0.442
# 					-->MAE: 15.956
# 					-->MAPE: 16.817
# 					-->MASE: 1.132
# 			-->Dataset: TOP_10. X_train: (87456L, 10L), y_train: (87456L,)
#
# 		-->Evaluation (2014-08-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (87552L, 16L), y_train: (87552L,)
# 				-->Computing Last value
# 					-->R2: 0.701
# 					-->MAE: 14.051
# 					-->MAPE: 16.743
# 					-->MASE: 0.996
# 				-->Computing Previous day
# 					-->R2: 0.758
# 					-->MAE: 12.343
# 					-->MAPE: 13.963
# 					-->MASE: 0.875
# 				-->Computing Previous week
# 					-->R2: 0.646
# 					-->MAE: 15.205
# 					-->MAPE: 17.272
# 					-->MASE: 1.078
# 			-->Dataset: TOP_10. X_train: (87552L, 10L), y_train: (87552L,)
#
# 		-->Evaluation (2014-08-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (87648L, 16L), y_train: (87648L,)
# 				-->Computing Last value
# 					-->R2: 0.689
# 					-->MAE: 9.059
# 					-->MAPE: 14.560
# 					-->MASE: 0.642
# 				-->Computing Previous day
# 					-->R2: -1.611
# 					-->MAE: 24.467
# 					-->MAPE: 37.312
# 					-->MASE: 1.735
# 				-->Computing Previous week
# 					-->R2: 0.424
# 					-->MAE: 12.263
# 					-->MAPE: 19.930
# 					-->MASE: 0.870
# 			-->Dataset: TOP_10. X_train: (87648L, 10L), y_train: (87648L,)
#
# 		-->Evaluation (2014-08-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (87744L, 16L), y_train: (87744L,)
# 				-->Computing Last value
# 					-->R2: 0.550
# 					-->MAE: 8.910
# 					-->MAPE: 16.291
# 					-->MASE: 0.632
# 				-->Computing Previous day
# 					-->R2: 0.382
# 					-->MAE: 10.105
# 					-->MAPE: 17.287
# 					-->MASE: 0.717
# 				-->Computing Previous week
# 					-->R2: -0.725
# 					-->MAE: 20.214
# 					-->MAPE: 32.667
# 					-->MASE: 1.434
# 			-->Dataset: TOP_10. X_train: (87744L, 10L), y_train: (87744L,)
#
# 		-->Evaluation (2014-08-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (87840L, 16L), y_train: (87840L,)
# 				-->Computing Last value
# 					-->R2: 0.724
# 					-->MAE: 12.996
# 					-->MAPE: 16.025
# 					-->MASE: 0.922
# 				-->Computing Previous day
# 					-->R2: -0.571
# 					-->MAE: 29.739
# 					-->MAPE: 28.088
# 					-->MASE: 2.111
# 				-->Computing Previous week
# 					-->R2: 0.855
# 					-->MAE: 8.827
# 					-->MAPE: 9.498
# 					-->MASE: 0.626
# 			-->Dataset: TOP_10. X_train: (87840L, 10L), y_train: (87840L,)
#
# 		-->Evaluation (2014-08-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (87936L, 16L), y_train: (87936L,)
# 				-->Computing Last value
# 					-->R2: 0.587
# 					-->MAE: 11.447
# 					-->MAPE: 15.373
# 					-->MASE: 0.813
# 				-->Computing Previous day
# 					-->R2: 0.171
# 					-->MAE: 16.172
# 					-->MAPE: 21.492
# 					-->MASE: 1.148
# 				-->Computing Previous week
# 					-->R2: 0.673
# 					-->MAE: 10.401
# 					-->MAPE: 14.181
# 					-->MASE: 0.738
# 			-->Dataset: TOP_10. X_train: (87936L, 10L), y_train: (87936L,)
#
# 		-->Evaluation (2014-08-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (88032L, 16L), y_train: (88032L,)
# 				-->Computing Last value
# 					-->R2: 0.680
# 					-->MAE: 11.192
# 					-->MAPE: 13.979
# 					-->MASE: 0.795
# 				-->Computing Previous day
# 					-->R2: 0.773
# 					-->MAE: 9.873
# 					-->MAPE: 12.249
# 					-->MASE: 0.701
# 				-->Computing Previous week
# 					-->R2: 0.798
# 					-->MAE: 8.844
# 					-->MAPE: 10.683
# 					-->MASE: 0.628
# 			-->Dataset: TOP_10. X_train: (88032L, 10L), y_train: (88032L,)
#
# 		-->Evaluation (2014-08-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (88128L, 16L), y_train: (88128L,)
# 				-->Computing Last value
# 					-->R2: 0.641
# 					-->MAE: 12.555
# 					-->MAPE: 15.496
# 					-->MASE: 0.892
# 				-->Computing Previous day
# 					-->R2: 0.698
# 					-->MAE: 11.910
# 					-->MAPE: 13.716
# 					-->MASE: 0.846
# 				-->Computing Previous week
# 					-->R2: 0.726
# 					-->MAE: 10.196
# 					-->MAPE: 11.485
# 					-->MASE: 0.724
# 			-->Dataset: TOP_10. X_train: (88128L, 10L), y_train: (88128L,)
#
# 		-->Evaluation (2014-08-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (88224L, 16L), y_train: (88224L,)
# 				-->Computing Last value
# 					-->R2: 0.689
# 					-->MAE: 10.902
# 					-->MAPE: 12.584
# 					-->MASE: 0.774
# 				-->Computing Previous day
# 					-->R2: 0.852
# 					-->MAE: 7.886
# 					-->MAPE: 10.098
# 					-->MASE: 0.560
# 				-->Computing Previous week
# 					-->R2: 0.792
# 					-->MAE: 9.833
# 					-->MAPE: 11.696
# 					-->MASE: 0.698
# 			-->Dataset: TOP_10. X_train: (88224L, 10L), y_train: (88224L,)
#
# 		-->Evaluation (2014-08-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (88320L, 16L), y_train: (88320L,)
# 				-->Computing Last value
# 					-->R2: 0.574
# 					-->MAE: 10.352
# 					-->MAPE: 15.754
# 					-->MASE: 0.735
# 				-->Computing Previous day
# 					-->R2: -0.175
# 					-->MAE: 16.839
# 					-->MAPE: 24.263
# 					-->MASE: 1.196
# 				-->Computing Previous week
# 					-->R2: 0.810
# 					-->MAE: 7.067
# 					-->MAPE: 9.365
# 					-->MASE: 0.502
# 			-->Dataset: TOP_10. X_train: (88320L, 10L), y_train: (88320L,)
#
# 		-->Evaluation (2014-08-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (88416L, 16L), y_train: (88416L,)
# 				-->Computing Last value
# 					-->R2: 0.621
# 					-->MAE: 7.406
# 					-->MAPE: 12.725
# 					-->MASE: 0.526
# 				-->Computing Previous day
# 					-->R2: 0.259
# 					-->MAE: 11.612
# 					-->MAPE: 18.756
# 					-->MASE: 0.825
# 				-->Computing Previous week
# 					-->R2: 0.704
# 					-->MAE: 7.100
# 					-->MAPE: 11.054
# 					-->MASE: 0.505
# 			-->Dataset: TOP_10. X_train: (88416L, 10L), y_train: (88416L,)
#
# 		-->Evaluation (2014-08-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (88512L, 16L), y_train: (88512L,)
# 				-->Computing Last value
# 					-->R2: 0.681
# 					-->MAE: 12.893
# 					-->MAPE: 15.134
# 					-->MASE: 0.917
# 				-->Computing Previous day
# 					-->R2: -0.407
# 					-->MAE: 28.180
# 					-->MAPE: 27.366
# 					-->MASE: 2.003
# 				-->Computing Previous week
# 					-->R2: 0.875
# 					-->MAE: 7.702
# 					-->MAPE: 8.360
# 					-->MASE: 0.548
# 			-->Dataset: TOP_10. X_train: (88512L, 10L), y_train: (88512L,)
#
# 		-->Evaluation (2014-08-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (88608L, 16L), y_train: (88608L,)
# 				-->Computing Last value
# 					-->R2: 0.660
# 					-->MAE: 10.595
# 					-->MAPE: 13.132
# 					-->MASE: 0.753
# 				-->Computing Previous day
# 					-->R2: 0.401
# 					-->MAE: 13.352
# 					-->MAPE: 16.782
# 					-->MASE: 0.949
# 				-->Computing Previous week
# 					-->R2: 0.773
# 					-->MAE: 8.954
# 					-->MAPE: 10.721
# 					-->MASE: 0.637
# 			-->Dataset: TOP_10. X_train: (88608L, 10L), y_train: (88608L,)
#
# 		-->Evaluation (2014-08-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (88704L, 16L), y_train: (88704L,)
# 				-->Computing Last value
# 					-->R2: 0.705
# 					-->MAE: 11.889
# 					-->MAPE: 14.447
# 					-->MASE: 0.846
# 				-->Computing Previous day
# 					-->R2: 0.867
# 					-->MAE: 7.723
# 					-->MAPE: 8.657
# 					-->MASE: 0.549
# 				-->Computing Previous week
# 					-->R2: 0.854
# 					-->MAE: 8.826
# 					-->MAPE: 10.300
# 					-->MASE: 0.628
# 			-->Dataset: TOP_10. X_train: (88704L, 10L), y_train: (88704L,)
#
# 		-->Evaluation (2014-08-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (88800L, 16L), y_train: (88800L,)
# 				-->Computing Last value
# 					-->R2: 0.596
# 					-->MAE: 10.413
# 					-->MAPE: 13.011
# 					-->MASE: 0.741
# 				-->Computing Previous day
# 					-->R2: 0.361
# 					-->MAE: 12.557
# 					-->MAPE: 14.585
# 					-->MASE: 0.893
# 				-->Computing Previous week
# 					-->R2: 0.587
# 					-->MAE: 10.210
# 					-->MAPE: 12.305
# 					-->MASE: 0.726
# 			-->Dataset: TOP_10. X_train: (88800L, 10L), y_train: (88800L,)
#
# 		-->Evaluation (2014-08-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (88896L, 16L), y_train: (88896L,)
# 				-->Computing Last value
# 					-->R2: 0.558
# 					-->MAE: 11.295
# 					-->MAPE: 15.914
# 					-->MASE: 0.804
# 				-->Computing Previous day
# 					-->R2: 0.169
# 					-->MAE: 13.158
# 					-->MAPE: 20.295
# 					-->MASE: 0.936
# 				-->Computing Previous week
# 					-->R2: -0.367
# 					-->MAE: 17.610
# 					-->MAPE: 25.692
# 					-->MASE: 1.253
# 			-->Dataset: TOP_10. X_train: (88896L, 10L), y_train: (88896L,)
#
# 		-->Evaluation (2014-08-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (88992L, 16L), y_train: (88992L,)
# 				-->Computing Last value
# 					-->R2: 0.543
# 					-->MAE: 10.511
# 					-->MAPE: 17.143
# 					-->MASE: 0.748
# 				-->Computing Previous day
# 					-->R2: 0.515
# 					-->MAE: 9.779
# 					-->MAPE: 15.319
# 					-->MASE: 0.696
# 				-->Computing Previous week
# 					-->R2: 0.542
# 					-->MAE: 10.309
# 					-->MAPE: 16.164
# 					-->MASE: 0.734
# 			-->Dataset: TOP_10. X_train: (88992L, 10L), y_train: (88992L,)
#
# 		-->Evaluation (2014-08-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (89088L, 16L), y_train: (89088L,)
# 				-->Computing Last value
# 					-->R2: 0.498
# 					-->MAE: 14.626
# 					-->MAPE: 20.291
# 					-->MASE: 1.041
# 				-->Computing Previous day
# 					-->R2: 0.180
# 					-->MAE: 19.081
# 					-->MAPE: 21.795
# 					-->MASE: 1.358
# 				-->Computing Previous week
# 					-->R2: 0.074
# 					-->MAE: 19.886
# 					-->MAPE: 23.063
# 					-->MASE: 1.416
# 			-->Dataset: TOP_10. X_train: (89088L, 10L), y_train: (89088L,)
#
# 		-->Evaluation (2014-08-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (89184L, 16L), y_train: (89184L,)
# 				-->Computing Last value
# 					-->R2: 0.434
# 					-->MAE: 14.518
# 					-->MAPE: 16.093
# 					-->MASE: 1.033
# 				-->Computing Previous day
# 					-->R2: -0.523
# 					-->MAE: 23.570
# 					-->MAPE: 24.213
# 					-->MASE: 1.678
# 				-->Computing Previous week
# 					-->R2: 0.667
# 					-->MAE: 11.607
# 					-->MAPE: 12.369
# 					-->MASE: 0.826
# 			-->Dataset: TOP_10. X_train: (89184L, 10L), y_train: (89184L,)
#
# 		-->Evaluation (2014-08-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (89280L, 16L), y_train: (89280L,)
# 				-->Computing Last value
# 					-->R2: 0.563
# 					-->MAE: 12.488
# 					-->MAPE: 14.396
# 					-->MASE: 0.889
# 				-->Computing Previous day
# 					-->R2: 0.436
# 					-->MAE: 13.374
# 					-->MAPE: 15.599
# 					-->MASE: 0.952
# 				-->Computing Previous week
# 					-->R2: 0.807
# 					-->MAE: 8.242
# 					-->MAPE: 8.822
# 					-->MASE: 0.587
# 			-->Dataset: TOP_10. X_train: (89280L, 10L), y_train: (89280L,)
#
# 		-->Evaluation (2014-08-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (89376L, 16L), y_train: (89376L,)
# 				-->Computing Last value
# 					-->R2: 0.672
# 					-->MAE: 12.233
# 					-->MAPE: 12.524
# 					-->MASE: 0.871
# 				-->Computing Previous day
# 					-->R2: 0.682
# 					-->MAE: 11.341
# 					-->MAPE: 10.694
# 					-->MASE: 0.807
# 				-->Computing Previous week
# 					-->R2: 0.638
# 					-->MAE: 13.378
# 					-->MAPE: 13.656
# 					-->MASE: 0.952
# 			-->Dataset: TOP_10. X_train: (89376L, 10L), y_train: (89376L,)
#
# 		-->Evaluation (2014-08-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (89472L, 16L), y_train: (89472L,)
# 				-->Computing Last value
# 					-->R2: 0.579
# 					-->MAE: 15.752
# 					-->MAPE: 16.568
# 					-->MASE: 1.121
# 				-->Computing Previous day
# 					-->R2: 0.653
# 					-->MAE: 13.856
# 					-->MAPE: 13.732
# 					-->MASE: 0.986
# 				-->Computing Previous week
# 					-->R2: 0.419
# 					-->MAE: 17.824
# 					-->MAPE: 16.271
# 					-->MASE: 1.269
# 			-->Dataset: TOP_10. X_train: (89472L, 10L), y_train: (89472L,)
#
# 		-->Evaluation (2014-08-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (89568L, 16L), y_train: (89568L,)
# 				-->Computing Last value
# 					-->R2: 0.677
# 					-->MAE: 12.812
# 					-->MAPE: 13.817
# 					-->MASE: 0.912
# 				-->Computing Previous day
# 					-->R2: 0.709
# 					-->MAE: 12.414
# 					-->MAPE: 14.708
# 					-->MASE: 0.884
# 				-->Computing Previous week
# 					-->R2: -0.252
# 					-->MAE: 22.711
# 					-->MAPE: 21.032
# 					-->MASE: 1.617
# 			-->Dataset: TOP_10. X_train: (89568L, 10L), y_train: (89568L,)
#
# 		-->Evaluation (2014-08-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (89664L, 16L), y_train: (89664L,)
# 				-->Computing Last value
# 					-->R2: 0.581
# 					-->MAE: 9.224
# 					-->MAPE: 12.808
# 					-->MASE: 0.657
# 				-->Computing Previous day
# 					-->R2: -3.333
# 					-->MAE: 27.751
# 					-->MAPE: 44.509
# 					-->MASE: 1.976
# 				-->Computing Previous week
# 					-->R2: 0.493
# 					-->MAE: 10.188
# 					-->MAPE: 14.513
# 					-->MASE: 0.725
# 			-->Dataset: TOP_10. X_train: (89664L, 10L), y_train: (89664L,)
#
# 		-->Evaluation (2014-08-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (89760L, 16L), y_train: (89760L,)
# 				-->Computing Last value
# 					-->R2: 0.323
# 					-->MAE: 8.933
# 					-->MAPE: 13.646
# 					-->MASE: 0.636
# 				-->Computing Previous day
# 					-->R2: 0.089
# 					-->MAE: 11.061
# 					-->MAPE: 15.454
# 					-->MASE: 0.788
# 				-->Computing Previous week
# 					-->R2: -1.135
# 					-->MAE: 16.965
# 					-->MAPE: 25.008
# 					-->MASE: 1.208
# 			-->Dataset: TOP_10. X_train: (89760L, 10L), y_train: (89760L,)
#
# 		-->Evaluation (2014-08-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (89856L, 16L), y_train: (89856L,)
# 				-->Computing Last value
# 					-->R2: 0.522
# 					-->MAE: 16.509
# 					-->MAPE: 16.934
# 					-->MASE: 1.176
# 				-->Computing Previous day
# 					-->R2: -0.778
# 					-->MAE: 32.226
# 					-->MAPE: 27.350
# 					-->MASE: 2.296
# 				-->Computing Previous week
# 					-->R2: 0.710
# 					-->MAE: 12.633
# 					-->MAPE: 12.023
# 					-->MASE: 0.900
# 			-->Dataset: TOP_10. X_train: (89856L, 10L), y_train: (89856L,)
#
# 		-->Evaluation (2014-08-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (89952L, 16L), y_train: (89952L,)
# 				-->Computing Last value
# 					-->R2: 0.506
# 					-->MAE: 12.835
# 					-->MAPE: 14.384
# 					-->MASE: 0.914
# 				-->Computing Previous day
# 					-->R2: 0.299
# 					-->MAE: 15.953
# 					-->MAPE: 17.002
# 					-->MASE: 1.136
# 				-->Computing Previous week
# 					-->R2: 0.687
# 					-->MAE: 10.154
# 					-->MAPE: 10.622
# 					-->MASE: 0.723
# 			-->Dataset: TOP_10. X_train: (89952L, 10L), y_train: (89952L,)
#
# 		-->Evaluation (2014-08-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (90048L, 16L), y_train: (90048L,)
# 				-->Computing Last value
# 					-->R2: 0.718
# 					-->MAE: 13.522
# 					-->MAPE: 13.874
# 					-->MASE: 0.963
# 				-->Computing Previous day
# 					-->R2: 0.703
# 					-->MAE: 12.753
# 					-->MAPE: 11.649
# 					-->MASE: 0.908
# 				-->Computing Previous week
# 					-->R2: 0.735
# 					-->MAE: 12.777
# 					-->MAPE: 12.333
# 					-->MASE: 0.910
# 			-->Dataset: TOP_10. X_train: (90048L, 10L), y_train: (90048L,)
#
# 		-->Evaluation (2014-08-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (90144L, 16L), y_train: (90144L,)
# 				-->Computing Last value
# 					-->R2: 0.637
# 					-->MAE: 14.565
# 					-->MAPE: 14.211
# 					-->MASE: 1.038
# 				-->Computing Previous day
# 					-->R2: 0.676
# 					-->MAE: 15.242
# 					-->MAPE: 13.726
# 					-->MASE: 1.086
# 				-->Computing Previous week
# 					-->R2: 0.686
# 					-->MAE: 15.770
# 					-->MAPE: 14.024
# 					-->MASE: 1.123
# 			-->Dataset: TOP_10. X_train: (90144L, 10L), y_train: (90144L,)
#
# 		-->Evaluation (2014-08-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (90240L, 16L), y_train: (90240L,)
# 				-->Computing Last value
# 					-->R2: 0.669
# 					-->MAE: 16.321
# 					-->MAPE: 16.095
# 					-->MASE: 1.163
# 				-->Computing Previous day
# 					-->R2: 0.821
# 					-->MAE: 11.922
# 					-->MAPE: 11.528
# 					-->MASE: 0.849
# 				-->Computing Previous week
# 					-->R2: 0.623
# 					-->MAE: 17.671
# 					-->MAPE: 15.437
# 					-->MASE: 1.259
# 			-->Dataset: TOP_10. X_train: (90240L, 10L), y_train: (90240L,)
#
# 		-->Evaluation (2014-08-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (90336L, 16L), y_train: (90336L,)
# 				-->Computing Last value
# 					-->R2: 0.622
# 					-->MAE: 9.745
# 					-->MAPE: 12.137
# 					-->MASE: 0.694
# 				-->Computing Previous day
# 					-->R2: -2.512
# 					-->MAE: 27.394
# 					-->MAPE: 34.366
# 					-->MASE: 1.951
# 				-->Computing Previous week
# 					-->R2: 0.118
# 					-->MAE: 16.418
# 					-->MAPE: 19.090
# 					-->MASE: 1.169
# 			-->Dataset: TOP_10. X_train: (90336L, 10L), y_train: (90336L,)
#
# 		-->Evaluation (2014-09-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (90432L, 16L), y_train: (90432L,)
# 				-->Computing Last value
# 					-->R2: 0.382
# 					-->MAE: 10.423
# 					-->MAPE: 14.816
# 					-->MASE: 0.743
# 				-->Computing Previous day
# 					-->R2: 0.150
# 					-->MAE: 12.249
# 					-->MAPE: 16.987
# 					-->MASE: 0.873
# 				-->Computing Previous week
# 					-->R2: 0.631
# 					-->MAE: 7.070
# 					-->MAPE: 9.027
# 					-->MASE: 0.504
# 			-->Dataset: TOP_10. X_train: (90432L, 10L), y_train: (90432L,)
#
# 		-->Evaluation (2014-09-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (90528L, 16L), y_train: (90528L,)
# 				-->Computing Last value
# 					-->R2: 0.617
# 					-->MAE: 17.580
# 					-->MAPE: 16.989
# 					-->MASE: 1.253
# 				-->Computing Previous day
# 					-->R2: -0.902
# 					-->MAE: 37.808
# 					-->MAPE: 29.774
# 					-->MASE: 2.694
# 				-->Computing Previous week
# 					-->R2: 0.771
# 					-->MAE: 12.572
# 					-->MAPE: 10.839
# 					-->MASE: 0.896
# 			-->Dataset: TOP_10. X_train: (90528L, 10L), y_train: (90528L,)
#
# 		-->Evaluation (2014-09-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (90624L, 16L), y_train: (90624L,)
# 				-->Computing Last value
# 					-->R2: 0.619
# 					-->MAE: 13.257
# 					-->MAPE: 14.589
# 					-->MASE: 0.944
# 				-->Computing Previous day
# 					-->R2: 0.250
# 					-->MAE: 18.887
# 					-->MAPE: 20.470
# 					-->MASE: 1.346
# 				-->Computing Previous week
# 					-->R2: 0.782
# 					-->MAE: 10.327
# 					-->MAPE: 10.290
# 					-->MASE: 0.736
# 			-->Dataset: TOP_10. X_train: (90624L, 10L), y_train: (90624L,)
#
# 		-->Evaluation (2014-09-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (90720L, 16L), y_train: (90720L,)
# 				-->Computing Last value
# 					-->R2: 0.539
# 					-->MAE: 15.185
# 					-->MAPE: 16.822
# 					-->MASE: 1.082
# 				-->Computing Previous day
# 					-->R2: 0.786
# 					-->MAE: 9.773
# 					-->MAPE: 9.433
# 					-->MASE: 0.696
# 				-->Computing Previous week
# 					-->R2: 0.780
# 					-->MAE: 9.756
# 					-->MAPE: 10.181
# 					-->MASE: 0.695
# 			-->Dataset: TOP_10. X_train: (90720L, 10L), y_train: (90720L,)
#
# 		-->Evaluation (2014-09-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (90816L, 16L), y_train: (90816L,)
# 				-->Computing Last value
# 					-->R2: 0.556
# 					-->MAE: 14.443
# 					-->MAPE: 15.007
# 					-->MASE: 1.029
# 				-->Computing Previous day
# 					-->R2: 0.538
# 					-->MAE: 14.644
# 					-->MAPE: 14.023
# 					-->MASE: 1.043
# 				-->Computing Previous week
# 					-->R2: 0.570
# 					-->MAE: 13.995
# 					-->MAPE: 12.881
# 					-->MASE: 0.997
# 			-->Dataset: TOP_10. X_train: (90816L, 10L), y_train: (90816L,)
#
# 		-->Evaluation (2014-09-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (90912L, 16L), y_train: (90912L,)
# 				-->Computing Last value
# 					-->R2: 0.599
# 					-->MAE: 16.953
# 					-->MAPE: 17.395
# 					-->MASE: 1.208
# 				-->Computing Previous day
# 					-->R2: 0.721
# 					-->MAE: 13.324
# 					-->MAPE: 12.035
# 					-->MASE: 0.949
# 				-->Computing Previous week
# 					-->R2: 0.779
# 					-->MAE: 12.065
# 					-->MAPE: 11.257
# 					-->MASE: 0.860
# 			-->Dataset: TOP_10. X_train: (90912L, 10L), y_train: (90912L,)
#
# 		-->Evaluation (2014-09-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (91008L, 16L), y_train: (91008L,)
# 				-->Computing Last value
# 					-->R2: 0.038
# 					-->MAE: 16.468
# 					-->MAPE: 21.187
# 					-->MASE: 1.173
# 				-->Computing Previous day
# 					-->R2: -2.434
# 					-->MAE: 30.233
# 					-->MAPE: 39.179
# 					-->MASE: 2.153
# 				-->Computing Previous week
# 					-->R2: 0.532
# 					-->MAE: 11.937
# 					-->MAPE: 14.258
# 					-->MASE: 0.850
# 			-->Dataset: TOP_10. X_train: (91008L, 10L), y_train: (91008L,)
#
# 		-->Evaluation (2014-09-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (91104L, 16L), y_train: (91104L,)
# 				-->Computing Last value
# 					-->R2: 0.201
# 					-->MAE: 16.267
# 					-->MAPE: 22.932
# 					-->MASE: 1.158
# 				-->Computing Previous day
# 					-->R2: 0.302
# 					-->MAE: 14.502
# 					-->MAPE: 20.787
# 					-->MASE: 1.033
# 				-->Computing Previous week
# 					-->R2: 0.631
# 					-->MAE: 10.402
# 					-->MAPE: 13.515
# 					-->MASE: 0.741
# 			-->Dataset: TOP_10. X_train: (91104L, 10L), y_train: (91104L,)
#
# 		-->Evaluation (2014-09-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (91200L, 16L), y_train: (91200L,)
# 				-->Computing Last value
# 					-->R2: 0.573
# 					-->MAE: 16.606
# 					-->MAPE: 18.106
# 					-->MASE: 1.182
# 				-->Computing Previous day
# 					-->R2: -0.499
# 					-->MAE: 30.202
# 					-->MAPE: 26.192
# 					-->MASE: 2.150
# 				-->Computing Previous week
# 					-->R2: 0.622
# 					-->MAE: 13.994
# 					-->MAPE: 13.725
# 					-->MASE: 0.996
# 			-->Dataset: TOP_10. X_train: (91200L, 10L), y_train: (91200L,)
#
# 		-->Evaluation (2014-09-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (91296L, 16L), y_train: (91296L,)
# 				-->Computing Last value
# 					-->R2: 0.552
# 					-->MAE: 17.279
# 					-->MAPE: 19.532
# 					-->MASE: 1.230
# 				-->Computing Previous day
# 					-->R2: 0.699
# 					-->MAE: 14.560
# 					-->MAPE: 15.886
# 					-->MASE: 1.036
# 				-->Computing Previous week
# 					-->R2: 0.637
# 					-->MAE: 15.428
# 					-->MAPE: 14.425
# 					-->MASE: 1.098
# 			-->Dataset: TOP_10. X_train: (91296L, 10L), y_train: (91296L,)
#
# 		-->Evaluation (2014-09-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (91392L, 16L), y_train: (91392L,)
# 				-->Computing Last value
# 					-->R2: 0.616
# 					-->MAE: 15.804
# 					-->MAPE: 17.983
# 					-->MASE: 1.125
# 				-->Computing Previous day
# 					-->R2: 0.822
# 					-->MAE: 10.560
# 					-->MAPE: 12.168
# 					-->MASE: 0.752
# 				-->Computing Previous week
# 					-->R2: 0.777
# 					-->MAE: 11.371
# 					-->MAPE: 11.430
# 					-->MASE: 0.809
# 			-->Dataset: TOP_10. X_train: (91392L, 10L), y_train: (91392L,)
#
# 		-->Evaluation (2014-09-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (91488L, 16L), y_train: (91488L,)
# 				-->Computing Last value
# 					-->R2: 0.562
# 					-->MAE: 17.196
# 					-->MAPE: 17.850
# 					-->MASE: 1.224
# 				-->Computing Previous day
# 					-->R2: 0.671
# 					-->MAE: 13.867
# 					-->MAPE: 14.168
# 					-->MASE: 0.987
# 				-->Computing Previous week
# 					-->R2: 0.734
# 					-->MAE: 11.522
# 					-->MAPE: 10.658
# 					-->MASE: 0.820
# 			-->Dataset: TOP_10. X_train: (91488L, 10L), y_train: (91488L,)
#
# 		-->Evaluation (2014-09-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (91584L, 16L), y_train: (91584L,)
# 				-->Computing Last value
# 					-->R2: 0.423
# 					-->MAE: 16.418
# 					-->MAPE: 17.888
# 					-->MASE: 1.168
# 				-->Computing Previous day
# 					-->R2: 0.451
# 					-->MAE: 15.882
# 					-->MAPE: 17.590
# 					-->MASE: 1.130
# 				-->Computing Previous week
# 					-->R2: 0.078
# 					-->MAE: 19.652
# 					-->MAPE: 21.996
# 					-->MASE: 1.398
# 			-->Dataset: TOP_10. X_train: (91584L, 10L), y_train: (91584L,)
#
# 		-->Evaluation (2014-09-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (91680L, 16L), y_train: (91680L,)
# 				-->Computing Last value
# 					-->R2: 0.218
# 					-->MAE: 14.175
# 					-->MAPE: 19.971
# 					-->MASE: 1.008
# 				-->Computing Previous day
# 					-->R2: -1.915
# 					-->MAE: 25.206
# 					-->MAPE: 40.169
# 					-->MASE: 1.793
# 				-->Computing Previous week
# 					-->R2: 0.056
# 					-->MAE: 15.482
# 					-->MAPE: 23.214
# 					-->MASE: 1.101
# 			-->Dataset: TOP_10. X_train: (91680L, 10L), y_train: (91680L,)
#
# 		-->Evaluation (2014-09-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (91776L, 16L), y_train: (91776L,)
# 				-->Computing Last value
# 					-->R2: 0.427
# 					-->MAE: 13.774
# 					-->MAPE: 20.968
# 					-->MASE: 0.980
# 				-->Computing Previous day
# 					-->R2: 0.399
# 					-->MAE: 13.002
# 					-->MAPE: 19.955
# 					-->MASE: 0.925
# 				-->Computing Previous week
# 					-->R2: 0.527
# 					-->MAE: 12.714
# 					-->MAPE: 20.204
# 					-->MASE: 0.904
# 			-->Dataset: TOP_10. X_train: (91776L, 10L), y_train: (91776L,)
#
# 		-->Evaluation (2014-09-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (91872L, 16L), y_train: (91872L,)
# 				-->Computing Last value
# 					-->R2: 0.633
# 					-->MAE: 18.680
# 					-->MAPE: 20.091
# 					-->MASE: 1.329
# 				-->Computing Previous day
# 					-->R2: -0.448
# 					-->MAE: 37.864
# 					-->MAPE: 32.313
# 					-->MASE: 2.693
# 				-->Computing Previous week
# 					-->R2: 0.772
# 					-->MAE: 14.851
# 					-->MAPE: 16.456
# 					-->MASE: 1.056
# 			-->Dataset: TOP_10. X_train: (91872L, 10L), y_train: (91872L,)
#
# 		-->Evaluation (2014-09-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (91968L, 16L), y_train: (91968L,)
# 				-->Computing Last value
# 					-->R2: 0.430
# 					-->MAE: 15.719
# 					-->MAPE: 19.246
# 					-->MASE: 1.118
# 				-->Computing Previous day
# 					-->R2: -0.128
# 					-->MAE: 21.640
# 					-->MAPE: 25.086
# 					-->MASE: 1.539
# 				-->Computing Previous week
# 					-->R2: 0.547
# 					-->MAE: 14.842
# 					-->MAPE: 16.816
# 					-->MASE: 1.055
# 			-->Dataset: TOP_10. X_train: (91968L, 10L), y_train: (91968L,)
#
# 		-->Evaluation (2014-09-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (92064L, 16L), y_train: (92064L,)
# 				-->Computing Last value
# 					-->R2: 0.453
# 					-->MAE: 17.327
# 					-->MAPE: 20.851
# 					-->MASE: 1.232
# 				-->Computing Previous day
# 					-->R2: 0.739
# 					-->MAE: 11.743
# 					-->MAPE: 14.370
# 					-->MASE: 0.835
# 				-->Computing Previous week
# 					-->R2: 0.620
# 					-->MAE: 14.706
# 					-->MAPE: 18.616
# 					-->MASE: 1.046
# 			-->Dataset: TOP_10. X_train: (92064L, 10L), y_train: (92064L,)
#
# 		-->Evaluation (2014-09-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (92160L, 16L), y_train: (92160L,)
# 				-->Computing Last value
# 					-->R2: 0.557
# 					-->MAE: 12.453
# 					-->MAPE: 16.349
# 					-->MASE: 0.885
# 				-->Computing Previous day
# 					-->R2: -0.136
# 					-->MAE: 20.277
# 					-->MAPE: 23.649
# 					-->MASE: 1.441
# 				-->Computing Previous week
# 					-->R2: -0.242
# 					-->MAE: 21.213
# 					-->MAPE: 25.248
# 					-->MASE: 1.508
# 			-->Dataset: TOP_10. X_train: (92160L, 10L), y_train: (92160L,)
#
# 		-->Evaluation (2014-09-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (92256L, 16L), y_train: (92256L,)
# 				-->Computing Last value
# 					-->R2: 0.554
# 					-->MAE: 13.693
# 					-->MAPE: 15.983
# 					-->MASE: 0.973
# 				-->Computing Previous day
# 					-->R2: 0.767
# 					-->MAE: 9.738
# 					-->MAPE: 11.143
# 					-->MASE: 0.692
# 				-->Computing Previous week
# 					-->R2: 0.457
# 					-->MAE: 14.677
# 					-->MAPE: 17.825
# 					-->MASE: 1.043
# 			-->Dataset: TOP_10. X_train: (92256L, 10L), y_train: (92256L,)
#
# 		-->Evaluation (2014-09-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (92352L, 16L), y_train: (92352L,)
# 				-->Computing Last value
# 					-->R2: 0.647
# 					-->MAE: 12.482
# 					-->MAPE: 17.015
# 					-->MASE: 0.887
# 				-->Computing Previous day
# 					-->R2: 0.351
# 					-->MAE: 15.213
# 					-->MAPE: 21.655
# 					-->MASE: 1.082
# 				-->Computing Previous week
# 					-->R2: 0.526
# 					-->MAE: 13.282
# 					-->MAPE: 15.277
# 					-->MASE: 0.944
# 			-->Dataset: TOP_10. X_train: (92352L, 10L), y_train: (92352L,)
#
# 		-->Evaluation (2014-09-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (92448L, 16L), y_train: (92448L,)
# 				-->Computing Last value
# 					-->R2: 0.438
# 					-->MAE: 11.311
# 					-->MAPE: 16.556
# 					-->MASE: 0.804
# 				-->Computing Previous day
# 					-->R2: 0.215
# 					-->MAE: 13.752
# 					-->MAPE: 19.230
# 					-->MASE: 0.978
# 				-->Computing Previous week
# 					-->R2: 0.514
# 					-->MAE: 11.051
# 					-->MAPE: 14.826
# 					-->MASE: 0.786
# 			-->Dataset: TOP_10. X_train: (92448L, 10L), y_train: (92448L,)
#
# 		-->Evaluation (2014-09-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (92544L, 16L), y_train: (92544L,)
# 				-->Computing Last value
# 					-->R2: 0.599
# 					-->MAE: 17.322
# 					-->MAPE: 20.029
# 					-->MASE: 1.232
# 				-->Computing Previous day
# 					-->R2: 0.380
# 					-->MAE: 23.093
# 					-->MAPE: 26.197
# 					-->MASE: 1.642
# 				-->Computing Previous week
# 					-->R2: 0.499
# 					-->MAE: 20.508
# 					-->MAPE: 24.214
# 					-->MASE: 1.458
# 			-->Dataset: TOP_10. X_train: (92544L, 10L), y_train: (92544L,)
#
# 		-->Evaluation (2014-09-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (92640L, 16L), y_train: (92640L,)
# 				-->Computing Last value
# 					-->R2: 0.509
# 					-->MAE: 15.588
# 					-->MAPE: 18.922
# 					-->MASE: 1.108
# 				-->Computing Previous day
# 					-->R2: 0.445
# 					-->MAE: 14.838
# 					-->MAPE: 18.481
# 					-->MASE: 1.055
# 				-->Computing Previous week
# 					-->R2: 0.446
# 					-->MAE: 17.263
# 					-->MAPE: 20.868
# 					-->MASE: 1.227
# 			-->Dataset: TOP_10. X_train: (92640L, 10L), y_train: (92640L,)
#
# 		-->Evaluation (2014-09-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (92736L, 16L), y_train: (92736L,)
# 				-->Computing Last value
# 					-->R2: 0.521
# 					-->MAE: 13.511
# 					-->MAPE: 16.051
# 					-->MASE: 0.960
# 				-->Computing Previous day
# 					-->R2: 0.708
# 					-->MAE: 10.871
# 					-->MAPE: 11.921
# 					-->MASE: 0.773
# 				-->Computing Previous week
# 					-->R2: 0.155
# 					-->MAE: 18.424
# 					-->MAPE: 20.071
# 					-->MASE: 1.310
# 			-->Dataset: TOP_10. X_train: (92736L, 10L), y_train: (92736L,)
#
# 		-->Evaluation (2014-09-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (92832L, 16L), y_train: (92832L,)
# 				-->Computing Last value
# 					-->R2: 0.617
# 					-->MAE: 15.786
# 					-->MAPE: 16.870
# 					-->MASE: 1.122
# 				-->Computing Previous day
# 					-->R2: 0.602
# 					-->MAE: 15.601
# 					-->MAPE: 14.486
# 					-->MASE: 1.109
# 				-->Computing Previous week
# 					-->R2: 0.532
# 					-->MAE: 17.275
# 					-->MAPE: 15.707
# 					-->MASE: 1.228
# 			-->Dataset: TOP_10. X_train: (92832L, 10L), y_train: (92832L,)
#
# 		-->Evaluation (2014-09-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (92928L, 16L), y_train: (92928L,)
# 				-->Computing Last value
# 					-->R2: 0.430
# 					-->MAE: 13.709
# 					-->MAPE: 15.434
# 					-->MASE: 0.974
# 				-->Computing Previous day
# 					-->R2: -0.092
# 					-->MAE: 17.643
# 					-->MAPE: 20.328
# 					-->MASE: 1.254
# 				-->Computing Previous week
# 					-->R2: 0.565
# 					-->MAE: 11.997
# 					-->MAPE: 13.575
# 					-->MASE: 0.853
# 			-->Dataset: TOP_10. X_train: (92928L, 10L), y_train: (92928L,)
#
# 		-->Evaluation (2014-09-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (93024L, 16L), y_train: (93024L,)
# 				-->Computing Last value
# 					-->R2: 0.505
# 					-->MAE: 13.795
# 					-->MAPE: 19.473
# 					-->MASE: 0.981
# 				-->Computing Previous day
# 					-->R2: -0.416
# 					-->MAE: 22.506
# 					-->MAPE: 36.773
# 					-->MASE: 1.600
# 				-->Computing Previous week
# 					-->R2: 0.524
# 					-->MAE: 13.261
# 					-->MAPE: 18.565
# 					-->MASE: 0.943
# 			-->Dataset: TOP_10. X_train: (93024L, 10L), y_train: (93024L,)
#
# 		-->Evaluation (2014-09-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (93120L, 16L), y_train: (93120L,)
# 				-->Computing Last value
# 					-->R2: 0.312
# 					-->MAE: 13.771
# 					-->MAPE: 18.694
# 					-->MASE: 0.979
# 				-->Computing Previous day
# 					-->R2: 0.384
# 					-->MAE: 12.984
# 					-->MAPE: 16.760
# 					-->MASE: 0.923
# 				-->Computing Previous week
# 					-->R2: 0.570
# 					-->MAE: 11.214
# 					-->MAPE: 14.967
# 					-->MASE: 0.797
# 			-->Dataset: TOP_10. X_train: (93120L, 10L), y_train: (93120L,)
#
# 		-->Evaluation (2014-09-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (93216L, 16L), y_train: (93216L,)
# 				-->Computing Last value
# 					-->R2: 0.555
# 					-->MAE: 15.425
# 					-->MAPE: 17.745
# 					-->MASE: 1.096
# 				-->Computing Previous day
# 					-->R2: 0.053
# 					-->MAE: 21.303
# 					-->MAPE: 20.293
# 					-->MASE: 1.514
# 				-->Computing Previous week
# 					-->R2: 0.427
# 					-->MAE: 14.728
# 					-->MAPE: 16.574
# 					-->MASE: 1.047
# 			-->Dataset: TOP_10. X_train: (93216L, 10L), y_train: (93216L,)
#
# 		-->Evaluation (2014-10-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (93312L, 16L), y_train: (93312L,)
# 				-->Computing Last value
# 					-->R2: 0.565
# 					-->MAE: 13.771
# 					-->MAPE: 17.092
# 					-->MASE: 0.979
# 				-->Computing Previous day
# 					-->R2: 0.719
# 					-->MAE: 10.089
# 					-->MAPE: 11.485
# 					-->MASE: 0.717
# 				-->Computing Previous week
# 					-->R2: 0.841
# 					-->MAE: 8.071
# 					-->MAPE: 8.861
# ...
#
# 		-->Evaluation (2015-01-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (102624L, 16L), y_train: (102624L,)
# 				-->Computing Last value
# 					-->R2: -1.022
# 					-->MAE: 49.633
# 					-->MAPE: 60.946
# 					-->MASE: 1.190
# 				-->Computing Previous day
# 					-->R2: -0.033
# 					-->MAE: 30.744
# 					-->MAPE: 32.711
# 					-->MASE: 0.737
# 				-->Computing Previous week
# 					-->R2: 0.242
# 					-->MAE: 26.728
# 					-->MAPE: 24.862
# 					-->MASE: 0.641
# 			-->Dataset: TOP_10. X_train: (102624L, 10L), y_train: (102624L,)
#
# 		-->Evaluation (2015-01-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (102720L, 16L), y_train: (102720L,)
# 				-->Computing Last value
# 					-->R2: -1.448
# 					-->MAE: 49.630
# 					-->MAPE: 65.993
# 					-->MASE: 1.189
# 				-->Computing Previous day
# 					-->R2: 0.629
# 					-->MAE: 19.124
# 					-->MAPE: 22.669
# 					-->MASE: 0.458
# 				-->Computing Previous week
# 					-->R2: 0.251
# 					-->MAE: 24.957
# 					-->MAPE: 23.801
# 					-->MASE: 0.598
# 			-->Dataset: TOP_10. X_train: (102720L, 10L), y_train: (102720L,)
#
# 		-->Evaluation (2015-01-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (102816L, 16L), y_train: (102816L,)
# 				-->Computing Last value
# 					-->R2: -1.336
# 					-->MAE: 46.854
# 					-->MAPE: 67.599
# 					-->MASE: 1.123
# 				-->Computing Previous day
# 					-->R2: 0.749
# 					-->MAE: 13.069
# 					-->MAPE: 15.221
# 					-->MASE: 0.313
# 				-->Computing Previous week
# 					-->R2: -2.941
# 					-->MAE: 62.641
# 					-->MAPE: 60.154
# 					-->MASE: 1.501
# 			-->Dataset: TOP_10. X_train: (102816L, 10L), y_train: (102816L,)
#
# 		-->Evaluation (2015-01-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (102912L, 16L), y_train: (102912L,)
# 				-->Computing Last value
# 					-->R2: -1.273
# 					-->MAE: 51.356
# 					-->MAPE: 77.946
# 					-->MASE: 1.230
# 				-->Computing Previous day
# 					-->R2: 0.774
# 					-->MAE: 14.453
# 					-->MAPE: 19.032
# 					-->MASE: 0.346
# 				-->Computing Previous week
# 					-->R2: -1.875
# 					-->MAE: 54.651
# 					-->MAPE: 51.380
# 					-->MASE: 1.309
# 			-->Dataset: TOP_10. X_train: (102912L, 10L), y_train: (102912L,)
#
# 		-->Evaluation (2015-01-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (103008L, 16L), y_train: (103008L,)
# 				-->Computing Last value
# 					-->R2: -1.599
# 					-->MAE: 47.857
# 					-->MAPE: 71.362
# 					-->MASE: 1.146
# 				-->Computing Previous day
# 					-->R2: 0.621
# 					-->MAE: 16.701
# 					-->MAPE: 19.180
# 					-->MASE: 0.400
# 				-->Computing Previous week
# 					-->R2: -0.009
# 					-->MAE: 27.257
# 					-->MAPE: 26.372
# 					-->MASE: 0.653
# 			-->Dataset: TOP_10. X_train: (103008L, 10L), y_train: (103008L,)
#
# 		-->Evaluation (2015-01-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (103104L, 16L), y_train: (103104L,)
# 				-->Computing Last value
# 					-->R2: -1.527
# 					-->MAE: 41.986
# 					-->MAPE: 60.048
# 					-->MASE: 1.005
# 				-->Computing Previous day
# 					-->R2: -0.325
# 					-->MAE: 25.347
# 					-->MAPE: 40.066
# 					-->MASE: 0.607
# 				-->Computing Previous week
# 					-->R2: 0.673
# 					-->MAE: 13.528
# 					-->MAPE: 17.657
# 					-->MASE: 0.324
# 			-->Dataset: TOP_10. X_train: (103104L, 10L), y_train: (103104L,)
#
# 		-->Evaluation (2015-01-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (103200L, 16L), y_train: (103200L,)
# 				-->Computing Last value
# 					-->R2: -1.441
# 					-->MAE: 37.474
# 					-->MAPE: 76.868
# 					-->MASE: 0.897
# 				-->Computing Previous day
# 					-->R2: 0.440
# 					-->MAE: 17.079
# 					-->MAPE: 35.424
# 					-->MASE: 0.409
# 				-->Computing Previous week
# 					-->R2: -0.024
# 					-->MAE: 26.266
# 					-->MAPE: 52.437
# 					-->MASE: 0.629
# 			-->Dataset: TOP_10. X_train: (103200L, 10L), y_train: (103200L,)
#
# 		-->Evaluation (2015-01-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (103296L, 16L), y_train: (103296L,)
# 				-->Computing Last value
# 					-->R2: -1.696
# 					-->MAE: 46.372
# 					-->MAPE: 77.654
# 					-->MASE: 1.111
# 				-->Computing Previous day
# 					-->R2: 0.392
# 					-->MAE: 19.465
# 					-->MAPE: 19.982
# 					-->MASE: 0.466
# 				-->Computing Previous week
# 					-->R2: 0.443
# 					-->MAE: 20.413
# 					-->MAPE: 28.202
# 					-->MASE: 0.489
# 			-->Dataset: TOP_10. X_train: (103296L, 10L), y_train: (103296L,)
#
# 		-->Evaluation (2015-01-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (103392L, 16L), y_train: (103392L,)
# 				-->Computing Last value
# 					-->R2: -1.546
# 					-->MAE: 63.889
# 					-->MAPE: 88.436
# 					-->MASE: 1.530
# 				-->Computing Previous day
# 					-->R2: 0.596
# 					-->MAE: 22.142
# 					-->MAPE: 20.008
# 					-->MASE: 0.530
# 				-->Computing Previous week
# 					-->R2: 0.541
# 					-->MAE: 26.265
# 					-->MAPE: 29.192
# 					-->MASE: 0.629
# 			-->Dataset: TOP_10. X_train: (103392L, 10L), y_train: (103392L,)
#
# 		-->Evaluation (2015-01-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (103488L, 16L), y_train: (103488L,)
# 				-->Computing Last value
# 					-->R2: -1.497
# 					-->MAE: 62.963
# 					-->MAPE: 81.332
# 					-->MASE: 1.507
# 				-->Computing Previous day
# 					-->R2: 0.552
# 					-->MAE: 23.808
# 					-->MAPE: 24.564
# 					-->MASE: 0.570
# 				-->Computing Previous week
# 					-->R2: 0.601
# 					-->MAE: 22.808
# 					-->MAPE: 23.627
# 					-->MASE: 0.546
# 			-->Dataset: TOP_10. X_train: (103488L, 10L), y_train: (103488L,)
#
# 		-->Evaluation (2015-01-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (103584L, 16L), y_train: (103584L,)
# 				-->Computing Last value
# 					-->R2: -1.400
# 					-->MAE: 61.181
# 					-->MAPE: 74.468
# 					-->MASE: 1.464
# 				-->Computing Previous day
# 					-->R2: 0.599
# 					-->MAE: 20.732
# 					-->MAPE: 24.153
# 					-->MASE: 0.496
# 				-->Computing Previous week
# 					-->R2: 0.686
# 					-->MAE: 18.127
# 					-->MAPE: 16.380
# 					-->MASE: 0.434
# 			-->Dataset: TOP_10. X_train: (103584L, 10L), y_train: (103584L,)
#
# 		-->Evaluation (2015-01-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (103680L, 16L), y_train: (103680L,)
# 				-->Computing Last value
# 					-->R2: -1.595
# 					-->MAE: 55.880
# 					-->MAPE: 64.415
# 					-->MASE: 1.336
# 				-->Computing Previous day
# 					-->R2: 0.766
# 					-->MAE: 15.213
# 					-->MAPE: 15.878
# 					-->MASE: 0.364
# 				-->Computing Previous week
# 					-->R2: 0.607
# 					-->MAE: 18.878
# 					-->MAPE: 16.764
# 					-->MASE: 0.451
# 			-->Dataset: TOP_10. X_train: (103680L, 10L), y_train: (103680L,)
#
# 		-->Evaluation (2015-01-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (103776L, 16L), y_train: (103776L,)
# 				-->Computing Last value
# 					-->R2: -0.964
# 					-->MAE: 37.326
# 					-->MAPE: 49.941
# 					-->MASE: 0.892
# 				-->Computing Previous day
# 					-->R2: -1.092
# 					-->MAE: 33.051
# 					-->MAPE: 44.573
# 					-->MASE: 0.790
# 				-->Computing Previous week
# 					-->R2: 0.515
# 					-->MAE: 14.748
# 					-->MAPE: 15.025
# 					-->MASE: 0.353
# 			-->Dataset: TOP_10. X_train: (103776L, 10L), y_train: (103776L,)
#
# 		-->Evaluation (2015-01-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (103872L, 16L), y_train: (103872L,)
# 				-->Computing Last value
# 					-->R2: -1.059
# 					-->MAE: 39.030
# 					-->MAPE: 68.953
# 					-->MASE: 0.933
# 				-->Computing Previous day
# 					-->R2: 0.485
# 					-->MAE: 18.427
# 					-->MAPE: 32.145
# 					-->MASE: 0.441
# 				-->Computing Previous week
# 					-->R2: 0.631
# 					-->MAE: 13.057
# 					-->MAPE: 15.542
# 					-->MASE: 0.312
# 			-->Dataset: TOP_10. X_train: (103872L, 10L), y_train: (103872L,)
#
# 		-->Evaluation (2015-01-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (103968L, 16L), y_train: (103968L,)
# 				-->Computing Last value
# 					-->R2: -1.369
# 					-->MAE: 58.419
# 					-->MAPE: 76.953
# 					-->MASE: 1.397
# 				-->Computing Previous day
# 					-->R2: -0.089
# 					-->MAE: 33.882
# 					-->MAPE: 30.576
# 					-->MASE: 0.810
# 				-->Computing Previous week
# 					-->R2: 0.635
# 					-->MAE: 20.093
# 					-->MAPE: 18.593
# 					-->MASE: 0.480
# 			-->Dataset: TOP_10. X_train: (103968L, 10L), y_train: (103968L,)
#
# 		-->Evaluation (2015-01-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (104064L, 16L), y_train: (104064L,)
# 				-->Computing Last value
# 					-->R2: -1.072
# 					-->MAE: 63.089
# 					-->MAPE: 149.262
# 					-->MASE: 1.508
# 				-->Computing Previous day
# 					-->R2: 0.782
# 					-->MAE: 18.523
# 					-->MAPE: 43.177
# 					-->MASE: 0.443
# 				-->Computing Previous week
# 					-->R2: 0.653
# 					-->MAE: 24.960
# 					-->MAPE: 47.178
# 					-->MASE: 0.597
# 			-->Dataset: TOP_10. X_train: (104064L, 10L), y_train: (104064L,)
#
# 		-->Evaluation (2015-01-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (104160L, 16L), y_train: (104160L,)
# 				-->Computing Last value
# 					-->R2: -1.814
# 					-->MAE: 71.527
# 					-->MAPE: 92.718
# 					-->MASE: 1.709
# 				-->Computing Previous day
# 					-->R2: 0.643
# 					-->MAE: 23.497
# 					-->MAPE: 32.026
# 					-->MASE: 0.561
# 				-->Computing Previous week
# 					-->R2: 0.555
# 					-->MAE: 22.352
# 					-->MAPE: 26.060
# 					-->MASE: 0.534
# 			-->Dataset: TOP_10. X_train: (104160L, 10L), y_train: (104160L,)
#
# 		-->Evaluation (2015-01-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (104256L, 16L), y_train: (104256L,)
# 				-->Computing Last value
# 					-->R2: -1.556
# 					-->MAE: 60.644
# 					-->MAPE: 72.364
# 					-->MASE: 1.448
# 				-->Computing Previous day
# 					-->R2: 0.518
# 					-->MAE: 23.647
# 					-->MAPE: 24.539
# 					-->MASE: 0.565
# 				-->Computing Previous week
# 					-->R2: 0.587
# 					-->MAE: 22.945
# 					-->MAPE: 23.593
# 					-->MASE: 0.548
# 			-->Dataset: TOP_10. X_train: (104256L, 10L), y_train: (104256L,)
#
# 		-->Evaluation (2015-01-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (104352L, 16L), y_train: (104352L,)
# 				-->Computing Last value
# 					-->R2: -1.316
# 					-->MAE: 49.789
# 					-->MAPE: 69.063
# 					-->MASE: 1.188
# 				-->Computing Previous day
# 					-->R2: 0.326
# 					-->MAE: 26.466
# 					-->MAPE: 30.999
# 					-->MASE: 0.632
# 				-->Computing Previous week
# 					-->R2: 0.378
# 					-->MAE: 23.689
# 					-->MAPE: 27.015
# 					-->MASE: 0.565
# 			-->Dataset: TOP_10. X_train: (104352L, 10L), y_train: (104352L,)
#
# 		-->Evaluation (2015-01-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (104448L, 16L), y_train: (104448L,)
# 				-->Computing Last value
# 					-->R2: -0.995
# 					-->MAE: 38.362
# 					-->MAPE: 53.323
# 					-->MASE: 0.915
# 				-->Computing Previous day
# 					-->R2: -1.357
# 					-->MAE: 34.533
# 					-->MAPE: 53.542
# 					-->MASE: 0.824
# 				-->Computing Previous week
# 					-->R2: 0.177
# 					-->MAE: 21.367
# 					-->MAPE: 27.373
# 					-->MASE: 0.510
# 			-->Dataset: TOP_10. X_train: (104448L, 10L), y_train: (104448L,)
#
# 		-->Evaluation (2015-01-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (104544L, 16L), y_train: (104544L,)
# 				-->Computing Last value
# 					-->R2: -0.764
# 					-->MAE: 33.794
# 					-->MAPE: 62.522
# 					-->MASE: 0.806
# 				-->Computing Previous day
# 					-->R2: 0.245
# 					-->MAE: 21.091
# 					-->MAPE: 36.341
# 					-->MASE: 0.503
# 				-->Computing Previous week
# 					-->R2: 0.076
# 					-->MAE: 23.192
# 					-->MAPE: 35.532
# 					-->MASE: 0.553
# 			-->Dataset: TOP_10. X_train: (104544L, 10L), y_train: (104544L,)
#
# 		-->Evaluation (2015-01-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (104640L, 16L), y_train: (104640L,)
# 				-->Computing Last value
# 					-->R2: -1.553
# 					-->MAE: 61.775
# 					-->MAPE: 78.618
# 					-->MASE: 1.474
# 				-->Computing Previous day
# 					-->R2: -0.117
# 					-->MAE: 36.390
# 					-->MAPE: 33.432
# 					-->MASE: 0.868
# 				-->Computing Previous week
# 					-->R2: 0.807
# 					-->MAE: 14.049
# 					-->MAPE: 14.090
# 					-->MASE: 0.335
# 			-->Dataset: TOP_10. X_train: (104640L, 10L), y_train: (104640L,)
#
# 		-->Evaluation (2015-01-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (104736L, 16L), y_train: (104736L,)
# 				-->Computing Last value
# 					-->R2: -1.494
# 					-->MAE: 53.037
# 					-->MAPE: 72.850
# 					-->MASE: 1.265
# 				-->Computing Previous day
# 					-->R2: 0.771
# 					-->MAE: 14.548
# 					-->MAPE: 16.215
# 					-->MASE: 0.347
# 				-->Computing Previous week
# 					-->R2: 0.605
# 					-->MAE: 20.813
# 					-->MAPE: 26.792
# 					-->MASE: 0.496
# 			-->Dataset: TOP_10. X_train: (104736L, 10L), y_train: (104736L,)
#
# 		-->Evaluation (2015-01-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (104832L, 16L), y_train: (104832L,)
# 				-->Computing Last value
# 					-->R2: -1.597
# 					-->MAE: 74.815
# 					-->MAPE: 79.429
# 					-->MASE: 1.784
# 				-->Computing Previous day
# 					-->R2: 0.634
# 					-->MAE: 25.945
# 					-->MAPE: 24.263
# 					-->MASE: 0.619
# 				-->Computing Previous week
# 					-->R2: 0.646
# 					-->MAE: 23.614
# 					-->MAPE: 23.163
# 					-->MASE: 0.563
# 			-->Dataset: TOP_10. X_train: (104832L, 10L), y_train: (104832L,)
#
# 		-->Evaluation (2015-01-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (104928L, 16L), y_train: (104928L,)
# 				-->Computing Last value
# 					-->R2: -1.282
# 					-->MAE: 69.343
# 					-->MAPE: 84.840
# 					-->MASE: 1.652
# 				-->Computing Previous day
# 					-->R2: 0.823
# 					-->MAE: 15.830
# 					-->MAPE: 20.999
# 					-->MASE: 0.377
# 				-->Computing Previous week
# 					-->R2: 0.735
# 					-->MAE: 20.807
# 					-->MAPE: 25.413
# 					-->MASE: 0.496
# 			-->Dataset: TOP_10. X_train: (104928L, 10L), y_train: (104928L,)
#
# 		-->Evaluation (2015-01-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (105024L, 16L), y_train: (105024L,)
# 				-->Computing Last value
# 					-->R2: -1.759
# 					-->MAE: 69.567
# 					-->MAPE: 70.115
# 					-->MASE: 1.657
# 				-->Computing Previous day
# 					-->R2: 0.718
# 					-->MAE: 20.404
# 					-->MAPE: 20.468
# 					-->MASE: 0.486
# 				-->Computing Previous week
# 					-->R2: 0.447
# 					-->MAE: 29.857
# 					-->MAPE: 25.981
# 					-->MASE: 0.711
# 			-->Dataset: TOP_10. X_train: (105024L, 10L), y_train: (105024L,)
#
# 		-->Evaluation (2015-02-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (105120L, 16L), y_train: (105120L,)
# 				-->Computing Last value
# 					-->R2: -1.595
# 					-->MAE: 35.244
# 					-->MAPE: 43.305
# 					-->MASE: 0.839
# 				-->Computing Previous day
# 					-->R2: -3.885
# 					-->MAE: 47.615
# 					-->MAPE: 59.094
# 					-->MASE: 1.133
# 				-->Computing Previous week
# 					-->R2: 0.324
# 					-->MAE: 16.104
# 					-->MAPE: 19.016
# 					-->MASE: 0.383
# 			-->Dataset: TOP_10. X_train: (105120L, 10L), y_train: (105120L,)
#
# 		-->Evaluation (2015-02-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (105200L, 16L), y_train: (105200L,)
# 				-->Computing Last value
# regression_metrics.py:27: RuntimeWarning: Found 1 zero elements in y_pred. Removing 1 zero elements
#   warnings.warn(warning_msg, RuntimeWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-7d110c98b32d> in <module>()
#     152 """
#     153
# --> 154 start_prediction_valuation(verbose=True)
#     155 #start_prediction_valuation(verbose=False)
#     156 #validation_df
#
# <ipython-input-56-7d110c98b32d> in start_prediction_valuation(verbose)
#     108                                                                y_test, testing_data[bl.target])
#     109                                 else:
# --> 110                                     error = metric['function'](y_test, testing_data[bl.target])
#     111
#     112                                 validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error
#
# C:\Python27\lib\site-packages\sklearn\metrics\regression.pyc in r2_score(y_true, y_pred, sample_weight, multioutput)
#     528     """
#     529     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 530         y_true, y_pred, multioutput)
#     531
#     532     if sample_weight is not None:
#
# C:\Python27\lib\site-packages\sklearn\metrics\regression.pyc in _check_reg_targets(y_true, y_pred, multioutput)
#      74     """
#      75     check_consistent_length(y_true, y_pred)
# ---> 76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#      78
#
# C:\Python27\lib\site-packages\sklearn\utils\validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     460                              " minimum of %d is required%s."
#     461                              % (n_samples, shape_repr, ensure_min_samples,
# --> 462                                 context))
#     463
#     464     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

def start_prediction_valuation(verbose=False):

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041992']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
        
        #for horizon in range (1,25):
        for horizon in horizons:

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            # Split Training and Testing set
            training_data = sensor_data[:splitting_time]
            testing_data = sensor_data[splitting_time:]
            
            # Create dummy feature vector for linear regression
            sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                    prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                    prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                    prefix='dummy_shifted_Month'))))
            #sensor_data_dummy.dropna(inplace=True)
            dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
            training_data_dummy = sensor_data_dummy[:splitting_time]
            testing_data_dummy = sensor_data_dummy[splitting_time:]

            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            for data_set in data_sets:            
                # Create training vectors
                X_train = training_data[data_set['ftrs']].values
                y_train = training_data[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_train.shape
                
                # Create testing vectors
                X_test = testing_data[data_set['ftrs']].values
                y_test = testing_data[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_test.shape
                
                # Create dummy feature vector for linear regression
                if "shifted_HourOfDay" in data_set['ftrs']: 
                    X_train_dummy = training_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                else: 
                    X_train_dummy = training_data_dummy[data_set['ftrs']].values
                y_train_dummy = training_data_dummy[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_train_dummy.shape

                if "shifted_HourOfDay" in data_set['ftrs']:
                    X_test_dummy = testing_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                else:
                    X_test_dummy = testing_data_dummy[data_set['ftrs']].values    
                y_test_dummy = testing_data_dummy[["shifted_measurement"]].values.ravel()
                #print "Using dummy features: ", X_test_dummy.shape
                                                           
                if verbose: print "\n\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                          X_train.shape, y_train.shape)

                if data_set['name'] == "Baselines":
                    for baseline in baselines:
                        
                        if verbose: print "\t\t\t-->Computing {}".format(baseline['name'])
                        bl = eval(baseline['init'])

                        for metric in error_metrics:
                            if metric['short'] == 'MASE':
                                error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                           y_test, testing_data[bl.target])
                            else:
                                error = metric['function'](y_test, testing_data[bl.target])

                            validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)
                                
                else:    
                    for model in models: 
                        # Initializing model
                        mdl = eval(model['init'])

                        # Model leraning
                        start = time.time() # Start measuring time
                        if model['name'] == "Ridge Regression":
                            mdl.fit(X_train_dummy, y_train_dummy)
                        else:
                            mdl.fit(X_train,y_train)
                        runtime = time.time() - start # Calculate runtime

                        if verbose: print "\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

                        for metric in error_metrics:
                            #print "\t-->Error metric: {}".format(metric['name'])

                            if model['name'] == "Ridge Regression":
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
                                                               y_test_dummy, mdl.predict(X_test_dummy))
                                else:
                                    error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

                            else: 
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
                                                               y_test, mdl.predict(X_test))
                                else:
                                    error = metric['function'](y_test, mdl.predict(X_test))

                            #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
                            validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df

print "Finished."
# Out:
# Working with sensor: id12041992
#
# 	-->Prediction horizont: 1h. Shifting runtime: 0.76s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: 0.637
# 				-->MAE: 15.876
# 				-->MAPE: 18.577
# 				-->MASE: 1.123
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.918
# 				-->MAPE: 23.415
# 				-->MASE: 1.409
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.400
# 				-->MAPE: 20.381
# 				-->MASE: 1.231
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Random Forest, runtime: 5.59s
# 				-->R2: 0.788
# 				-->MAE: 12.403
# 				-->MAPE: 15.257
# 				-->MASE: 0.877
# Finished.

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

def start_prediction_valuation(verbose=False):

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041992']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek, sensor_data.index.time], how = 'left')
        
        for horizon in range (1,25):
        #for horizon in range (1,4):

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            # Split Training and Testing set
            training_data = sensor_data[:splitting_time]
            testing_data = sensor_data[splitting_time:]
            
            # Create dummy feature vector for linear regression
            sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                    prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                    prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                    prefix='dummy_shifted_Month'))))
            #sensor_data_dummy.dropna(inplace=True)
            dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
            training_data_dummy = sensor_data_dummy[:splitting_time]
            testing_data_dummy = sensor_data_dummy[splitting_time:]

            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            for data_set in data_sets:            
                # Create training vectors
                X_train = training_data[data_set['ftrs']].values
                y_train = training_data[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_train.shape
                
                # Create testing vectors
                X_test = testing_data[data_set['ftrs']].values
                y_test = testing_data[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_test.shape
                
                # Create dummy feature vector for linear regression
                if "shifted_HourOfDay" in data_set['ftrs']: 
                    X_train_dummy = training_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                else: 
                    X_train_dummy = training_data_dummy[data_set['ftrs']].values
                y_train_dummy = training_data_dummy[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_train_dummy.shape

                if "shifted_HourOfDay" in data_set['ftrs']:
                    X_test_dummy = testing_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                else:
                    X_test_dummy = testing_data_dummy[data_set['ftrs']].values    
                y_test_dummy = testing_data_dummy[["shifted_measurement"]].values.ravel()
                #print "Using dummy features: ", X_test_dummy.shape
                                                           
                if verbose: print "\n\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                          X_train.shape, y_train.shape)

                if data_set['name'] == "Baselines":
                    for baseline in baselines:
                        
                        if verbose: print "\t\t\t-->Computing {}".format(baseline['name'])
                        bl = eval(baseline['init'])

                        for metric in error_metrics:
                            if metric['short'] == 'MASE':
                                error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                           y_test, testing_data[bl.target])
                            else:
                                error = metric['function'](y_test, testing_data[bl.target])

                            validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)
                                
                else:    
                    for model in models: 
                        # Initializing model
                        mdl = eval(model['init'])

                        # Model leraning
                        start = time.time() # Start measuring time
                        if model['name'] == "Ridge Regression":
                            mdl.fit(X_train_dummy, y_train_dummy)
                        else:
                            mdl.fit(X_train,y_train)
                        runtime = time.time() - start # Calculate runtime

                        if verbose: print "\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

                        for metric in error_metrics:
                            #print "\t-->Error metric: {}".format(metric['name'])

                            if model['name'] == "Ridge Regression":
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
                                                               y_test_dummy, mdl.predict(X_test_dummy))
                                else:
                                    error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

                            else: 
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
                                                               y_test, mdl.predict(X_test))
                                else:
                                    error = metric['function'](y_test, mdl.predict(X_test))

                            #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
                            validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-630de5f0ce77> in <module>()
# ----> 1 validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
#       2                              columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric']))
#       3
#       4 def start_prediction_valuation(verbose=False):
#       5
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Save to file

# %%
output_file_name = "validationResults_id12041992.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

validation_df.to_csv(output_file_path)

# %% [markdown]
# ### Read from file

# %%
output_file_name = "validationResults_id12041992.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

validation_df = pd.read_csv(output_file_path, index_col=[0,1,2], header=[0,1])

# %% [markdown]
# ## Entire Validation Dataset

# %%
#validation_df = pd.read_csv(output_file_path, index_col=[0,1,2], header=[0,1])

# %%
validation_df
# Out:
# sensor                                    id12041992                        \
# error metric                                      R2        MAE       MAPE
# horizon dataset       model
# 1       Last value    Baselines             0.636684  15.875924  18.577076
#         Previous day  Baselines             0.381451  19.918373  23.415252
#         Previous week Baselines             0.546953  17.399943  20.381010
#         AR            Ridge Regression      0.766562  13.006488  15.645965
#                       K Nearest Neighbors   0.638083  16.421954  20.571655
#                       Random Forest         0.768992  12.919006  15.904520
#         AR_WC_WF      Ridge Regression      0.768665  13.004687  15.788711
#                       K Nearest Neighbors   0.212736  24.491439  33.188670
#                       Random Forest         0.773841  12.803924  15.819571
#         AR_DT         Ridge Regression      0.788009  12.489516  15.283738
#                       K Nearest Neighbors   0.615003  16.979757  21.281848
#                       Random Forest         0.788856  12.448496  15.437230
#         AR_WC_DT      Ridge Regression      0.787101  12.560460  15.397247
#                       K Nearest Neighbors   0.183183  24.873140  33.942062
#                       Random Forest         0.782855  12.638271  15.721077
#         AR_WF_DT      Ridge Regression      0.788062  12.496202  15.277545
#                       K Nearest Neighbors   0.567042  17.931741  22.463461
#                       Random Forest         0.788980  12.453238  15.411947
#         ALL           Ridge Regression      0.787098  12.564994  15.402169
#                       K Nearest Neighbors   0.201385  24.620576  33.399518
#                       Random Forest         0.783825  12.607759  15.700652
#         TOP_20        Ridge Regression      0.787454  12.503395  15.264128
#                       K Nearest Neighbors   0.749947  13.537262  16.427855
#                       Random Forest         0.790447  12.393298  15.358188
#         TOP_10        Ridge Regression      0.788317  12.423933  15.025069
#                       K Nearest Neighbors   0.744775  13.654261  16.413264
#                       Random Forest         0.787629  12.410205  15.274166
# 2       Last value    Baselines             0.370072  21.306933  25.289154
#         Previous day  Baselines             0.381349  19.918217  23.411514
#         Previous week Baselines             0.546821  17.401540  20.380839
# ...                                              ...        ...        ...
# 23      TOP_10        Ridge Regression      0.707255  14.510977  18.325181
#                       K Nearest Neighbors   0.599342  16.714938  20.759809
#                       Random Forest         0.715139  14.167380  18.004275
# 24      Last value    Baselines             0.378388  19.711000  23.144362
#         Previous day  Baselines             0.378388  19.711000  23.144362
#         Previous week Baselines             0.541665  17.255681  20.248929
#         AR            Ridge Regression      0.665275  15.257475  18.975125
#                       K Nearest Neighbors   0.490266  19.014155  23.921505
#                       Random Forest         0.651329  15.660183  20.281104
#         AR_WC_WF      Ridge Regression      0.663656  15.472958  19.514113
#                       K Nearest Neighbors   0.119258  25.754057  35.063444
#                       Random Forest         0.654012  15.604389  20.190309
#         AR_DT         Ridge Regression      0.705551  14.627673  18.659706
#                       K Nearest Neighbors   0.457693  19.745510  25.182480
#                       Random Forest         0.720320  14.234518  18.454356
#         AR_WC_DT      Ridge Regression      0.706705  14.692178  18.699027
#                       K Nearest Neighbors   0.102228  25.949268  35.563768
#                       Random Forest         0.721585  14.212870  18.391587
#         AR_WF_DT      Ridge Regression      0.704903  14.668816  18.665479
#                       K Nearest Neighbors   0.412986  20.579362  26.159174
#                       Random Forest         0.723081  14.155856  18.397661
#         ALL           Ridge Regression      0.706901  14.693114  18.643355
#                       K Nearest Neighbors   0.124849  25.697364  34.948616
#                       Random Forest         0.719901  14.248675  18.467197
#         TOP_20        Ridge Regression      0.703177  14.640814  18.590530
#                       K Nearest Neighbors   0.604104  16.662824  20.675919
#                       Random Forest         0.722807  14.161381  18.279729
#         TOP_10        Ridge Regression      0.704714  14.558086  18.436126
#                       K Nearest Neighbors   0.592913  16.776789  20.776035
#                       Random Forest         0.715974  14.151379  17.941886
#
# sensor
# error metric                                   MASE
# horizon dataset       model
# 1       Last value    Baselines            1.122833
#         Previous day  Baselines            1.408737
#         Previous week Baselines            1.230620
#         AR            Ridge Regression     0.919890
#                       K Nearest Neighbors  1.161451
#                       Random Forest        0.913703
#         AR_WC_WF      Ridge Regression     0.919763
#                       K Nearest Neighbors  1.732169
#                       Random Forest        0.905564
#         AR_DT         Ridge Regression     0.883327
#                       K Nearest Neighbors  1.200902
#                       Random Forest        0.880426
#         AR_WC_DT      Ridge Regression     0.888345
#                       K Nearest Neighbors  1.759165
#                       Random Forest        0.893848
#         AR_WF_DT      Ridge Regression     0.883800
#                       K Nearest Neighbors  1.268231
#                       Random Forest        0.880761
#         ALL           Ridge Regression     0.888665
#                       K Nearest Neighbors  1.741303
#                       Random Forest        0.891690
#         TOP_20        Ridge Regression     0.884309
#                       K Nearest Neighbors  0.957430
#                       Random Forest        0.876522
#         TOP_10        Ridge Regression     0.878689
#                       K Nearest Neighbors  0.965704
#                       Random Forest        0.877718
# 2       Last value    Baselines            1.035404
#         Previous day  Baselines            0.967920
#         Previous week Baselines            0.845622
# ...                                             ...
# 23      TOP_10        Ridge Regression     0.657346
#                       K Nearest Neighbors  0.757185
#                       Random Forest        0.641781
# 24      Last value    Baselines            1.042030
#         Previous day  Baselines            1.042030
#         Previous week Baselines            0.912228
#         AR            Ridge Regression     0.806592
#                       K Nearest Neighbors  1.005191
#                       Random Forest        0.827882
#         AR_WC_WF      Ridge Regression     0.817984
#                       K Nearest Neighbors  1.361498
#                       Random Forest        0.824932
#         AR_DT         Ridge Regression     0.773298
#                       K Nearest Neighbors  1.043854
#                       Random Forest        0.752513
#         AR_WC_DT      Ridge Regression     0.776708
#                       K Nearest Neighbors  1.371818
#                       Random Forest        0.751369
#         AR_WF_DT      Ridge Regression     0.775473
#                       K Nearest Neighbors  1.087936
#                       Random Forest        0.748355
#         ALL           Ridge Regression     0.776757
#                       K Nearest Neighbors  1.358501
#                       Random Forest        0.753262
#         TOP_20        Ridge Regression     0.773992
#                       K Nearest Neighbors  0.880887
#                       Random Forest        0.748647
#         TOP_10        Ridge Regression     0.769619
#                       K Nearest Neighbors  0.886911
#                       Random Forest        0.748118
#
# [648 rows x 4 columns]

# %% [markdown]
# ## Evaluation Scores Over All Horizons

# %%
validation_df.groupby(level=['dataset', 'model'], sort=False).mean()
# Out:
# sensor                            id12041992
# error metric                              R2        MAE       MAPE      MASE
# dataset       model
# Last value    Baselines            -0.765331  36.904146  47.137848  1.006007
# Previous day  Baselines             0.380352  19.853584  23.331656  0.609474
# Previous week Baselines             0.545064  17.352144  20.334814  0.532726
# AR            Ridge Regression      0.675136  15.169802  18.781403  0.460499
#               K Nearest Neighbors   0.479010  19.502946  25.067923  0.589047
#               Random Forest         0.667643  15.418243  19.934093  0.467240
# AR_WC_WF      Ridge Regression      0.672523  15.425997  19.435275  0.467395
#               K Nearest Neighbors   0.044903  26.920785  36.751562  0.818142
#               Random Forest         0.672102  15.295806  19.774312  0.463767
# AR_DT         Ridge Regression      0.718375  14.427290  18.252264  0.438529
#               K Nearest Neighbors   0.449584  20.099784  25.881471  0.607775
#               Random Forest         0.731601  14.022380  18.117393  0.427004
# AR_WC_DT      Ridge Regression      0.717226  14.543929  18.403971  0.441924
#               K Nearest Neighbors   0.001415  27.542692  37.943464  0.836821
#               Random Forest         0.731290  14.077713  18.198839  0.429301
# AR_WF_DT      Ridge Regression      0.718151  14.458425  18.257723  0.439446
#               K Nearest Neighbors   0.406289  20.934927  26.942185  0.633751
#               Random Forest         0.733502  13.989535  18.073922  0.426114
# ALL           Ridge Regression      0.717493  14.545325  18.373530  0.441982
#               K Nearest Neighbors   0.045128  26.912038  36.749838  0.817992
#               Random Forest         0.731724  14.074994  18.197575  0.429091
# TOP_20        Ridge Regression      0.715729  14.450273  18.194124  0.439190
#               K Nearest Neighbors   0.626254  16.361109  20.290428  0.495448
#               Random Forest         0.732221  14.029265  18.102572  0.427092
# TOP_10        Ridge Regression      0.717848  14.339168  17.942363  0.435870
#               K Nearest Neighbors   0.617190  16.489192  20.303340  0.499643
#               Random Forest         0.725003  14.052527  17.842614  0.427608

# %%
for sensor_id in validation_df.columns.levels[0]:
        
    err = validation_df.groupby(level=['dataset', 'model']).std()[sensor_id]['R2'].unstack(0)
            
    ax = validation_df.groupby(level=['dataset', 'model']).mean()[sensor_id]['R2'].unstack(0).plot(
        yerr=err, kind='bar', figsize=(15,4), rot=0, title=sensor_id, colormap='Blues', ylim=(0,1))
    
    for p in ax.patches:
        ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha='center')
    
    plt.gca().yaxis.grid(True)
    ax.set_ylabel('R2')
    plt.legend(loc='right', bbox_to_anchor=(1.23, 0.5), ncol=1, fancybox=True, shadow=True)

# %% [markdown]
# ### Errors only for specific prediction horizon

# %%
"""
for sensor_id in validation_df.columns.levels[0]:
    ax = validation_df.loc[20][sensor_id]['R2'].unstack(0).plot(
        kind='bar', figsize=(15,4), rot=0, title=sensor_id, colormap='Blues', ylim=(0,1))
    
    for p in ax.patches:
        ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha='center')
    
    plt.gca().yaxis.grid(True)
    ax.set_ylabel(measure)
    plt.legend(loc='right', bbox_to_anchor=(1.2, 0.5), ncol=1, fancybox=True, shadow=True)
"""
# Out:
# '\nfor sensor_id in validation_df.columns.levels[0]:\n    ax = validation_df.loc[20][sensor_id][\'R2\'].unstack(0).plot(\n        kind=\'bar\', figsize=(15,4), rot=0, title=sensor_id, colormap=\'Blues\', ylim=(0,1))\n    \n    for p in ax.patches:\n        ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha=\'center\')\n    \n    plt.gca().yaxis.grid(True)\n    ax.set_ylabel(measure)\n    plt.legend(loc=\'right\', bbox_to_anchor=(1.2, 0.5), ncol=1, fancybox=True, shadow=True)\n'

# %% [markdown]
# ## Evaluation Scores for Each Horizon

# %%
ax = validation_df.xs(["Baselines"], level=["model"]).unstack()['id14061709']['R2'][['Last value', 'Previous week']].join(
    validation_df.xs(["TOP_20"], level=["dataset"]).unstack()['id14061709']['R2']).plot(
    kind='bar', figsize=(20,5), title='R2 results - all horizons (id14061709)', ylim=(0,1), colormap='Blues')

for p in ax.patches:
    ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha='center')

ax.yaxis.grid()
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True, shadow=True)
#plt.legend(loc='lower center', bbox_to_anchor=(0.5, 0.), ncol=5, fancybox=True, shadow=True)
#plt.legend(loc=4)
plt.ylabel('R2 Score')

# %%
for measure in validation_df.columns.levels[1]:
    
    ax = validation_df.xs(["Baselines"], level=["model"]).unstack()['id14061709'][measure][['Last value', 'Previous week']].join(
        validation_df.xs(["TOP_20"], level=["dataset"]).unstack()['id14061709'][measure]).plot(
        kind='bar', figsize=(20,5), colormap='Blues')
    
    ax.yaxis.grid()   
    plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True, shadow=True)
    plt.ylabel(measure)

# %% [markdown]
# ## Average Score by Sensors and Horizons

# %%
validation_df.groupby(level=['dataset', 'model']).mean().groupby(level='error metric', axis=1).mean()
# Out:
# error metric                                   R2       MAE       MAPE  \
# dataset             model
# Last value          Baselines            0.561509  1.675817  29.038490
# Previous day        Baselines            0.399188  2.035682  41.442958
# Previous week       Baselines            0.655598  1.569669  30.650789
# Measurement average Baselines            0.176525  3.042106  72.821162
# AR                  Ridge Regression     0.812825  1.276349  27.640770
#                     K Nearest Neighbors  0.785566  1.356553  29.801900
#                     Random Forest        0.823768  1.255085  29.553442
# SELECTED            Ridge Regression     0.755056  1.611357  39.967885
#                     K Nearest Neighbors  0.781093  1.401275  30.995457
#                     Random Forest        0.842835  1.194789  26.340880
#
# error metric                                 MASE
# dataset             model
# Last value          Baselines            0.728761
# Previous day        Baselines            0.939339
# Previous week       Baselines            0.724327
# Measurement average Baselines            1.378100
# AR                  Ridge Regression     0.575318
#                     K Nearest Neighbors  0.616033
#                     Random Forest        0.565061
# SELECTED            Ridge Regression     0.711889
#                     K Nearest Neighbors  0.631593
#                     Random Forest        0.538496

# %%
for measure in validation_df.columns.levels[1]:

    err = ax = validation_df.groupby(level=['dataset', 'model']).std().groupby(
        level='error metric', axis=1).mean()[measure].unstack(0)
    
    ax = validation_df.groupby(level=['dataset', 'model']).mean().groupby(
        level='error metric', axis=1).mean()[measure].unstack(0).plot(
        yerr=err, kind='bar', figsize=(15,5), rot=0, title="Error Measure: {}".format(measure), colormap='Blues')

    for p in ax.patches:
        ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha='center')
    
    plt.gca().yaxis.grid(True)
    ax.set_ylabel(measure)
    plt.legend(loc='right', bbox_to_anchor=(1.2, 0.5), ncol=1, fancybox=True, shadow=True)

# %% [markdown]
# NOTE: From this, it looks like weather does not help to improve accuracy. Date time features are the most important.
