# %% [markdown]
# #Evaluation -  id12041992

# %%
# %matplotlib inline
import matplotlib as mpl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import numpy as np
import os
import time

# %% [markdown]
# ### Load dataset

# %%
input_file_name = "lotOfFeatures.csv"
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), input_file_name)

original_data = pd.read_csv(input_file_path, index_col=0, parse_dates=True)
originalSize = original_data.shape[1]
original_data.head()
original_data.shape
# Out:
# (139678, 535)

# %% [markdown]
# ## Excluding Testing Set

# %% [markdown]
# Spliting the dataset into three parts: training, testing and evaluation (last 10 percent).

# %%
start_time = '2012-02-01 00:00:00'
#start_time = '2014-02-01 00:00:00'
splitting_point = int(0.8 * original_data.shape[0])
splitting_time = original_data.iloc[[splitting_point]].index.to_pydatetime()[0]
#data = original_data[:splitting_time]
data = original_data[start_time:]

# %%
f = original_data[["id12041992"]].plot(figsize=(20,5)) 
original_data.iloc(splitting_point)
f.axvline(start_time, color='g')
f.axvline(splitting_time, color='r')

# %% [markdown]
# # Define Machine Learning Models and Data Sets

# %%
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import svm
from sklearn import neighbors
from sklearn import metrics
import regression_metrics as additional_metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.learning_curve import learning_curve
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import explained_variance_score
from neural_network import PyBrainNN

# %% [markdown]
# ## Creating Feature Sets

# %%
autoregressive_ftrs = ['measurement', 'shifted_measurement_1d', 'shifted_measurement_2d', 'shifted_measurement_1w', 
                       'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_mean_d', 
                       'measurement_roll_mean_w', 'measurement_roll_mean_m', 'measurement_roll_min2_d',
                       'measurement_roll_min2_w', 'measurement_roll_max2_d', 'measurement_roll_max2_w',
                       'measurement_roll_var_6h', 'measurement_roll_var_d', 'measurement_roll_var_w']

wetaher_current_ftrs =  ['p', 't2m_termin', 'rh_termin', 'padavine', 'veter_hitrost', 'veter_vek_smer', 'energija_gl',
 'energija_di', 'p_roll_mean_1h', 'p_roll_mean_6h', 'p_roll_mean_d', 'p_roll_mean_w', 'p_roll_mean_m', 'p_roll_var_1h',
 'p_roll_var_d', 't2m_termin_roll_mean_1h', 't2m_termin_roll_mean_6h', 't2m_termin_roll_mean_d', 't2m_termin_roll_mean_w',
 't2m_termin_roll_mean_m', 't2m_termin_roll_min2_d', 't2m_termin_roll_min2_w', 't2m_termin_roll_max2_d',
 't2m_termin_roll_max2_w', 't2m_termin_roll_var_1h', 't2m_termin_roll_var_d', 'rh_termin_roll_mean_1h',
 'rh_termin_roll_mean_6h', 'rh_termin_roll_mean_d', 'rh_termin_roll_mean_w', 'rh_termin_roll_mean_m',
 'rh_termin_roll_min2_d', 'rh_termin_roll_min2_w', 'rh_termin_roll_max2_d', 'rh_termin_roll_max2_w',
 'rh_termin_roll_var_1h', 'rh_termin_roll_var_d', 'energija_gl_roll_mean_1h', 'energija_gl_roll_mean_6h',
 'energija_gl_roll_mean_d', 'energija_gl_roll_mean_w', 'energija_gl_roll_mean_m', 'energija_gl_roll_var_1h',
 'energija_gl_roll_var_d']

weather_forecasted_ftrs =  ['shifted_p', 'shifted_t2m_termin', 'shifted_rh_termin', 'shifted_padavine', 
                            'shifted_veter_hitrost', 'shifted_veter_vek_smer', 'shifted_energija_gl']

date_time_ftrs =  ['shifted_HourOfDay', 'shifted_DayOfWeek', 'shifted_Month', 'shifted_Weekday', 'shifted_Weekend', 
                   'shifted_Holiday', 'shifted_DayBeforeHoliday', 'shifted_DayAfterHodliay', 'shifted_BusinessDay', 
                   'shifted_BusinessDay_sum', 'shifted_Holiday_sum']

top20_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay', 't2m_termin_roll_mean_m', 'shifted_Holiday', 
              'shifted_energija_gl', 'shifted_DayOfWeek', 'shifted_t2m_termin', 'p_roll_var_d', 'shifted_measurement_2d', 
              'measurement_roll_mean_m', 'p_roll_mean_m', 'rh_termin_roll_mean_w']

top10_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay']

# %%
all_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_wc_wf_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs
ar_wc_dt_ftrs = autoregressive_ftrs + wetaher_current_ftrs + date_time_ftrs 
ar_wf_dt_ftrs = autoregressive_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_dt_ftrs = autoregressive_ftrs + date_time_ftrs 
ar_ftrs = autoregressive_ftrs
top20_ftrs = top20_ftrs
top10_ftrs = top10_ftrs

# %% [markdown]
# ## Prediction Results

# %%
class NaiveModel:
    
    def __init__(self, target):
        self.target = target

# %%
baselines = [{'name': "Last value", 'init': "NaiveModel('measurement')"},
             {'name': "Previous day", 'init': "NaiveModel('shifted_measurement_1d')"},
             {'name': "Previous week", 'init': "NaiveModel('shifted_measurement_1w')"},
             #{'name': "Measurement average", 'init': "NaiveModel('measurement_avr')"},
            ]

models = [{'name': "Ridge Regression", 'init': "linear_model.Ridge()"},
          {'name': "K Nearest Neighbors", 'init': "neighbors.KNeighborsRegressor(n_neighbors = 5)"},
          {'name': "Random Forest", 'init': "RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, n_jobs=8)"},
          #{'name': "SVR", 'init': "svm.SVR(kernel ='rbf', C = 10, gamma = .001)"},
          #{'name': "Neural Network", 'init': "PyBrainNN(hidden_size = 100, learningrate = 0.001, momentum = 0.1, maxEpochs=10)"},
          ]

data_sets = [{'name': "Baselines", 'ftrs': ar_ftrs},
             {'name': "AR", 'ftrs': ar_ftrs},
             {'name': "AR_WC_WF", 'ftrs': ar_wc_wf_ftrs},
             {'name': "AR_DT", 'ftrs': ar_dt_ftrs},             
             {'name': "AR_WC_DT", 'ftrs': ar_wc_dt_ftrs},
             {'name': "AR_WF_DT", 'ftrs': ar_wf_dt_ftrs},    
             {'name': "ALL", 'ftrs': all_ftrs},
             {'name': "TOP_20", 'ftrs': top20_ftrs},
             {'name': "TOP_10", 'ftrs': top10_ftrs},
             ]

error_metrics = [{'name': "R2 Score", 'short': "R2", 'function': metrics.r2_score},
                 #{'name': "Explained Variance Score", 'short': "EV", 'function': metrics.explained_variance_score},
                 {'name': "Mean Absolute Error", 'short': "MAE", 'function': metrics.mean_absolute_error},
                 #{'name': "Mean Squared Error", 'short': "MSE", 'function': metrics.mean_squared_error},
                 {'name': "Mean Absolute Percentage Error", 'short': "MAPE", 'function': additional_metrics.mean_absolute_percentage_error},
                 {'name': "Mean Absolute Scaled Error", 'short': "MASE", 'function': additional_metrics.mean_absolute_scaled_error}
                ]

#validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['sensor', 'horizon', 'error metric']),
#                             columns=pd.MultiIndex.from_arrays([[],[]], names=['method', 'data set']))

validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric']))

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

def start_prediction_valuation(verbose=False):

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id12041992']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek, sensor_data.index.time], how = 'left')
        
        for horizon in range (1,25):
        #for horizon in range (1,4):

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            # Split Training and Testing set
            training_data = sensor_data[:splitting_time]
            testing_data = sensor_data[splitting_time:]
            
            # Create dummy feature vector for linear regression
            sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                    prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                    prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                    prefix='dummy_shifted_Month'))))
            #sensor_data_dummy.dropna(inplace=True)
            dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
            training_data_dummy = sensor_data_dummy[:splitting_time]
            testing_data_dummy = sensor_data_dummy[splitting_time:]

            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            for data_set in data_sets:            
                # Create training vectors
                X_train = training_data[data_set['ftrs']].values
                y_train = training_data[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_train.shape
                
                # Create testing vectors
                X_test = testing_data[data_set['ftrs']].values
                y_test = testing_data[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_test.shape
                
                # Create dummy feature vector for linear regression
                if "shifted_HourOfDay" in data_set['ftrs']: 
                    X_train_dummy = training_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                else: 
                    X_train_dummy = training_data_dummy[data_set['ftrs']].values
                y_train_dummy = training_data_dummy[["shifted_measurement"]].values.ravel()
                #print "Using dummy features:", X_train_dummy.shape

                if "shifted_HourOfDay" in data_set['ftrs']:
                    X_test_dummy = testing_data_dummy[data_set['ftrs'] + dummy_ftrs].values
                else:
                    X_test_dummy = testing_data_dummy[data_set['ftrs']].values    
                y_test_dummy = testing_data_dummy[["shifted_measurement"]].values.ravel()
                #print "Using dummy features: ", X_test_dummy.shape
                                                           
                if verbose: print "\n\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                          X_train.shape, y_train.shape)

                if data_set['name'] == "Baselines":
                    for baseline in baselines:
                        
                        if verbose: print "\t\t\t-->Computing {}".format(baseline['name'])
                        bl = eval(baseline['init'])

                        for metric in error_metrics:
                            if metric['short'] == 'MASE':
                                error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                           y_test, testing_data[bl.target])
                            else:
                                error = metric['function'](y_test, testing_data[bl.target])

                            validation_df.loc[(horizon, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)
                                
                else:    
                    for model in models: 
                        # Initializing model
                        mdl = eval(model['init'])

                        # Model leraning
                        start = time.time() # Start measuring time
                        if model['name'] == "Ridge Regression":
                            mdl.fit(X_train_dummy, y_train_dummy)
                        else:
                            mdl.fit(X_train,y_train)
                        runtime = time.time() - start # Calculate runtime

                        if verbose: print "\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

                        for metric in error_metrics:
                            #print "\t-->Error metric: {}".format(metric['name'])

                            if model['name'] == "Ridge Regression":
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
                                                               y_test_dummy, mdl.predict(X_test_dummy))
                                else:
                                    error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

                            else: 
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
                                                               y_test, mdl.predict(X_test))
                                else:
                                    error = metric['function'](y_test, mdl.predict(X_test))

                            #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
                            validation_df.loc[(horizon, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                            if verbose: print "\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df
# Out:
# Working with sensor: id12041992
#
# 	-->Prediction horizont: 1h. Shifting runtime: 16.42s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# D:\Users\bkazic\Envs\py27_64bit\lib\site-packages\pandas\core\frame.py:2524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# regression_metrics.py:27: RuntimeWarning: Found 4 zero elements in y_pred. Removing 4 zero elements
#   warnings.warn(warning_msg, RuntimeWarning)
# 			-->Computing Last value
# 				-->R2: 0.637
# 				-->MAE: 15.876
# 				-->MAPE: 18.577
# 				-->MASE: 1.123
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.918
# 				-->MAPE: 23.415
# 				-->MASE: 1.409
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.400
# 				-->MAPE: 20.381
# 				-->MASE: 1.231
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 2.88s
# 				-->R2: 0.767
# 				-->MAE: 13.006
# 				-->MAPE: 15.646
# 				-->MASE: 0.920
# 			-->Training model: K Nearest Neighbors, runtime: 0.40s
# 				-->R2: 0.638
# 				-->MAE: 16.422
# 				-->MAPE: 20.572
# 				-->MASE: 1.161
# 			-->Training model: Random Forest, runtime: 50.61s
# 				-->R2: 0.769
# 				-->MAE: 12.919
# 				-->MAPE: 15.905
# 				-->MASE: 0.914
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.38s
# 				-->R2: 0.769
# 				-->MAE: 13.005
# 				-->MAPE: 15.789
# 				-->MASE: 0.920
# 			-->Training model: K Nearest Neighbors, runtime: 0.72s
# 				-->R2: 0.213
# 				-->MAE: 24.491
# 				-->MAPE: 33.189
# 				-->MASE: 1.732
# 			-->Training model: Random Forest, runtime: 211.96s
# 				-->R2: 0.774
# 				-->MAE: 12.804
# 				-->MAPE: 15.820
# 				-->MASE: 0.906
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.43s
# 				-->R2: 0.788
# 				-->MAE: 12.490
# 				-->MAPE: 15.284
# 				-->MASE: 0.883
# 			-->Training model: K Nearest Neighbors, runtime: 0.40s
# 				-->R2: 0.615
# 				-->MAE: 16.980
# 				-->MAPE: 21.282
# 				-->MASE: 1.201
# 			-->Training model: Random Forest, runtime: 49.17s
# 				-->R2: 0.789
# 				-->MAE: 12.448
# 				-->MAPE: 15.437
# 				-->MASE: 0.880
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.69s
# 				-->R2: 0.787
# 				-->MAE: 12.560
# 				-->MAPE: 15.397
# 				-->MASE: 0.888
# 			-->Training model: K Nearest Neighbors, runtime: 0.71s
# 				-->R2: 0.183
# 				-->MAE: 24.873
# 				-->MAPE: 33.942
# 				-->MASE: 1.759
# 			-->Training model: Random Forest, runtime: 192.81s
# 				-->R2: 0.783
# 				-->MAE: 12.638
# 				-->MAPE: 15.721
# 				-->MASE: 0.894
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.45s
# 				-->R2: 0.788
# 				-->MAE: 12.496
# 				-->MAPE: 15.278
# 				-->MASE: 0.884
# 			-->Training model: K Nearest Neighbors, runtime: 0.52s
# 				-->R2: 0.567
# 				-->MAE: 17.932
# 				-->MAPE: 22.463
# 				-->MASE: 1.268
# 			-->Training model: Random Forest, runtime: 60.96s
# 				-->R2: 0.789
# 				-->MAE: 12.453
# 				-->MAPE: 15.412
# 				-->MASE: 0.881
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.69s
# 				-->R2: 0.787
# 				-->MAE: 12.565
# 				-->MAPE: 15.402
# 				-->MASE: 0.889
# 			-->Training model: K Nearest Neighbors, runtime: 0.95s
# 				-->R2: 0.201
# 				-->MAE: 24.621
# 				-->MAPE: 33.400
# 				-->MASE: 1.741
# 			-->Training model: Random Forest, runtime: 183.88s
# 				-->R2: 0.784
# 				-->MAE: 12.608
# 				-->MAPE: 15.701
# 				-->MASE: 0.892
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.37s
# 				-->R2: 0.787
# 				-->MAE: 12.503
# 				-->MAPE: 15.264
# 				-->MASE: 0.884
# 			-->Training model: K Nearest Neighbors, runtime: 0.35s
# 				-->R2: 0.750
# 				-->MAE: 13.537
# 				-->MAPE: 16.428
# 				-->MASE: 0.957
# 			-->Training model: Random Forest, runtime: 50.14s
# 				-->R2: 0.790
# 				-->MAE: 12.393
# 				-->MAPE: 15.358
# 				-->MASE: 0.877
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.31s
# 				-->R2: 0.788
# 				-->MAE: 12.424
# 				-->MAPE: 15.025
# 				-->MASE: 0.879
# 			-->Training model: K Nearest Neighbors, runtime: 0.34s
# 				-->R2: 0.745
# 				-->MAE: 13.654
# 				-->MAPE: 16.413
# 				-->MASE: 0.966
# 			-->Training model: Random Forest, runtime: 21.41s
# 				-->R2: 0.788
# 				-->MAE: 12.410
# 				-->MAPE: 15.274
# 				-->MASE: 0.878
#
# 	-->Prediction horizont: 2h. Shifting runtime: 17.98s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: 0.370
# 				-->MAE: 21.307
# 				-->MAPE: 25.289
# 				-->MASE: 1.035
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.918
# 				-->MAPE: 23.412
# 				-->MASE: 0.968
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.402
# 				-->MAPE: 20.381
# 				-->MASE: 0.846
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.711
# 				-->MAE: 14.535
# 				-->MAPE: 17.769
# 				-->MASE: 0.706
# 			-->Training model: K Nearest Neighbors, runtime: 0.27s
# 				-->R2: 0.564
# 				-->MAE: 17.851
# 				-->MAPE: 22.464
# 				-->MASE: 0.867
# 			-->Training model: Random Forest, runtime: 54.35s
# 				-->R2: 0.720
# 				-->MAE: 14.283
# 				-->MAPE: 18.043
# 				-->MASE: 0.694
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.64s
# 				-->R2: 0.714
# 				-->MAE: 14.559
# 				-->MAPE: 18.027
# 				-->MASE: 0.707
# 			-->Training model: K Nearest Neighbors, runtime: 1.22s
# 				-->R2: 0.133
# 				-->MAE: 25.469
# 				-->MAPE: 34.449
# 				-->MASE: 1.238
# 			-->Training model: Random Forest, runtime: 204.63s
# 				-->R2: 0.727
# 				-->MAE: 14.197
# 				-->MAPE: 17.974
# 				-->MASE: 0.690
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.45s
# 				-->R2: 0.745
# 				-->MAE: 13.794
# 				-->MAPE: 17.203
# 				-->MASE: 0.670
# 			-->Training model: K Nearest Neighbors, runtime: 0.38s
# 				-->R2: 0.544
# 				-->MAE: 18.370
# 				-->MAPE: 23.114
# 				-->MASE: 0.893
# 			-->Training model: Random Forest, runtime: 49.74s
# 				-->R2: 0.759
# 				-->MAE: 13.405
# 				-->MAPE: 16.992
# 				-->MASE: 0.651
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.74s
# 				-->R2: 0.743
# 				-->MAE: 13.942
# 				-->MAPE: 17.418
# 				-->MASE: 0.678
# 			-->Training model: K Nearest Neighbors, runtime: 0.78s
# 				-->R2: 0.074
# 				-->MAE: 26.341
# 				-->MAPE: 35.971
# 				-->MASE: 1.280
# 			-->Training model: Random Forest, runtime: 171.25s
# 				-->R2: 0.754
# 				-->MAE: 13.658
# 				-->MAPE: 17.350
# 				-->MASE: 0.664
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.745
# 				-->MAE: 13.815
# 				-->MAPE: 17.204
# 				-->MASE: 0.671
# 			-->Training model: K Nearest Neighbors, runtime: 0.42s
# 				-->R2: 0.499
# 				-->MAE: 19.176
# 				-->MAPE: 24.150
# 				-->MASE: 0.932
# 			-->Training model: Random Forest, runtime: 60.42s
# 				-->R2: 0.759
# 				-->MAE: 13.448
# 				-->MAPE: 17.026
# 				-->MASE: 0.654
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.70s
# 				-->R2: 0.743
# 				-->MAE: 13.948
# 				-->MAPE: 17.422
# 				-->MASE: 0.678
# 			-->Training model: K Nearest Neighbors, runtime: 1.09s
# 				-->R2: 0.125
# 				-->MAE: 25.537
# 				-->MAPE: 34.571
# 				-->MASE: 1.241
# 			-->Training model: Random Forest, runtime: 180.50s
# 				-->R2: 0.756
# 				-->MAE: 13.579
# 				-->MAPE: 17.223
# 				-->MASE: 0.660
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.40s
# 				-->R2: 0.744
# 				-->MAE: 13.825
# 				-->MAPE: 17.178
# 				-->MASE: 0.672
# 			-->Training model: K Nearest Neighbors, runtime: 0.35s
# 				-->R2: 0.691
# 				-->MAE: 15.054
# 				-->MAPE: 18.393
# 				-->MASE: 0.732
# 			-->Training model: Random Forest, runtime: 52.25s
# 				-->R2: 0.755
# 				-->MAE: 13.515
# 				-->MAPE: 17.208
# 				-->MASE: 0.657
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.27s
# 				-->R2: 0.746
# 				-->MAE: 13.691
# 				-->MAPE: 16.820
# 				-->MASE: 0.665
# 			-->Training model: K Nearest Neighbors, runtime: 0.29s
# 				-->R2: 0.674
# 				-->MAE: 15.370
# 				-->MAPE: 18.914
# 				-->MASE: 0.747
# 			-->Training model: Random Forest, runtime: 23.59s
# 				-->R2: 0.753
# 				-->MAE: 13.441
# 				-->MAPE: 16.914
# 				-->MASE: 0.653
#
# 	-->Prediction horizont: 3h. Shifting runtime: 18.60s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: 0.121
# 				-->MAE: 25.282
# 				-->MAPE: 30.290
# 				-->MASE: 0.980
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.919
# 				-->MAPE: 23.411
# 				-->MASE: 0.772
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.404
# 				-->MAPE: 20.383
# 				-->MASE: 0.675
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.698
# 				-->MAE: 14.763
# 				-->MAPE: 18.129
# 				-->MASE: 0.572
# 			-->Training model: K Nearest Neighbors, runtime: 0.30s
# 				-->R2: 0.507
# 				-->MAE: 18.852
# 				-->MAPE: 23.975
# 				-->MASE: 0.731
# 			-->Training model: Random Forest, runtime: 49.06s
# 				-->R2: 0.697
# 				-->MAE: 14.717
# 				-->MAPE: 18.985
# 				-->MASE: 0.571
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.43s
# 				-->R2: 0.699
# 				-->MAE: 14.897
# 				-->MAPE: 18.570
# 				-->MASE: 0.578
# 			-->Training model: K Nearest Neighbors, runtime: 0.78s
# 				-->R2: 0.091
# 				-->MAE: 26.253
# 				-->MAPE: 35.798
# 				-->MASE: 1.018
# 			-->Training model: Random Forest, runtime: 220.51s
# 				-->R2: 0.703
# 				-->MAE: 14.661
# 				-->MAPE: 18.978
# 				-->MASE: 0.568
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.38s
# 				-->R2: 0.736
# 				-->MAE: 14.021
# 				-->MAPE: 17.573
# 				-->MASE: 0.544
# 			-->Training model: K Nearest Neighbors, runtime: 0.38s
# 				-->R2: 0.481
# 				-->MAE: 19.406
# 				-->MAPE: 24.717
# 				-->MASE: 0.752
# 			-->Training model: Random Forest, runtime: 51.12s
# 				-->R2: 0.747
# 				-->MAE: 13.664
# 				-->MAPE: 17.557
# 				-->MASE: 0.530
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.61s
# 				-->R2: 0.733
# 				-->MAE: 14.203
# 				-->MAPE: 17.826
# 				-->MASE: 0.551
# 			-->Training model: K Nearest Neighbors, runtime: 0.77s
# 				-->R2: -0.002
# 				-->MAE: 27.526
# 				-->MAPE: 37.963
# 				-->MASE: 1.067
# 			-->Training model: Random Forest, runtime: 180.07s
# 				-->R2: 0.738
# 				-->MAE: 13.933
# 				-->MAPE: 17.994
# 				-->MASE: 0.540
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.41s
# 				-->R2: 0.736
# 				-->MAE: 14.051
# 				-->MAPE: 17.577
# 				-->MASE: 0.545
# 			-->Training model: K Nearest Neighbors, runtime: 0.45s
# 				-->R2: 0.451
# 				-->MAE: 20.058
# 				-->MAPE: 25.514
# 				-->MASE: 0.778
# 			-->Training model: Random Forest, runtime: 77.80s
# 				-->R2: 0.745
# 				-->MAE: 13.715
# 				-->MAPE: 17.646
# 				-->MASE: 0.532
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.63s
# 				-->R2: 0.733
# 				-->MAE: 14.208
# 				-->MAPE: 17.826
# 				-->MASE: 0.551
# 			-->Training model: K Nearest Neighbors, runtime: 0.82s
# 				-->R2: 0.088
# 				-->MAE: 26.258
# 				-->MAPE: 35.794
# 				-->MASE: 1.018
# 			-->Training model: Random Forest, runtime: 187.41s
# 				-->R2: 0.739
# 				-->MAE: 13.899
# 				-->MAPE: 17.965
# 				-->MASE: 0.539
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.31s
# 				-->R2: 0.735
# 				-->MAE: 14.063
# 				-->MAPE: 17.545
# 				-->MASE: 0.545
# 			-->Training model: K Nearest Neighbors, runtime: 0.31s
# 				-->R2: 0.665
# 				-->MAE: 15.664
# 				-->MAPE: 19.261
# 				-->MASE: 0.607
# 			-->Training model: Random Forest, runtime: 52.45s
# 				-->R2: 0.742
# 				-->MAE: 13.712
# 				-->MAPE: 17.740
# 				-->MASE: 0.532
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.30s
# 				-->R2: 0.737
# 				-->MAE: 13.911
# 				-->MAPE: 17.156
# 				-->MASE: 0.539
# 			-->Training model: K Nearest Neighbors, runtime: 0.25s
# 				-->R2: 0.647
# 				-->MAE: 15.982
# 				-->MAPE: 19.764
# 				-->MASE: 0.620
# 			-->Training model: Random Forest, runtime: 20.17s
# 				-->R2: 0.737
# 				-->MAE: 13.753
# 				-->MAPE: 17.518
# 				-->MASE: 0.533
#
# 	-->Prediction horizont: 4h. Shifting runtime: 19.73s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -0.128
# 				-->MAE: 28.848
# 				-->MAPE: 34.850
# 				-->MASE: 0.953
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.924
# 				-->MAPE: 23.418
# 				-->MASE: 0.658
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.407
# 				-->MAPE: 20.387
# 				-->MASE: 0.575
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.691
# 				-->MAE: 14.867
# 				-->MAPE: 18.279
# 				-->MASE: 0.491
# 			-->Training model: K Nearest Neighbors, runtime: 0.28s
# 				-->R2: 0.471
# 				-->MAE: 19.497
# 				-->MAPE: 25.165
# 				-->MASE: 0.644
# 			-->Training model: Random Forest, runtime: 48.02s
# 				-->R2: 0.683
# 				-->MAE: 14.999
# 				-->MAPE: 19.535
# 				-->MASE: 0.495
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.47s
# 				-->R2: 0.689
# 				-->MAE: 15.096
# 				-->MAPE: 18.859
# 				-->MASE: 0.499
# 			-->Training model: K Nearest Neighbors, runtime: 0.91s
# 				-->R2: 0.041
# 				-->MAE: 26.906
# 				-->MAPE: 37.190
# 				-->MASE: 0.889
# 			-->Training model: Random Forest, runtime: 199.16s
# 				-->R2: 0.683
# 				-->MAE: 15.050
# 				-->MAPE: 19.692
# 				-->MASE: 0.497
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.35s
# 				-->R2: 0.732
# 				-->MAE: 14.128
# 				-->MAPE: 17.744
# 				-->MASE: 0.467
# 			-->Training model: K Nearest Neighbors, runtime: 0.37s
# 				-->R2: 0.446
# 				-->MAE: 20.008
# 				-->MAPE: 25.866
# 				-->MASE: 0.661
# 			-->Training model: Random Forest, runtime: 57.11s
# 				-->R2: 0.736
# 				-->MAE: 13.875
# 				-->MAPE: 18.033
# 				-->MASE: 0.458
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.82s
# 				-->R2: 0.728
# 				-->MAE: 14.323
# 				-->MAPE: 18.009
# 				-->MASE: 0.473
# 			-->Training model: K Nearest Neighbors, runtime: 0.83s
# 				-->R2: -0.068
# 				-->MAE: 28.420
# 				-->MAPE: 39.831
# 				-->MASE: 0.939
# 			-->Training model: Random Forest, runtime: 181.70s
# 				-->R2: 0.728
# 				-->MAE: 14.154
# 				-->MAPE: 18.468
# 				-->MASE: 0.467
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.45s
# 				-->R2: 0.732
# 				-->MAE: 14.157
# 				-->MAPE: 17.748
# 				-->MASE: 0.468
# 			-->Training model: K Nearest Neighbors, runtime: 0.49s
# 				-->R2: 0.424
# 				-->MAE: 20.509
# 				-->MAPE: 26.255
# 				-->MASE: 0.677
# 			-->Training model: Random Forest, runtime: 65.08s
# 				-->R2: 0.736
# 				-->MAE: 13.900
# 				-->MAPE: 18.060
# 				-->MASE: 0.459
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.80s
# 				-->R2: 0.728
# 				-->MAE: 14.333
# 				-->MAPE: 18.010
# 				-->MASE: 0.473
# 			-->Training model: K Nearest Neighbors, runtime: 0.77s
# 				-->R2: 0.038
# 				-->MAE: 26.930
# 				-->MAPE: 37.230
# 				-->MASE: 0.889
# 			-->Training model: Random Forest, runtime: 193.87s
# 				-->R2: 0.729
# 				-->MAE: 14.126
# 				-->MAPE: 18.439
# 				-->MASE: 0.467
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.730
# 				-->MAE: 14.169
# 				-->MAPE: 17.712
# 				-->MASE: 0.468
# 			-->Training model: K Nearest Neighbors, runtime: 0.44s
# 				-->R2: 0.648
# 				-->MAE: 15.970
# 				-->MAPE: 19.715
# 				-->MASE: 0.527
# 			-->Training model: Random Forest, runtime: 56.13s
# 				-->R2: 0.733
# 				-->MAE: 13.969
# 				-->MAPE: 18.171
# 				-->MASE: 0.461
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.42s
# 				-->R2: 0.733
# 				-->MAE: 14.013
# 				-->MAPE: 17.327
# 				-->MASE: 0.463
# 			-->Training model: K Nearest Neighbors, runtime: 0.22s
# 				-->R2: 0.634
# 				-->MAE: 16.209
# 				-->MAPE: 20.002
# 				-->MASE: 0.535
# 			-->Training model: Random Forest, runtime: 25.23s
# 				-->R2: 0.729
# 				-->MAE: 13.938
# 				-->MAPE: 17.825
# 				-->MASE: 0.460
#
# 	-->Prediction horizont: 5h. Shifting runtime: 22.08s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -0.422
# 				-->MAE: 33.102
# 				-->MAPE: 40.839
# 				-->MASE: 0.969
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.926
# 				-->MAPE: 23.423
# 				-->MASE: 0.583
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.410
# 				-->MAPE: 20.391
# 				-->MASE: 0.510
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.05s
# 				-->R2: 0.682
# 				-->MAE: 15.075
# 				-->MAPE: 18.596
# 				-->MASE: 0.441
# 			-->Training model: K Nearest Neighbors, runtime: 0.33s
# 				-->R2: 0.456
# 				-->MAE: 19.788
# 				-->MAPE: 25.780
# 				-->MASE: 0.579
# 			-->Training model: Random Forest, runtime: 45.24s
# 				-->R2: 0.679
# 				-->MAE: 15.192
# 				-->MAPE: 19.683
# 				-->MASE: 0.445
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.41s
# 				-->R2: 0.679
# 				-->MAE: 15.373
# 				-->MAPE: 19.271
# 				-->MASE: 0.450
# 			-->Training model: K Nearest Neighbors, runtime: 0.74s
# 				-->R2: -0.004
# 				-->MAE: 27.523
# 				-->MAPE: 38.340
# 				-->MASE: 0.806
# 			-->Training model: Random Forest, runtime: 173.38s
# 				-->R2: 0.684
# 				-->MAE: 15.144
# 				-->MAPE: 19.627
# 				-->MASE: 0.443
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.39s
# 				-->R2: 0.727
# 				-->MAE: 14.281
# 				-->MAPE: 18.001
# 				-->MASE: 0.418
# 			-->Training model: K Nearest Neighbors, runtime: 0.37s
# 				-->R2: 0.426
# 				-->MAE: 20.384
# 				-->MAPE: 26.621
# 				-->MASE: 0.597
# 			-->Training model: Random Forest, runtime: 50.30s
# 				-->R2: 0.739
# 				-->MAE: 13.911
# 				-->MAPE: 17.963
# 				-->MASE: 0.407
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.75s
# 				-->R2: 0.723
# 				-->MAE: 14.478
# 				-->MAPE: 18.275
# 				-->MASE: 0.424
# 			-->Training model: K Nearest Neighbors, runtime: 0.98s
# 				-->R2: -0.101
# 				-->MAE: 29.000
# 				-->MAPE: 40.954
# 				-->MASE: 0.849
# 			-->Training model: Random Forest, runtime: 167.86s
# 				-->R2: 0.736
# 				-->MAE: 14.062
# 				-->MAPE: 18.188
# 				-->MASE: 0.412
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.33s
# 				-->R2: 0.727
# 				-->MAE: 14.314
# 				-->MAPE: 18.008
# 				-->MASE: 0.419
# 			-->Training model: K Nearest Neighbors, runtime: 0.41s
# 				-->R2: 0.401
# 				-->MAE: 20.972
# 				-->MAPE: 27.094
# 				-->MASE: 0.614
# 			-->Training model: Random Forest, runtime: 59.77s
# 				-->R2: 0.740
# 				-->MAE: 13.894
# 				-->MAPE: 17.928
# 				-->MASE: 0.407
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.56s
# 				-->R2: 0.723
# 				-->MAE: 14.500
# 				-->MAPE: 18.282
# 				-->MASE: 0.424
# 			-->Training model: K Nearest Neighbors, runtime: 0.77s
# 				-->R2: -0.001
# 				-->MAE: 27.466
# 				-->MAPE: 38.254
# 				-->MASE: 0.804
# 			-->Training model: Random Forest, runtime: 201.09s
# 				-->R2: 0.736
# 				-->MAE: 14.059
# 				-->MAPE: 18.177
# 				-->MASE: 0.412
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.28s
# 				-->R2: 0.725
# 				-->MAE: 14.328
# 				-->MAPE: 17.969
# 				-->MASE: 0.419
# 			-->Training model: K Nearest Neighbors, runtime: 0.31s
# 				-->R2: 0.635
# 				-->MAE: 16.221
# 				-->MAPE: 20.092
# 				-->MASE: 0.475
# 			-->Training model: Random Forest, runtime: 47.42s
# 				-->R2: 0.739
# 				-->MAE: 13.943
# 				-->MAPE: 18.012
# 				-->MASE: 0.408
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.24s
# 				-->R2: 0.728
# 				-->MAE: 14.169
# 				-->MAPE: 17.602
# 				-->MASE: 0.415
# 			-->Training model: K Nearest Neighbors, runtime: 0.25s
# 				-->R2: 0.624
# 				-->MAE: 16.346
# 				-->MAPE: 20.133
# 				-->MASE: 0.478
# 			-->Training model: Random Forest, runtime: 19.63s
# 				-->R2: 0.735
# 				-->MAE: 13.895
# 				-->MAPE: 17.587
# 				-->MASE: 0.407
#
# 	-->Prediction horizont: 6h. Shifting runtime: 24.27s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -0.758
# 				-->MAE: 37.641
# 				-->MAPE: 47.316
# 				-->MASE: 0.987
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.928
# 				-->MAPE: 23.421
# 				-->MASE: 0.523
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.407
# 				-->MAPE: 20.385
# 				-->MASE: 0.457
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.03s
# 				-->R2: 0.674
# 				-->MAE: 15.300
# 				-->MAPE: 18.937
# 				-->MASE: 0.401
# 			-->Training model: K Nearest Neighbors, runtime: 0.36s
# 				-->R2: 0.450
# 				-->MAE: 20.130
# 				-->MAPE: 26.383
# 				-->MASE: 0.528
# 			-->Training model: Random Forest, runtime: 54.55s
# 				-->R2: 0.665
# 				-->MAE: 15.457
# 				-->MAPE: 20.154
# 				-->MASE: 0.405
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.44s
# 				-->R2: 0.669
# 				-->MAE: 15.638
# 				-->MAPE: 19.676
# 				-->MASE: 0.410
# 			-->Training model: K Nearest Neighbors, runtime: 1.05s
# 				-->R2: -0.010
# 				-->MAE: 27.482
# 				-->MAPE: 38.049
# 				-->MASE: 0.721
# 			-->Training model: Random Forest, runtime: 254.79s
# 				-->R2: 0.670
# 				-->MAE: 15.356
# 				-->MAPE: 20.008
# 				-->MASE: 0.403
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.68s
# 				-->R2: 0.718
# 				-->MAE: 14.541
# 				-->MAPE: 18.398
# 				-->MASE: 0.381
# 			-->Training model: K Nearest Neighbors, runtime: 0.39s
# 				-->R2: 0.404
# 				-->MAE: 20.927
# 				-->MAPE: 27.553
# 				-->MASE: 0.549
# 			-->Training model: Random Forest, runtime: 51.82s
# 				-->R2: 0.729
# 				-->MAE: 14.055
# 				-->MAPE: 18.236
# 				-->MASE: 0.369
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 1.04s
# 				-->R2: 0.714
# 				-->MAE: 14.737
# 				-->MAPE: 18.668
# 				-->MASE: 0.387
# 			-->Training model: K Nearest Neighbors, runtime: 0.86s
# 				-->R2: -0.138
# 				-->MAE: 29.352
# 				-->MAPE: 41.429
# 				-->MASE: 0.770
# 			-->Training model: Random Forest, runtime: 173.59s
# 				-->R2: 0.727
# 				-->MAE: 14.147
# 				-->MAPE: 18.425
# 				-->MASE: 0.371
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.49s
# 				-->R2: 0.718
# 				-->MAE: 14.573
# 				-->MAPE: 18.405
# 				-->MASE: 0.382
# 			-->Training model: K Nearest Neighbors, runtime: 0.59s
# 				-->R2: 0.383
# 				-->MAE: 21.508
# 				-->MAPE: 27.866
# 				-->MASE: 0.564
# 			-->Training model: Random Forest, runtime: 64.16s
# 				-->R2: 0.729
# 				-->MAE: 14.082
# 				-->MAPE: 18.305
# 				-->MASE: 0.369
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.68s
# 				-->R2: 0.713
# 				-->MAE: 14.761
# 				-->MAPE: 18.675
# 				-->MASE: 0.387
# 			-->Training model: K Nearest Neighbors, runtime: 0.84s
# 				-->R2: -0.011
# 				-->MAE: 27.492
# 				-->MAPE: 38.051
# 				-->MASE: 0.721
# 			-->Training model: Random Forest, runtime: 189.08s
# 				-->R2: 0.726
# 				-->MAE: 14.183
# 				-->MAPE: 18.497
# 				-->MASE: 0.372
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.24s
# 				-->R2: 0.715
# 				-->MAE: 14.580
# 				-->MAPE: 18.346
# 				-->MASE: 0.382
# 			-->Training model: K Nearest Neighbors, runtime: 0.30s
# 				-->R2: 0.627
# 				-->MAE: 16.376
# 				-->MAPE: 20.305
# 				-->MASE: 0.430
# 			-->Training model: Random Forest, runtime: 54.61s
# 				-->R2: 0.729
# 				-->MAE: 14.091
# 				-->MAPE: 18.342
# 				-->MASE: 0.370
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.25s
# 				-->R2: 0.718
# 				-->MAE: 14.431
# 				-->MAPE: 17.999
# 				-->MASE: 0.379
# 			-->Training model: K Nearest Neighbors, runtime: 0.25s
# 				-->R2: 0.613
# 				-->MAE: 16.605
# 				-->MAPE: 20.373
# 				-->MASE: 0.436
# 			-->Training model: Random Forest, runtime: 22.06s
# 				-->R2: 0.722
# 				-->MAE: 14.101
# 				-->MAPE: 17.973
# 				-->MASE: 0.370
#
# 	-->Prediction horizont: 7h. Shifting runtime: 30.07s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -1.064
# 				-->MAE: 41.866
# 				-->MAPE: 52.871
# 				-->MASE: 0.995
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.931
# 				-->MAPE: 23.418
# 				-->MASE: 0.474
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.405
# 				-->MAPE: 20.373
# 				-->MASE: 0.414
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.03s
# 				-->R2: 0.669
# 				-->MAE: 15.424
# 				-->MAPE: 19.133
# 				-->MASE: 0.367
# 			-->Training model: K Nearest Neighbors, runtime: 0.29s
# 				-->R2: 0.435
# 				-->MAE: 20.489
# 				-->MAPE: 27.032
# 				-->MASE: 0.487
# 			-->Training model: Random Forest, runtime: 52.83s
# 				-->R2: 0.657
# 				-->MAE: 15.663
# 				-->MAPE: 20.498
# 				-->MASE: 0.372
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.45s
# 				-->R2: 0.663
# 				-->MAE: 15.788
# 				-->MAPE: 19.913
# 				-->MASE: 0.375
# 			-->Training model: K Nearest Neighbors, runtime: 0.90s
# 				-->R2: -0.022
# 				-->MAE: 27.747
# 				-->MAPE: 38.289
# 				-->MASE: 0.660
# 			-->Training model: Random Forest, runtime: 214.04s
# 				-->R2: 0.661
# 				-->MAE: 15.519
# 				-->MAPE: 20.233
# 				-->MASE: 0.369
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.42s
# 				-->R2: 0.712
# 				-->MAE: 14.702
# 				-->MAPE: 18.636
# 				-->MASE: 0.350
# 			-->Training model: K Nearest Neighbors, runtime: 0.40s
# 				-->R2: 0.390
# 				-->MAE: 21.251
# 				-->MAPE: 28.159
# 				-->MASE: 0.505
# 			-->Training model: Random Forest, runtime: 62.04s
# 				-->R2: 0.725
# 				-->MAE: 14.176
# 				-->MAPE: 18.476
# 				-->MASE: 0.337
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.67s
# 				-->R2: 0.707
# 				-->MAE: 14.911
# 				-->MAPE: 18.928
# 				-->MASE: 0.355
# 			-->Training model: K Nearest Neighbors, runtime: 0.83s
# 				-->R2: -0.138
# 				-->MAE: 29.350
# 				-->MAPE: 41.320
# 				-->MASE: 0.698
# 			-->Training model: Random Forest, runtime: 206.11s
# 				-->R2: 0.723
# 				-->MAE: 14.254
# 				-->MAPE: 18.567
# 				-->MASE: 0.339
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.712
# 				-->MAE: 14.734
# 				-->MAPE: 18.641
# 				-->MASE: 0.350
# 			-->Training model: K Nearest Neighbors, runtime: 0.44s
# 				-->R2: 0.365
# 				-->MAE: 21.927
# 				-->MAPE: 28.748
# 				-->MASE: 0.521
# 			-->Training model: Random Forest, runtime: 76.66s
# 				-->R2: 0.726
# 				-->MAE: 14.156
# 				-->MAPE: 18.459
# 				-->MASE: 0.337
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.74s
# 				-->R2: 0.707
# 				-->MAE: 14.933
# 				-->MAPE: 18.931
# 				-->MASE: 0.355
# 			-->Training model: K Nearest Neighbors, runtime: 0.84s
# 				-->R2: -0.027
# 				-->MAE: 27.776
# 				-->MAPE: 38.353
# 				-->MASE: 0.660
# 			-->Training model: Random Forest, runtime: 170.73s
# 				-->R2: 0.720
# 				-->MAE: 14.324
# 				-->MAPE: 18.675
# 				-->MASE: 0.341
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.33s
# 				-->R2: 0.709
# 				-->MAE: 14.730
# 				-->MAPE: 18.563
# 				-->MASE: 0.350
# 			-->Training model: K Nearest Neighbors, runtime: 0.41s
# 				-->R2: 0.617
# 				-->MAE: 16.590
# 				-->MAPE: 20.654
# 				-->MASE: 0.394
# 			-->Training model: Random Forest, runtime: 49.45s
# 				-->R2: 0.723
# 				-->MAE: 14.224
# 				-->MAPE: 18.518
# 				-->MASE: 0.338
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.23s
# 				-->R2: 0.713
# 				-->MAE: 14.582
# 				-->MAPE: 18.218
# 				-->MASE: 0.347
# 			-->Training model: K Nearest Neighbors, runtime: 0.32s
# 				-->R2: 0.609
# 				-->MAE: 16.708
# 				-->MAPE: 20.539
# 				-->MASE: 0.397
# 			-->Training model: Random Forest, runtime: 20.40s
# 				-->R2: 0.717
# 				-->MAE: 14.282
# 				-->MAPE: 18.233
# 				-->MASE: 0.340
#
# 	-->Prediction horizont: 8h. Shifting runtime: 31.22s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -1.340
# 				-->MAE: 45.267
# 				-->MAPE: 57.504
# 				-->MASE: 1.002
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.930
# 				-->MAPE: 23.418
# 				-->MASE: 0.441
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.397
# 				-->MAPE: 20.370
# 				-->MASE: 0.385
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.669
# 				-->MAE: 15.424
# 				-->MAPE: 19.208
# 				-->MASE: 0.341
# 			-->Training model: K Nearest Neighbors, runtime: 0.27s
# 				-->R2: 0.431
# 				-->MAE: 20.584
# 				-->MAPE: 27.160
# 				-->MASE: 0.455
# 			-->Training model: Random Forest, runtime: 55.30s
# 				-->R2: 0.652
# 				-->MAE: 15.762
# 				-->MAPE: 20.703
# 				-->MASE: 0.349
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.44s
# 				-->R2: 0.662
# 				-->MAE: 15.791
# 				-->MAPE: 19.999
# 				-->MASE: 0.349
# 			-->Training model: K Nearest Neighbors, runtime: 1.01s
# 				-->R2: -0.033
# 				-->MAE: 28.098
# 				-->MAPE: 38.802
# 				-->MASE: 0.622
# 			-->Training model: Random Forest, runtime: 218.43s
# 				-->R2: 0.660
# 				-->MAE: 15.557
# 				-->MAPE: 20.315
# 				-->MASE: 0.344
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.711
# 				-->MAE: 14.708
# 				-->MAPE: 18.702
# 				-->MASE: 0.325
# 			-->Training model: K Nearest Neighbors, runtime: 0.38s
# 				-->R2: 0.401
# 				-->MAE: 21.114
# 				-->MAPE: 27.975
# 				-->MASE: 0.467
# 			-->Training model: Random Forest, runtime: 46.89s
# 				-->R2: 0.722
# 				-->MAE: 14.298
# 				-->MAPE: 18.665
# 				-->MASE: 0.316
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.75s
# 				-->R2: 0.706
# 				-->MAE: 14.923
# 				-->MAPE: 19.002
# 				-->MASE: 0.330
# 			-->Training model: K Nearest Neighbors, runtime: 0.81s
# 				-->R2: -0.095
# 				-->MAE: 28.894
# 				-->MAPE: 40.793
# 				-->MASE: 0.639
# 			-->Training model: Random Forest, runtime: 204.94s
# 				-->R2: 0.721
# 				-->MAE: 14.354
# 				-->MAPE: 18.715
# 				-->MASE: 0.318
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.43s
# 				-->R2: 0.711
# 				-->MAE: 14.732
# 				-->MAPE: 18.697
# 				-->MASE: 0.326
# 			-->Training model: K Nearest Neighbors, runtime: 0.44s
# 				-->R2: 0.362
# 				-->MAE: 21.889
# 				-->MAPE: 28.817
# 				-->MASE: 0.484
# 			-->Training model: Random Forest, runtime: 63.34s
# 				-->R2: 0.725
# 				-->MAE: 14.217
# 				-->MAPE: 18.557
# 				-->MASE: 0.315
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.68s
# 				-->R2: 0.706
# 				-->MAE: 14.941
# 				-->MAPE: 18.998
# 				-->MASE: 0.331
# 			-->Training model: K Nearest Neighbors, runtime: 0.87s
# 				-->R2: -0.036
# 				-->MAE: 28.102
# 				-->MAPE: 38.864
# 				-->MASE: 0.622
# 			-->Training model: Random Forest, runtime: 189.70s
# 				-->R2: 0.724
# 				-->MAE: 14.307
# 				-->MAPE: 18.695
# 				-->MASE: 0.317
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.35s
# 				-->R2: 0.708
# 				-->MAE: 14.735
# 				-->MAPE: 18.629
# 				-->MASE: 0.326
# 			-->Training model: K Nearest Neighbors, runtime: 0.34s
# 				-->R2: 0.610
# 				-->MAE: 16.703
# 				-->MAPE: 20.797
# 				-->MASE: 0.370
# 			-->Training model: Random Forest, runtime: 50.64s
# 				-->R2: 0.722
# 				-->MAE: 14.314
# 				-->MAPE: 18.606
# 				-->MASE: 0.317
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.26s
# 				-->R2: 0.711
# 				-->MAE: 14.588
# 				-->MAPE: 18.291
# 				-->MASE: 0.323
# 			-->Training model: K Nearest Neighbors, runtime: 0.27s
# 				-->R2: 0.598
# 				-->MAE: 16.958
# 				-->MAPE: 20.976
# 				-->MASE: 0.375
# 			-->Training model: Random Forest, runtime: 23.60s
# 				-->R2: 0.715
# 				-->MAE: 14.355
# 				-->MAPE: 18.336
# 				-->MASE: 0.318
#
# 	-->Prediction horizont: 9h. Shifting runtime: 30.61s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -1.562
# 				-->MAE: 47.824
# 				-->MAPE: 61.076
# 				-->MASE: 1.008
# 			-->Computing Previous day
# 				-->R2: 0.384
# 				-->MAE: 19.890
# 				-->MAPE: 23.384
# 				-->MASE: 0.419
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.401
# 				-->MAPE: 20.379
# 				-->MASE: 0.367
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.671
# 				-->MAE: 15.370
# 				-->MAPE: 19.138
# 				-->MASE: 0.324
# 			-->Training model: K Nearest Neighbors, runtime: 0.30s
# 				-->R2: 0.445
# 				-->MAE: 20.262
# 				-->MAPE: 26.653
# 				-->MASE: 0.427
# 			-->Training model: Random Forest, runtime: 51.84s
# 				-->R2: 0.655
# 				-->MAE: 15.788
# 				-->MAPE: 20.726
# 				-->MASE: 0.333
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.43s
# 				-->R2: 0.664
# 				-->MAE: 15.747
# 				-->MAPE: 19.940
# 				-->MASE: 0.332
# 			-->Training model: K Nearest Neighbors, runtime: 0.79s
# 				-->R2: -0.030
# 				-->MAE: 28.063
# 				-->MAPE: 38.717
# 				-->MASE: 0.592
# 			-->Training model: Random Forest, runtime: 185.57s
# 				-->R2: 0.666
# 				-->MAE: 15.518
# 				-->MAPE: 20.177
# 				-->MASE: 0.327
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.40s
# 				-->R2: 0.713
# 				-->MAE: 14.666
# 				-->MAPE: 18.664
# 				-->MASE: 0.309
# 			-->Training model: K Nearest Neighbors, runtime: 0.44s
# 				-->R2: 0.413
# 				-->MAE: 20.769
# 				-->MAPE: 27.357
# 				-->MASE: 0.438
# 			-->Training model: Random Forest, runtime: 53.47s
# 				-->R2: 0.730
# 				-->MAE: 14.207
# 				-->MAPE: 18.446
# 				-->MASE: 0.300
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.63s
# 				-->R2: 0.709
# 				-->MAE: 14.873
# 				-->MAPE: 18.946
# 				-->MASE: 0.314
# 			-->Training model: K Nearest Neighbors, runtime: 1.22s
# 				-->R2: -0.050
# 				-->MAE: 28.271
# 				-->MAPE: 39.686
# 				-->MASE: 0.596
# 			-->Training model: Random Forest, runtime: 196.49s
# 				-->R2: 0.730
# 				-->MAE: 14.234
# 				-->MAPE: 18.477
# 				-->MASE: 0.300
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.31s
# 				-->R2: 0.713
# 				-->MAE: 14.690
# 				-->MAPE: 18.656
# 				-->MASE: 0.310
# 			-->Training model: K Nearest Neighbors, runtime: 0.40s
# 				-->R2: 0.387
# 				-->MAE: 21.378
# 				-->MAPE: 27.942
# 				-->MASE: 0.451
# 			-->Training model: Random Forest, runtime: 56.94s
# 				-->R2: 0.731
# 				-->MAE: 14.187
# 				-->MAPE: 18.426
# 				-->MASE: 0.299
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.82s
# 				-->R2: 0.709
# 				-->MAE: 14.882
# 				-->MAPE: 18.933
# 				-->MASE: 0.314
# 			-->Training model: K Nearest Neighbors, runtime: 1.03s
# 				-->R2: -0.030
# 				-->MAE: 27.994
# 				-->MAPE: 38.633
# 				-->MASE: 0.590
# 			-->Training model: Random Forest, runtime: 206.25s
# 				-->R2: 0.730
# 				-->MAE: 14.266
# 				-->MAPE: 18.493
# 				-->MASE: 0.301
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.32s
# 				-->R2: 0.709
# 				-->MAE: 14.730
# 				-->MAPE: 18.645
# 				-->MASE: 0.311
# 			-->Training model: K Nearest Neighbors, runtime: 0.35s
# 				-->R2: 0.610
# 				-->MAE: 16.765
# 				-->MAPE: 20.972
# 				-->MASE: 0.354
# 			-->Training model: Random Forest, runtime: 53.94s
# 				-->R2: 0.730
# 				-->MAE: 14.193
# 				-->MAPE: 18.343
# 				-->MASE: 0.299
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.30s
# 				-->R2: 0.712
# 				-->MAE: 14.589
# 				-->MAPE: 18.328
# 				-->MASE: 0.308
# 			-->Training model: K Nearest Neighbors, runtime: 0.27s
# 				-->R2: 0.598
# 				-->MAE: 16.971
# 				-->MAPE: 21.006
# 				-->MASE: 0.358
# 			-->Training model: Random Forest, runtime: 21.55s
# 				-->R2: 0.722
# 				-->MAE: 14.279
# 				-->MAPE: 18.125
# 				-->MASE: 0.301
#
# 	-->Prediction horizont: 10h. Shifting runtime: 29.98s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -1.702
# 				-->MAE: 49.174
# 				-->MAPE: 63.204
# 				-->MASE: 1.015
# 			-->Computing Previous day
# 				-->R2: 0.387
# 				-->MAE: 19.855
# 				-->MAPE: 23.317
# 				-->MASE: 0.410
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.400
# 				-->MAPE: 20.365
# 				-->MASE: 0.359
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.670
# 				-->MAE: 15.374
# 				-->MAPE: 19.073
# 				-->MASE: 0.317
# 			-->Training model: K Nearest Neighbors, runtime: 0.30s
# 				-->R2: 0.454
# 				-->MAE: 20.136
# 				-->MAPE: 26.304
# 				-->MASE: 0.416
# 			-->Training model: Random Forest, runtime: 51.34s
# 				-->R2: 0.663
# 				-->MAE: 15.694
# 				-->MAPE: 20.409
# 				-->MASE: 0.324
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.43s
# 				-->R2: 0.663
# 				-->MAE: 15.744
# 				-->MAPE: 19.884
# 				-->MASE: 0.325
# 			-->Training model: K Nearest Neighbors, runtime: 0.75s
# 				-->R2: -0.013
# 				-->MAE: 27.577
# 				-->MAPE: 37.878
# 				-->MASE: 0.569
# 			-->Training model: Random Forest, runtime: 277.56s
# 				-->R2: 0.668
# 				-->MAE: 15.508
# 				-->MAPE: 20.096
# 				-->MASE: 0.320
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.37s
# 				-->R2: 0.713
# 				-->MAE: 14.666
# 				-->MAPE: 18.629
# 				-->MASE: 0.303
# 			-->Training model: K Nearest Neighbors, runtime: 0.42s
# 				-->R2: 0.423
# 				-->MAE: 20.652
# 				-->MAPE: 27.011
# 				-->MASE: 0.426
# 			-->Training model: Random Forest, runtime: 56.24s
# 				-->R2: 0.730
# 				-->MAE: 14.188
# 				-->MAPE: 18.329
# 				-->MASE: 0.293
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.69s
# 				-->R2: 0.709
# 				-->MAE: 14.839
# 				-->MAPE: 18.858
# 				-->MASE: 0.306
# 			-->Training model: K Nearest Neighbors, runtime: 0.83s
# 				-->R2: -0.012
# 				-->MAE: 27.577
# 				-->MAPE: 38.317
# 				-->MASE: 0.569
# 			-->Training model: Random Forest, runtime: 214.58s
# 				-->R2: 0.730
# 				-->MAE: 14.228
# 				-->MAPE: 18.381
# 				-->MASE: 0.294
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.40s
# 				-->R2: 0.713
# 				-->MAE: 14.692
# 				-->MAPE: 18.617
# 				-->MASE: 0.303
# 			-->Training model: K Nearest Neighbors, runtime: 0.42s
# 				-->R2: 0.401
# 				-->MAE: 21.131
# 				-->MAPE: 27.386
# 				-->MASE: 0.436
# 			-->Training model: Random Forest, runtime: 61.43s
# 				-->R2: 0.733
# 				-->MAE: 14.106
# 				-->MAPE: 18.209
# 				-->MASE: 0.291
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.72s
# 				-->R2: 0.710
# 				-->MAE: 14.843
# 				-->MAPE: 18.836
# 				-->MASE: 0.307
# 			-->Training model: K Nearest Neighbors, runtime: 0.86s
# 				-->R2: -0.014
# 				-->MAE: 27.602
# 				-->MAPE: 37.902
# 				-->MASE: 0.570
# 			-->Training model: Random Forest, runtime: 183.09s
# 				-->R2: 0.732
# 				-->MAE: 14.217
# 				-->MAPE: 18.344
# 				-->MASE: 0.294
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.42s
# 				-->R2: 0.708
# 				-->MAE: 14.730
# 				-->MAPE: 18.618
# 				-->MASE: 0.304
# 			-->Training model: K Nearest Neighbors, runtime: 0.49s
# 				-->R2: 0.610
# 				-->MAE: 16.798
# 				-->MAPE: 20.895
# 				-->MASE: 0.347
# 			-->Training model: Random Forest, runtime: 50.24s
# 				-->R2: 0.729
# 				-->MAE: 14.227
# 				-->MAPE: 18.301
# 				-->MASE: 0.294
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.33s
# 				-->R2: 0.711
# 				-->MAE: 14.600
# 				-->MAPE: 18.326
# 				-->MASE: 0.301
# 			-->Training model: K Nearest Neighbors, runtime: 0.23s
# 				-->R2: 0.605
# 				-->MAE: 16.886
# 				-->MAPE: 20.917
# 				-->MASE: 0.349
# 			-->Training model: Random Forest, runtime: 22.18s
# 				-->R2: 0.720
# 				-->MAE: 14.263
# 				-->MAPE: 18.066
# 				-->MASE: 0.295
#
# 	-->Prediction horizont: 11h. Shifting runtime: 32.70s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -1.759
# 				-->MAE: 49.951
# 				-->MAPE: 64.553
# 				-->MASE: 1.025
# 			-->Computing Previous day
# 				-->R2: 0.387
# 				-->MAE: 19.842
# 				-->MAPE: 23.313
# 				-->MASE: 0.407
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.388
# 				-->MAPE: 20.364
# 				-->MASE: 0.357
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.668
# 				-->MAE: 15.404
# 				-->MAPE: 19.077
# 				-->MASE: 0.316
# 			-->Training model: K Nearest Neighbors, runtime: 0.28s
# 				-->R2: 0.457
# 				-->MAE: 20.106
# 				-->MAPE: 26.102
# 				-->MASE: 0.413
# 			-->Training model: Random Forest, runtime: 52.92s
# 				-->R2: 0.664
# 				-->MAE: 15.675
# 				-->MAPE: 20.345
# 				-->MASE: 0.322
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.62s
# 				-->R2: 0.663
# 				-->MAE: 15.732
# 				-->MAPE: 19.863
# 				-->MASE: 0.323
# 			-->Training model: K Nearest Neighbors, runtime: 0.77s
# 				-->R2: 0.012
# 				-->MAE: 27.138
# 				-->MAPE: 36.978
# 				-->MASE: 0.557
# 			-->Training model: Random Forest, runtime: 220.97s
# 				-->R2: 0.669
# 				-->MAE: 15.485
# 				-->MAPE: 20.048
# 				-->MASE: 0.318
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.52s
# 				-->R2: 0.712
# 				-->MAE: 14.662
# 				-->MAPE: 18.610
# 				-->MASE: 0.301
# 			-->Training model: K Nearest Neighbors, runtime: 0.43s
# 				-->R2: 0.433
# 				-->MAE: 20.548
# 				-->MAPE: 26.661
# 				-->MASE: 0.422
# 			-->Training model: Random Forest, runtime: 68.40s
# 				-->R2: 0.730
# 				-->MAE: 14.217
# 				-->MAPE: 18.345
# 				-->MASE: 0.292
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.75s
# 				-->R2: 0.711
# 				-->MAE: 14.803
# 				-->MAPE: 18.787
# 				-->MASE: 0.304
# 			-->Training model: K Nearest Neighbors, runtime: 0.81s
# 				-->R2: 0.018
# 				-->MAE: 27.054
# 				-->MAPE: 37.117
# 				-->MASE: 0.555
# 			-->Training model: Random Forest, runtime: 183.87s
# 				-->R2: 0.734
# 				-->MAE: 14.165
# 				-->MAPE: 18.292
# 				-->MASE: 0.291
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.46s
# 				-->R2: 0.712
# 				-->MAE: 14.692
# 				-->MAPE: 18.598
# 				-->MASE: 0.302
# 			-->Training model: K Nearest Neighbors, runtime: 0.46s
# 				-->R2: 0.402
# 				-->MAE: 21.143
# 				-->MAPE: 27.235
# 				-->MASE: 0.434
# 			-->Training model: Random Forest, runtime: 67.36s
# 				-->R2: 0.734
# 				-->MAE: 14.131
# 				-->MAPE: 18.213
# 				-->MASE: 0.290
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.70s
# 				-->R2: 0.711
# 				-->MAE: 14.802
# 				-->MAPE: 18.754
# 				-->MASE: 0.304
# 			-->Training model: K Nearest Neighbors, runtime: 0.85s
# 				-->R2: 0.007
# 				-->MAE: 27.225
# 				-->MAPE: 37.069
# 				-->MASE: 0.559
# 			-->Training model: Random Forest, runtime: 200.82s
# 				-->R2: 0.735
# 				-->MAE: 14.145
# 				-->MAPE: 18.274
# 				-->MASE: 0.290
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.709
# 				-->MAE: 14.703
# 				-->MAPE: 18.578
# 				-->MASE: 0.302
# 			-->Training model: K Nearest Neighbors, runtime: 0.38s
# 				-->R2: 0.615
# 				-->MAE: 16.714
# 				-->MAPE: 20.725
# 				-->MASE: 0.343
# 			-->Training model: Random Forest, runtime: 56.06s
# 				-->R2: 0.732
# 				-->MAE: 14.182
# 				-->MAPE: 18.230
# 				-->MASE: 0.291
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.38s
# 				-->R2: 0.711
# 				-->MAE: 14.588
# 				-->MAPE: 18.312
# 				-->MASE: 0.299
# 			-->Training model: K Nearest Neighbors, runtime: 0.22s
# 				-->R2: 0.602
# 				-->MAE: 16.954
# 				-->MAPE: 20.858
# 				-->MASE: 0.348
# 			-->Training model: Random Forest, runtime: 24.77s
# 				-->R2: 0.723
# 				-->MAE: 14.226
# 				-->MAPE: 17.936
# 				-->MASE: 0.292
#
# 	-->Prediction horizont: 12h. Shifting runtime: 32.66s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: -1.776
# 				-->MAE: 50.163
# 				-->MAPE: 65.163
# 				-->MASE: 1.029
# 			-->Computing Previous day
# 				-->R2: 0.383
# 				-->MAE: 19.854
# 				-->MAPE: 23.336
# 				-->MASE: 0.407
# 			-->Computing Previous week
# 				-->R2: 0.547
# 				-->MAE: 17.356
# 				-->MAPE: 20.356
# 				-->MASE: 0.356
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.03s
# 				-->R2: 0.665
# 				-->MAE: 15.437
# 				-->MAPE: 19.139
# 				-->MASE: 0.317
# 			-->Training model: K Nearest Neighbors, runtime: 0.27s
# 				-->R2: 0.466
# 				-->MAE: 19.861
# 				-->MAPE: 25.493
# 				-->MASE: 0.407
# 			-->Training model: Random Forest, runtime: 44.88s
# 				-->R2: 0.661
# 				-->MAE: 15.686
# 				-->MAPE: 20.289
# 				-->MASE: 0.322
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.41s
# 				-->R2: 0.661
# 				-->MAE: 15.725
# 				-->MAPE: 19.890
# 				-->MASE: 0.322
# 			-->Training model: K Nearest Neighbors, runtime: 0.73s
# 				-->R2: 0.042
# 				-->MAE: 26.688
# 				-->MAPE: 36.234
# 				-->MASE: 0.547
# 			-->Training model: Random Forest, runtime: 267.64s
# 				-->R2: 0.663
# 				-->MAE: 15.570
# 				-->MAPE: 20.136
# 				-->MASE: 0.319
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.39s
# 				-->R2: 0.711
# 				-->MAE: 14.653
# 				-->MAPE: 18.602
# 				-->MASE: 0.300
# 			-->Training model: K Nearest Neighbors, runtime: 0.40s
# 				-->R2: 0.434
# 				-->MAE: 20.509
# 				-->MAPE: 26.272
# 				-->MASE: 0.421
# 			-->Training model: Random Forest, runtime: 55.29s
# 				-->R2: 0.729
# 				-->MAE: 14.182
# 				-->MAPE: 18.330
# 				-->MASE: 0.291
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.70s
# 				-->R2: 0.710
# 				-->MAE: 14.773
# 				-->MAPE: 18.740
# 				-->MASE: 0.303
# 			-->Training model: K Nearest Neighbors, runtime: 0.98s
# 				-->R2: 0.037
# 				-->MAE: 26.635
# 				-->MAPE: 36.384
# 				-->MASE: 0.546
# 			-->Training model: Random Forest, runtime: 172.68s
# 				-->R2: 0.733
# 				-->MAE: 14.120
# 				-->MAPE: 18.281
# 				-->MASE: 0.290
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.40s
# 				-->R2: 0.711
# 				-->MAE: 14.687
# 				-->MAPE: 18.598
# 				-->MASE: 0.301
# ...
# 				-->MAE: 17.288
# 				-->MAPE: 20.255
# 				-->MASE: 0.593
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.07s
# 				-->R2: 0.669
# 				-->MAE: 15.201
# 				-->MAPE: 18.809
# 				-->MASE: 0.521
# 			-->Training model: K Nearest Neighbors, runtime: 0.50s
# 				-->R2: 0.492
# 				-->MAE: 19.236
# 				-->MAPE: 24.322
# 				-->MASE: 0.659
# 			-->Training model: Random Forest, runtime: 62.74s
# 				-->R2: 0.655
# 				-->MAE: 15.567
# 				-->MAPE: 20.101
# 				-->MASE: 0.534
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.37s
# 				-->R2: 0.666
# 				-->MAE: 15.446
# 				-->MAPE: 19.464
# 				-->MASE: 0.529
# 			-->Training model: K Nearest Neighbors, runtime: 1.21s
# 				-->R2: 0.040
# 				-->MAE: 27.166
# 				-->MAPE: 36.871
# 				-->MASE: 0.931
# 			-->Training model: Random Forest, runtime: 299.56s
# 				-->R2: 0.658
# 				-->MAE: 15.425
# 				-->MAPE: 19.832
# 				-->MASE: 0.529
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.38s
# 				-->R2: 0.711
# 				-->MAE: 14.544
# 				-->MAPE: 18.444
# 				-->MASE: 0.499
# 			-->Training model: K Nearest Neighbors, runtime: 0.58s
# 				-->R2: 0.455
# 				-->MAE: 20.018
# 				-->MAPE: 25.456
# 				-->MASE: 0.686
# 			-->Training model: Random Forest, runtime: 98.22s
# 				-->R2: 0.724
# 				-->MAE: 14.102
# 				-->MAPE: 18.250
# 				-->MASE: 0.483
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.76s
# 				-->R2: 0.712
# 				-->MAE: 14.598
# 				-->MAPE: 18.514
# 				-->MASE: 0.500
# 			-->Training model: K Nearest Neighbors, runtime: 0.79s
# 				-->R2: 0.021
# 				-->MAE: 27.536
# 				-->MAPE: 37.618
# 				-->MASE: 0.944
# 			-->Training model: Random Forest, runtime: 188.40s
# 				-->R2: 0.726
# 				-->MAE: 14.046
# 				-->MAPE: 18.121
# 				-->MASE: 0.482
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.37s
# 				-->R2: 0.710
# 				-->MAE: 14.577
# 				-->MAPE: 18.459
# 				-->MASE: 0.500
# 			-->Training model: K Nearest Neighbors, runtime: 0.64s
# 				-->R2: 0.393
# 				-->MAE: 21.151
# 				-->MAPE: 27.104
# 				-->MASE: 0.725
# 			-->Training model: Random Forest, runtime: 66.80s
# 				-->R2: 0.727
# 				-->MAE: 14.039
# 				-->MAPE: 18.220
# 				-->MASE: 0.481
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.67s
# 				-->R2: 0.712
# 				-->MAE: 14.592
# 				-->MAPE: 18.462
# 				-->MASE: 0.500
# 			-->Training model: K Nearest Neighbors, runtime: 0.92s
# 				-->R2: 0.043
# 				-->MAE: 27.151
# 				-->MAPE: 36.858
# 				-->MASE: 0.931
# 			-->Training model: Random Forest, runtime: 238.97s
# 				-->R2: 0.728
# 				-->MAE: 14.010
# 				-->MAPE: 18.067
# 				-->MASE: 0.480
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.708
# 				-->MAE: 14.535
# 				-->MAPE: 18.328
# 				-->MASE: 0.498
# 			-->Training model: K Nearest Neighbors, runtime: 0.39s
# 				-->R2: 0.610
# 				-->MAE: 16.568
# 				-->MAPE: 20.635
# 				-->MASE: 0.568
# 			-->Training model: Random Forest, runtime: 57.73s
# 				-->R2: 0.728
# 				-->MAE: 14.014
# 				-->MAPE: 18.083
# 				-->MASE: 0.480
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.25s
# 				-->R2: 0.710
# 				-->MAE: 14.459
# 				-->MAPE: 18.173
# 				-->MASE: 0.496
# 			-->Training model: K Nearest Neighbors, runtime: 0.28s
# 				-->R2: 0.603
# 				-->MAE: 16.663
# 				-->MAPE: 20.596
# 				-->MASE: 0.571
# 			-->Training model: Random Forest, runtime: 27.72s
# 				-->R2: 0.717
# 				-->MAE: 14.132
# 				-->MAPE: 17.969
# 				-->MASE: 0.484
#
# 	-->Prediction horizont: 22h. Shifting runtime: 67.44s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: 0.102
# 				-->MAE: 25.224
# 				-->MAPE: 31.152
# 				-->MASE: 0.983
# 			-->Computing Previous day
# 				-->R2: 0.381
# 				-->MAE: 19.728
# 				-->MAPE: 23.158
# 				-->MASE: 0.769
# 			-->Computing Previous week
# 				-->R2: 0.543
# 				-->MAE: 17.272
# 				-->MAPE: 20.242
# 				-->MASE: 0.673
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.669
# 				-->MAE: 15.197
# 				-->MAPE: 18.811
# 				-->MASE: 0.592
# 			-->Training model: K Nearest Neighbors, runtime: 0.26s
# 				-->R2: 0.487
# 				-->MAE: 19.182
# 				-->MAPE: 24.203
# 				-->MASE: 0.747
# 			-->Training model: Random Forest, runtime: 61.37s
# 				-->R2: 0.652
# 				-->MAE: 15.656
# 				-->MAPE: 20.200
# 				-->MASE: 0.610
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.49s
# 				-->R2: 0.667
# 				-->MAE: 15.411
# 				-->MAPE: 19.392
# 				-->MASE: 0.600
# 			-->Training model: K Nearest Neighbors, runtime: 1.10s
# 				-->R2: 0.061
# 				-->MAE: 26.812
# 				-->MAPE: 36.457
# 				-->MASE: 1.045
# 			-->Training model: Random Forest, runtime: 253.74s
# 				-->R2: 0.653
# 				-->MAE: 15.568
# 				-->MAPE: 20.161
# 				-->MASE: 0.607
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.37s
# 				-->R2: 0.710
# 				-->MAE: 14.551
# 				-->MAPE: 18.475
# 				-->MASE: 0.567
# 			-->Training model: K Nearest Neighbors, runtime: 0.35s
# 				-->R2: 0.452
# 				-->MAE: 19.922
# 				-->MAPE: 25.326
# 				-->MASE: 0.776
# 			-->Training model: Random Forest, runtime: 60.04s
# 				-->R2: 0.718
# 				-->MAE: 14.226
# 				-->MAPE: 18.410
# 				-->MASE: 0.554
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.76s
# 				-->R2: 0.711
# 				-->MAE: 14.608
# 				-->MAPE: 18.529
# 				-->MASE: 0.569
# 			-->Training model: K Nearest Neighbors, runtime: 1.02s
# 				-->R2: 0.062
# 				-->MAE: 26.791
# 				-->MAPE: 36.632
# 				-->MASE: 1.044
# 			-->Training model: Random Forest, runtime: 202.56s
# 				-->R2: 0.718
# 				-->MAE: 14.305
# 				-->MAPE: 18.469
# 				-->MASE: 0.557
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.43s
# 				-->R2: 0.710
# 				-->MAE: 14.588
# 				-->MAPE: 18.486
# 				-->MASE: 0.568
# 			-->Training model: K Nearest Neighbors, runtime: 0.78s
# 				-->R2: 0.395
# 				-->MAE: 20.998
# 				-->MAPE: 26.887
# 				-->MASE: 0.818
# 			-->Training model: Random Forest, runtime: 71.98s
# 				-->R2: 0.722
# 				-->MAE: 14.172
# 				-->MAPE: 18.370
# 				-->MASE: 0.552
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 1.09s
# 				-->R2: 0.712
# 				-->MAE: 14.603
# 				-->MAPE: 18.475
# 				-->MASE: 0.569
# 			-->Training model: K Nearest Neighbors, runtime: 3.05s
# 				-->R2: 0.067
# 				-->MAE: 26.712
# 				-->MAPE: 36.288
# 				-->MASE: 1.041
# 			-->Training model: Random Forest, runtime: 236.74s
# 				-->R2: 0.719
# 				-->MAE: 14.295
# 				-->MAPE: 18.447
# 				-->MASE: 0.557
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.37s
# 				-->R2: 0.707
# 				-->MAE: 14.567
# 				-->MAPE: 18.411
# 				-->MASE: 0.568
# 			-->Training model: K Nearest Neighbors, runtime: 0.50s
# 				-->R2: 0.612
# 				-->MAE: 16.557
# 				-->MAPE: 20.621
# 				-->MASE: 0.645
# 			-->Training model: Random Forest, runtime: 67.66s
# 				-->R2: 0.722
# 				-->MAE: 14.156
# 				-->MAPE: 18.303
# 				-->MASE: 0.552
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.709
# 				-->MAE: 14.486
# 				-->MAPE: 18.250
# 				-->MASE: 0.564
# 			-->Training model: K Nearest Neighbors, runtime: 0.30s
# 				-->R2: 0.599
# 				-->MAE: 16.746
# 				-->MAPE: 20.813
# 				-->MASE: 0.652
# 			-->Training model: Random Forest, runtime: 23.24s
# 				-->R2: 0.713
# 				-->MAE: 14.212
# 				-->MAPE: 18.087
# 				-->MASE: 0.554
#
# 	-->Prediction horizont: 23h. Shifting runtime: 87.73s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: 0.269
# 				-->MAE: 22.263
# 				-->MAPE: 26.847
# 				-->MASE: 1.008
# 			-->Computing Previous day
# 				-->R2: 0.380
# 				-->MAE: 19.721
# 				-->MAPE: 23.158
# 				-->MASE: 0.893
# 			-->Computing Previous week
# 				-->R2: 0.543
# 				-->MAE: 17.249
# 				-->MAPE: 20.227
# 				-->MASE: 0.781
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.04s
# 				-->R2: 0.668
# 				-->MAE: 15.197
# 				-->MAPE: 18.857
# 				-->MASE: 0.688
# 			-->Training model: K Nearest Neighbors, runtime: 0.27s
# 				-->R2: 0.480
# 				-->MAE: 19.222
# 				-->MAPE: 24.200
# 				-->MASE: 0.871
# 			-->Training model: Random Forest, runtime: 67.35s
# 				-->R2: 0.655
# 				-->MAE: 15.602
# 				-->MAPE: 20.097
# 				-->MASE: 0.707
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.41s
# 				-->R2: 0.667
# 				-->MAE: 15.411
# 				-->MAPE: 19.403
# 				-->MASE: 0.698
# 			-->Training model: K Nearest Neighbors, runtime: 1.32s
# 				-->R2: 0.106
# 				-->MAE: 26.040
# 				-->MAPE: 35.424
# 				-->MASE: 1.180
# 			-->Training model: Random Forest, runtime: 313.12s
# 				-->R2: 0.659
# 				-->MAE: 15.502
# 				-->MAPE: 19.969
# 				-->MASE: 0.702
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.50s
# 				-->R2: 0.709
# 				-->MAE: 14.570
# 				-->MAPE: 18.535
# 				-->MASE: 0.660
# 			-->Training model: K Nearest Neighbors, runtime: 0.52s
# 				-->R2: 0.442
# 				-->MAE: 19.990
# 				-->MAPE: 25.437
# 				-->MASE: 0.906
# 			-->Training model: Random Forest, runtime: 58.08s
# 				-->R2: 0.722
# 				-->MAE: 14.156
# 				-->MAPE: 18.299
# 				-->MASE: 0.641
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.74s
# 				-->R2: 0.710
# 				-->MAE: 14.628
# 				-->MAPE: 18.575
# 				-->MASE: 0.663
# 			-->Training model: K Nearest Neighbors, runtime: 1.30s
# 				-->R2: 0.109
# 				-->MAE: 25.910
# 				-->MAPE: 35.469
# 				-->MASE: 1.174
# 			-->Training model: Random Forest, runtime: 229.59s
# 				-->R2: 0.725
# 				-->MAE: 14.170
# 				-->MAPE: 18.298
# 				-->MASE: 0.642
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.39s
# 				-->R2: 0.708
# 				-->MAE: 14.608
# 				-->MAPE: 18.538
# 				-->MASE: 0.662
# 			-->Training model: K Nearest Neighbors, runtime: 0.54s
# 				-->R2: 0.401
# 				-->MAE: 20.774
# 				-->MAPE: 26.605
# 				-->MASE: 0.941
# 			-->Training model: Random Forest, runtime: 68.14s
# 				-->R2: 0.727
# 				-->MAE: 14.068
# 				-->MAPE: 18.214
# 				-->MASE: 0.637
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.74s
# 				-->R2: 0.710
# 				-->MAE: 14.627
# 				-->MAPE: 18.521
# 				-->MASE: 0.663
# 			-->Training model: K Nearest Neighbors, runtime: 1.32s
# 				-->R2: 0.112
# 				-->MAE: 25.946
# 				-->MAPE: 35.290
# 				-->MASE: 1.175
# 			-->Training model: Random Forest, runtime: 220.06s
# 				-->R2: 0.725
# 				-->MAE: 14.191
# 				-->MAPE: 18.320
# 				-->MASE: 0.643
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.40s
# 				-->R2: 0.706
# 				-->MAE: 14.594
# 				-->MAPE: 18.483
# 				-->MASE: 0.661
# 			-->Training model: K Nearest Neighbors, runtime: 0.42s
# 				-->R2: 0.608
# 				-->MAE: 16.600
# 				-->MAPE: 20.649
# 				-->MASE: 0.752
# 			-->Training model: Random Forest, runtime: 41.56s
# 				-->R2: 0.725
# 				-->MAE: 14.148
# 				-->MAPE: 18.269
# 				-->MASE: 0.641
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.29s
# 				-->R2: 0.707
# 				-->MAE: 14.511
# 				-->MAPE: 18.325
# 				-->MASE: 0.657
# 			-->Training model: K Nearest Neighbors, runtime: 0.21s
# 				-->R2: 0.599
# 				-->MAE: 16.715
# 				-->MAPE: 20.760
# 				-->MASE: 0.757
# 			-->Training model: Random Forest, runtime: 20.61s
# 				-->R2: 0.715
# 				-->MAE: 14.167
# 				-->MAPE: 18.004
# 				-->MASE: 0.642
#
# 	-->Prediction horizont: 24h. Shifting runtime: 59.16s
#
# 		-->Dataset: Baselines. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Computing Last value
# 				-->R2: 0.378
# 				-->MAE: 19.711
# 				-->MAPE: 23.144
# 				-->MASE: 1.042
# 			-->Computing Previous day
# 				-->R2: 0.378
# 				-->MAE: 19.711
# 				-->MAPE: 23.144
# 				-->MASE: 1.042
# 			-->Computing Previous week
# 				-->R2: 0.542
# 				-->MAE: 17.256
# 				-->MAPE: 20.249
# 				-->MASE: 0.912
#
# 		-->Dataset: AR. X_train: (77377L, 16L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.03s
# 				-->R2: 0.665
# 				-->MAE: 15.257
# 				-->MAPE: 18.975
# 				-->MASE: 0.807
# 			-->Training model: K Nearest Neighbors, runtime: 0.26s
# 				-->R2: 0.490
# 				-->MAE: 19.014
# 				-->MAPE: 23.922
# 				-->MASE: 1.005
# 			-->Training model: Random Forest, runtime: 49.52s
# 				-->R2: 0.651
# 				-->MAE: 15.660
# 				-->MAPE: 20.281
# 				-->MASE: 0.828
#
# 		-->Dataset: AR_WC_WF. X_train: (77377L, 67L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.33s
# 				-->R2: 0.664
# 				-->MAE: 15.473
# 				-->MAPE: 19.514
# 				-->MASE: 0.818
# 			-->Training model: K Nearest Neighbors, runtime: 0.69s
# 				-->R2: 0.119
# 				-->MAE: 25.754
# 				-->MAPE: 35.063
# 				-->MASE: 1.361
# 			-->Training model: Random Forest, runtime: 190.89s
# 				-->R2: 0.654
# 				-->MAE: 15.604
# 				-->MAPE: 20.190
# 				-->MASE: 0.825
#
# 		-->Dataset: AR_DT. X_train: (77377L, 27L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.706
# 				-->MAE: 14.628
# 				-->MAPE: 18.660
# 				-->MASE: 0.773
# 			-->Training model: K Nearest Neighbors, runtime: 0.35s
# 				-->R2: 0.458
# 				-->MAE: 19.746
# 				-->MAPE: 25.182
# 				-->MASE: 1.044
# 			-->Training model: Random Forest, runtime: 48.63s
# 				-->R2: 0.720
# 				-->MAE: 14.235
# 				-->MAPE: 18.454
# 				-->MASE: 0.753
#
# 		-->Dataset: AR_WC_DT. X_train: (77377L, 71L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.62s
# 				-->R2: 0.707
# 				-->MAE: 14.692
# 				-->MAPE: 18.699
# 				-->MASE: 0.777
# 			-->Training model: K Nearest Neighbors, runtime: 0.72s
# 				-->R2: 0.102
# 				-->MAE: 25.949
# 				-->MAPE: 35.564
# 				-->MASE: 1.372
# 			-->Training model: Random Forest, runtime: 159.80s
# 				-->R2: 0.722
# 				-->MAE: 14.213
# 				-->MAPE: 18.392
# 				-->MASE: 0.751
#
# 		-->Dataset: AR_WF_DT. X_train: (77377L, 34L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.36s
# 				-->R2: 0.705
# 				-->MAE: 14.669
# 				-->MAPE: 18.665
# 				-->MASE: 0.775
# 			-->Training model: K Nearest Neighbors, runtime: 0.54s
# 				-->R2: 0.413
# 				-->MAE: 20.579
# 				-->MAPE: 26.159
# 				-->MASE: 1.088
# 			-->Training model: Random Forest, runtime: 62.47s
# 				-->R2: 0.723
# 				-->MAE: 14.156
# 				-->MAPE: 18.398
# 				-->MASE: 0.748
#
# 		-->Dataset: ALL. X_train: (77377L, 78L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.64s
# 				-->R2: 0.707
# 				-->MAE: 14.693
# 				-->MAPE: 18.643
# 				-->MASE: 0.777
# 			-->Training model: K Nearest Neighbors, runtime: 0.74s
# 				-->R2: 0.125
# 				-->MAE: 25.697
# 				-->MAPE: 34.949
# 				-->MASE: 1.359
# 			-->Training model: Random Forest, runtime: 161.64s
# 				-->R2: 0.720
# 				-->MAE: 14.249
# 				-->MAPE: 18.467
# 				-->MASE: 0.753
#
# 		-->Dataset: TOP_20. X_train: (77377L, 20L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.33s
# 				-->R2: 0.703
# 				-->MAE: 14.641
# 				-->MAPE: 18.591
# 				-->MASE: 0.774
# 			-->Training model: K Nearest Neighbors, runtime: 0.43s
# 				-->R2: 0.604
# 				-->MAE: 16.663
# 				-->MAPE: 20.676
# 				-->MASE: 0.881
# 			-->Training model: Random Forest, runtime: 47.99s
# 				-->R2: 0.723
# 				-->MAE: 14.161
# 				-->MAPE: 18.280
# 				-->MASE: 0.749
#
# 		-->Dataset: TOP_10. X_train: (77377L, 10L), y_train: (77377L,)
# 			-->Training model: Ridge Regression, runtime: 0.32s
# 				-->R2: 0.705
# 				-->MAE: 14.558
# 				-->MAPE: 18.436
# 				-->MASE: 0.770
# 			-->Training model: K Nearest Neighbors, runtime: 0.26s
# 				-->R2: 0.593
# 				-->MAE: 16.777
# 				-->MAPE: 20.776
# 				-->MASE: 0.887
# 			-->Training model: Random Forest, runtime: 17.15s
# 				-->R2: 0.716
# 				-->MAE: 14.151
# 				-->MAPE: 17.942
# 				-->MASE: 0.748

# %% [markdown]
# ### Save to file

# %%
output_file_name = "validationResults_id12041992.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

validation_df.to_csv(output_file_path)

# %% [markdown]
# ### Read from file

# %%
output_file_name = "validationResults_id12041992.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

validation_df = pd.read_csv(output_file_path, index_col=[0,1,2], header=[0,1])

# %% [markdown]
# ## Entire Validation Dataset

# %%
#validation_df = pd.read_csv(output_file_path, index_col=[0,1,2], header=[0,1])

# %%
validation_df
# Out:
# sensor                                    id12041992                        \
# error metric                                      R2        MAE       MAPE
# horizon dataset       model
# 1       Last value    Baselines             0.636684  15.875924  18.577076
#         Previous day  Baselines             0.381451  19.918373  23.415252
#         Previous week Baselines             0.546953  17.399943  20.381010
#         AR            Ridge Regression      0.766562  13.006488  15.645965
#                       K Nearest Neighbors   0.638083  16.421954  20.571655
#                       Random Forest         0.768992  12.919006  15.904520
#         AR_WC_WF      Ridge Regression      0.768665  13.004687  15.788711
#                       K Nearest Neighbors   0.212736  24.491439  33.188670
#                       Random Forest         0.773841  12.803924  15.819571
#         AR_DT         Ridge Regression      0.788009  12.489516  15.283738
#                       K Nearest Neighbors   0.615003  16.979757  21.281848
#                       Random Forest         0.788856  12.448496  15.437230
#         AR_WC_DT      Ridge Regression      0.787101  12.560460  15.397247
#                       K Nearest Neighbors   0.183183  24.873140  33.942062
#                       Random Forest         0.782855  12.638271  15.721077
#         AR_WF_DT      Ridge Regression      0.788062  12.496202  15.277545
#                       K Nearest Neighbors   0.567042  17.931741  22.463461
#                       Random Forest         0.788980  12.453238  15.411947
#         ALL           Ridge Regression      0.787098  12.564994  15.402169
#                       K Nearest Neighbors   0.201385  24.620576  33.399518
#                       Random Forest         0.783825  12.607759  15.700652
#         TOP_20        Ridge Regression      0.787454  12.503395  15.264128
#                       K Nearest Neighbors   0.749947  13.537262  16.427855
#                       Random Forest         0.790447  12.393298  15.358188
#         TOP_10        Ridge Regression      0.788317  12.423933  15.025069
#                       K Nearest Neighbors   0.744775  13.654261  16.413264
#                       Random Forest         0.787629  12.410205  15.274166
# 2       Last value    Baselines             0.370072  21.306933  25.289154
#         Previous day  Baselines             0.381349  19.918217  23.411514
#         Previous week Baselines             0.546821  17.401540  20.380839
# ...                                              ...        ...        ...
# 23      TOP_10        Ridge Regression      0.707255  14.510977  18.325181
#                       K Nearest Neighbors   0.599342  16.714938  20.759809
#                       Random Forest         0.715139  14.167380  18.004275
# 24      Last value    Baselines             0.378388  19.711000  23.144362
#         Previous day  Baselines             0.378388  19.711000  23.144362
#         Previous week Baselines             0.541665  17.255681  20.248929
#         AR            Ridge Regression      0.665275  15.257475  18.975125
#                       K Nearest Neighbors   0.490266  19.014155  23.921505
#                       Random Forest         0.651329  15.660183  20.281104
#         AR_WC_WF      Ridge Regression      0.663656  15.472958  19.514113
#                       K Nearest Neighbors   0.119258  25.754057  35.063444
#                       Random Forest         0.654012  15.604389  20.190309
#         AR_DT         Ridge Regression      0.705551  14.627673  18.659706
#                       K Nearest Neighbors   0.457693  19.745510  25.182480
#                       Random Forest         0.720320  14.234518  18.454356
#         AR_WC_DT      Ridge Regression      0.706705  14.692178  18.699027
#                       K Nearest Neighbors   0.102228  25.949268  35.563768
#                       Random Forest         0.721585  14.212870  18.391587
#         AR_WF_DT      Ridge Regression      0.704903  14.668816  18.665479
#                       K Nearest Neighbors   0.412986  20.579362  26.159174
#                       Random Forest         0.723081  14.155856  18.397661
#         ALL           Ridge Regression      0.706901  14.693114  18.643355
#                       K Nearest Neighbors   0.124849  25.697364  34.948616
#                       Random Forest         0.719901  14.248675  18.467197
#         TOP_20        Ridge Regression      0.703177  14.640814  18.590530
#                       K Nearest Neighbors   0.604104  16.662824  20.675919
#                       Random Forest         0.722807  14.161381  18.279729
#         TOP_10        Ridge Regression      0.704714  14.558086  18.436126
#                       K Nearest Neighbors   0.592913  16.776789  20.776035
#                       Random Forest         0.715974  14.151379  17.941886
#
# sensor
# error metric                                   MASE
# horizon dataset       model
# 1       Last value    Baselines            1.122833
#         Previous day  Baselines            1.408737
#         Previous week Baselines            1.230620
#         AR            Ridge Regression     0.919890
#                       K Nearest Neighbors  1.161451
#                       Random Forest        0.913703
#         AR_WC_WF      Ridge Regression     0.919763
#                       K Nearest Neighbors  1.732169
#                       Random Forest        0.905564
#         AR_DT         Ridge Regression     0.883327
#                       K Nearest Neighbors  1.200902
#                       Random Forest        0.880426
#         AR_WC_DT      Ridge Regression     0.888345
#                       K Nearest Neighbors  1.759165
#                       Random Forest        0.893848
#         AR_WF_DT      Ridge Regression     0.883800
#                       K Nearest Neighbors  1.268231
#                       Random Forest        0.880761
#         ALL           Ridge Regression     0.888665
#                       K Nearest Neighbors  1.741303
#                       Random Forest        0.891690
#         TOP_20        Ridge Regression     0.884309
#                       K Nearest Neighbors  0.957430
#                       Random Forest        0.876522
#         TOP_10        Ridge Regression     0.878689
#                       K Nearest Neighbors  0.965704
#                       Random Forest        0.877718
# 2       Last value    Baselines            1.035404
#         Previous day  Baselines            0.967920
#         Previous week Baselines            0.845622
# ...                                             ...
# 23      TOP_10        Ridge Regression     0.657346
#                       K Nearest Neighbors  0.757185
#                       Random Forest        0.641781
# 24      Last value    Baselines            1.042030
#         Previous day  Baselines            1.042030
#         Previous week Baselines            0.912228
#         AR            Ridge Regression     0.806592
#                       K Nearest Neighbors  1.005191
#                       Random Forest        0.827882
#         AR_WC_WF      Ridge Regression     0.817984
#                       K Nearest Neighbors  1.361498
#                       Random Forest        0.824932
#         AR_DT         Ridge Regression     0.773298
#                       K Nearest Neighbors  1.043854
#                       Random Forest        0.752513
#         AR_WC_DT      Ridge Regression     0.776708
#                       K Nearest Neighbors  1.371818
#                       Random Forest        0.751369
#         AR_WF_DT      Ridge Regression     0.775473
#                       K Nearest Neighbors  1.087936
#                       Random Forest        0.748355
#         ALL           Ridge Regression     0.776757
#                       K Nearest Neighbors  1.358501
#                       Random Forest        0.753262
#         TOP_20        Ridge Regression     0.773992
#                       K Nearest Neighbors  0.880887
#                       Random Forest        0.748647
#         TOP_10        Ridge Regression     0.769619
#                       K Nearest Neighbors  0.886911
#                       Random Forest        0.748118
#
# [648 rows x 4 columns]

# %% [markdown]
# ## Evaluation Scores Over All Horizons

# %%
validation_df.groupby(level=['dataset', 'model'], sort=False).mean()
# Out:
# sensor                            id12041992
# error metric                              R2        MAE       MAPE      MASE
# dataset       model
# Last value    Baselines            -0.765331  36.904146  47.137848  1.006007
# Previous day  Baselines             0.380352  19.853584  23.331656  0.609474
# Previous week Baselines             0.545064  17.352144  20.334814  0.532726
# AR            Ridge Regression      0.675136  15.169802  18.781403  0.460499
#               K Nearest Neighbors   0.479010  19.502946  25.067923  0.589047
#               Random Forest         0.667643  15.418243  19.934093  0.467240
# AR_WC_WF      Ridge Regression      0.672523  15.425997  19.435275  0.467395
#               K Nearest Neighbors   0.044903  26.920785  36.751562  0.818142
#               Random Forest         0.672102  15.295806  19.774312  0.463767
# AR_DT         Ridge Regression      0.718375  14.427290  18.252264  0.438529
#               K Nearest Neighbors   0.449584  20.099784  25.881471  0.607775
#               Random Forest         0.731601  14.022380  18.117393  0.427004
# AR_WC_DT      Ridge Regression      0.717226  14.543929  18.403971  0.441924
#               K Nearest Neighbors   0.001415  27.542692  37.943464  0.836821
#               Random Forest         0.731290  14.077713  18.198839  0.429301
# AR_WF_DT      Ridge Regression      0.718151  14.458425  18.257723  0.439446
#               K Nearest Neighbors   0.406289  20.934927  26.942185  0.633751
#               Random Forest         0.733502  13.989535  18.073922  0.426114
# ALL           Ridge Regression      0.717493  14.545325  18.373530  0.441982
#               K Nearest Neighbors   0.045128  26.912038  36.749838  0.817992
#               Random Forest         0.731724  14.074994  18.197575  0.429091
# TOP_20        Ridge Regression      0.715729  14.450273  18.194124  0.439190
#               K Nearest Neighbors   0.626254  16.361109  20.290428  0.495448
#               Random Forest         0.732221  14.029265  18.102572  0.427092
# TOP_10        Ridge Regression      0.717848  14.339168  17.942363  0.435870
#               K Nearest Neighbors   0.617190  16.489192  20.303340  0.499643
#               Random Forest         0.725003  14.052527  17.842614  0.427608

# %%
for sensor_id in validation_df.columns.levels[0]:
        
    err = validation_df.groupby(level=['dataset', 'model']).std()[sensor_id]['R2'].unstack(0)
            
    ax = validation_df.groupby(level=['dataset', 'model']).mean()[sensor_id]['R2'].unstack(0).plot(
        yerr=err, kind='bar', figsize=(15,4), rot=0, title=sensor_id, colormap='Blues', ylim=(0,1))
    
    for p in ax.patches:
        ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha='center')
    
    plt.gca().yaxis.grid(True)
    ax.set_ylabel('R2')
    plt.legend(loc='right', bbox_to_anchor=(1.23, 0.5), ncol=1, fancybox=True, shadow=True)

# %% [markdown]
# ### Errors only for specific prediction horizon

# %%
"""
for sensor_id in validation_df.columns.levels[0]:
    ax = validation_df.loc[20][sensor_id]['R2'].unstack(0).plot(
        kind='bar', figsize=(15,4), rot=0, title=sensor_id, colormap='Blues', ylim=(0,1))
    
    for p in ax.patches:
        ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha='center')
    
    plt.gca().yaxis.grid(True)
    ax.set_ylabel(measure)
    plt.legend(loc='right', bbox_to_anchor=(1.2, 0.5), ncol=1, fancybox=True, shadow=True)
"""
# Out:
# '\nfor sensor_id in validation_df.columns.levels[0]:\n    ax = validation_df.loc[20][sensor_id][\'R2\'].unstack(0).plot(\n        kind=\'bar\', figsize=(15,4), rot=0, title=sensor_id, colormap=\'Blues\', ylim=(0,1))\n    \n    for p in ax.patches:\n        ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha=\'center\')\n    \n    plt.gca().yaxis.grid(True)\n    ax.set_ylabel(measure)\n    plt.legend(loc=\'right\', bbox_to_anchor=(1.2, 0.5), ncol=1, fancybox=True, shadow=True)\n'

# %% [markdown]
# ## Evaluation Scores for Each Horizon

# %%
ax = validation_df.xs(["Baselines"], level=["model"]).unstack()['id14061709']['R2'][['Last value', 'Previous week']].join(
    validation_df.xs(["TOP_20"], level=["dataset"]).unstack()['id14061709']['R2']).plot(
    kind='bar', figsize=(20,5), title='R2 results - all horizons (id14061709)', ylim=(0,1), colormap='Blues')

for p in ax.patches:
    ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha='center')

ax.yaxis.grid()
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True, shadow=True)
#plt.legend(loc='lower center', bbox_to_anchor=(0.5, 0.), ncol=5, fancybox=True, shadow=True)
#plt.legend(loc=4)
plt.ylabel('R2 Score')

# %%
for measure in validation_df.columns.levels[1]:
    
    ax = validation_df.xs(["Baselines"], level=["model"]).unstack()['id14061709'][measure][['Last value', 'Previous week']].join(
        validation_df.xs(["TOP_20"], level=["dataset"]).unstack()['id14061709'][measure]).plot(
        kind='bar', figsize=(20,5), colormap='Blues')
    
    ax.yaxis.grid()   
    plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True, shadow=True)
    plt.ylabel(measure)

# %% [markdown]
# ## Average Score by Sensors and Horizons

# %%
validation_df.groupby(level=['dataset', 'model']).mean().groupby(level='error metric', axis=1).mean()
# Out:
# error metric                                   R2       MAE       MAPE  \
# dataset             model
# Last value          Baselines            0.561509  1.675817  29.038490
# Previous day        Baselines            0.399188  2.035682  41.442958
# Previous week       Baselines            0.655598  1.569669  30.650789
# Measurement average Baselines            0.176525  3.042106  72.821162
# AR                  Ridge Regression     0.812825  1.276349  27.640770
#                     K Nearest Neighbors  0.785566  1.356553  29.801900
#                     Random Forest        0.823768  1.255085  29.553442
# SELECTED            Ridge Regression     0.755056  1.611357  39.967885
#                     K Nearest Neighbors  0.781093  1.401275  30.995457
#                     Random Forest        0.842835  1.194789  26.340880
#
# error metric                                 MASE
# dataset             model
# Last value          Baselines            0.728761
# Previous day        Baselines            0.939339
# Previous week       Baselines            0.724327
# Measurement average Baselines            1.378100
# AR                  Ridge Regression     0.575318
#                     K Nearest Neighbors  0.616033
#                     Random Forest        0.565061
# SELECTED            Ridge Regression     0.711889
#                     K Nearest Neighbors  0.631593
#                     Random Forest        0.538496

# %%
for measure in validation_df.columns.levels[1]:

    err = ax = validation_df.groupby(level=['dataset', 'model']).std().groupby(
        level='error metric', axis=1).mean()[measure].unstack(0)
    
    ax = validation_df.groupby(level=['dataset', 'model']).mean().groupby(
        level='error metric', axis=1).mean()[measure].unstack(0).plot(
        yerr=err, kind='bar', figsize=(15,5), rot=0, title="Error Measure: {}".format(measure), colormap='Blues')

    for p in ax.patches:
        ax.annotate(str("%.2f" % p.get_height()), (p.get_x()+p.get_width()/2., p.get_height() * 1.02), fontsize=10, ha='center')
    
    plt.gca().yaxis.grid(True)
    ax.set_ylabel(measure)
    plt.legend(loc='right', bbox_to_anchor=(1.2, 0.5), ncol=1, fancybox=True, shadow=True)

# %% [markdown]
# NOTE: From this, it looks like weather does not help to improve accuracy. Date time features are the most important.
