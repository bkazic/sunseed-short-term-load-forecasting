# %% [markdown]
# # Results Analysis

# %%
# %matplotlib inline
import matplotlib as mpl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import numpy as np
import os
import time
from datetime import timedelta

# %% [markdown]
# ### Load dataset

# %%
input_file_name = "lotOfFeatures.csv"
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), input_file_name)

original_data = pd.read_csv(input_file_path, index_col=0, parse_dates=True)
originalSize = original_data.shape[1]
original_data.head()
original_data.shape
# Out:
# (139678, 535)

# %% [markdown]
# ## Excluding Testing Set

# %% [markdown]
# Spliting the dataset into three parts: training, testing and evaluation (last 10 percent).

# %%
start_time = '2012-02-01 00:00:00'
#start_time = '2013-01-01 00:00:00'
#start_time = '2014-02-01 00:00:00'
splitting_point = int(0.8 * original_data.shape[0])
splitting_time = original_data.iloc[[splitting_point]].index.to_pydatetime()[0]
#data = original_data[:splitting_time]
data = original_data[start_time:]

# %%
splitting_time
# Out:
# datetime.datetime(2014, 4, 17, 0, 0)

# %%
f = original_data[["id11010024"]].plot(figsize=(20,5)) 
original_data.iloc(splitting_point)
f.axvline(start_time, color='g')
f.axvline(splitting_time, color='r')

# %% [markdown]
# # Define Machine Learning Models and Data Sets

# %%
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import svm
from sklearn import neighbors
from sklearn import metrics
import regression_metrics as additional_metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.learning_curve import learning_curve
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import explained_variance_score
#from neural_network import PyBrainNN

# %% [markdown]
# ## Creating Feature Sets

# %%
autoregressive_ftrs = ['measurement', 'shifted_measurement_1d', 'shifted_measurement_2d', 'shifted_measurement_1w', 
                       'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_mean_d', 
                       'measurement_roll_mean_w', 'measurement_roll_mean_m', 'measurement_roll_min2_d',
                       'measurement_roll_min2_w', 'measurement_roll_max2_d', 'measurement_roll_max2_w',
                       'measurement_roll_var_6h', 'measurement_roll_var_d', 'measurement_roll_var_w']

wetaher_current_ftrs =  ['p', 't2m_termin', 'rh_termin', 'padavine', 'veter_hitrost', 'veter_vek_smer', 'energija_gl',
 'energija_di', 'p_roll_mean_1h', 'p_roll_mean_6h', 'p_roll_mean_d', 'p_roll_mean_w', 'p_roll_mean_m', 'p_roll_var_1h',
 'p_roll_var_d', 't2m_termin_roll_mean_1h', 't2m_termin_roll_mean_6h', 't2m_termin_roll_mean_d', 't2m_termin_roll_mean_w',
 't2m_termin_roll_mean_m', 't2m_termin_roll_min2_d', 't2m_termin_roll_min2_w', 't2m_termin_roll_max2_d',
 't2m_termin_roll_max2_w', 't2m_termin_roll_var_1h', 't2m_termin_roll_var_d', 'rh_termin_roll_mean_1h',
 'rh_termin_roll_mean_6h', 'rh_termin_roll_mean_d', 'rh_termin_roll_mean_w', 'rh_termin_roll_mean_m',
 'rh_termin_roll_min2_d', 'rh_termin_roll_min2_w', 'rh_termin_roll_max2_d', 'rh_termin_roll_max2_w',
 'rh_termin_roll_var_1h', 'rh_termin_roll_var_d', 'energija_gl_roll_mean_1h', 'energija_gl_roll_mean_6h',
 'energija_gl_roll_mean_d', 'energija_gl_roll_mean_w', 'energija_gl_roll_mean_m', 'energija_gl_roll_var_1h',
 'energija_gl_roll_var_d']

weather_forecasted_ftrs =  ['shifted_p', 'shifted_t2m_termin', 'shifted_rh_termin', 'shifted_padavine', 
                            'shifted_veter_hitrost', 'shifted_veter_vek_smer', 'shifted_energija_gl']

date_time_ftrs =  ['shifted_HourOfDay', 'shifted_DayOfWeek', 'shifted_Month', 'shifted_Weekday', 'shifted_Weekend', 
                   'shifted_Holiday', 'shifted_DayBeforeHoliday', 'shifted_DayAfterHodliay', 'shifted_BusinessDay', 
                   'shifted_BusinessDay_sum', 'shifted_Holiday_sum']

top20_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay', 't2m_termin_roll_mean_m', 'shifted_Holiday', 
              'shifted_energija_gl', 'shifted_DayOfWeek', 'shifted_t2m_termin', 'p_roll_var_d', 'shifted_measurement_2d', 
              'measurement_roll_mean_m', 'p_roll_mean_m', 'rh_termin_roll_mean_w']

top10_ftrs = ['shifted_measurement_1w', 'shifted_measurement_1d', 'measurement_roll_mean_d', 'measurement', 
              'measurement_roll_mean_1h', 'measurement_roll_mean_6h', 'measurement_roll_max2_w', 'shifted_BusinessDay', 
              'measurement_roll_mean_w', 'shifted_HourOfDay']

# %%
all_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_wc_wf_ftrs = autoregressive_ftrs + wetaher_current_ftrs + weather_forecasted_ftrs
ar_wc_dt_ftrs = autoregressive_ftrs + wetaher_current_ftrs + date_time_ftrs 
ar_wf_dt_ftrs = autoregressive_ftrs + weather_forecasted_ftrs + date_time_ftrs 
ar_dt_ftrs = autoregressive_ftrs + date_time_ftrs 
ar_ftrs = autoregressive_ftrs
top20_ftrs = top20_ftrs
top10_ftrs = top10_ftrs

# %% [markdown]
# ## Prediction Results

# %%
class NaiveModel:
    
    def __init__(self, target):
        self.target = target

# %%
horizons = range(1,25)

baselines = [{'name': "Last value", 'init': "NaiveModel('measurement')"},
             {'name': "Previous day", 'init': "NaiveModel('shifted_measurement_1d')"},
             {'name': "Previous week", 'init': "NaiveModel('shifted_measurement_1w')"},
             #{'name': "Measurement average", 'init': "NaiveModel('measurement_avr')"},
            ]

models = [#{'name': "Ridge Regression", 'init': "linear_model.Ridge()"},
          #{'name': "K Nearest Neighbors", 'init': "neighbors.KNeighborsRegressor(n_neighbors = 5)"},
          {'name': "Random Forest", 'init': "RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, n_jobs=16)"},
          #{'name': "SVR", 'init': "svm.SVR(kernel ='rbf', C = 10, gamma = .001)"},
          #{'name': "Neural Network", 'init': "PyBrainNN(hidden_size = 100, learningrate = 0.001, momentum = 0.1, maxEpochs=10)"},
          ]

data_sets = [{'name': "Baselines", 'ftrs': ar_ftrs},
             #{'name': "AR", 'ftrs': ar_ftrs},
             #{'name': "AR_WC_WF", 'ftrs': ar_wc_wf_ftrs},
             #{'name': "AR_DT", 'ftrs': ar_dt_ftrs},             
             #{'name': "AR_WC_DT", 'ftrs': ar_wc_dt_ftrs},
             #{'name': "AR_WF_DT", 'ftrs': ar_wf_dt_ftrs},    
             #{'name': "ALL", 'ftrs': all_ftrs},
             {'name': "TOP_20", 'ftrs': top20_ftrs},
             #{'name': "TOP_10", 'ftrs': top10_ftrs},
             ]

error_metrics = [{'name': "R2 Score", 'short': "R2", 'function': metrics.r2_score},
                 #{'name': "Explained Variance Score", 'short': "EV", 'function': metrics.explained_variance_score},
                 {'name': "Mean Absolute Error", 'short': "MAE", 'function': metrics.mean_absolute_error},
                 #{'name': "Mean Squared Error", 'short': "MSE", 'function': metrics.mean_squared_error},
                 {'name': "Mean Absolute Percentage Error", 'short': "MAPE", 'function': additional_metrics.mean_absolute_percentage_error},
                 {'name': "Mean Absolute Scaled Error", 'short': "MASE", 'function': additional_metrics.mean_absolute_scaled_error}
                ]

#validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['sensor', 'horizon', 'error metric']),
#                             columns=pd.MultiIndex.from_arrays([[],[]], names=['method', 'data set']))

validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[]], names=['horizon', 'dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric']))

# %%
results_df = pd.DataFrame()

# %%
validation_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[],[],[]], names=['horizon', 'testing_day','dataset', 'model']),
                             columns=pd.MultiIndex.from_arrays([[],[]], names=['sensor', 'error metric'])) 

#results_df = pd.DataFrame(index=pd.MultiIndex.from_arrays([[],[]], names=['horizon', 'ts']))
results_df = pd.DataFrame()

output_file_name = "results_id11010024.csv"
output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

#horizons = [2, 10]
horizons = [20]
#horizons = range(1,25)


def start_prediction_valuation(verbose=False):
    
    arr = []

    #sensor_list = list(data)[:15] # Sensor ids (30)
    #sensor_list = ['id14061721', 'id14061674', 'id14061709']
    #sensor_list = ['id14061721']
    sensor_list = ['id11010024']

    for sensor_name in sensor_list:
        print "Working with sensor: {}".format(sensor_name)

        # Create dataframe for specific sensor
        sensor_ftrs_to_drop = [col for col in list(data) if col.startswith('id') and not col.startswith(sensor_name)]
        sensor_data_ftrs = [col for col in list(data) if col not in sensor_ftrs_to_drop]
        sensor_data = data[sensor_data_ftrs]

        # Replace 'sensor id' column names with 'measurement'
        sensor_data.rename(columns=lambda col: col.replace(sensor_name, 'measurement') if sensor_name in col else col, inplace=True)

        # Compute localized average
        average = sensor_data.groupby([sensor_data.index.dayofweek.values, sensor_data.index.time])['measurement'].mean()
        sensor_data = sensor_data.join(pd.DataFrame(average).rename(columns={"measurement":"measurement_avr"}), 
                         on=[sensor_data.index.dayofweek.values, sensor_data.index.time], how = 'left')
        
        #for horizon in range (1,25):
        for horizon in horizons:

            # Prepare columns to shift
            columnsToShift = list(sensor_data)
            shiftedColumns = ["shifted_" + col for col in columnsToShift]

            # Shift columns
            start = time.time() # Start measuring time
            sensor_data[shiftedColumns] = sensor_data[columnsToShift].shift(-1 * horizon, freq='H')
            sensor_data.dropna(inplace=True)
            runtime = time.time() - start # Calculate runtime
            
            if verbose: print "\n\t-->Prediction horizont: {}h. Shifting runtime: {:.2f}s".format(horizon, runtime)

            #splitting_point = int(0.8 * data.shape[0]) # this is the reason for differences in baseline results (we use original_data in first which is wrong)
            #original_splitting_time = data.iloc[[splitting_point]].index.to_pydatetime()[0] # here as well
            splitting_point = int(0.8 * original_data.shape[0])
            original_splitting_time = original_data.iloc[[splitting_point]].index.to_pydatetime()[0]
            splitting_time = original_splitting_time.replace(hour=0, minute=0, second=0, microsecond=0) # setting to middnight
            latest_time = data.iloc[[-1]].index.to_pydatetime()[0]
            
            
            # Split Training and Testing set
            training_data = sensor_data[:splitting_time]
            testing_data = sensor_data[splitting_time:]
            
            # Create training vectors
            X_train = training_data[ar_wf_dt_ftrs].values
            y_train = training_data[["shifted_measurement"]].values.ravel()
            #print "Using dummy features:", X_train.shape

            # Create testing vectors
            X_test = testing_data[ar_wf_dt_ftrs].values
            y_test = testing_data[["shifted_measurement"]].values.ravel()
            
            # Initializing model
            mdl = RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, n_jobs=16)
            mdl.fit(X_train,y_train)
            pred = mdl.predict(X_test)
            

            # Prepare results df
            results_df = testing_data[["shifted_measurement"]]
            results_df.rename(columns={"shifted_measurement":"true"}, inplace=True)

            results_df['last value'] = testing_data[["measurement"]]
            results_df['previous day'] = testing_data[["shifted_measurement_1d"]]
            results_df['previous week'] = testing_data[["shifted_measurement_1w"]]           
            
            results_df['offline'] = mdl.predict(X_test)
            results_df['batch'] = np.nan
            
            arr.append(results_df)
            
            while (splitting_time < latest_time):
                                
                eval_start_time = splitting_time
                splitting_time = splitting_time + timedelta(days=1)
                eval_end_time = splitting_time
                    
                # Split Training and Testing set
                training_data = sensor_data[:eval_start_time - timedelta(minutes=15)]
                testing_data = sensor_data[eval_start_time:eval_end_time]
                
                # init temoporary batch datafreame
                batch_df_temp = pd.DataFrame(index = testing_data.index)

                # Create dummy feature vector for linear regression
                sensor_data_dummy = sensor_data.join(pd.get_dummies(sensor_data['shifted_HourOfDay'], 
                        prefix='dummy_shifted_HourOfDay').join(pd.get_dummies(sensor_data['shifted_DayOfWeek'], 
                        prefix='dummy_shifted_DayOfWeek').join(pd.get_dummies(sensor_data['shifted_Month'], 
                        prefix='dummy_shifted_Month'))))
                #sensor_data_dummy.dropna(inplace=True)
                dummy_ftrs = [col for col in list(sensor_data_dummy.columns) if col.startswith('dummy')]
                training_data_dummy = sensor_data_dummy[:eval_start_time - timedelta(minutes=15)]
                testing_data_dummy = sensor_data_dummy[eval_start_time:eval_start_time]
                
                if verbose: print "\n\t\t-->{} ({})".format('Evaluation', splitting_time)
                
                for data_set in data_sets:              
                
                    # Create training vectors
                    X_train = training_data[data_set['ftrs']].values
                    y_train = training_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_train.shape

                    # Create testing vectors
                    X_test = testing_data[data_set['ftrs']].values
                    y_test = testing_data[["shifted_measurement"]].values.ravel()
                    #print "Using dummy features:", X_test.shape

                    if verbose: print "\t\t\t-->Dataset: {}. X_train: {}, y_train: {}".format(data_set['name'], 
                                                                                              X_train.shape, y_train.shape)

                    if data_set['name'] == "Baselines":
                        for baseline in baselines:

                            if verbose: print "\t\t\t\t-->Computing {}".format(baseline['name'])
                            bl = eval(baseline['init'])

                            for metric in error_metrics:
                                if metric['short'] == 'MASE':
                                    error = metric['function'](y_train, training_data[["measurement"]].values.ravel(),
                                                               y_test, testing_data[bl.target])
                                else:
                                    error = metric['function'](y_test, testing_data[bl.target])

                                validation_df.loc[(horizon, splitting_time, baseline['name'], data_set['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

                    else:    
                        for model in models: 
                            # Initializing model
                            mdl = eval(model['init'])

                            # Model leraning
                            start = time.time() # Start measuring time
                            if model['name'] == "Ridge Regression":
                                mdl.fit(X_train_dummy, y_train_dummy)
                            else:
                                mdl.fit(X_train,y_train)
                                
                            # predictions
                            pred = mdl.predict(X_test)
                            batch_df_temp['batch'] = pred
                                
                            runtime = time.time() - start # Calculate runtime
                            
                            results_df.update(batch_df_temp)

                            if verbose: print "\t\t\t\t-->Training model: {}, runtime: {:.2f}s".format(model['name'], runtime)

                            for metric in error_metrics:
                                #print "\t-->Error metric: {}".format(metric['name'])

                                if model['name'] == "Ridge Regression":
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train_dummy, training_data[["measurement"]].values.ravel(),
                                                                   y_test_dummy, mdl.predict(X_test_dummy))
                                    else:
                                        error = metric['function'](y_test_dummy, mdl.predict(X_test_dummy))

                                else: 
                                    if metric['short'] == 'MASE':
                                        error = metric['function'](y_train, training_data[["measurement"]].values.ravel(), 
                                                                   y_test, mdl.predict(X_test))
                                    else:
                                        error = metric['function'](y_test, mdl.predict(X_test))

                                #validation_df.loc[(sensor_name, horizon, metric['short']),(data_set['name'], model['name'])] = error
                                validation_df.loc[(horizon, splitting_time, data_set['name'], model['name']), (sensor_name, metric['short'])] = error

                                if verbose: print "\t\t\t\t\t-->{}: {:.3f}".format(metric['short'], error)

            
                #print results_df
        
        all_results = pd.concat(arr, keys=horizons)
        all_results.index.set_names(['horizons', 'values'], inplace=True)

        print all_results
        
        all_results.to_csv(output_file_path)
        
start_prediction_valuation(verbose=True)
#start_prediction_valuation(verbose=False)
#validation_df

print "Finished."

#output_file_name = "testni_eval_top20_id12041992.csv"
#output_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)

#validation_df.to_csv(output_file_path)
# Out:
# Working with sensor: id11010024
#
# 	-->Prediction horizont: 20h. Shifting runtime: 0.74s
# C:\Python27\lib\site-packages\ipykernel\__main__.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\ipykernel\__main__.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 		-->Evaluation (2014-04-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (77376L, 16L), y_train: (77376L,)
# 				-->Computing Last value
# 					-->R2: -7.639
# 					-->MAE: 1.423
# 					-->MAPE: 127.857
# 					-->MASE: 1.097
# 				-->Computing Previous day
# 					-->R2: -6.775
# 					-->MAE: 1.237
# 					-->MAPE: 121.429
# 					-->MASE: 0.954
# 				-->Computing Previous week
# 					-->R2: -0.824
# 					-->MAE: 0.619
# 					-->MAPE: 84.286
# 					-->MASE: 0.477
# 			-->Dataset: TOP_20. X_train: (77376L, 20L), y_train: (77376L,)
# 				-->Training model: Random Forest, runtime: 8.39s
# 					-->R2: 0.032
# 					-->MAE: 0.502
# 					-->MAPE: 60.864
# 					-->MASE: 0.387
#
# 		-->Evaluation (2014-04-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (77472L, 16L), y_train: (77472L,)
# 				-->Computing Last value
# 					-->R2: -0.525
# 					-->MAE: 0.691
# 					-->MAPE: 81.313
# 					-->MASE: 0.532
# 				-->Computing Previous day
# 					-->R2: -0.343
# 					-->MAE: 0.588
# 					-->MAPE: 67.929
# 					-->MASE: 0.453
# 				-->Computing Previous week
# 					-->R2: -0.026
# 					-->MAE: 0.598
# 					-->MAPE: 82.323
# 					-->MASE: 0.461
# 			-->Dataset: TOP_20. X_train: (77472L, 20L), y_train: (77472L,)
# 				-->Training model: Random Forest, runtime: 8.75s
# 					-->R2: 0.349
# 					-->MAE: 0.520
# 					-->MAPE: 62.298
# 					-->MASE: 0.401
#
# 		-->Evaluation (2014-04-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (77568L, 16L), y_train: (77568L,)
# 				-->Computing Last value
# 					-->R2: -2.880
# 					-->MAE: 0.371
# 					-->MAPE: 40.000
# 					-->MASE: 0.286
# 				-->Computing Previous day
# 					-->R2: -4.443
# 					-->MAE: 0.670
# 					-->MAPE: 96.000
# 					-->MASE: 0.517
# 				-->Computing Previous week
# 					-->R2: -1.748
# 					-->MAE: 0.526
# 					-->MAPE: 100.000
# 					-->MASE: 0.405
# 			-->Dataset: TOP_20. X_train: (77568L, 20L), y_train: (77568L,)
# 				-->Training model: Random Forest, runtime: 8.55s
# 					-->R2: -0.062
# 					-->MAE: 0.403
# 					-->MAPE: 67.029
# 					-->MASE: 0.311
#
# 		-->Evaluation (2014-04-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (77664L, 16L), y_train: (77664L,)
# 				-->Computing Last value
# 					-->R2: -0.051
# 					-->MAE: 0.206
# 					-->MAPE: 38.462
# 					-->MASE: 0.159
# 				-->Computing Previous day
# 					-->R2: -1.365
# 					-->MAE: 0.464
# 					-->MAPE: 88.462
# 					-->MASE: 0.358
# 				-->Computing Previous week
# 					-->R2: -26.114
# 					-->MAE: 1.608
# 					-->MAPE: 153.846
# 					-->MASE: 1.241
# 			-->Dataset: TOP_20. X_train: (77664L, 20L), y_train: (77664L,)
# 				-->Training model: Random Forest, runtime: 8.90s
# 					-->R2: -2.233
# 					-->MAE: 0.573
# 					-->MAPE: 66.263
# 					-->MASE: 0.442
#
# 		-->Evaluation (2014-04-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (77760L, 16L), y_train: (77760L,)
# 				-->Computing Last value
# 					-->R2: -0.556
# 					-->MAE: 1.320
# 					-->MAPE: 74.846
# 					-->MASE: 1.020
# 				-->Computing Previous day
# 					-->R2: -0.601
# 					-->MAE: 1.423
# 					-->MAPE: 83.951
# 					-->MASE: 1.099
# 				-->Computing Previous week
# 					-->R2: 0.741
# 					-->MAE: 0.588
# 					-->MAPE: 38.488
# 					-->MASE: 0.454
# 			-->Dataset: TOP_20. X_train: (77760L, 20L), y_train: (77760L,)
# 				-->Training model: Random Forest, runtime: 8.78s
# 					-->R2: 0.759
# 					-->MAE: 0.594
# 					-->MAPE: 45.164
# 					-->MASE: 0.459
#
# 		-->Evaluation (2014-04-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (77856L, 16L), y_train: (77856L,)
# 				-->Computing Last value
# 					-->R2: -0.387
# 					-->MAE: 1.247
# 					-->MAPE: 64.152
# 					-->MASE: 0.964
# 				-->Computing Previous day
# 					-->R2: 0.577
# 					-->MAE: 0.660
# 					-->MAPE: 54.766
# 					-->MASE: 0.510
# 				-->Computing Previous week
# 					-->R2: 0.593
# 					-->MAE: 0.722
# 					-->MAPE: 53.918
# 					-->MASE: 0.558
# 			-->Dataset: TOP_20. X_train: (77856L, 20L), y_train: (77856L,)
# 				-->Training model: Random Forest, runtime: 8.90s
# 					-->R2: 0.766
# 					-->MAE: 0.594
# 					-->MAPE: 48.106
# 					-->MASE: 0.459
#
# 		-->Evaluation (2014-04-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (77952L, 16L), y_train: (77952L,)
# 				-->Computing Last value
# 					-->R2: -0.506
# 					-->MAE: 1.402
# 					-->MAPE: 70.000
# 					-->MASE: 1.083
# 				-->Computing Previous day
# 					-->R2: 0.686
# 					-->MAE: 0.629
# 					-->MAPE: 43.830
# 					-->MASE: 0.486
# 				-->Computing Previous week
# 					-->R2: 0.659
# 					-->MAE: 0.660
# 					-->MAPE: 45.205
# 					-->MASE: 0.510
# 			-->Dataset: TOP_20. X_train: (77952L, 20L), y_train: (77952L,)
# 				-->Training model: Random Forest, runtime: 7.87s
# 					-->R2: 0.819
# 					-->MAE: 0.550
# 					-->MAPE: 36.469
# 					-->MASE: 0.425
#
# 		-->Evaluation (2014-04-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (78048L, 16L), y_train: (78048L,)
# 				-->Computing Last value
# 					-->R2: -4.525
# 					-->MAE: 1.660
# 					-->MAPE: 114.028
# 					-->MASE: 1.282
# 				-->Computing Previous day
# 					-->R2: -3.288
# 					-->MAE: 1.351
# 					-->MAPE: 134.722
# 					-->MASE: 1.043
# 				-->Computing Previous week
# 					-->R2: -0.422
# 					-->MAE: 0.753
# 					-->MAPE: 87.083
# 					-->MASE: 0.581
# 			-->Dataset: TOP_20. X_train: (78048L, 20L), y_train: (78048L,)
# 				-->Training model: Random Forest, runtime: 8.21s
# 					-->R2: 0.037
# 					-->MAE: 0.619
# 					-->MAPE: 59.277
# 					-->MASE: 0.479
#
# 		-->Evaluation (2014-04-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (78144L, 16L), y_train: (78144L,)
# 				-->Computing Last value
# 					-->R2: -5.313
# 					-->MAE: 0.649
# 					-->MAPE: 85.185
# 					-->MASE: 0.502
# 				-->Computing Previous day
# 					-->R2: -4.184
# 					-->MAE: 0.423
# 					-->MAPE: 44.444
# 					-->MASE: 0.326
# 				-->Computing Previous week
# 					-->R2: -3.157
# 					-->MAE: 0.546
# 					-->MAPE: 85.185
# 					-->MASE: 0.422
# 			-->Dataset: TOP_20. X_train: (78144L, 20L), y_train: (78144L,)
# 				-->Training model: Random Forest, runtime: 8.58s
# 					-->R2: 0.068
# 					-->MAE: 0.394
# 					-->MAPE: 51.081
# 					-->MASE: 0.304
#
# 		-->Evaluation (2014-04-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (78240L, 16L), y_train: (78240L,)
# 				-->Computing Last value
# 					-->R2: -0.455
# 					-->MAE: 0.278
# 					-->MAPE: 48.000
# 					-->MASE: 0.215
# 				-->Computing Previous day
# 					-->R2: -0.401
# 					-->MAE: 0.268
# 					-->MAPE: 48.000
# 					-->MASE: 0.207
# 				-->Computing Previous week
# 					-->R2: 0.138
# 					-->MAE: 0.165
# 					-->MAPE: 32.000
# 					-->MASE: 0.127
# 			-->Dataset: TOP_20. X_train: (78240L, 20L), y_train: (78240L,)
# 				-->Training model: Random Forest, runtime: 7.99s
# 					-->R2: 0.004
# 					-->MAE: 0.386
# 					-->MAPE: 72.611
# 					-->MASE: 0.298
#
# 		-->Evaluation (2014-04-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (78336L, 16L), y_train: (78336L,)
# 				-->Computing Last value
# 					-->R2: -0.570
# 					-->MAE: 1.526
# 					-->MAPE: 92.827
# 					-->MASE: 1.180
# 				-->Computing Previous day
# 					-->R2: -0.549
# 					-->MAE: 1.381
# 					-->MAPE: 79.643
# 					-->MASE: 1.069
# 				-->Computing Previous week
# 					-->R2: -0.588
# 					-->MAE: 1.474
# 					-->MAPE: 84.940
# 					-->MASE: 1.140
# 			-->Dataset: TOP_20. X_train: (78336L, 20L), y_train: (78336L,)
# 				-->Training model: Random Forest, runtime: 8.03s
# 					-->R2: 0.386
# 					-->MAE: 0.943
# 					-->MAPE: 48.639
# 					-->MASE: 0.729
#
# 		-->Evaluation (2014-04-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (78432L, 16L), y_train: (78432L,)
# 				-->Computing Last value
# 					-->R2: -0.572
# 					-->MAE: 1.814
# 					-->MAPE: 78.998
# 					-->MASE: 1.403
# 				-->Computing Previous day
# 					-->R2: 0.561
# 					-->MAE: 0.928
# 					-->MAPE: 54.395
# 					-->MASE: 0.718
# 				-->Computing Previous week
# 					-->R2: 0.477
# 					-->MAE: 1.000
# 					-->MAPE: 57.813
# 					-->MASE: 0.773
# 			-->Dataset: TOP_20. X_train: (78432L, 20L), y_train: (78432L,)
# 				-->Training model: Random Forest, runtime: 8.02s
# 					-->R2: 0.604
# 					-->MAE: 0.899
# 					-->MAPE: 40.720
# 					-->MASE: 0.695
#
# 		-->Evaluation (2014-04-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (78528L, 16L), y_train: (78528L,)
# 				-->Computing Last value
# 					-->R2: -0.527
# 					-->MAE: 1.742
# 					-->MAPE: 78.287
# 					-->MASE: 1.347
# 				-->Computing Previous day
# 					-->R2: 0.520
# 					-->MAE: 0.835
# 					-->MAPE: 49.935
# 					-->MASE: 0.645
# 				-->Computing Previous week
# 					-->R2: 0.506
# 					-->MAE: 0.887
# 					-->MAPE: 49.139
# 					-->MASE: 0.685
# 			-->Dataset: TOP_20. X_train: (78528L, 20L), y_train: (78528L,)
# 				-->Training model: Random Forest, runtime: 7.57s
# 					-->R2: 0.742
# 					-->MAE: 0.700
# 					-->MAPE: 36.100
# 					-->MASE: 0.541
#
# 		-->Evaluation (2014-05-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (78624L, 16L), y_train: (78624L,)
# 				-->Computing Last value
# 					-->R2: -30.902
# 					-->MAE: 1.753
# 					-->MAPE: 164.000
# 					-->MASE: 1.354
# 				-->Computing Previous day
# 					-->R2: -30.848
# 					-->MAE: 1.784
# 					-->MAPE: 176.000
# 					-->MASE: 1.378
# 				-->Computing Previous week
# 					-->R2: -22.172
# 					-->MAE: 1.402
# 					-->MAPE: 120.000
# 					-->MASE: 1.083
# 			-->Dataset: TOP_20. X_train: (78624L, 20L), y_train: (78624L,)
# 				-->Training model: Random Forest, runtime: 7.67s
# 					-->R2: -3.916
# 					-->MAE: 0.659
# 					-->MAPE: 71.194
# 					-->MASE: 0.510
#
# 		-->Evaluation (2014-05-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (78720L, 16L), y_train: (78720L,)
# 				-->Computing Last value
# 					-->R2: -0.848
# 					-->MAE: 0.371
# 					-->MAPE: 70.370
# 					-->MASE: 0.287
# 				-->Computing Previous day
# 					-->R2: -0.540
# 					-->MAE: 0.309
# 					-->MAPE: 59.259
# 					-->MASE: 0.239
# 				-->Computing Previous week
# 					-->R2: -4.799
# 					-->MAE: 0.546
# 					-->MAPE: 66.667
# 					-->MASE: 0.422
# 			-->Dataset: TOP_20. X_train: (78720L, 20L), y_train: (78720L,)
# 				-->Training model: Random Forest, runtime: 8.29s
# 					-->R2: -0.187
# 					-->MAE: 0.475
# 					-->MAPE: 55.752
# 					-->MASE: 0.367
#
# 		-->Evaluation (2014-05-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (78816L, 16L), y_train: (78816L,)
# 				-->Computing Last value
# 					-->R2: -0.970
# 					-->MAE: 0.433
# 					-->MAPE: 75.000
# 					-->MASE: 0.335
# 				-->Computing Previous day
# 					-->R2: -0.702
# 					-->MAE: 0.371
# 					-->MAPE: 64.286
# 					-->MASE: 0.287
# 				-->Computing Previous week
# 					-->R2: -0.702
# 					-->MAE: 0.371
# 					-->MAPE: 64.286
# 					-->MASE: 0.287
# 			-->Dataset: TOP_20. X_train: (78816L, 20L), y_train: (78816L,)
# 				-->Training model: Random Forest, runtime: 7.32s
# 					-->R2: -0.034
# 					-->MAE: 0.444
# 					-->MAPE: 61.287
# 					-->MASE: 0.343
#
# 		-->Evaluation (2014-05-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (78912L, 16L), y_train: (78912L,)
# 				-->Computing Last value
# 					-->R2: -1.371
# 					-->MAE: 0.433
# 					-->MAPE: 76.000
# 					-->MASE: 0.335
# 				-->Computing Previous day
# 					-->R2: -1.263
# 					-->MAE: 0.412
# 					-->MAPE: 72.000
# 					-->MASE: 0.319
# 				-->Computing Previous week
# 					-->R2: -0.509
# 					-->MAE: 0.289
# 					-->MAPE: 56.000
# 					-->MASE: 0.223
# 			-->Dataset: TOP_20. X_train: (78912L, 20L), y_train: (78912L,)
# 				-->Training model: Random Forest, runtime: 7.43s
# 					-->R2: -0.170
# 					-->MAE: 0.450
# 					-->MAPE: 65.620
# 					-->MASE: 0.348
#
# 		-->Evaluation (2014-05-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (79008L, 16L), y_train: (79008L,)
# 				-->Computing Last value
# 					-->R2: -0.503
# 					-->MAE: 1.237
# 					-->MAPE: 70.000
# 					-->MASE: 0.958
# 				-->Computing Previous day
# 					-->R2: -0.627
# 					-->MAE: 1.474
# 					-->MAPE: 89.561
# 					-->MASE: 1.141
# 				-->Computing Previous week
# 					-->R2: 0.756
# 					-->MAE: 0.505
# 					-->MAPE: 37.339
# 					-->MASE: 0.391
# 			-->Dataset: TOP_20. X_train: (79008L, 20L), y_train: (79008L,)
# 				-->Training model: Random Forest, runtime: 7.67s
# 					-->R2: 0.746
# 					-->MAE: 0.634
# 					-->MAPE: 47.120
# 					-->MASE: 0.491
#
# 		-->Evaluation (2014-05-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (79104L, 16L), y_train: (79104L,)
# 				-->Computing Last value
# 					-->R2: -0.464
# 					-->MAE: 1.340
# 					-->MAPE: 71.132
# 					-->MASE: 1.038
# 				-->Computing Previous day
# 					-->R2: 0.613
# 					-->MAE: 0.680
# 					-->MAPE: 48.994
# 					-->MASE: 0.527
# 				-->Computing Previous week
# 					-->R2: 0.012
# 					-->MAE: 0.835
# 					-->MAPE: 57.327
# 					-->MASE: 0.647
# 			-->Dataset: TOP_20. X_train: (79104L, 20L), y_train: (79104L,)
# 				-->Training model: Random Forest, runtime: 7.41s
# 					-->R2: 0.764
# 					-->MAE: 0.595
# 					-->MAPE: 43.166
# 					-->MASE: 0.460
#
# 		-->Evaluation (2014-05-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (79200L, 16L), y_train: (79200L,)
# 				-->Computing Last value
# 					-->R2: -0.622
# 					-->MAE: 1.526
# 					-->MAPE: 85.648
# 					-->MASE: 1.181
# 				-->Computing Previous day
# 					-->R2: 0.620
# 					-->MAE: 0.701
# 					-->MAPE: 51.327
# 					-->MASE: 0.543
# 				-->Computing Previous week
# 					-->R2: 0.356
# 					-->MAE: 0.701
# 					-->MAPE: 44.290
# 					-->MASE: 0.543
# 			-->Dataset: TOP_20. X_train: (79200L, 20L), y_train: (79200L,)
# 				-->Training model: Random Forest, runtime: 7.48s
# 					-->R2: 0.750
# 					-->MAE: 0.617
# 					-->MAPE: 43.575
# 					-->MASE: 0.477
#
# 		-->Evaluation (2014-05-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (79296L, 16L), y_train: (79296L,)
# 				-->Computing Last value
# 					-->R2: -0.574
# 					-->MAE: 1.309
# 					-->MAPE: 62.845
# 					-->MASE: 1.013
# 				-->Computing Previous day
# 					-->R2: 0.648
# 					-->MAE: 0.577
# 					-->MAPE: 43.448
# 					-->MASE: 0.447
# 				-->Computing Previous week
# 					-->R2: -0.710
# 					-->MAE: 1.433
# 					-->MAPE: 90.374
# 					-->MASE: 1.109
# 			-->Dataset: TOP_20. X_train: (79296L, 20L), y_train: (79296L,)
# 				-->Training model: Random Forest, runtime: 7.34s
# 					-->R2: 0.777
# 					-->MAE: 0.517
# 					-->MAPE: 37.253
# 					-->MASE: 0.400
#
# 		-->Evaluation (2014-05-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (79392L, 16L), y_train: (79392L,)
# 				-->Computing Last value
# 					-->R2: -15.975
# 					-->MAE: 1.361
# 					-->MAPE: 115.625
# 					-->MASE: 1.053
# 				-->Computing Previous day
# 					-->R2: -15.229
# 					-->MAE: 1.402
# 					-->MAPE: 153.125
# 					-->MASE: 1.085
# 				-->Computing Previous week
# 					-->R2: -1.472
# 					-->MAE: 0.546
# 					-->MAPE: 90.625
# 					-->MASE: 0.423
# 			-->Dataset: TOP_20. X_train: (79392L, 20L), y_train: (79392L,)
# 				-->Training model: Random Forest, runtime: 7.65s
# 					-->R2: -0.077
# 					-->MAE: 0.456
# 					-->MAPE: 53.771
# 					-->MASE: 0.353
#
# 		-->Evaluation (2014-05-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (79488L, 16L), y_train: (79488L,)
# 				-->Computing Last value
# 					-->R2: -0.796
# 					-->MAE: 0.361
# 					-->MAPE: 55.556
# 					-->MASE: 0.279
# 				-->Computing Previous day
# 					-->R2: -1.207
# 					-->MAE: 0.443
# 					-->MAPE: 70.370
# 					-->MASE: 0.343
# 				-->Computing Previous week
# 					-->R2: -1.669
# 					-->MAE: 0.515
# 					-->MAPE: 88.889
# 					-->MASE: 0.399
# 			-->Dataset: TOP_20. X_train: (79488L, 20L), y_train: (79488L,)
# 				-->Training model: Random Forest, runtime: 7.62s
# 					-->R2: 0.042
# 					-->MAE: 0.388
# 					-->MAPE: 69.504
# 					-->MASE: 0.300
#
# 		-->Evaluation (2014-05-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (79584L, 16L), y_train: (79584L,)
# 				-->Computing Last value
# 					-->R2: -0.787
# 					-->MAE: 0.351
# 					-->MAPE: 65.385
# 					-->MASE: 0.272
# 				-->Computing Previous day
# 					-->R2: -0.103
# 					-->MAE: 0.216
# 					-->MAPE: 38.462
# 					-->MASE: 0.168
# 				-->Computing Previous week
# 					-->R2: -1.680
# 					-->MAE: 0.526
# 					-->MAPE: 100.000
# 					-->MASE: 0.407
# 			-->Dataset: TOP_20. X_train: (79584L, 20L), y_train: (79584L,)
# 				-->Training model: Random Forest, runtime: 7.33s
# 					-->R2: 0.080
# 					-->MAE: 0.347
# 					-->MAPE: 74.068
# 					-->MASE: 0.269
#
# 		-->Evaluation (2014-05-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (79680L, 16L), y_train: (79680L,)
# 				-->Computing Last value
# 					-->R2: -0.615
# 					-->MAE: 1.340
# 					-->MAPE: 79.454
# 					-->MASE: 1.039
# 				-->Computing Previous day
# 					-->R2: -0.670
# 					-->MAE: 1.474
# 					-->MAPE: 89.598
# 					-->MASE: 1.143
# 				-->Computing Previous week
# 					-->R2: 0.654
# 					-->MAE: 0.670
# 					-->MAPE: 45.431
# 					-->MASE: 0.520
# 			-->Dataset: TOP_20. X_train: (79680L, 20L), y_train: (79680L,)
# 				-->Training model: Random Forest, runtime: 7.37s
# 					-->R2: 0.765
# 					-->MAE: 0.598
# 					-->MAPE: 44.042
# 					-->MASE: 0.463
#
# 		-->Evaluation (2014-05-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (79776L, 16L), y_train: (79776L,)
# 				-->Computing Last value
# 					-->R2: -0.169
# 					-->MAE: 1.289
# 					-->MAPE: 59.967
# 					-->MASE: 0.999
# 				-->Computing Previous day
# 					-->R2: 0.699
# 					-->MAE: 0.639
# 					-->MAPE: 36.144
# 					-->MASE: 0.496
# 				-->Computing Previous week
# 					-->R2: 0.715
# 					-->MAE: 0.608
# 					-->MAPE: 43.366
# 					-->MASE: 0.472
# 			-->Dataset: TOP_20. X_train: (79776L, 20L), y_train: (79776L,)
# 				-->Training model: Random Forest, runtime: 7.50s
# 					-->R2: 0.796
# 					-->MAE: 0.646
# 					-->MAPE: 38.394
# 					-->MASE: 0.501
#
# 		-->Evaluation (2014-05-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (79872L, 16L), y_train: (79872L,)
# 				-->Computing Last value
# 					-->R2: -0.764
# 					-->MAE: 1.371
# 					-->MAPE: 82.661
# 					-->MASE: 1.063
# 				-->Computing Previous day
# 					-->R2: 0.558
# 					-->MAE: 0.722
# 					-->MAPE: 57.953
# 					-->MASE: 0.559
# 				-->Computing Previous week
# 					-->R2: 0.638
# 					-->MAE: 0.526
# 					-->MAPE: 43.392
# 					-->MASE: 0.408
# 			-->Dataset: TOP_20. X_train: (79872L, 20L), y_train: (79872L,)
# 				-->Training model: Random Forest, runtime: 7.63s
# 					-->R2: 0.805
# 					-->MAE: 0.536
# 					-->MAPE: 41.684
# 					-->MASE: 0.415
#
# 		-->Evaluation (2014-05-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (79968L, 16L), y_train: (79968L,)
# 				-->Computing Last value
# 					-->R2: -0.435
# 					-->MAE: 1.340
# 					-->MAPE: 77.673
# 					-->MASE: 1.039
# 				-->Computing Previous day
# 					-->R2: 0.570
# 					-->MAE: 0.794
# 					-->MAPE: 53.805
# 					-->MASE: 0.615
# 				-->Computing Previous week
# 					-->R2: 0.683
# 					-->MAE: 0.619
# 					-->MAPE: 41.761
# 					-->MASE: 0.479
# 			-->Dataset: TOP_20. X_train: (79968L, 20L), y_train: (79968L,)
# 				-->Training model: Random Forest, runtime: 7.64s
# 					-->R2: 0.753
# 					-->MAE: 0.609
# 					-->MAPE: 42.952
# 					-->MASE: 0.472
#
# 		-->Evaluation (2014-05-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (80064L, 16L), y_train: (80064L,)
# 				-->Computing Last value
# 					-->R2: -3.405
# 					-->MAE: 1.268
# 					-->MAPE: 96.905
# 					-->MASE: 0.983
# 				-->Computing Previous day
# 					-->R2: -2.573
# 					-->MAE: 1.093
# 					-->MAPE: 115.357
# 					-->MASE: 0.847
# 				-->Computing Previous week
# 					-->R2: 0.018
# 					-->MAE: 0.474
# 					-->MAPE: 57.262
# 					-->MASE: 0.368
# 			-->Dataset: TOP_20. X_train: (80064L, 20L), y_train: (80064L,)
# 				-->Training model: Random Forest, runtime: 7.59s
# 					-->R2: -0.021
# 					-->MAE: 0.610
# 					-->MAPE: 66.108
# 					-->MASE: 0.473
#
# 		-->Evaluation (2014-05-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (80160L, 16L), y_train: (80160L,)
# 				-->Computing Last value
# 					-->R2: -3.747
# 					-->MAE: 0.773
# 					-->MAPE: 88.889
# 					-->MASE: 0.599
# 				-->Computing Previous day
# 					-->R2: -2.988
# 					-->MAE: 0.691
# 					-->MAPE: 91.358
# 					-->MASE: 0.535
# 				-->Computing Previous week
# 					-->R2: -1.127
# 					-->MAE: 0.515
# 					-->MAPE: 88.889
# 					-->MASE: 0.400
# 			-->Dataset: TOP_20. X_train: (80160L, 20L), y_train: (80160L,)
# 				-->Training model: Random Forest, runtime: 7.48s
# 					-->R2: -0.240
# 					-->MAE: 0.482
# 					-->MAPE: 66.719
# 					-->MASE: 0.374
#
# 		-->Evaluation (2014-05-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (80256L, 16L), y_train: (80256L,)
# 				-->Computing Last value
# 					-->R2: -1.802
# 					-->MAE: 0.474
# 					-->MAPE: 84.000
# 					-->MASE: 0.368
# 				-->Computing Previous day
# 					-->R2: -1.802
# 					-->MAE: 0.474
# 					-->MAPE: 84.000
# 					-->MASE: 0.368
# 				-->Computing Previous week
# 					-->R2: -1.748
# 					-->MAE: 0.526
# 					-->MAPE: 100.000
# 					-->MASE: 0.408
# 			-->Dataset: TOP_20. X_train: (80256L, 20L), y_train: (80256L,)
# 				-->Training model: Random Forest, runtime: 7.32s
# 					-->R2: -0.073
# 					-->MAE: 0.415
# 					-->MAPE: 71.284
# 					-->MASE: 0.322
#
# 		-->Evaluation (2014-05-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (80352L, 16L), y_train: (80352L,)
# 				-->Computing Last value
# 					-->R2: -0.606
# 					-->MAE: 1.474
# 					-->MAPE: 84.971
# 					-->MASE: 1.144
# 				-->Computing Previous day
# 					-->R2: -0.613
# 					-->MAE: 1.515
# 					-->MAPE: 87.836
# 					-->MASE: 1.176
# 				-->Computing Previous week
# 					-->R2: 0.599
# 					-->MAE: 0.711
# 					-->MAPE: 43.918
# 					-->MASE: 0.552
# 			-->Dataset: TOP_20. X_train: (80352L, 20L), y_train: (80352L,)
# 				-->Training model: Random Forest, runtime: 7.34s
# 					-->R2: 0.810
# 					-->MAE: 0.529
# 					-->MAPE: 35.820
# 					-->MASE: 0.411
#
# 		-->Evaluation (2014-05-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (80448L, 16L), y_train: (80448L,)
# 				-->Computing Last value
# 					-->R2: -0.602
# 					-->MAE: 1.495
# 					-->MAPE: 83.459
# 					-->MASE: 1.160
# 				-->Computing Previous day
# 					-->R2: 0.636
# 					-->MAE: 0.619
# 					-->MAPE: 40.094
# 					-->MASE: 0.480
# 				-->Computing Previous week
# 					-->R2: 0.696
# 					-->MAE: 0.546
# 					-->MAPE: 43.931
# 					-->MASE: 0.424
# 			-->Dataset: TOP_20. X_train: (80448L, 20L), y_train: (80448L,)
# 				-->Training model: Random Forest, runtime: 8.14s
# 					-->R2: 0.808
# 					-->MAE: 0.582
# 					-->MAPE: 40.248
# 					-->MASE: 0.452
#
# 		-->Evaluation (2014-05-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (80544L, 16L), y_train: (80544L,)
# 				-->Computing Last value
# 					-->R2: -0.332
# 					-->MAE: 1.351
# 					-->MAPE: 71.698
# 					-->MASE: 1.048
# 				-->Computing Previous day
# 					-->R2: 0.632
# 					-->MAE: 0.711
# 					-->MAPE: 53.239
# 					-->MASE: 0.552
# 				-->Computing Previous week
# 					-->R2: 0.664
# 					-->MAE: 0.680
# 					-->MAPE: 46.572
# 					-->MASE: 0.528
# 			-->Dataset: TOP_20. X_train: (80544L, 20L), y_train: (80544L,)
# 				-->Training model: Random Forest, runtime: 7.47s
# 					-->R2: 0.784
# 					-->MAE: 0.616
# 					-->MAPE: 44.728
# 					-->MASE: 0.478
#
# 		-->Evaluation (2014-05-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (80640L, 16L), y_train: (80640L,)
# 				-->Computing Last value
# 					-->R2: -0.680
# 					-->MAE: 1.392
# 					-->MAPE: 78.879
# 					-->MASE: 1.080
# 				-->Computing Previous day
# 					-->R2: 0.515
# 					-->MAE: 0.784
# 					-->MAPE: 63.247
# 					-->MASE: 0.608
# 				-->Computing Previous week
# 					-->R2: 0.561
# 					-->MAE: 0.732
# 					-->MAPE: 56.264
# 					-->MASE: 0.568
# 			-->Dataset: TOP_20. X_train: (80640L, 20L), y_train: (80640L,)
# 				-->Training model: Random Forest, runtime: 7.50s
# 					-->R2: 0.755
# 					-->MAE: 0.615
# 					-->MAPE: 48.586
# 					-->MASE: 0.477
#
# 		-->Evaluation (2014-05-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (80736L, 16L), y_train: (80736L,)
# 				-->Computing Last value
# 					-->R2: -0.309
# 					-->MAE: 1.289
# 					-->MAPE: 66.374
# 					-->MASE: 1.000
# 				-->Computing Previous day
# 					-->R2: 0.583
# 					-->MAE: 0.691
# 					-->MAPE: 44.152
# 					-->MASE: 0.536
# 				-->Computing Previous week
# 					-->R2: -0.214
# 					-->MAE: 1.237
# 					-->MAPE: 73.801
# 					-->MASE: 0.960
# 			-->Dataset: TOP_20. X_train: (80736L, 20L), y_train: (80736L,)
# 				-->Training model: Random Forest, runtime: 7.85s
# 					-->R2: -0.319
# 					-->MAE: 1.297
# 					-->MAPE: 74.768
# 					-->MASE: 1.006
#
# 		-->Evaluation (2014-05-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (80832L, 16L), y_train: (80832L,)
# 				-->Computing Last value
# 					-->R2: -19.478
# 					-->MAE: 1.392
# 					-->MAPE: 122.222
# 					-->MASE: 1.080
# 				-->Computing Previous day
# 					-->R2: -18.862
# 					-->MAE: 1.309
# 					-->MAPE: 114.815
# 					-->MASE: 1.016
# 				-->Computing Previous week
# 					-->R2: -1.361
# 					-->MAE: 0.412
# 					-->MAPE: 70.370
# 					-->MASE: 0.320
# 			-->Dataset: TOP_20. X_train: (80832L, 20L), y_train: (80832L,)
# 				-->Training model: Random Forest, runtime: 8.36s
# 					-->R2: -0.293
# 					-->MAE: 0.457
# 					-->MAPE: 53.971
# 					-->MASE: 0.355
#
# 		-->Evaluation (2014-05-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (80928L, 16L), y_train: (80928L,)
# 				-->Computing Last value
# 					-->R2: -0.401
# 					-->MAE: 0.268
# 					-->MAPE: 48.000
# 					-->MASE: 0.208
# 				-->Computing Previous day
# 					-->R2: -0.724
# 					-->MAE: 0.330
# 					-->MAPE: 60.000
# 					-->MASE: 0.256
# 				-->Computing Previous week
# 					-->R2: 0.353
# 					-->MAE: 0.124
# 					-->MAPE: 24.000
# 					-->MASE: 0.096
# 			-->Dataset: TOP_20. X_train: (80928L, 20L), y_train: (80928L,)
# 				-->Training model: Random Forest, runtime: 8.73s
# 					-->R2: -0.207
# 					-->MAE: 0.415
# 					-->MAPE: 81.785
# 					-->MASE: 0.322
#
# 		-->Evaluation (2014-05-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (81024L, 16L), y_train: (81024L,)
# 				-->Computing Last value
# 					-->R2: -0.472
# 					-->MAE: 1.361
# 					-->MAPE: 80.409
# 					-->MASE: 1.056
# 				-->Computing Previous day
# 					-->R2: -0.493
# 					-->MAE: 1.361
# 					-->MAPE: 79.843
# 					-->MASE: 1.056
# 				-->Computing Previous week
# 					-->R2: 0.620
# 					-->MAE: 0.649
# 					-->MAPE: 42.013
# 					-->MASE: 0.504
# 			-->Dataset: TOP_20. X_train: (81024L, 20L), y_train: (81024L,)
# 				-->Training model: Random Forest, runtime: 8.84s
# 					-->R2: 0.681
# 					-->MAE: 0.758
# 					-->MAPE: 52.347
# 					-->MASE: 0.588
#
# 		-->Evaluation (2014-05-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (81120L, 16L), y_train: (81120L,)
# 				-->Computing Last value
# 					-->R2: -0.683
# 					-->MAE: 1.742
# 					-->MAPE: 86.096
# 					-->MASE: 1.352
# 				-->Computing Previous day
# 					-->R2: 0.624
# 					-->MAE: 0.701
# 					-->MAPE: 42.763
# 					-->MASE: 0.544
# 				-->Computing Previous week
# 					-->R2: 0.621
# 					-->MAE: 0.691
# 					-->MAPE: 42.339
# 					-->MASE: 0.536
# 			-->Dataset: TOP_20. X_train: (81120L, 20L), y_train: (81120L,)
# 				-->Training model: Random Forest, runtime: 8.37s
# 					-->R2: 0.723
# 					-->MAE: 0.706
# 					-->MAPE: 45.368
# 					-->MASE: 0.548
#
# 		-->Evaluation (2014-05-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (81216L, 16L), y_train: (81216L,)
# 				-->Computing Last value
# 					-->R2: -0.486
# 					-->MAE: 1.258
# 					-->MAPE: 74.697
# 					-->MASE: 0.976
# 				-->Computing Previous day
# 					-->R2: 0.361
# 					-->MAE: 0.784
# 					-->MAPE: 58.485
# 					-->MASE: 0.608
# 				-->Computing Previous week
# 					-->R2: 0.703
# 					-->MAE: 0.536
# 					-->MAPE: 39.455
# 					-->MASE: 0.416
# 			-->Dataset: TOP_20. X_train: (81216L, 20L), y_train: (81216L,)
# 				-->Training model: Random Forest, runtime: 8.71s
# 					-->R2: 0.775
# 					-->MAE: 0.543
# 					-->MAPE: 40.136
# 					-->MASE: 0.421
#
# 		-->Evaluation (2014-05-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (81312L, 16L), y_train: (81312L,)
# 				-->Computing Last value
# 					-->R2: -0.511
# 					-->MAE: 1.433
# 					-->MAPE: 82.458
# 					-->MASE: 1.112
# 				-->Computing Previous day
# 					-->R2: 0.654
# 					-->MAE: 0.608
# 					-->MAPE: 43.136
# 					-->MASE: 0.472
# 				-->Computing Previous week
# 					-->R2: 0.480
# 					-->MAE: 0.773
# 					-->MAPE: 50.452
# 					-->MASE: 0.600
# 			-->Dataset: TOP_20. X_train: (81312L, 20L), y_train: (81312L,)
# 				-->Training model: Random Forest, runtime: 8.55s
# 					-->R2: 0.717
# 					-->MAE: 0.662
# 					-->MAPE: 47.051
# 					-->MASE: 0.513
#
# 		-->Evaluation (2014-05-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (81408L, 16L), y_train: (81408L,)
# 				-->Computing Last value
# 					-->R2: -9.140
# 					-->MAE: 1.505
# 					-->MAPE: 126.754
# 					-->MASE: 1.168
# 				-->Computing Previous day
# 					-->R2: -8.640
# 					-->MAE: 1.443
# 					-->MAPE: 135.088
# 					-->MASE: 1.120
# 				-->Computing Previous week
# 					-->R2: -8.790
# 					-->MAE: 1.485
# 					-->MAPE: 143.860
# 					-->MASE: 1.152
# 			-->Dataset: TOP_20. X_train: (81408L, 20L), y_train: (81408L,)
# 				-->Training model: Random Forest, runtime: 8.40s
# 					-->R2: -1.277
# 					-->MAE: 0.771
# 					-->MAPE: 61.374
# 					-->MASE: 0.598
#
# 		-->Evaluation (2014-05-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (81504L, 16L), y_train: (81504L,)
# 				-->Computing Last value
# 					-->R2: -1.056
# 					-->MAE: 0.588
# 					-->MAPE: 71.905
# 					-->MASE: 0.456
# 				-->Computing Previous day
# 					-->R2: -1.253
# 					-->MAE: 0.639
# 					-->MAPE: 80.000
# 					-->MASE: 0.496
# 				-->Computing Previous week
# 					-->R2: -0.436
# 					-->MAE: 0.443
# 					-->MAPE: 68.571
# 					-->MASE: 0.344
# 			-->Dataset: TOP_20. X_train: (81504L, 20L), y_train: (81504L,)
# 				-->Training model: Random Forest, runtime: 8.48s
# 					-->R2: -0.010
# 					-->MAE: 0.506
# 					-->MAPE: 68.309
# 					-->MASE: 0.392
#
# 		-->Evaluation (2014-06-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (81600L, 16L), y_train: (81600L,)
# 				-->Computing Last value
# 					-->R2: -1.606
# 					-->MAE: 0.474
# 					-->MAPE: 66.667
# 					-->MASE: 0.368
# 				-->Computing Previous day
# 					-->R2: -2.089
# 					-->MAE: 0.557
# 					-->MAPE: 76.667
# 					-->MASE: 0.432
# 				-->Computing Previous week
# 					-->R2: -1.172
# 					-->MAE: 0.464
# 					-->MAPE: 83.333
# 					-->MASE: 0.360
# 			-->Dataset: TOP_20. X_train: (81600L, 20L), y_train: (81600L,)
# 				-->Training model: Random Forest, runtime: 8.92s
# 					-->R2: -0.059
# 					-->MAE: 0.435
# 					-->MAPE: 69.844
# 					-->MASE: 0.337
#
# 		-->Evaluation (2014-06-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (81696L, 16L), y_train: (81696L,)
# 				-->Computing Last value
# 					-->R2: -0.635
# 					-->MAE: 1.392
# 					-->MAPE: 74.425
# 					-->MASE: 1.081
# 				-->Computing Previous day
# 					-->R2: -0.627
# 					-->MAE: 1.351
# 					-->MAPE: 70.833
# 					-->MASE: 1.049
# 				-->Computing Previous week
# 					-->R2: 0.669
# 					-->MAE: 0.639
# 					-->MAPE: 45.546
# 					-->MASE: 0.496
# 			-->Dataset: TOP_20. X_train: (81696L, 20L), y_train: (81696L,)
# 				-->Training model: Random Forest, runtime: 9.08s
# 					-->R2: 0.801
# 					-->MAE: 0.591
# 					-->MAPE: 37.619
# 					-->MASE: 0.459
#
# 		-->Evaluation (2014-06-03 00:00:00)
# 			-->Dataset: Baselines. X_train: (81792L, 16L), y_train: (81792L,)
# 				-->Computing Last value
# 					-->R2: -0.526
# 					-->MAE: 1.330
# 					-->MAPE: 72.193
# 					-->MASE: 1.033
# 				-->Computing Previous day
# 					-->R2: 0.613
# 					-->MAE: 0.680
# 					-->MAPE: 49.415
# 					-->MASE: 0.528
# 				-->Computing Previous week
# 					-->R2: 0.381
# 					-->MAE: 0.887
# 					-->MAPE: 73.421
# 					-->MASE: 0.689
# 			-->Dataset: TOP_20. X_train: (81792L, 20L), y_train: (81792L,)
# 				-->Training model: Random Forest, runtime: 8.08s
# 					-->R2: 0.756
# 					-->MAE: 0.616
# 					-->MAPE: 46.351
# 					-->MASE: 0.479
#
# 		-->Evaluation (2014-06-04 00:00:00)
# 			-->Dataset: Baselines. X_train: (81888L, 16L), y_train: (81888L,)
# 				-->Computing Last value
# 					-->R2: -0.308
# 					-->MAE: 1.227
# 					-->MAPE: 60.679
# 					-->MASE: 0.953
# 				-->Computing Previous day
# 					-->R2: 0.807
# 					-->MAE: 0.474
# 					-->MAPE: 33.457
# 					-->MASE: 0.368
# 				-->Computing Previous week
# 					-->R2: 0.768
# 					-->MAE: 0.474
# 					-->MAPE: 34.599
# 					-->MASE: 0.368
# 			-->Dataset: TOP_20. X_train: (81888L, 20L), y_train: (81888L,)
# 				-->Training model: Random Forest, runtime: 8.38s
# 					-->R2: 0.859
# 					-->MAE: 0.492
# 					-->MAPE: 34.244
# 					-->MASE: 0.382
#
# 		-->Evaluation (2014-06-05 00:00:00)
# 			-->Dataset: Baselines. X_train: (81984L, 16L), y_train: (81984L,)
# 				-->Computing Last value
# 					-->R2: -0.554
# 					-->MAE: 1.361
# 					-->MAPE: 77.547
# 					-->MASE: 1.057
# 				-->Computing Previous day
# 					-->R2: 0.742
# 					-->MAE: 0.515
# 					-->MAPE: 37.673
# 					-->MASE: 0.400
# 				-->Computing Previous week
# 					-->R2: 0.647
# 					-->MAE: 0.649
# 					-->MAPE: 44.151
# 					-->MASE: 0.504
# 			-->Dataset: TOP_20. X_train: (81984L, 20L), y_train: (81984L,)
# 				-->Training model: Random Forest, runtime: 8.54s
# 					-->R2: 0.855
# 					-->MAE: 0.487
# 					-->MAPE: 36.583
# 					-->MASE: 0.378
#
# 		-->Evaluation (2014-06-06 00:00:00)
# 			-->Dataset: Baselines. X_train: (82080L, 16L), y_train: (82080L,)
# 				-->Computing Last value
# 					-->R2: -16.395
# 					-->MAE: 1.351
# 					-->MAPE: 121.875
# 					-->MASE: 1.049
# 				-->Computing Previous day
# 					-->R2: -14.902
# 					-->MAE: 1.186
# 					-->MAPE: 121.875
# 					-->MASE: 0.921
# 				-->Computing Previous week
# 					-->R2: -2.171
# 					-->MAE: 0.577
# 					-->MAPE: 75.000
# 					-->MASE: 0.448
# 			-->Dataset: TOP_20. X_train: (82080L, 20L), y_train: (82080L,)
# 				-->Training model: Random Forest, runtime: 8.38s
# 					-->R2: -0.199
# 					-->MAE: 0.455
# 					-->MAPE: 44.410
# 					-->MASE: 0.353
#
# 		-->Evaluation (2014-06-07 00:00:00)
# 			-->Dataset: Baselines. X_train: (82176L, 16L), y_train: (82176L,)
# 				-->Computing Last value
# 					-->R2: -0.887
# 					-->MAE: 0.474
# 					-->MAPE: 71.667
# 					-->MASE: 0.368
# 				-->Computing Previous day
# 					-->R2: -0.258
# 					-->MAE: 0.330
# 					-->MAPE: 50.000
# 					-->MASE: 0.256
# 				-->Computing Previous week
# 					-->R2: -1.358
# 					-->MAE: 0.557
# 					-->MAPE: 83.333
# 					-->MASE: 0.432
# 			-->Dataset: TOP_20. X_train: (82176L, 20L), y_train: (82176L,)
# 				-->Training model: Random Forest, runtime: 8.43s
# 					-->R2: 0.170
# 					-->MAE: 0.399
# 					-->MAPE: 64.666
# 					-->MASE: 0.310
#
# 		-->Evaluation (2014-06-08 00:00:00)
# 			-->Dataset: Baselines. X_train: (82272L, 16L), y_train: (82272L,)
# 				-->Computing Last value
# 					-->R2: -1.417
# 					-->MAE: 0.433
# 					-->MAPE: 69.231
# 					-->MASE: 0.336
# 				-->Computing Previous day
# 					-->R2: -1.312
# 					-->MAE: 0.412
# 					-->MAPE: 65.385
# 					-->MASE: 0.320
# 				-->Computing Previous week
# 					-->R2: -0.892
# 					-->MAE: 0.371
# 					-->MAPE: 61.538
# 					-->MASE: 0.288
# 			-->Dataset: TOP_20. X_train: (82272L, 20L), y_train: (82272L,)
# 				-->Training model: Random Forest, runtime: 8.26s
# 					-->R2: -0.122
# 					-->MAE: 0.420
# 					-->MAPE: 72.759
# 					-->MASE: 0.326
#
# 		-->Evaluation (2014-06-09 00:00:00)
# 			-->Dataset: Baselines. X_train: (82368L, 16L), y_train: (82368L,)
# 				-->Computing Last value
# 					-->R2: -0.785
# 					-->MAE: 1.876
# 					-->MAPE: 92.139
# 					-->MASE: 1.459
# 				-->Computing Previous day
# 					-->R2: -0.759
# 					-->MAE: 1.742
# 					-->MAPE: 80.056
# 					-->MASE: 1.355
# 				-->Computing Previous week
# 					-->R2: 0.550
# 					-->MAE: 0.866
# 					-->MAPE: 46.333
# 					-->MASE: 0.673
# 			-->Dataset: TOP_20. X_train: (82368L, 20L), y_train: (82368L,)
# 				-->Training model: Random Forest, runtime: 8.06s
# 					-->R2: 0.692
# 					-->MAE: 0.759
# 					-->MAPE: 43.021
# 					-->MASE: 0.590
#
# 		-->Evaluation (2014-06-10 00:00:00)
# 			-->Dataset: Baselines. X_train: (82464L, 16L), y_train: (82464L,)
# 				-->Computing Last value
# 					-->R2: -0.531
# 					-->MAE: 1.856
# 					-->MAPE: 87.237
# 					-->MASE: 1.442
# 				-->Computing Previous day
# 					-->R2: 0.632
# 					-->MAE: 0.866
# 					-->MAPE: 54.852
# 					-->MASE: 0.673
# 				-->Computing Previous week
# 					-->R2: 0.547
# 					-->MAE: 0.907
# 					-->MAPE: 49.228
# 					-->MASE: 0.705
# 			-->Dataset: TOP_20. X_train: (82464L, 20L), y_train: (82464L,)
# 				-->Training model: Random Forest, runtime: 8.37s
# 					-->R2: 0.782
# 					-->MAE: 0.733
# 					-->MAPE: 46.245
# 					-->MASE: 0.570
#
# 		-->Evaluation (2014-06-11 00:00:00)
# 			-->Dataset: Baselines. X_train: (82560L, 16L), y_train: (82560L,)
# 				-->Computing Last value
# 					-->R2: -0.183
# 					-->MAE: 1.969
# 					-->MAPE: 80.313
# 					-->MASE: 1.530
# 				-->Computing Previous day
# 					-->R2: 0.768
# 					-->MAE: 0.814
# 					-->MAPE: 43.226
# 					-->MASE: 0.633
# 				-->Computing Previous week
# 					-->R2: 0.501
# 					-->MAE: 1.124
# 					-->MAPE: 50.319
# 					-->MASE: 0.873
# 			-->Dataset: TOP_20. X_train: (82560L, 20L), y_train: (82560L,)
# 				-->Training model: Random Forest, runtime: 8.11s
# 					-->R2: 0.813
# 					-->MAE: 0.788
# 					-->MAPE: 35.461
# 					-->MASE: 0.612
#
# 		-->Evaluation (2014-06-12 00:00:00)
# 			-->Dataset: Baselines. X_train: (82656L, 16L), y_train: (82656L,)
# 				-->Computing Last value
# 					-->R2: -0.349
# 					-->MAE: 2.309
# 					-->MAPE: 103.242
# 					-->MASE: 1.793
# 				-->Computing Previous day
# 					-->R2: 0.852
# 					-->MAE: 0.660
# 					-->MAPE: 42.046
# 					-->MASE: 0.512
# 				-->Computing Previous week
# 					-->R2: 0.459
# 					-->MAE: 1.289
# 					-->MAPE: 60.998
# 					-->MASE: 1.000
# 			-->Dataset: TOP_20. X_train: (82656L, 20L), y_train: (82656L,)
# 				-->Training model: Random Forest, runtime: 8.53s
# 					-->R2: 0.838
# 					-->MAE: 0.803
# 					-->MAPE: 41.872
# 					-->MASE: 0.623
#
# 		-->Evaluation (2014-06-13 00:00:00)
# 			-->Dataset: Baselines. X_train: (82752L, 16L), y_train: (82752L,)
# 				-->Computing Last value
# 					-->R2: -0.456
# 					-->MAE: 2.062
# 					-->MAPE: 101.359
# 					-->MASE: 1.599
# 				-->Computing Previous day
# 					-->R2: 0.727
# 					-->MAE: 0.845
# 					-->MAPE: 50.896
# 					-->MASE: 0.656
# 				-->Computing Previous week
# 					-->R2: -0.420
# 					-->MAE: 1.876
# 					-->MAPE: 87.745
# 					-->MASE: 1.455
# 			-->Dataset: TOP_20. X_train: (82752L, 20L), y_train: (82752L,)
# 				-->Training model: Random Forest, runtime: 7.95s
# 					-->R2: -0.347
# 					-->MAE: 1.843
# 					-->MAPE: 80.948
# 					-->MASE: 1.430
#
# 		-->Evaluation (2014-06-14 00:00:00)
# 			-->Dataset: Baselines. X_train: (82848L, 16L), y_train: (82848L,)
# 				-->Computing Last value
# 					-->R2: -37.245
# 					-->MAE: 1.938
# 					-->MAPE: 173.214
# 					-->MASE: 1.502
# 				-->Computing Previous day
# 					-->R2: -35.050
# 					-->MAE: 1.784
# 					-->MAPE: 180.357
# 					-->MASE: 1.382
# 				-->Computing Previous week
# 					-->R2: -1.553
# 					-->MAE: 0.546
# 					-->MAPE: 87.500
# 					-->MASE: 0.424
# 			-->Dataset: TOP_20. X_train: (82848L, 20L), y_train: (82848L,)
# 				-->Training model: Random Forest, runtime: 8.27s
# 					-->R2: -0.183
# 					-->MAE: 0.482
# 					-->MAPE: 51.230
# 					-->MASE: 0.373
#
# 		-->Evaluation (2014-06-15 00:00:00)
# 			-->Dataset: Baselines. X_train: (82944L, 16L), y_train: (82944L,)
# 				-->Computing Last value
# 					-->R2: -1.694
# 					-->MAE: 0.495
# 					-->MAPE: 88.000
# 					-->MASE: 0.383
# 				-->Computing Previous day
# 					-->R2: -1.156
# 					-->MAE: 0.392
# 					-->MAPE: 68.000
# 					-->MASE: 0.303
# 				-->Computing Previous week
# 					-->R2: -1.748
# 					-->MAE: 0.526
# 					-->MAPE: 100.000
# 					-->MASE: 0.407
# 			-->Dataset: TOP_20. X_train: (82944L, 20L), y_train: (82944L,)
# 				-->Training model: Random Forest, runtime: 8.21s
# 					-->R2: -0.022
# 					-->MAE: 0.414
# 					-->MAPE: 65.915
# 					-->MASE: 0.320
#
# 		-->Evaluation (2014-06-16 00:00:00)
# 			-->Dataset: Baselines. X_train: (83040L, 16L), y_train: (83040L,)
# 				-->Computing Last value
# 					-->R2: -0.563
# 					-->MAE: 1.351
# 					-->MAPE: 91.993
# 					-->MASE: 1.047
# 				-->Computing Previous day
# 					-->R2: -0.572
# 					-->MAE: 1.330
# 					-->MAPE: 89.314
# 					-->MASE: 1.031
# 				-->Computing Previous week
# 					-->R2: 0.113
# 					-->MAE: 1.041
# 					-->MAPE: 72.974
# 					-->MASE: 0.807
# 			-->Dataset: TOP_20. X_train: (83040L, 20L), y_train: (83040L,)
# 				-->Training model: Random Forest, runtime: 7.96s
# 					-->R2: 0.497
# 					-->MAE: 0.810
# 					-->MAPE: 53.186
# 					-->MASE: 0.628
#
# 		-->Evaluation (2014-06-17 00:00:00)
# 			-->Dataset: Baselines. X_train: (83136L, 16L), y_train: (83136L,)
# 				-->Computing Last value
# 					-->R2: -0.685
# 					-->MAE: 1.351
# 					-->MAPE: 79.340
# 					-->MASE: 1.047
# 				-->Computing Previous day
# 					-->R2: 0.674
# 					-->MAE: 0.505
# 					-->MAPE: 39.214
# 					-->MASE: 0.392
# 				-->Computing Previous week
# 					-->R2: 0.075
# 					-->MAE: 1.031
# 					-->MAPE: 77.673
# 					-->MASE: 0.799
# 			-->Dataset: TOP_20. X_train: (83136L, 20L), y_train: (83136L,)
# 				-->Training model: Random Forest, runtime: 8.79s
# 					-->R2: 0.733
# 					-->MAE: 0.614
# 					-->MAPE: 43.213
# 					-->MASE: 0.476
#
# 		-->Evaluation (2014-06-18 00:00:00)
# 			-->Dataset: Baselines. X_train: (83232L, 16L), y_train: (83232L,)
# 				-->Computing Last value
# 					-->R2: -0.515
# 					-->MAE: 1.330
# 					-->MAPE: 70.957
# 					-->MASE: 1.031
# 				-->Computing Previous day
# 					-->R2: 0.598
# 					-->MAE: 0.670
# 					-->MAPE: 52.994
# 					-->MASE: 0.519
# 				-->Computing Previous week
# 					-->R2: -0.316
# 					-->MAE: 1.216
# 					-->MAPE: 86.543
# 					-->MASE: 0.943
# 			-->Dataset: TOP_20. X_train: (83232L, 20L), y_train: (83232L,)
# 				-->Training model: Random Forest, runtime: 8.58s
# 					-->R2: 0.771
# 					-->MAE: 0.591
# 					-->MAPE: 40.988
# 					-->MASE: 0.458
#
# 		-->Evaluation (2014-06-19 00:00:00)
# 			-->Dataset: Baselines. X_train: (83328L, 16L), y_train: (83328L,)
# 				-->Computing Last value
# 					-->R2: -0.647
# 					-->MAE: 1.351
# 					-->MAPE: 80.655
# 					-->MASE: 1.047
# 				-->Computing Previous day
# 					-->R2: 0.575
# 					-->MAE: 0.711
# 					-->MAPE: 57.054
# 					-->MASE: 0.551
# 				-->Computing Previous week
# 					-->R2: -0.559
# 					-->MAE: 1.000
# 					-->MAPE: 61.875
# 					-->MASE: 0.775
# 			-->Dataset: TOP_20. X_train: (83328L, 20L), y_train: (83328L,)
# 				-->Training model: Random Forest, runtime: 9.11s
# 					-->R2: 0.717
# 					-->MAE: 0.617
# 					-->MAPE: 44.578
# 					-->MASE: 0.478
#
# 		-->Evaluation (2014-06-20 00:00:00)
# 			-->Dataset: Baselines. X_train: (83424L, 16L), y_train: (83424L,)
# 				-->Computing Last value
# 					-->R2: -7.939
# 					-->MAE: 1.433
# 					-->MAPE: 121.429
# 					-->MASE: 1.111
# 				-->Computing Previous day
# 					-->R2: -6.662
# 					-->MAE: 1.237
# 					-->MAPE: 117.143
# 					-->MASE: 0.959
# 				-->Computing Previous week
# 					-->R2: -19.306
# 					-->MAE: 1.928
# 					-->MAPE: 205.714
# 					-->MASE: 1.494
# 			-->Dataset: TOP_20. X_train: (83424L, 20L), y_train: (83424L,)
# 				-->Training model: Random Forest, runtime: 8.45s
# 					-->R2: -0.046
# 					-->MAE: 0.561
# 					-->MAPE: 50.998
# 					-->MASE: 0.435
#
# 		-->Evaluation (2014-06-21 00:00:00)
# 			-->Dataset: Baselines. X_train: (83520L, 16L), y_train: (83520L,)
# 				-->Computing Last value
# 					-->R2: -0.926
# 					-->MAE: 0.443
# 					-->MAPE: 65.000
# 					-->MASE: 0.344
# 				-->Computing Previous day
# 					-->R2: -1.712
# 					-->MAE: 0.546
# 					-->MAPE: 70.000
# 					-->MASE: 0.423
# 				-->Computing Previous week
# 					-->R2: -0.926
# 					-->MAE: 0.485
# 					-->MAPE: 81.667
# 					-->MASE: 0.375
# 			-->Dataset: TOP_20. X_train: (83520L, 20L), y_train: (83520L,)
# 				-->Training model: Random Forest, runtime: 8.39s
# 					-->R2: 0.010
# 					-->MAE: 0.453
# 					-->MAPE: 67.136
# 					-->MASE: 0.351
#
# 		-->Evaluation (2014-06-22 00:00:00)
# 			-->Dataset: Baselines. X_train: (83616L, 16L), y_train: (83616L,)
# 				-->Computing Last value
# 					-->R2: -1.641
# 					-->MAE: 0.464
# 					-->MAPE: 76.000
# 					-->MASE: 0.360
# 				-->Computing Previous day
# 					-->R2: -0.778
# 					-->MAE: 0.299
# 					-->MAPE: 44.000
# 					-->MASE: 0.232
# 				-->Computing Previous week
# 					-->R2: -1.694
# 					-->MAE: 0.515
# 					-->MAPE: 100.000
# 					-->MASE: 0.400
# 			-->Dataset: TOP_20. X_train: (83616L, 20L), y_train: (83616L,)
# 				-->Training model: Random Forest, runtime: 8.28s
# 					-->R2: -0.024
# 					-->MAE: 0.420
# 					-->MAPE: 62.034
# 					-->MASE: 0.325
#
# 		-->Evaluation (2014-06-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (83712L, 16L), y_train: (83712L,)
# 				-->Computing Last value
# 					-->R2: -0.668
# 					-->MAE: 1.619
# 					-->MAPE: 90.316
# 					-->MASE: 1.256
# 				-->Computing Previous day
# 					-->R2: -0.662
# 					-->MAE: 1.577
# 					-->MAPE: 86.724
# 					-->MASE: 1.224
# 				-->Computing Previous week
# 					-->R2: 0.639
# 					-->MAE: 0.784
# 					-->MAPE: 53.420
# 					-->MASE: 0.608
# 			-->Dataset: TOP_20. X_train: (83712L, 20L), y_train: (83712L,)
# 				-->Training model: Random Forest, runtime: 9.23s
# 					-->R2: 0.777
# 					-->MAE: 0.644
# 					-->MAPE: 40.326
# 					-->MASE: 0.500
#
# 		-->Evaluation (2014-06-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (83808L, 16L), y_train: (83808L,)
# 				-->Computing Last value
# 					-->R2: -1.106
# 					-->MAE: 1.711
# 					-->MAPE: 74.946
# 					-->MASE: 1.328
# 				-->Computing Previous day
# 					-->R2: 0.371
# 					-->MAE: 0.918
# 					-->MAPE: 57.634
# 					-->MASE: 0.712
# 				-->Computing Previous week
# 					-->R2: 0.279
# 					-->MAE: 0.866
# 					-->MAPE: 52.742
# 					-->MASE: 0.672
# 			-->Dataset: TOP_20. X_train: (83808L, 20L), y_train: (83808L,)
# 				-->Training model: Random Forest, runtime: 8.31s
# 					-->R2: 0.526
# 					-->MAE: 0.832
# 					-->MAPE: 50.782
# 					-->MASE: 0.646
#
# 		-->Evaluation (2014-06-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (83904L, 16L), y_train: (83904L,)
# 				-->Computing Last value
# 					-->R2: -7.217
# 					-->MAE: 1.619
# 					-->MAPE: 127.000
# 					-->MASE: 1.255
# 				-->Computing Previous day
# 					-->R2: -6.856
# 					-->MAE: 1.454
# 					-->MAPE: 111.000
# 					-->MASE: 1.127
# 				-->Computing Previous week
# 					-->R2: -5.791
# 					-->MAE: 1.402
# 					-->MAPE: 112.000
# 					-->MASE: 1.087
# 			-->Dataset: TOP_20. X_train: (83904L, 20L), y_train: (83904L,)
# 				-->Training model: Random Forest, runtime: 9.09s
# 					-->R2: -0.715
# 					-->MAE: 0.731
# 					-->MAPE: 65.663
# 					-->MASE: 0.567
#
# 		-->Evaluation (2014-06-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (84000L, 16L), y_train: (84000L,)
# 				-->Computing Last value
# 					-->R2: -0.604
# 					-->MAE: 1.371
# 					-->MAPE: 71.448
# 					-->MASE: 1.063
# 				-->Computing Previous day
# 					-->R2: -0.584
# 					-->MAE: 1.330
# 					-->MAPE: 71.038
# 					-->MASE: 1.031
# 				-->Computing Previous week
# 					-->R2: 0.520
# 					-->MAE: 0.639
# 					-->MAPE: 41.694
# 					-->MASE: 0.496
# 			-->Dataset: TOP_20. X_train: (84000L, 20L), y_train: (84000L,)
# 				-->Training model: Random Forest, runtime: 8.56s
# 					-->R2: 0.505
# 					-->MAE: 0.798
# 					-->MAPE: 39.941
# 					-->MASE: 0.619
#
# 		-->Evaluation (2014-06-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (84096L, 16L), y_train: (84096L,)
# 				-->Computing Last value
# 					-->R2: -6.050
# 					-->MAE: 1.371
# 					-->MAPE: 97.727
# 					-->MASE: 1.063
# 				-->Computing Previous day
# 					-->R2: -4.979
# 					-->MAE: 1.340
# 					-->MAPE: 110.227
# 					-->MASE: 1.039
# 				-->Computing Previous week
# 					-->R2: -0.131
# 					-->MAE: 0.515
# 					-->MAPE: 67.045
# 					-->MASE: 0.400
# 			-->Dataset: TOP_20. X_train: (84096L, 20L), y_train: (84096L,)
# 				-->Training model: Random Forest, runtime: 8.89s
# 					-->R2: -0.071
# 					-->MAE: 0.634
# 					-->MAPE: 58.499
# 					-->MASE: 0.492
#
# 		-->Evaluation (2014-06-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (84192L, 16L), y_train: (84192L,)
# 				-->Computing Last value
# 					-->R2: -1.685
# 					-->MAE: 0.505
# 					-->MAPE: 58.621
# 					-->MASE: 0.392
# 				-->Computing Previous day
# 					-->R2: -2.565
# 					-->MAE: 0.608
# 					-->MAPE: 62.069
# 					-->MASE: 0.472
# 				-->Computing Previous week
# 					-->R2: -0.760
# 					-->MAE: 0.412
# 					-->MAPE: 70.690
# 					-->MASE: 0.320
# 			-->Dataset: TOP_20. X_train: (84192L, 20L), y_train: (84192L,)
# 				-->Training model: Random Forest, runtime: 9.13s
# 					-->R2: 0.024
# 					-->MAE: 0.439
# 					-->MAPE: 59.475
# 					-->MASE: 0.340
#
# 		-->Evaluation (2014-06-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (84288L, 16L), y_train: (84288L,)
# 				-->Computing Last value
# 					-->R2: -1.533
# 					-->MAE: 0.464
# 					-->MAPE: 80.000
# 					-->MASE: 0.360
# 				-->Computing Previous day
# 					-->R2: -1.641
# 					-->MAE: 0.485
# 					-->MAPE: 84.000
# 					-->MASE: 0.376
# 				-->Computing Previous week
# 					-->R2: -1.694
# 					-->MAE: 0.515
# 					-->MAPE: 100.000
# 					-->MASE: 0.400
# 			-->Dataset: TOP_20. X_train: (84288L, 20L), y_train: (84288L,)
# 				-->Training model: Random Forest, runtime: 8.67s
# 					-->R2: -0.028
# 					-->MAE: 0.415
# 					-->MAPE: 65.726
# 					-->MASE: 0.322
#
# 		-->Evaluation (2014-06-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (84384L, 16L), y_train: (84384L,)
# 				-->Computing Last value
# 					-->R2: -0.635
# 					-->MAE: 1.454
# 					-->MAPE: 93.056
# 					-->MASE: 1.128
# 				-->Computing Previous day
# 					-->R2: -0.611
# 					-->MAE: 1.433
# 					-->MAPE: 91.451
# 					-->MASE: 1.112
# 				-->Computing Previous week
# 					-->R2: 0.566
# 					-->MAE: 0.742
# 					-->MAPE: 51.019
# 					-->MASE: 0.576
# 			-->Dataset: TOP_20. X_train: (84384L, 20L), y_train: (84384L,)
# ...
# 					-->MASE: 1.297
# 				-->Computing Previous day
# 					-->R2: 0.830
# 					-->MAE: 0.473
# 					-->MAPE: 13.307
# 					-->MASE: 0.368
# 				-->Computing Previous week
# 					-->R2: 0.911
# 					-->MAE: 0.344
# 					-->MAPE: 12.781
# 					-->MASE: 0.268
# 			-->Dataset: TOP_20. X_train: (104160L, 20L), y_train: (104160L,)
# 				-->Training model: Random Forest, runtime: 10.79s
# 					-->R2: 0.932
# 					-->MAE: 0.338
# 					-->MAPE: 12.671
# 					-->MASE: 0.263
#
# 		-->Evaluation (2015-01-23 00:00:00)
# 			-->Dataset: Baselines. X_train: (104256L, 16L), y_train: (104256L,)
# 				-->Computing Last value
# 					-->R2: -11.789
# 					-->MAE: 2.115
# 					-->MAPE: 340.444
# 					-->MASE: 1.645
# 				-->Computing Previous day
# 					-->R2: -9.476
# 					-->MAE: 1.577
# 					-->MAPE: 285.302
# 					-->MASE: 1.226
# 				-->Computing Previous week
# 					-->R2: -0.791
# 					-->MAE: 0.558
# 					-->MAPE: 79.335
# 					-->MASE: 0.434
# 			-->Dataset: TOP_20. X_train: (104256L, 20L), y_train: (104256L,)
# 				-->Training model: Random Forest, runtime: 11.55s
# 					-->R2: -0.213
# 					-->MAE: 0.462
# 					-->MAPE: 88.138
# 					-->MASE: 0.359
#
# 		-->Evaluation (2015-01-24 00:00:00)
# 			-->Dataset: Baselines. X_train: (104352L, 16L), y_train: (104352L,)
# 				-->Computing Last value
# 					-->R2: 0.411
# 					-->MAE: 0.686
# 					-->MAPE: 162.978
# 					-->MASE: 0.533
# 				-->Computing Previous day
# 					-->R2: -0.298
# 					-->MAE: 0.956
# 					-->MAPE: 255.428
# 					-->MASE: 0.743
# 				-->Computing Previous week
# 					-->R2: 0.694
# 					-->MAE: 0.335
# 					-->MAPE: 27.753
# 					-->MASE: 0.260
# 			-->Dataset: TOP_20. X_train: (104352L, 20L), y_train: (104352L,)
# 				-->Training model: Random Forest, runtime: 11.30s
# 					-->R2: 0.603
# 					-->MAE: 0.373
# 					-->MAPE: 40.389
# 					-->MASE: 0.290
#
# 		-->Evaluation (2015-01-25 00:00:00)
# 			-->Dataset: Baselines. X_train: (104448L, 16L), y_train: (104448L,)
# 				-->Computing Last value
# 					-->R2: -48.272
# 					-->MAE: 0.693
# 					-->MAPE: 277.798
# 					-->MASE: 0.539
# 				-->Computing Previous day
# 					-->R2: -49.490
# 					-->MAE: 0.597
# 					-->MAPE: 316.163
# 					-->MASE: 0.464
# 				-->Computing Previous week
# 					-->R2: 0.850
# 					-->MAE: 0.068
# 					-->MAPE: 22.134
# 					-->MASE: 0.053
# 			-->Dataset: TOP_20. X_train: (104448L, 20L), y_train: (104448L,)
# 				-->Training model: Random Forest, runtime: 10.56s
# 					-->R2: 0.696
# 					-->MAE: 0.099
# 					-->MAPE: 41.173
# 					-->MASE: 0.077
#
# 		-->Evaluation (2015-01-26 00:00:00)
# 			-->Dataset: Baselines. X_train: (104544L, 16L), y_train: (104544L,)
# 				-->Computing Last value
# 					-->R2: -1.232
# 					-->MAE: 1.822
# 					-->MAPE: 60.983
# 					-->MASE: 1.417
# 				-->Computing Previous day
# 					-->R2: -1.324
# 					-->MAE: 1.819
# 					-->MAPE: 53.091
# 					-->MASE: 1.414
# 				-->Computing Previous week
# 					-->R2: 0.669
# 					-->MAE: 0.524
# 					-->MAPE: 44.137
# 					-->MASE: 0.407
# 			-->Dataset: TOP_20. X_train: (104544L, 20L), y_train: (104544L,)
# 				-->Training model: Random Forest, runtime: 10.61s
# 					-->R2: 0.751
# 					-->MAE: 0.524
# 					-->MAPE: 40.846
# 					-->MASE: 0.408
#
# 		-->Evaluation (2015-01-27 00:00:00)
# 			-->Dataset: Baselines. X_train: (104640L, 16L), y_train: (104640L,)
# 				-->Computing Last value
# 					-->R2: 0.120
# 					-->MAE: 1.236
# 					-->MAPE: 67.254
# 					-->MASE: 0.961
# 				-->Computing Previous day
# 					-->R2: 0.609
# 					-->MAE: 0.870
# 					-->MAPE: 55.010
# 					-->MASE: 0.676
# 				-->Computing Previous week
# 					-->R2: 0.417
# 					-->MAE: 1.016
# 					-->MAPE: 61.547
# 					-->MASE: 0.790
# 			-->Dataset: TOP_20. X_train: (104640L, 20L), y_train: (104640L,)
# 				-->Training model: Random Forest, runtime: 10.48s
# 					-->R2: 0.666
# 					-->MAE: 0.783
# 					-->MAPE: 50.829
# 					-->MASE: 0.609
#
# 		-->Evaluation (2015-01-28 00:00:00)
# 			-->Dataset: Baselines. X_train: (104736L, 16L), y_train: (104736L,)
# 				-->Computing Last value
# 					-->R2: -1.111
# 					-->MAE: 1.677
# 					-->MAPE: 159.382
# 					-->MASE: 1.304
# 				-->Computing Previous day
# 					-->R2: 0.626
# 					-->MAE: 0.755
# 					-->MAPE: 67.457
# 					-->MASE: 0.587
# 				-->Computing Previous week
# 					-->R2: 0.748
# 					-->MAE: 0.481
# 					-->MAPE: 20.141
# 					-->MASE: 0.374
# 			-->Dataset: TOP_20. X_train: (104736L, 20L), y_train: (104736L,)
# 				-->Training model: Random Forest, runtime: 10.56s
# 					-->R2: 0.876
# 					-->MAE: 0.351
# 					-->MAPE: 25.192
# 					-->MASE: 0.273
#
# 		-->Evaluation (2015-01-29 00:00:00)
# 			-->Dataset: Baselines. X_train: (104832L, 16L), y_train: (104832L,)
# 				-->Computing Last value
# 					-->R2: -0.472
# 					-->MAE: 1.966
# 					-->MAPE: 96.856
# 					-->MASE: 1.528
# 				-->Computing Previous day
# 					-->R2: 0.544
# 					-->MAE: 0.953
# 					-->MAPE: 24.321
# 					-->MASE: 0.740
# 				-->Computing Previous week
# 					-->R2: 0.746
# 					-->MAE: 0.649
# 					-->MAPE: 19.562
# 					-->MASE: 0.505
# 			-->Dataset: TOP_20. X_train: (104832L, 20L), y_train: (104832L,)
# 				-->Training model: Random Forest, runtime: 10.40s
# 					-->R2: 0.787
# 					-->MAE: 0.637
# 					-->MAPE: 22.501
# 					-->MASE: 0.495
#
# 		-->Evaluation (2015-01-30 00:00:00)
# 			-->Dataset: Baselines. X_train: (104928L, 16L), y_train: (104928L,)
# 				-->Computing Last value
# 					-->R2: -2.532
# 					-->MAE: 2.613
# 					-->MAPE: 300.093
# 					-->MASE: 2.030
# 				-->Computing Previous day
# 					-->R2: -0.618
# 					-->MAE: 1.569
# 					-->MAPE: 186.249
# 					-->MASE: 1.219
# 				-->Computing Previous week
# 					-->R2: 0.398
# 					-->MAE: 0.767
# 					-->MAPE: 43.927
# 					-->MASE: 0.596
# 			-->Dataset: TOP_20. X_train: (104928L, 20L), y_train: (104928L,)
# 				-->Training model: Random Forest, runtime: 10.49s
# 					-->R2: 0.265
# 					-->MAE: 0.825
# 					-->MAPE: 52.953
# 					-->MASE: 0.641
#
# 		-->Evaluation (2015-01-31 00:00:00)
# 			-->Dataset: Baselines. X_train: (105024L, 16L), y_train: (105024L,)
# 				-->Computing Last value
# 					-->R2: -0.443
# 					-->MAE: 0.909
# 					-->MAPE: 390.828
# 					-->MASE: 0.706
# 				-->Computing Previous day
# 					-->R2: -2.446
# 					-->MAE: 1.399
# 					-->MAPE: 591.063
# 					-->MASE: 1.086
# 				-->Computing Previous week
# 					-->R2: 0.666
# 					-->MAE: 0.254
# 					-->MAPE: 45.898
# 					-->MASE: 0.197
# 			-->Dataset: TOP_20. X_train: (105024L, 20L), y_train: (105024L,)
# 				-->Training model: Random Forest, runtime: 10.72s
# 					-->R2: 0.479
# 					-->MAE: 0.432
# 					-->MAPE: 95.487
# 					-->MASE: 0.336
#
# 		-->Evaluation (2015-02-01 00:00:00)
# 			-->Dataset: Baselines. X_train: (105120L, 16L), y_train: (105120L,)
# 				-->Computing Last value
# 					-->R2: -35.231
# 					-->MAE: 0.574
# 					-->MAPE: 225.395
# 					-->MASE: 0.446
# 				-->Computing Previous day
# 					-->R2: -34.807
# 					-->MAE: 0.451
# 					-->MAPE: 235.223
# 					-->MASE: 0.350
# 				-->Computing Previous week
# 					-->R2: 0.822
# 					-->MAE: 0.074
# 					-->MAPE: 21.635
# 					-->MASE: 0.058
# 			-->Dataset: TOP_20. X_train: (105120L, 20L), y_train: (105120L,)
# 				-->Training model: Random Forest, runtime: 11.72s
# 					-->R2: 0.800
# 					-->MAE: 0.083
# 					-->MAPE: 31.479
# 					-->MASE: 0.064
#
# 		-->Evaluation (2015-02-02 00:00:00)
# 			-->Dataset: Baselines. X_train: (105216L, 16L), y_train: (105216L,)
# 				-->Computing Last value
# 					-->R2: -1.900
# 					-->MAE: 0.094
# 					-->MAPE: 13.616
# 					-->MASE: 0.073
# 				-->Computing Previous day
# 					-->R2: -1.400
# 					-->MAE: 0.088
# 					-->MAPE: 12.165
# 					-->MASE: 0.068
# 				-->Computing Previous week
# 					-->R2: -0.600
# 					-->MAE: 0.075
# 					-->MAPE: 10.776
# 					-->MASE: 0.058
# 			-->Dataset: TOP_20. X_train: (105216L, 20L), y_train: (105216L,)
# 				-->Training model: Random Forest, runtime: 10.58s
# 					-->R2: 0.061
# 					-->MAE: 0.053
# 					-->MAPE: 7.418
# 					-->MASE: 0.041
#                               true  last value  previous day  previous week  \
# horizons values
# 20       2014-04-17 00:00:00   0.0         1.0           1.0            0.0
#          2014-04-17 00:15:00   0.0         0.0           0.0            1.0
#          2014-04-17 00:30:00   0.0         0.0           0.0            0.0
#          2014-04-17 00:45:00   1.0         0.0           0.0            0.0
#          2014-04-17 01:00:00   0.0         0.0           1.0            1.0
#          2014-04-17 01:15:00   0.0         1.0           0.0            0.0
#          2014-04-17 01:30:00   0.0         0.0           0.0            0.0
#          2014-04-17 01:45:00   1.0         0.0           0.0            0.0
#          2014-04-17 02:00:00   0.0         1.0           0.0            1.0
#          2014-04-17 02:15:00   0.0         0.0           1.0            0.0
#          2014-04-17 02:30:00   0.0         0.0           0.0            0.0
#          2014-04-17 02:45:00   1.0         0.0           0.0            0.0
#          2014-04-17 03:00:00   0.0         0.0           1.0            1.0
#          2014-04-17 03:15:00   0.0         1.0           0.0            0.0
#          2014-04-17 03:30:00   1.0         0.0           0.0            0.0
#          2014-04-17 03:45:00   0.0         0.0           0.0            1.0
#          2014-04-17 04:00:00   0.0         0.0           1.0            0.0
#          2014-04-17 04:15:00   0.0         1.0           0.0            0.0
#          2014-04-17 04:30:00   1.0         0.0           0.0            0.0
#          2014-04-17 04:45:00   0.0         0.0           0.0            1.0
#          2014-04-17 05:00:00   0.0         0.0           0.0            0.0
#          2014-04-17 05:15:00   0.0         1.0           1.0            0.0
#          2014-04-17 05:30:00   1.0         0.0           0.0            0.0
#          2014-04-17 05:45:00   0.0         2.0           0.0            1.0
#          2014-04-17 06:00:00   0.0         4.0           1.0            0.0
#          2014-04-17 06:15:00   1.0         4.0           0.0            0.0
#          2014-04-17 06:30:00   0.0         3.0           0.0            0.0
#          2014-04-17 06:45:00   0.0         4.0           0.0            1.0
#          2014-04-17 07:00:00   0.0         2.0           0.0            0.0
#          2014-04-17 07:15:00   1.0         4.0           1.0            0.0
# ...                            ...         ...           ...            ...
#          2015-01-31 20:30:00   0.2         0.6           0.1            0.2
#          2015-01-31 20:45:00   0.2         0.6           0.2            0.3
#          2015-01-31 21:00:00   0.2         0.7           0.1            0.2
#          2015-01-31 21:15:00   0.3         0.7           0.2            0.1
#          2015-01-31 21:30:00   0.4         0.8           0.3            0.4
#          2015-01-31 21:45:00   0.6         0.6           0.7            0.7
#          2015-01-31 22:00:00   0.6         0.6           0.6            0.8
#          2015-01-31 22:15:00   0.7         0.7           0.6            0.6
#          2015-01-31 22:30:00   0.7         0.7           0.7            0.7
#          2015-01-31 22:45:00   0.9         0.7           0.8            0.7
#          2015-01-31 23:00:00   0.6         0.8           0.6            0.7
#          2015-01-31 23:15:00   0.7         0.7           0.6            0.6
#          2015-01-31 23:30:00   0.6         0.7           0.7            0.8
#          2015-01-31 23:45:00   0.7         0.6           0.6            0.7
#          2015-02-01 00:00:00   0.7         0.7           0.7            0.7
#          2015-02-01 00:15:00   0.6         0.8           0.8            0.6
#          2015-02-01 00:30:00   0.9         0.6           0.6            0.8
#          2015-02-01 00:45:00   0.7         0.7           0.6            0.6
#          2015-02-01 01:00:00   0.6         0.7           0.7            0.7
#          2015-02-01 01:15:00   0.7         0.6           0.7            0.6
#          2015-02-01 01:30:00   0.7         0.7           0.8            0.7
#          2015-02-01 01:45:00   0.6         0.9           0.6            0.8
#          2015-02-01 02:00:00   0.8         0.7           0.6            0.7
#          2015-02-01 02:15:00   0.7         0.7           0.7            0.7
#          2015-02-01 02:30:00   0.6         0.7           0.7            0.7
#          2015-02-01 02:45:00   0.7         0.6           0.7            0.8
#          2015-02-01 03:00:00   0.7         0.7           0.8            0.6
#          2015-02-01 03:15:00   0.7         0.8           0.7            0.7
#          2015-02-01 03:30:00   0.8         0.7           0.7            0.6
#          2015-02-01 03:45:00   0.7         0.7           0.6            0.7
#
#                                offline     batch
# horizons values
# 20       2014-04-17 00:00:00  0.280215  0.357897
#          2014-04-17 00:15:00  0.201563  0.180256
#          2014-04-17 00:30:00  0.404310  0.312246
#          2014-04-17 00:45:00  0.350508  0.307373
#          2014-04-17 01:00:00  0.197699  0.254435
#          2014-04-17 01:15:00  0.321310  0.308740
#          2014-04-17 01:30:00  0.356196  0.291254
#          2014-04-17 01:45:00  0.285574  0.269530
#          2014-04-17 02:00:00  0.159335  0.144108
#          2014-04-17 02:15:00  0.253990  0.285330
#          2014-04-17 02:30:00  0.351742  0.268566
#          2014-04-17 02:45:00  0.342077  0.254325
#          2014-04-17 03:00:00  0.271073  0.227186
#          2014-04-17 03:15:00  0.371491  0.304599
#          2014-04-17 03:30:00  0.353859  0.289870
#          2014-04-17 03:45:00  0.344252  0.205162
#          2014-04-17 04:00:00  0.277180  0.316347
#          2014-04-17 04:15:00  0.239722  0.329048
#          2014-04-17 04:30:00  0.294803  0.320636
#          2014-04-17 04:45:00  0.263893  0.222654
#          2014-04-17 05:00:00  0.289153  0.338046
#          2014-04-17 05:15:00  0.258992  0.376282
#          2014-04-17 05:30:00  0.258206  0.373622
#          2014-04-17 05:45:00  0.281765  0.188309
#          2014-04-17 06:00:00  0.280823  0.316515
#          2014-04-17 06:15:00  0.304068  0.255847
#          2014-04-17 06:30:00  0.310158  0.264881
#          2014-04-17 06:45:00  0.299605  0.308858
#          2014-04-17 07:00:00  0.396525  0.315505
#          2014-04-17 07:15:00  0.215133  0.344605
# ...                                ...       ...
#          2015-01-31 20:30:00  0.414942  0.285642
#          2015-01-31 20:45:00  0.421994  0.299950
#          2015-01-31 21:00:00  0.415211  0.283901
#          2015-01-31 21:15:00  0.444918  0.300383
#          2015-01-31 21:30:00  0.503053  0.495879
#          2015-01-31 21:45:00  0.485403  0.643100
#          2015-01-31 22:00:00  0.494346  0.762871
#          2015-01-31 22:15:00  0.549143  0.755287
#          2015-01-31 22:30:00  0.520117  0.804496
#          2015-01-31 22:45:00  0.679034  0.726952
#          2015-01-31 23:00:00  0.688352  0.711071
#          2015-01-31 23:15:00  0.715448  0.732582
#          2015-01-31 23:30:00  0.738167  0.738876
#          2015-01-31 23:45:00  0.724446  0.715928
#          2015-02-01 00:00:00  0.737425  0.683694
#          2015-02-01 00:15:00  0.730818  0.679707
#          2015-02-01 00:30:00  0.741589  0.704215
#          2015-02-01 00:45:00  0.733725  0.696235
#          2015-02-01 01:00:00  0.755112  0.686427
#          2015-02-01 01:15:00  0.705003  0.689346
#          2015-02-01 01:30:00  0.710562  0.694651
#          2015-02-01 01:45:00  0.688100  0.700684
#          2015-02-01 02:00:00  0.694696  0.691812
#          2015-02-01 02:15:00  0.695053  0.698565
#          2015-02-01 02:30:00  0.705312  0.688886
#          2015-02-01 02:45:00  0.702865  0.704483
#          2015-02-01 03:00:00  0.639371  0.692192
#          2015-02-01 03:15:00  0.625313  0.682858
#          2015-02-01 03:30:00  0.627194  0.694418
#          2015-02-01 03:45:00  0.627194  0.690414
#
# [27856 rows x 6 columns]
# Finished.
# C:\Python27\lib\site-packages\ipykernel\__main__.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# read from csv
input_file_path = os.path.join(os.path.join(os.getcwd(), "data"), output_file_name)
test =  pd.read_csv(input_file_path, index_col=[0,1])

test
# Out:
#                               true  last value  previous day  previous week  \
# horizons values
# 20       2014-04-17 00:00:00   0.0         1.0           1.0            0.0
#          2014-04-17 00:15:00   0.0         0.0           0.0            1.0
#          2014-04-17 00:30:00   0.0         0.0           0.0            0.0
#          2014-04-17 00:45:00   1.0         0.0           0.0            0.0
#          2014-04-17 01:00:00   0.0         0.0           1.0            1.0
#          2014-04-17 01:15:00   0.0         1.0           0.0            0.0
#          2014-04-17 01:30:00   0.0         0.0           0.0            0.0
#          2014-04-17 01:45:00   1.0         0.0           0.0            0.0
#          2014-04-17 02:00:00   0.0         1.0           0.0            1.0
#          2014-04-17 02:15:00   0.0         0.0           1.0            0.0
#          2014-04-17 02:30:00   0.0         0.0           0.0            0.0
#          2014-04-17 02:45:00   1.0         0.0           0.0            0.0
#          2014-04-17 03:00:00   0.0         0.0           1.0            1.0
#          2014-04-17 03:15:00   0.0         1.0           0.0            0.0
#          2014-04-17 03:30:00   1.0         0.0           0.0            0.0
#          2014-04-17 03:45:00   0.0         0.0           0.0            1.0
#          2014-04-17 04:00:00   0.0         0.0           1.0            0.0
#          2014-04-17 04:15:00   0.0         1.0           0.0            0.0
#          2014-04-17 04:30:00   1.0         0.0           0.0            0.0
#          2014-04-17 04:45:00   0.0         0.0           0.0            1.0
#          2014-04-17 05:00:00   0.0         0.0           0.0            0.0
#          2014-04-17 05:15:00   0.0         1.0           1.0            0.0
#          2014-04-17 05:30:00   1.0         0.0           0.0            0.0
#          2014-04-17 05:45:00   0.0         2.0           0.0            1.0
#          2014-04-17 06:00:00   0.0         4.0           1.0            0.0
#          2014-04-17 06:15:00   1.0         4.0           0.0            0.0
#          2014-04-17 06:30:00   0.0         3.0           0.0            0.0
#          2014-04-17 06:45:00   0.0         4.0           0.0            1.0
#          2014-04-17 07:00:00   0.0         2.0           0.0            0.0
#          2014-04-17 07:15:00   1.0         4.0           1.0            0.0
# ...                            ...         ...           ...            ...
#          2015-01-31 20:30:00   0.2         0.6           0.1            0.2
#          2015-01-31 20:45:00   0.2         0.6           0.2            0.3
#          2015-01-31 21:00:00   0.2         0.7           0.1            0.2
#          2015-01-31 21:15:00   0.3         0.7           0.2            0.1
#          2015-01-31 21:30:00   0.4         0.8           0.3            0.4
#          2015-01-31 21:45:00   0.6         0.6           0.7            0.7
#          2015-01-31 22:00:00   0.6         0.6           0.6            0.8
#          2015-01-31 22:15:00   0.7         0.7           0.6            0.6
#          2015-01-31 22:30:00   0.7         0.7           0.7            0.7
#          2015-01-31 22:45:00   0.9         0.7           0.8            0.7
#          2015-01-31 23:00:00   0.6         0.8           0.6            0.7
#          2015-01-31 23:15:00   0.7         0.7           0.6            0.6
#          2015-01-31 23:30:00   0.6         0.7           0.7            0.8
#          2015-01-31 23:45:00   0.7         0.6           0.6            0.7
#          2015-02-01 00:00:00   0.7         0.7           0.7            0.7
#          2015-02-01 00:15:00   0.6         0.8           0.8            0.6
#          2015-02-01 00:30:00   0.9         0.6           0.6            0.8
#          2015-02-01 00:45:00   0.7         0.7           0.6            0.6
#          2015-02-01 01:00:00   0.6         0.7           0.7            0.7
#          2015-02-01 01:15:00   0.7         0.6           0.7            0.6
#          2015-02-01 01:30:00   0.7         0.7           0.8            0.7
#          2015-02-01 01:45:00   0.6         0.9           0.6            0.8
#          2015-02-01 02:00:00   0.8         0.7           0.6            0.7
#          2015-02-01 02:15:00   0.7         0.7           0.7            0.7
#          2015-02-01 02:30:00   0.6         0.7           0.7            0.7
#          2015-02-01 02:45:00   0.7         0.6           0.7            0.8
#          2015-02-01 03:00:00   0.7         0.7           0.8            0.6
#          2015-02-01 03:15:00   0.7         0.8           0.7            0.7
#          2015-02-01 03:30:00   0.8         0.7           0.7            0.6
#          2015-02-01 03:45:00   0.7         0.7           0.6            0.7
#
#                                offline     batch
# horizons values
# 20       2014-04-17 00:00:00  0.261299  0.426695
#          2014-04-17 00:15:00  0.171855  0.199961
#          2014-04-17 00:30:00  0.357864  0.337836
#          2014-04-17 00:45:00  0.341056  0.309874
#          2014-04-17 01:00:00  0.214796  0.251093
#          2014-04-17 01:15:00  0.299780  0.337469
#          2014-04-17 01:30:00  0.356398  0.304319
#          2014-04-17 01:45:00  0.305233  0.289283
#          2014-04-17 02:00:00  0.173487  0.182545
#          2014-04-17 02:15:00  0.263771  0.405222
#          2014-04-17 02:30:00  0.322937  0.314287
#          2014-04-17 02:45:00  0.307693  0.320839
#          2014-04-17 03:00:00  0.204197  0.239636
#          2014-04-17 03:15:00  0.313680  0.338691
#          2014-04-17 03:30:00  0.409911  0.352838
#          2014-04-17 03:45:00  0.395950  0.182027
#          2014-04-17 04:00:00  0.278781  0.361459
#          2014-04-17 04:15:00  0.232276  0.343491
#          2014-04-17 04:30:00  0.215190  0.325883
#          2014-04-17 04:45:00  0.257617  0.218918
#          2014-04-17 05:00:00  0.287206  0.344268
#          2014-04-17 05:15:00  0.309328  0.458021
#          2014-04-17 05:30:00  0.269004  0.396748
#          2014-04-17 05:45:00  0.271081  0.181132
#          2014-04-17 06:00:00  0.298976  0.283710
#          2014-04-17 06:15:00  0.304839  0.307063
#          2014-04-17 06:30:00  0.291901  0.286413
#          2014-04-17 06:45:00  0.275291  0.247733
#          2014-04-17 07:00:00  0.378465  0.361172
#          2014-04-17 07:15:00  0.255152  0.369180
# ...                                ...       ...
#          2015-01-31 20:30:00  0.440341  0.278283
#          2015-01-31 20:45:00  0.501625  0.261489
#          2015-01-31 21:00:00  0.491656  0.239120
#          2015-01-31 21:15:00  0.498405  0.264454
#          2015-01-31 21:30:00  0.614397  0.415354
#          2015-01-31 21:45:00  0.511284  0.636935
#          2015-01-31 22:00:00  0.507907  0.796163
#          2015-01-31 22:15:00  0.500895  0.781900
#          2015-01-31 22:30:00  0.530755  0.958974
#          2015-01-31 22:45:00  0.729484  0.744920
#          2015-01-31 23:00:00  0.699075  0.734326
#          2015-01-31 23:15:00  0.740982  0.735246
#          2015-01-31 23:30:00  0.779830  0.731716
#          2015-01-31 23:45:00  0.727319  0.738611
#          2015-02-01 00:00:00  0.724544  0.685366
#          2015-02-01 00:15:00  0.735238  0.674612
#          2015-02-01 00:30:00  0.749984  0.699658
#          2015-02-01 00:45:00  0.748121  0.692393
#          2015-02-01 01:00:00  0.754601  0.684444
#          2015-02-01 01:15:00  0.747488  0.681218
#          2015-02-01 01:30:00  0.741493  0.693480
#          2015-02-01 01:45:00  0.737610  0.696552
#          2015-02-01 02:00:00  0.727951  0.683484
#          2015-02-01 02:15:00  0.724144  0.694432
#          2015-02-01 02:30:00  0.731040  0.688251
#          2015-02-01 02:45:00  0.724503  0.698981
#          2015-02-01 03:00:00  0.659234  0.691054
#          2015-02-01 03:15:00  0.641959  0.683764
#          2015-02-01 03:30:00  0.644261  0.691510
#          2015-02-01 03:45:00  0.644261  0.683903
#
# [27856 rows x 6 columns]

# %%
test.loc[20]['2014-04-17 00:00:00':'2014-04-20 00:00:00'][['true','offline','batch']].plot(figsize=(15,4))
test.loc[20]['2015-01-27 00:00:00':'2015-02-01 23:59:00'][['true','offline','batch']].plot(figsize=(15,4))

# %%
a=test.loc[20].groupby(test.index.to_datetime().dayofyear, sort=False).mean()
a
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3e6c165fb994> in <module>()
# ----> 1 a=test.loc[20].groupby(test.index.to_datetime().dayofyear, sort=False).mean()
#       2 a
#
# C:\Python27\lib\site-packages\pandas\core\indexes\base.pyc in to_datetime(self, dayfirst)
#    1024             return DatetimeIndex(parsed)
#    1025         else:
# -> 1026             return DatetimeIndex(self.values)
#    1027
#    1028     def _assert_can_do_setop(self, other):
#
# C:\Python27\lib\site-packages\pandas\util\_decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# C:\Python27\lib\site-packages\pandas\core\indexes\datetimes.pyc in __new__(cls, data, freq, start, end, periods, copy, name, tz, verify_integrity, normalize, closed, ambiguous, dtype, **kwargs)
#     333                 is_integer_dtype(data)):
#     334             data = tools.to_datetime(data, dayfirst=dayfirst,
# --> 335                                      yearfirst=yearfirst)
#     336
#     337         if issubclass(data.dtype.type, np.datetime64) or is_datetimetz(data):
#
# C:\Python27\lib\site-packages\pandas\core\tools\datetimes.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     514         result = _convert_listlike(arg, box, format, name=arg.name)
#     515     elif is_list_like(arg):
# --> 516         result = _convert_listlike(arg, box, format)
#     517     else:
#     518         result = _convert_listlike(np.array([arg]), box, format)[0]
#
# C:\Python27\lib\site-packages\pandas\core\tools\datetimes.pyc in _convert_listlike(arg, box, format, name, tz)
#     433                     dayfirst=dayfirst,
#     434                     yearfirst=yearfirst,
# --> 435                     require_iso8601=require_iso8601
#     436                 )
#     437
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime (pandas\_libs\tslib.c:46617)()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime (pandas\_libs\tslib.c:46321)()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime (pandas\_libs\tslib.c:45268)()
#
# TypeError: <type 'tuple'> is not convertible to datetime

# %%
from sklearn.metrics import r2_score

def r2( g ):
    r2_lv = r2_score( g['true'], g['last value'] )
    r2_pd = r2_score( g['true'], g['previous day'] )
    r2_pw = r2_score( g['true'], g['previous week'] )
    r2_offline = r2_score( g['true'], g['offline'] )
    r2_batch = r2_score( g['true'], g['batch'] )
    return pd.Series( dict(  r2_lv=r2_lv, r2_pd=r2_pd, r2_pw=r2_pw, r2_offline=r2_offline, r2_batch=r2_batch ) )

#subset = test['2014-04-17 00:00:00':'2014-04-27 00:00:00']
subset = test.loc[20]['2015-01-05 00:00:00':'2015-02-01 23:59:00']
#subset = test['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)
a
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:14: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#     r2_batch      r2_lv  r2_offline      r2_pd     r2_pw
# 5   0.650629  -0.466792    0.631788   0.410490 -0.029031
# 6   0.687785  -0.337743    0.684113   0.809421 -0.893095
# 7   0.701322  -0.736158    0.687807   0.706376 -1.157494
# 8   0.624968  -1.965073    0.515317  -0.118795  0.481865
# 9   0.678785  -0.601358    0.578641  -1.546461  0.868344
# 10  0.468132 -29.816674    0.582218 -32.056645  0.693515
# 11  0.521862  -1.057234    0.746526  -1.146427  0.833297
# 12  0.758160  -0.359141    0.692031   0.864793  0.399927
# 13  0.909564  -0.096185    0.953991   0.629611  0.690272
# 14  0.873872  -0.491005    0.875105   0.927543  0.734044
# 15  0.354559  -3.530549    0.662975  -1.254719  0.624117
# 16  0.671737  -2.123816    0.766234  -3.433615  0.364245
# 17  0.700352 -13.395065    0.606281 -13.789877  0.774888
# 18  0.837492  -1.152574    0.827718  -1.275944  0.689295
# 19  0.880729  -0.284406    0.849612   0.851784  0.674527
# 20  0.871255  -0.281267    0.856674   0.862423  0.834486
# 21  0.933512  -0.175062    0.907404   0.829141  0.910675
# 22 -0.317719 -11.829821    0.561348  -9.509816 -0.794865
# 23  0.594524   0.410395    0.269791  -0.298593  0.694110
# 24  0.660273 -48.667396    0.665574 -49.895473  0.848800
# 25  0.736809  -1.235391    0.774954  -1.326738  0.670142
# 26  0.672874   0.111891    0.659381   0.606048  0.410655
# 27  0.875290  -1.125175    0.827008   0.623866  0.746783
# 28  0.775426  -0.486030    0.744487   0.540018  0.743473
# 29  0.269248  -2.541302    0.444240  -0.622494  0.396854
# 30  0.423520  -0.442879    0.243073  -2.446676  0.665970
# 31  0.744658 -35.502552    0.690066 -35.075245  0.820260
# 32  0.034068  -1.900000   -0.464647  -1.400000 -0.600000

# %% [markdown]
# Bar plot for last month. Major improvement for batch is not visible.

# %%
a[['r2_offline','r2_batch']].plot( kind='bar', figsize=(15,4), ylim=(-3, 1.1))

# %% [markdown]
# Diff is not very informative

# %%
#subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
#a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]
b['diff'] = b['r2_batch'] - b['r2_offline']
b.reset_index()['diff'].plot()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Scatter plot for entire testing dataset.

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]
#a[['r2_offline','r2_batch']].plot( kind='hist', figsize=(15,4))
#a[['r2_offline','r2_batch']].hist(figsize=(15,4), bins=20)
#a[['r2_offline','r2_batch']].plot.hist(bins=30)
b[b > 0].plot.hist(bins=30, alpha=0.8)
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

b = a[['r2_offline','r2_batch']]

c = b[b > 0].reset_index()[['r2_offline','r2_batch']]

c = c.fillna(0)

x = c["r2_offline"].values
y = c["r2_batch"].values
data = np.vstack([x, y]).T
bins = np.linspace(0, 1, 30)

plt.hist(data, bins, alpha=0.7, label=['Offline', 'Batch'])
plt.legend(loc='upper right')
plt.show()

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]

#a[['r2_offline','r2_batch']].plot( figsize=(15,4), marker='*')
b[b > 0].reset_index()[['r2_offline','r2_batch']].plot( figsize=(15,4), marker='.', linestyle='')
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %% [markdown]
# Scatter plot for entire testing dataset with regression plot trend, showing that Batch is better. Unfortunatelly the trend is downword. Maybe try with different sensor.

# %%
import seaborn as sns

sns.set_style("white")

subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(r2)

b = a[['r2_offline','r2_batch']]

#c = b.reset_index()[['r2_offline','r2_batch']]
c = b[b > 0].reset_index()[['r2_offline','r2_batch']]
c = c.fillna(0)
c['index'] = c.index

plt.figure(figsize=(13,4))
#sns.pairplot(c, size=5, aspect=.8, kind="reg");
g = sns.regplot(y="r2_offline", x="index", data=c, label='Offline');
g.set(xlim=(0,300), ylim=(0,1))
sns.regplot(y="r2_batch", x="index", data=c, label='Batch');

plt.legend(loc='upper right')
plt.show()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)

# %%
import scipy

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[0].get_xdata(),y=g.get_lines()[0].get_ydata())
print "Offline slope:", slope

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[1].get_xdata(),y=g.get_lines()[1].get_ydata())
print "Batch slope:", slope
# Out:
# Offline slope: -0.000525964532375
# Batch slope: -0.00329930970361

# %% [markdown]
# ## MAPE analysis

# %%
import regression_metrics as additional_metrics

def mape(g):
    mape_lv = additional_metrics.mean_absolute_percentage_error( g['true'], g['last value'] )
    mape_pd = additional_metrics.mean_absolute_percentage_error( g['true'], g['previous day'] )
    mape_pw = additional_metrics.mean_absolute_percentage_error( g['true'], g['previous week'] )
    mape_offline = additional_metrics.mean_absolute_percentage_error( g['true'], g['offline'] )
    mape_batch = additional_metrics.mean_absolute_percentage_error( g['true'], g['batch'] )
    return pd.Series( dict(  mape_lv=mape_lv, mape_pd=mape_pd, mape_pw=mape_pw, mape_offline=mape_offline, mape_batch=mape_batch ) )

# %%
subset = test.loc[20]['2014-04-17 00:00:00':'2015-02-01 23:59:00']
a=subset.groupby(subset.index.to_datetime().dayofyear, sort=False).apply(mape)
a

b = a[['mape_offline','mape_batch']]

c = b[b > 0].reset_index()[['mape_offline','mape_batch']]
c = c.fillna(0)
#c = b.reset_index()[['mape_offline','mape_batch']]
c['index'] = c.index

plt.figure(figsize=(13,4))
#sns.pairplot(c, size=5, aspect=.8, kind="reg");
g = sns.regplot(y="mape_offline", x="index", data=c, label='Offline');
g.set(xlim=(0,300), ylim=(0,70))
sns.regplot(y="mape_batch", x="index", data=c, label='Batch');

plt.legend(loc='upper right')
plt.show()
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)
#   from ipykernel import kernelapp as app

# %%
import scipy

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[0].get_xdata(),y=g.get_lines()[0].get_ydata())
print "Offline slope:", slope

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x=g.get_lines()[1].get_xdata(),y=g.get_lines()[1].get_ydata())
print "Batch slope:", slope
# Out:
# Offline slope: -0.0301269784077
# Batch slope: -0.0108998422488

# %% [markdown]
# ## Future work

# %% [markdown]
# - more horizons
# - more sensors
# - online approach
